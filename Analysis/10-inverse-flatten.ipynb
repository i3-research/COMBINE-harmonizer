# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

from tqdm import tqdm
import os

import COMBINE_harmonizer
from COMBINE_harmonizer import cfg

# %% [markdown]
# ## 01. Init

# %%
root_dir = '../'

# %%
COMBINE_harmonizer.init(f'{root_dir}/config.yaml')

# %%
input_dir = f"{cfg.config['out_dir']}/out-publish-normalized"
out_dir = f"{cfg.config['out_dir']}/stats"

os.makedirs(out_dir, exist_ok=True)

data_dict_filename = f"{root_dir}/{COMBINE_harmonizer.DATA_DICTIONARY_EXCEL}"

# %%
COMBINE_harmonizer.init_inv_mapping(data_dict_filename)

_INV_VALUE_MAP_MAIN = COMBINE_harmonizer.build_inv_value_map(data_dict_filename, COMBINE_harmonizer.SHEET_MAIN)
_INV_VALUE_MAP_FOLLOWUP = COMBINE_harmonizer.build_inv_value_map(data_dict_filename, COMBINE_harmonizer.SHEET_FOLLOW_UP)
_INV_VALUE_MAP_ANALYSIS = COMBINE_harmonizer.build_inv_value_map(data_dict_filename, COMBINE_harmonizer.SHEET_DERIVED_DATA)
# Out:
# build_inv_value_map: (0/979) variable: center type: center
# [INFO] _build_inv_value_map: to inv-text: type: center
# build_inv_value_map: (1/979) variable: subjectID type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (2/979) variable: siteID type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (3/979) variable: birthDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (4/979) variable: birthNumber type: int
# build_inv_value_map: (5/979) variable: screenComment type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (6/979) variable: coreTempLess32p5COverEq2Hr_e type: bool
# build_inv_value_map: (7/979) variable: coreTempLess33p5COver1Hr_e type: bool
# build_inv_value_map: (8/979) variable: coreTempLess34COver1Hr_e type: bool
# build_inv_value_map: (9/979) variable: first6HrCoolByClinicalProtocol_e type: bool
# build_inv_value_map: (10/979) variable: chromosomalAbnormality_e type: bool
# build_inv_value_map: (11/979) variable: majorCongenitalAnomaly_e type: bool
# build_inv_value_map: (12/979) variable: birthWeightLessEq1800g_e type: bool
# build_inv_value_map: (13/979) variable: infantUnlikelySurvive_e type: bool
# build_inv_value_map: (14/979) variable: first60MinAllBloodGasPHGreater7p15BaseDeficitLess10mEqPerL_e type: bool
# build_inv_value_map: (15/979) variable: postnatalAgeLess6HrOrGreater24Hr_e type: bool
# build_inv_value_map: (16/979) variable: enrolledConflictingTrial_e type: bool
# build_inv_value_map: (17/979) variable: first60MinAnyBloodGasPHLessEq7_i type: bool
# build_inv_value_map: (18/979) variable: first60MinAnyBloodGasBaseDeficitGreaterEq16mEqPerL_i type: bool
# build_inv_value_map: (19/979) variable: historyPerinatalEvent_i type: bool
# build_inv_value_map: (20/979) variable: at10MinApgarLessEq5OrVent_i type: bool
# build_inv_value_map: (21/979) variable: randomEligible type: bool
# build_inv_value_map: (22/979) variable: consentStatus type: consentStatus
# [INFO] _build_inv_value_map: to inv-text: type: consentStatus
# build_inv_value_map: (23/979) variable: noConsentReason type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (24/979) variable: noInStudyReason type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (25/979) variable: random type: bool
# build_inv_value_map: (26/979) variable: noRandomReason type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (27/979) variable: noRandomReasonText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (28/979) variable: randomDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (29/979) variable: randomTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (30/979) variable: randomNumber type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (31/979) variable: randomTreatmentAssign type: treatmentAssign
# [INFO] _build_inv_value_map: to inv-text: type: treatmentAssign
# build_inv_value_map: (32/979) variable: randomTreatmentReceive type: bool
# build_inv_value_map: (33/979) variable: treatmentBlanketType type: blanketType
# build_inv_value_map: (34/979) variable: inOtherTrial type: bool
# build_inv_value_map: (35/979) variable: inOtherTrialText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (36/979) variable: motherAge_year type: int
# build_inv_value_map: (37/979) variable: motherRace type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (38/979) variable: motherRaceOther1 type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (39/979) variable: motherRaceOther2 type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (40/979) variable: motherRaceOther3 type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (41/979) variable: motherRaceOther4 type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (42/979) variable: motherRaceOther5 type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (43/979) variable: motherRaceOther6 type: race
# [INFO] _build_inv_value_map: to inv-text: type: race
# build_inv_value_map: (44/979) variable: motherEthnicity type: ethnicity
# [INFO] _build_inv_value_map: to inv-text: type: ethnicity
# build_inv_value_map: (45/979) variable: motherMaritalStatus type: maritalStatus
# [INFO] _build_inv_value_map: to inv-text: type: maritalStatus
# build_inv_value_map: (46/979) variable: motherEducation type: education
# build_inv_value_map: (47/979) variable: motherInsurance type: insurance
# build_inv_value_map: (48/979) variable: gravida type: int
# build_inv_value_map: (49/979) variable: parity type: int
# build_inv_value_map: (50/979) variable: multipleBirth type: bool
# build_inv_value_map: (51/979) variable: numFetus type: int
# build_inv_value_map: (52/979) variable: prenatalCare type: bool
# build_inv_value_map: (53/979) variable: hypertensionEclampsia type: bool
# build_inv_value_map: (54/979) variable: antepartumHemorrhage type: bool
# build_inv_value_map: (55/979) variable: thyroidMalfunction type: bool
# build_inv_value_map: (56/979) variable: diabetes type: bool
# build_inv_value_map: (57/979) variable: maternalAdmissionDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (58/979) variable: maternalAdmissionTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (59/979) variable: ruptureDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (60/979) variable: ruptureTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (61/979) variable: ruptureOver18Hr type: bool
# build_inv_value_map: (62/979) variable: ruptureBeforeDelivery type: bool
# build_inv_value_map: (63/979) variable: labor type: bool
# build_inv_value_map: (64/979) variable: laborOnsetDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (65/979) variable: laborOnsetTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (66/979) variable: deliveryMode type: deliveryMode
# [INFO] _build_inv_value_map: to inv-text: type: deliveryMode
# build_inv_value_map: (67/979) variable: fetalDecelerate type: bool
# build_inv_value_map: (68/979) variable: cordMishap type: bool
# build_inv_value_map: (69/979) variable: uterineRupture type: bool
# build_inv_value_map: (70/979) variable: shoulderDystocia type: bool
# build_inv_value_map: (71/979) variable: placentalProblem type: bool
# build_inv_value_map: (72/979) variable: maternalHemorrhage type: bool
# build_inv_value_map: (73/979) variable: maternalTrauma type: bool
# build_inv_value_map: (74/979) variable: maternalCardioRespiratoryArrest type: bool
# build_inv_value_map: (75/979) variable: maternalSeizure type: bool
# build_inv_value_map: (76/979) variable: pyrexiaOver37p6C type: bool
# build_inv_value_map: (77/979) variable: chorioamnionitis type: bool
# build_inv_value_map: (78/979) variable: placentalPathologyPerformed type: bool
# build_inv_value_map: (79/979) variable: histologicChorioamionitis type: bool
# build_inv_value_map: (80/979) variable: laborAntibiotics type: bool
# build_inv_value_map: (81/979) variable: laborAntibioticsCode1 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (82/979) variable: laborAntibioticsCode2 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (83/979) variable: laborAntibioticsCode3 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (84/979) variable: laborAntibioticsCode4 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (85/979) variable: laborAntibioticsCode5 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (86/979) variable: laborAntibioticsCode6 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (87/979) variable: encephalopathyLevel type: encephalopathyLevel
# build_inv_value_map: (88/979) variable: randomInfantAge type: infantAge
# build_inv_value_map: (89/979) variable: birthDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (90/979) variable: birthTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (91/979) variable: birthWeight_g type: float
# build_inv_value_map: (92/979) variable: birthLength_cm type: float
# build_inv_value_map: (93/979) variable: birthHeadCircumference_cm type: float
# build_inv_value_map: (94/979) variable: birthGestationalAge_week type: int
# build_inv_value_map: (95/979) variable: infantSex type: infantSex
# build_inv_value_map: (96/979) variable: infantOutborn type: bool
# build_inv_value_map: (97/979) variable: outbornInHospital type: bool
# build_inv_value_map: (98/979) variable: outbornOutHospital type: bool
# build_inv_value_map: (99/979) variable: neonateAdmissionDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (100/979) variable: neonateAdmissionTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (101/979) variable: Apgar1min type: int
# build_inv_value_map: (102/979) variable: Apgar5min type: int
# build_inv_value_map: (103/979) variable: Apgar10min type: int
# build_inv_value_map: (104/979) variable: Apgar15min type: int
# build_inv_value_map: (105/979) variable: Apgar20min type: int
# build_inv_value_map: (106/979) variable: deliveryResuscitation type: bool
# build_inv_value_map: (107/979) variable: deliveryOxygen type: bool
# build_inv_value_map: (108/979) variable: deliveryBaggingAndMask type: bool
# build_inv_value_map: (109/979) variable: deliveryChestCompression type: bool
# build_inv_value_map: (110/979) variable: deliveryIntubation type: bool
# build_inv_value_map: (111/979) variable: deliveryDrug type: bool
# build_inv_value_map: (112/979) variable: at10MinContinueResuscitation type: bool
# build_inv_value_map: (113/979) variable: at10MinOxygen type: bool
# build_inv_value_map: (114/979) variable: at10MinBaggingAndMask type: bool
# build_inv_value_map: (115/979) variable: at10MinChestCompression type: bool
# build_inv_value_map: (116/979) variable: at10MinIntubation type: bool
# build_inv_value_map: (117/979) variable: at10MinDrug type: bool
# build_inv_value_map: (118/979) variable: spontaneousRespirationTime type: spontaneousRespirationTime
# build_inv_value_map: (119/979) variable: cordBloodGas type: bool
# build_inv_value_map: (120/979) variable: cordBloodGasSrc type: cordBloodGasSrc
# [INFO] _build_inv_value_map: to inv-text: type: cordBloodGasSrc
# build_inv_value_map: (121/979) variable: cordBloodGasPH type: float
# build_inv_value_map: (122/979) variable: cordBloodGasPCO2_mmHg type: float
# build_inv_value_map: (123/979) variable: cordBloodGasPO2_mmHg type: float
# build_inv_value_map: (124/979) variable: cordBloodGasHCO3_mEqPerL type: float
# build_inv_value_map: (125/979) variable: cordBloodGasBaseDeficit_mEqPerL type: float
# build_inv_value_map: (126/979) variable: firstPostnatalBloodGas type: bool
# build_inv_value_map: (127/979) variable: firstPostnatalBloodGasSrc type: bloodGasSrc
# [INFO] _build_inv_value_map: to inv-text: type: bloodGasSrc
# build_inv_value_map: (128/979) variable: firstPostnatalBloodGasDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (129/979) variable: firstPostnatalBloodGasTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (130/979) variable: firstPostnatalBloodGasPH type: float
# build_inv_value_map: (131/979) variable: firstPostnatalBloodGasPCO2_mmHg type: float
# build_inv_value_map: (132/979) variable: firstPostnatalBloodGasPO2_mmHg type: float
# build_inv_value_map: (133/979) variable: firstPostnatalBloodGasHCO3_mEqPerL type: float
# build_inv_value_map: (134/979) variable: firstPostnatalBloodGasBaseDeficit_mEqPerL type: float
# build_inv_value_map: (135/979) variable: targetTreatmentTemperature_C type: targetTreatmentTemperature
# [INFO] _build_inv_value_map: to inv-text: type: targetTreatmentTemperature
# build_inv_value_map: (136/979) variable: pre_CoolInitiate type: bool
# build_inv_value_map: (137/979) variable: pre_CoolbyIceGelPack type: bool
# build_inv_value_map: (138/979) variable: pre_CoolPassively type: bool
# build_inv_value_map: (139/979) variable: pre_CoolClinically type: bool
# build_inv_value_map: (140/979) variable: pre_CoolInitiateDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (141/979) variable: pre_CoolInitiateTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (142/979) variable: pre_AfterOvershootReach33p5C type: bool
# build_inv_value_map: (143/979) variable: pre_AfterOvershootReach33p5CDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (144/979) variable: pre_AfterOvershootReach33p5CTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (145/979) variable: pre_TemperatureMinDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (146/979) variable: pre_TemperatureMinTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (147/979) variable: pre_SkinTemperatureMin_C type: float
# build_inv_value_map: (148/979) variable: pre_AxillaryTemperatureMin_C type: float
# build_inv_value_map: (149/979) variable: pre_EsophagealTemperatureMin_C type: float
# build_inv_value_map: (150/979) variable: pre_ServoSetMin_C type: float
# build_inv_value_map: (151/979) variable: pre_TemperatureMaxDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (152/979) variable: pre_TemperatureMaxTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (153/979) variable: pre_SkinTemperatureMax_C type: float
# build_inv_value_map: (154/979) variable: pre_AxillaryTemperatureMax_C type: float
# build_inv_value_map: (155/979) variable: pre_EsophagealTemperatureMax_C type: float
# build_inv_value_map: (156/979) variable: pre_ServoSetMax_C type: float
# build_inv_value_map: (157/979) variable: pre_CardioDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (158/979) variable: pre_CardioTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (159/979) variable: pre_CardioSystolicBloodPressure_mmHg type: float
# build_inv_value_map: (160/979) variable: pre_CardioDiastolicBloodPressure_mmHg type: float
# build_inv_value_map: (161/979) variable: pre_CardioHeartRate_BPM type: float
# build_inv_value_map: (162/979) variable: pre_CardioVolumeExpand type: bool
# build_inv_value_map: (163/979) variable: pre_CardioInotropicAgent type: bool
# build_inv_value_map: (164/979) variable: pre_CardioBloodTransfusion type: bool
# build_inv_value_map: (165/979) variable: pre_CardioPlatelets type: bool
# build_inv_value_map: (166/979) variable: pre_RespiratoryDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (167/979) variable: pre_RespiratoryTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (168/979) variable: pre_RespiratorySupportType type: respiratorySupportType
# [INFO] _build_inv_value_map: to inv-text: type: respiratorySupportType
# build_inv_value_map: (169/979) variable: pre_RespiratoryFiO2 type: float
# build_inv_value_map: (170/979) variable: pre_RespiratoryRate_Hz type: float
# build_inv_value_map: (171/979) variable: pre_RespiratoryPIP_cmH2O type: float
# build_inv_value_map: (172/979) variable: pre_RespiratoryMAP_cmH2O type: float
# build_inv_value_map: (173/979) variable: pre_RespiratoryPEEP_cmH2O type: float
# build_inv_value_map: (174/979) variable: pre_BloodGasDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (175/979) variable: pre_BloodGasTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (176/979) variable: pre_BloodGasSrc type: bloodGasSrc
# [INFO] _build_inv_value_map: to inv-text: type: bloodGasSrc
# build_inv_value_map: (177/979) variable: pre_BloodGasPH type: float
# build_inv_value_map: (178/979) variable: pre_BloodGasPCO2_mmHg type: float
# build_inv_value_map: (179/979) variable: pre_BloodGasPO2_mmHg type: float
# build_inv_value_map: (180/979) variable: pre_BloodGasHCO3_mEqPerL type: float
# build_inv_value_map: (181/979) variable: pre_BloodGasBaseDeficit_mEqPerL type: float
# build_inv_value_map: (182/979) variable: pre_BloodGasPHCorrect type: float
# build_inv_value_map: (183/979) variable: pre_BloodGasPCO2Correct_mmHg type: float
# build_inv_value_map: (184/979) variable: pre_BloodGasPO2Correct_mmHg type: float
# build_inv_value_map: (185/979) variable: pre_BloodGasHCO3Correct_mEqPerL type: float
# build_inv_value_map: (186/979) variable: pre_BloodGasBaseDeficitCorrect_mEqPerL type: float
# build_inv_value_map: (187/979) variable: pre_Hematology type: bool
# build_inv_value_map: (188/979) variable: pre_HematologyDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (189/979) variable: pre_HematologyTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (190/979) variable: pre_HematologyWBC type: float
# build_inv_value_map: (191/979) variable: pre_HematologyHemoglobin type: float
# build_inv_value_map: (192/979) variable: pre_HematologyPolymorphNeutrophilsDifferentialCount type: float
# build_inv_value_map: (193/979) variable: pre_HematologyMonocytes type: float
# build_inv_value_map: (194/979) variable: pre_HematologyLymphocytes type: float
# build_inv_value_map: (195/979) variable: pre_HematologyPlateletCount type: float
# build_inv_value_map: (196/979) variable: pre_HematologyPT_s type: float
# build_inv_value_map: (197/979) variable: pre_HematologyPTT_s type: float
# build_inv_value_map: (198/979) variable: pre_PositiveCulture type: bool
# build_inv_value_map: (199/979) variable: pre_PositiveCultureSrc type: positiveCultureSrc
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureSrc
# build_inv_value_map: (200/979) variable: pre_PositiveCultureDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (201/979) variable: pre_PositiveCultureTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (202/979) variable: pre_PositiveCultureOrganismCode1 type: positiveCultureOrganism
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureOrganism
# build_inv_value_map: (203/979) variable: pre_PositiveCultureOrganismCode2 type: positiveCultureOrganism
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureOrganism
# build_inv_value_map: (204/979) variable: pre_PositiveCultureOrganismCode3 type: positiveCultureOrganism
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureOrganism
# build_inv_value_map: (205/979) variable: pre_Antibiotics type: bool
# build_inv_value_map: (206/979) variable: pre_AntibioticsCode1 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (207/979) variable: pre_AntibioticsCode2 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (208/979) variable: pre_AntibioticsCode3 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (209/979) variable: pre_OtherMedTargetDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (210/979) variable: pre_OtherMedTargetTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (211/979) variable: pre_Anticonvulsants type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (212/979) variable: pre_Anticonvulsants1 type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (213/979) variable: pre_Anticonvulsants2 type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (214/979) variable: pre_Anticonvulsants3 type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (215/979) variable: pre_Analgesics type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (216/979) variable: pre_AnalgesicsSedatives1 type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (217/979) variable: pre_AnalgesicsSedatives2 type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (218/979) variable: pre_AnalgesicsSedatives3 type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (219/979) variable: pre_Antipyretics type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (220/979) variable: pre_Antipyretics1 type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (221/979) variable: pre_Antipyretics2 type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (222/979) variable: pre_Antipyretics3 type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (223/979) variable: pre_Paralytics type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (224/979) variable: pre_Paralytics1 type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (225/979) variable: pre_Paralytics2 type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (226/979) variable: pre_Paralytics3 type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (227/979) variable: pre_OtherMedFluidIntake_ccPerKg type: float
# build_inv_value_map: (228/979) variable: pre_OtherMedUrineOutput_ccPerKg type: float
# build_inv_value_map: (229/979) variable: pre_HeadSonogram type: bool
# build_inv_value_map: (230/979) variable: pre_HeadSonogramDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (231/979) variable: pre_HeadSonogramTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (232/979) variable: pre_HeadSonogramResult1 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (233/979) variable: pre_HeadSonogramResult2 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (234/979) variable: pre_HeadSonogramResult3 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (235/979) variable: pre_HeadSonogramResult4 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (236/979) variable: pre_HeadSonogramResult5 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (237/979) variable: pre_HeadSonogramResult6 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (238/979) variable: pre_HeadSonogramResult7 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (239/979) variable: pre_HeadSonogramResult8 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (240/979) variable: pre_HeadSonogramResultText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (241/979) variable: pre_HeadCT type: bool
# build_inv_value_map: (242/979) variable: pre_HeadCTDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (243/979) variable: pre_HeadCTTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (244/979) variable: pre_HeadCTResult1 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (245/979) variable: pre_HeadCTResult2 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (246/979) variable: pre_HeadCTResult3 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (247/979) variable: pre_HeadCTResult4 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (248/979) variable: pre_HeadCTResult5 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (249/979) variable: pre_HeadCTResult6 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (250/979) variable: pre_HeadCTResult7 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (251/979) variable: pre_HeadCTResult8 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (252/979) variable: pre_HeadCTResultText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (253/979) variable: pre_BrainMRI type: bool
# build_inv_value_map: (254/979) variable: pre_BrainMRIDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (255/979) variable: pre_BrainMRITime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (256/979) variable: pre_BrainMRIResult1 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (257/979) variable: pre_BrainMRIResult2 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (258/979) variable: pre_BrainMRIResult3 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (259/979) variable: pre_BrainMRIResult4 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (260/979) variable: pre_BrainMRIResult5 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (261/979) variable: pre_BrainMRIResult6 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (262/979) variable: pre_BrainMRIResult7 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (263/979) variable: pre_BrainMRIResult8 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (264/979) variable: pre_BrainMRIResultText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (265/979) variable: pre_NeuroExam type: bool
# build_inv_value_map: (266/979) variable: pre_NoNeuroExamReason type: noNeuroExamReason
# [INFO] _build_inv_value_map: to inv-text: type: noNeuroExamReason
# build_inv_value_map: (267/979) variable: pre_NeuroExamSignModerateSevereHIE3Category type: bool
# build_inv_value_map: (268/979) variable: pre_NeuroExamLevelConsciousness type: signOfHIELvlOfCons
# build_inv_value_map: (269/979) variable: pre_NeuroExamSpontaneousActivity type: signOfHIESpontaneousActivity
# build_inv_value_map: (270/979) variable: pre_NeuroExamPosture type: signOfHIEPosture
# build_inv_value_map: (271/979) variable: pre_NeuroExamTone type: signOfHIETone
# build_inv_value_map: (272/979) variable: pre_NeuroExamSuck type: signOfHIESuck
# build_inv_value_map: (273/979) variable: pre_NeuroExamMoro type: signOfHIEMoro
# build_inv_value_map: (274/979) variable: pre_NeuroExamPupils type: signOfHIEPupils
# build_inv_value_map: (275/979) variable: pre_NeuroExamHeartRate type: signOfHIEHeartRate
# build_inv_value_map: (276/979) variable: pre_NeuroExamRespiration type: signOfHIERespiratory
# build_inv_value_map: (277/979) variable: pre_NeuroExamDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (278/979) variable: pre_NeuroExamTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (279/979) variable: pre_NeuroExamSedate type: bool
# build_inv_value_map: (280/979) variable: pre_NeuroExamSeizure type: bool
# build_inv_value_map: (281/979) variable: temperatureTimeSlot type: int
# build_inv_value_map: (282/979) variable: temperatureTimeSlotNoForm type: bool
# build_inv_value_map: (283/979) variable: temperatureDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (284/979) variable: temperatureTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (285/979) variable: skinTemperature_C type: float
# build_inv_value_map: (286/979) variable: axillaryTemperature_C type: float
# build_inv_value_map: (287/979) variable: esophagealTemperature_C type: float
# build_inv_value_map: (288/979) variable: blanketTemperature_C type: float
# build_inv_value_map: (289/979) variable: servoSetTemperature_C type: float
# build_inv_value_map: (290/979) variable: alterationSkinIntegrity type: bool
# build_inv_value_map: (291/979) variable: shiver type: bool
# build_inv_value_map: (292/979) variable: cardioTimeSlot type: int
# build_inv_value_map: (293/979) variable: cardioDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (294/979) variable: cardioTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (295/979) variable: cardioSystolicBloodPressure_mmHg type: float
# build_inv_value_map: (296/979) variable: cardioDiastolicBloodPressure_mmHg type: float
# build_inv_value_map: (297/979) variable: cardioHeartRate_BPM type: float
# build_inv_value_map: (298/979) variable: cardioVolumeExpand type: bool
# build_inv_value_map: (299/979) variable: cardioInotropicAgent type: bool
# build_inv_value_map: (300/979) variable: cardioBloodTransfusion type: bool
# build_inv_value_map: (301/979) variable: cardioPlatelets type: bool
# build_inv_value_map: (302/979) variable: respiratoryTimeSlot type: int
# build_inv_value_map: (303/979) variable: respiratoryDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (304/979) variable: respiratoryTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (305/979) variable: respiratorySupportType type: respiratorySupportType
# [INFO] _build_inv_value_map: to inv-text: type: respiratorySupportType
# build_inv_value_map: (306/979) variable: respiratoryFiO2 type: float
# build_inv_value_map: (307/979) variable: respiratoryRate_Hz type: float
# build_inv_value_map: (308/979) variable: respiratoryPIP_cmH2O type: float
# build_inv_value_map: (309/979) variable: respiratoryMAP_cmH2O type: float
# build_inv_value_map: (310/979) variable: respiratoryPEEP_cmH2O type: float
# build_inv_value_map: (311/979) variable: bloodGasTimeSlot type: int
# build_inv_value_map: (312/979) variable: bloodGasDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (313/979) variable: bloodGasTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (314/979) variable: bloodGasSrc type: bloodGasSrc
# [INFO] _build_inv_value_map: to inv-text: type: bloodGasSrc
# build_inv_value_map: (315/979) variable: bloodGasPH type: float
# build_inv_value_map: (316/979) variable: bloodGasPCO2_mmHg type: float
# build_inv_value_map: (317/979) variable: bloodGasPO2_mmHg type: float
# build_inv_value_map: (318/979) variable: bloodGasHCO3_mEqPerL type: float
# build_inv_value_map: (319/979) variable: bloodGasBaseDeficit_mEqPerL type: float
# build_inv_value_map: (320/979) variable: bloodGasPHCorrect type: float
# build_inv_value_map: (321/979) variable: bloodGasPCO2Correct_mmHg type: float
# build_inv_value_map: (322/979) variable: bloodGasPO2Correct_mmHg type: float
# build_inv_value_map: (323/979) variable: bloodGasHCO3Correct_mEqPerL type: float
# build_inv_value_map: (324/979) variable: bloodGasBaseDeficitCorrect_mEqPerL type: float
# build_inv_value_map: (325/979) variable: hematology type: bool
# build_inv_value_map: (326/979) variable: hematologyTimeSlot type: int
# build_inv_value_map: (327/979) variable: hematologyDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (328/979) variable: hematologyTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (329/979) variable: hematologyWBC type: float
# build_inv_value_map: (330/979) variable: hematologyHemoglobin type: float
# build_inv_value_map: (331/979) variable: hematologyPolymorphNeutrophilsDifferentialCount type: float
# build_inv_value_map: (332/979) variable: hematologyMonocytes type: float
# build_inv_value_map: (333/979) variable: hematologyLymphocytes type: float
# build_inv_value_map: (334/979) variable: hematologyPlateletCount type: float
# build_inv_value_map: (335/979) variable: hematologyPT_s type: float
# build_inv_value_map: (336/979) variable: hematologyPTT_s type: float
# build_inv_value_map: (337/979) variable: hematologyHematocritMin type: float
# build_inv_value_map: (338/979) variable: hematologyHematocritMinDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (339/979) variable: hematologyPlateletCountMin type: float
# build_inv_value_map: (340/979) variable: hematologyPlateletCountMinDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (341/979) variable: bloodValueBunBaseline_mgPerdL type: float
# build_inv_value_map: (342/979) variable: bloodValueBunBaseline_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (343/979) variable: bloodValueCreatinineBaseline_mgPerdL type: float
# build_inv_value_map: (344/979) variable: bloodValueCreatinineBaseline_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (345/979) variable: bloodValueASTSGOTBaseline_UPerL type: float
# build_inv_value_map: (346/979) variable: bloodValueASTSGOTBaseline_UPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (347/979) variable: bloodValueALTSGPTBaseline_UPerL type: float
# build_inv_value_map: (348/979) variable: bloodValueALTSGPTBaseline_UPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (349/979) variable: bloodValueTotalBilirubinBaseline_mgPerdL type: float
# build_inv_value_map: (350/979) variable: bloodValueTotalBilirubinBaseline_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (351/979) variable: bloodValuePHMin type: float
# build_inv_value_map: (352/979) variable: bloodValuePHMinDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (353/979) variable: bloodValueHCO3Min_mEqPerL type: float
# build_inv_value_map: (354/979) variable: bloodValueHCO3Min_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (355/979) variable: bloodValueSerumNaMin_mEqPerL type: float
# build_inv_value_map: (356/979) variable: bloodValueSerumNaMin_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (357/979) variable: bloodValueSerumKMin_mEqPerL type: float
# build_inv_value_map: (358/979) variable: bloodValueSerumKMin_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (359/979) variable: bloodValueClMin_mEqPerL type: float
# build_inv_value_map: (360/979) variable: bloodValueClMin_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (361/979) variable: bloodValueGlucoseMin_mgPerdL type: float
# build_inv_value_map: (362/979) variable: bloodValueGlucoseMin_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (363/979) variable: bloodValueTotalCaMin_mgPerdL type: float
# build_inv_value_map: (364/979) variable: bloodValueTotalCaMin_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (365/979) variable: bloodValueIonCaMin_mgPerdL type: float
# build_inv_value_map: (366/979) variable: bloodValueIonCaMin_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (367/979) variable: bloodValueASTSGOTMin_UPerL type: float
# build_inv_value_map: (368/979) variable: bloodValueASTSGOTMin_UPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (369/979) variable: bloodValueALTSGPTMin_UPerL type: float
# build_inv_value_map: (370/979) variable: bloodValueALTSGPTMin_UPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (371/979) variable: bloodValueTotalBilirubinMin_mgPerdL type: float
# build_inv_value_map: (372/979) variable: bloodValueTotalBilirubinMin_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (373/979) variable: bloodValuePHMax type: float
# build_inv_value_map: (374/979) variable: bloodValuePHMaxDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (375/979) variable: bloodValueBaseDeficitMax_mEqPerL type: float
# build_inv_value_map: (376/979) variable: bloodValueBaseDeficitMax_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (377/979) variable: bloodValueSerumNaMax_mEqPerL type: float
# build_inv_value_map: (378/979) variable: bloodValueSerumNaMax_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (379/979) variable: bloodValueSerumKMax_mEqPerL type: float
# build_inv_value_map: (380/979) variable: bloodValueSerumKMax_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (381/979) variable: bloodValueClMax_mEqPerL type: float
# build_inv_value_map: (382/979) variable: bloodValueClMax_mEqPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (383/979) variable: bloodValueBunMax_mgPerdL type: float
# build_inv_value_map: (384/979) variable: bloodValueBunMax_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (385/979) variable: bloodValueCreatinineMax_mgPerdL type: float
# build_inv_value_map: (386/979) variable: bloodValueCreatinineMax_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (387/979) variable: bloodValueGlucoseMax_mgPerdL type: float
# build_inv_value_map: (388/979) variable: bloodValueGlucoseMax_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (389/979) variable: bloodValueTotalCaMax_mgPerdL type: float
# build_inv_value_map: (390/979) variable: bloodValueTotalCaMax_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (391/979) variable: bloodValueIonCaMax_mgPerdL type: float
# build_inv_value_map: (392/979) variable: bloodValueIonCaMax_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (393/979) variable: bloodValueASTSGOTMax_UPerL type: float
# build_inv_value_map: (394/979) variable: bloodValueASTSGOTMax_UPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (395/979) variable: bloodValueALTSGPTMax_UPerL type: float
# build_inv_value_map: (396/979) variable: bloodValueALTSGPTMax_UPerLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (397/979) variable: bloodValueTotalBilirubinMax_mgPerdL type: float
# build_inv_value_map: (398/979) variable: bloodValueTotalBilirubinMax_mgPerdLDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (399/979) variable: positiveCultureNumber type: int
# build_inv_value_map: (400/979) variable: positiveCulture type: bool
# build_inv_value_map: (401/979) variable: positiveCultureSrc type: positiveCultureSrc
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureSrc
# build_inv_value_map: (402/979) variable: positiveCultureDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (403/979) variable: positiveCultureTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (404/979) variable: positiveCultureOrganismCode1 type: positiveCultureOrganism
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureOrganism
# build_inv_value_map: (405/979) variable: positiveCultureOrganismCode2 type: positiveCultureOrganism
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureOrganism
# build_inv_value_map: (406/979) variable: positiveCultureOrganismCode3 type: positiveCultureOrganism
# [INFO] _build_inv_value_map: to inv-text: type: positiveCultureOrganism
# build_inv_value_map: (407/979) variable: antibiotics type: bool
# build_inv_value_map: (408/979) variable: antibioticsCode1 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (409/979) variable: antibioticsCode2 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (410/979) variable: antibioticsCode3 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (411/979) variable: rewarmingAntibiotics type: bool
# build_inv_value_map: (412/979) variable: rewarmingAntibioticsCode1 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (413/979) variable: rewarmingAntibioticsCode2 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (414/979) variable: rewarmingAntibioticsCode3 type: antibiotics
# [INFO] _build_inv_value_map: to inv-text: type: antibiotics
# build_inv_value_map: (415/979) variable: otherMedTimeSlot type: int
# build_inv_value_map: (416/979) variable: otherMedTargetDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (417/979) variable: otherMedTargetTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (418/979) variable: anticonvulsants type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (419/979) variable: anticonvulsants1 type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (420/979) variable: anticonvulsants2 type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (421/979) variable: anticonvulsants3 type: anticonvulsants
# [INFO] _build_inv_value_map: to inv-text: type: anticonvulsants
# build_inv_value_map: (422/979) variable: analgesics type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (423/979) variable: analgesicsSedatives1 type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (424/979) variable: analgesicsSedatives2 type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (425/979) variable: analgesicsSedatives3 type: analgesics
# [INFO] _build_inv_value_map: to inv-text: type: analgesics
# build_inv_value_map: (426/979) variable: antipyretics type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (427/979) variable: antipyretics1 type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (428/979) variable: antipyretics2 type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (429/979) variable: antipyretics3 type: antipyretics
# [INFO] _build_inv_value_map: to inv-text: type: antipyretics
# build_inv_value_map: (430/979) variable: paralytics type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (431/979) variable: paralytics1 type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (432/979) variable: paralytics2 type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (433/979) variable: paralytics3 type: paralytics
# [INFO] _build_inv_value_map: to inv-text: type: paralytics
# build_inv_value_map: (434/979) variable: otherMedFluidIntake_ccPerKg type: float
# build_inv_value_map: (435/979) variable: otherMedUrineOutput_ccPerKg type: float
# build_inv_value_map: (436/979) variable: imagingTimeSlot type: int
# build_inv_value_map: (437/979) variable: headSonogram type: bool
# build_inv_value_map: (438/979) variable: headSonogramDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (439/979) variable: headSonogramTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (440/979) variable: headSonogramResult1 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (441/979) variable: headSonogramResult2 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (442/979) variable: headSonogramResult3 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (443/979) variable: headSonogramResult4 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (444/979) variable: headSonogramResult5 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (445/979) variable: headSonogramResult6 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (446/979) variable: headSonogramResult7 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (447/979) variable: headSonogramResult8 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (448/979) variable: headSonogramResultText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (449/979) variable: headCT type: bool
# build_inv_value_map: (450/979) variable: headCTDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (451/979) variable: headCTTime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (452/979) variable: headCTResult1 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (453/979) variable: headCTResult2 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (454/979) variable: headCTResult3 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (455/979) variable: headCTResult4 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (456/979) variable: headCTResult5 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (457/979) variable: headCTResult6 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (458/979) variable: headCTResult7 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (459/979) variable: headCTResult8 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (460/979) variable: headCTResultText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (461/979) variable: brainMRI type: bool
# build_inv_value_map: (462/979) variable: brainMRIDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (463/979) variable: brainMRITime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (464/979) variable: brainMRIResult1 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# build_inv_value_map: (465/979) variable: brainMRIResult2 type: imaging
# [INFO] _build_inv_value_map: to inv-text: type: imaging
# ...
# build_inv_value_map: (304/355) variable: lostFollowUpInterview type: bool
# build_inv_value_map: (305/355) variable: lostFollowUpInterviewDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (306/355) variable: lostFollowUpInterviewCorrectedAge_mo type: int
# build_inv_value_map: (307/355) variable: lostFollowUpAnyQuestionCompleteChartReview type: bool
# build_inv_value_map: (308/355) variable: lostFollowUpChartReviewDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (309/355) variable: lostFollowUpChartReviewCorrectedAge_mo type: int
# build_inv_value_map: (310/355) variable: interviewChildHealth type: childHealth
# build_inv_value_map: (311/355) variable: interviewWalkAlone type: bool
# build_inv_value_map: (312/355) variable: interviewWalkAloneAge_mo type: int
# build_inv_value_map: (313/355) variable: interviewSittingAlong type: bool
# build_inv_value_map: (314/355) variable: interviewHeadControl type: bool
# build_inv_value_map: (315/355) variable: interviewSee type: bool
# build_inv_value_map: (316/355) variable: interviewEyeExam type: bool
# build_inv_value_map: (317/355) variable: interviewNeedWearGlasses type: bool
# build_inv_value_map: (318/355) variable: interviewHear type: bool
# build_inv_value_map: (319/355) variable: interviewHearExam type: bool
# build_inv_value_map: (320/355) variable: interviewNeedWearHearingAid type: bool
# build_inv_value_map: (321/355) variable: interviewNumberWordVocabulary type: int
# build_inv_value_map: (322/355) variable: interviewCombine2Words type: bool
# build_inv_value_map: (323/355) variable: interviewCombine3Words type: bool
# build_inv_value_map: (324/355) variable: interviewHydrocephalusShunt type: bool
# build_inv_value_map: (325/355) variable: interviewCerebralPalsy type: bool
# build_inv_value_map: (326/355) variable: interviewDevelopmentalDelay type: bool
# build_inv_value_map: (327/355) variable: interviewLanguageDelay type: bool
# build_inv_value_map: (328/355) variable: interviewPoorWeightGain type: bool
# build_inv_value_map: (329/355) variable: interviewSeizure type: bool
# build_inv_value_map: (330/355) variable: interviewBlindness type: bool
# build_inv_value_map: (331/355) variable: interviewOtherBehaviorProblem type: bool
# build_inv_value_map: (332/355) variable: interviewOtherBehaviorProblemText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (333/355) variable: interviewOtherMajorMedicalProblem type: bool
# build_inv_value_map: (334/355) variable: interviewOtherMajorMedicalProblemText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (335/355) variable: interviewOtherNeuraldevelopmentalProblem type: bool
# build_inv_value_map: (336/355) variable: interviewOtherNeuraldevelopmentalProblemText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (337/355) variable: interviewMotorGrossFunctionLevel type: grossMotorFunctionLevel
# build_inv_value_map: (338/355) variable: chartReviewEyeExam type: chartReview
# build_inv_value_map: (339/355) variable: chartReviewHearingExam type: chartReview
# build_inv_value_map: (340/355) variable: chartReviewNeedWearHearingAid type: chartReview
# build_inv_value_map: (341/355) variable: chartReviewHydrocephalusShunt type: chartReview
# build_inv_value_map: (342/355) variable: chartReviewCerebralPalsy type: chartReview
# build_inv_value_map: (343/355) variable: chartReviewDevelopmentalDelay type: chartReview
# build_inv_value_map: (344/355) variable: chartReviewLanguageDelay type: chartReview
# build_inv_value_map: (345/355) variable: chartReviewPoorWeightGain type: chartReview
# build_inv_value_map: (346/355) variable: chartReviewSeizure type: chartReview
# build_inv_value_map: (347/355) variable: chartReviewBlindness type: chartReview
# build_inv_value_map: (348/355) variable: chartReviewOtherBehaviorProblem type: chartReview
# build_inv_value_map: (349/355) variable: chartReviewOtherBehaviorProblemText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (350/355) variable: chartReviewOtherMajorMedicalProblem type: chartReview
# build_inv_value_map: (351/355) variable: chartReviewOtherMajorMedicalProblemText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (352/355) variable: chartReviewOtherNeuraldevelopmentalProblem type: chartReview
# build_inv_value_map: (353/355) variable: chartReviewOtherNeuraldevelopmentalProblemText type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (354/355) variable: chartReviewMotorGrossFunctionLevel type: grossMotorFunctionLevel
# build_inv_value_map: (0/148) variable: center type: center
# [INFO] _build_inv_value_map: to inv-text: type: center
# build_inv_value_map: (1/148) variable: followupCenter type: center
# [INFO] _build_inv_value_map: to inv-text: type: center
# build_inv_value_map: (2/148) variable: subjectID type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (3/148) variable: followupID type: text
# [INFO] _build_inv_value_map: to inv-text: type: text
# build_inv_value_map: (4/148) variable: acidosis type: bool
# build_inv_value_map: (5/148) variable: ageDeath_day type: int
# build_inv_value_map: (6/148) variable: ageRand_hr type: float
# build_inv_value_map: (7/148) variable: baselineAnticonvulsants type: bool
# build_inv_value_map: (8/148) variable: dischargeAnticonvulsants type: bool
# build_inv_value_map: (9/148) variable: inotropicAgent type: bool
# build_inv_value_map: (10/148) variable: perinatalSentinelEvent type: bool
# build_inv_value_map: (11/148) variable: dischargeSeizure type: bool
# build_inv_value_map: (12/148) variable: Apgar10minLt5 type: bool
# build_inv_value_map: (13/148) variable: Apgar10minLte5 type: bool
# build_inv_value_map: (14/148) variable: Apgar5minLte5 type: bool
# build_inv_value_map: (15/148) variable: bloodGasBaseDeficit_mEqPerL type: float
# build_inv_value_map: (16/148) variable: bloodGasPH type: float
# build_inv_value_map: (17/148) variable: emergencyCSection type: bool
# build_inv_value_map: (18/148) variable: encephalopathyLevel type: encephalopathyLevel
# build_inv_value_map: (19/148) variable: inotropicAgentBaseline type: bool
# build_inv_value_map: (20/148) variable: maleSex type: bool
# build_inv_value_map: (21/148) variable: maternalEducation type: education2
# build_inv_value_map: (22/148) variable: motherInsurancePublic type: bool
# build_inv_value_map: (23/148) variable: motherRace type: race2
# build_inv_value_map: (24/148) variable: treatmentAssignmentDuration_hr type: int
# build_inv_value_map: (25/148) variable: treatmentAssignmentTemperature type: float
# build_inv_value_map: (26/148) variable: bloodGasBaseDeficit_mEqPerLSrc type: bloodGasSrc2
# build_inv_value_map: (27/148) variable: bloodGasPHSrc type: bloodGasSrc2
# build_inv_value_map: (28/148) variable: usualCoolingTreatmentGroup type: bool
# build_inv_value_map: (29/148) variable: blindness type: bool
# build_inv_value_map: (30/148) variable: moderateSevereCerebralPalsy type: bool
# build_inv_value_map: (31/148) variable: cerebralPalsy type: bool
# build_inv_value_map: (32/148) variable: gastrostomyTube type: bool
# build_inv_value_map: (33/148) variable: grossMotorFunctionLevel type: severity
# build_inv_value_map: (34/148) variable: hearingImpairedWithAid type: bool
# build_inv_value_map: (35/148) variable: hearingImpairedLevel type: severity
# build_inv_value_map: (36/148) variable: multipleImpairment type: bool
# build_inv_value_map: (37/148) variable: afterDischargeSeizure type: bool
# build_inv_value_map: (38/148) variable: lengthOfStay_day type: int
# build_inv_value_map: (39/148) variable: flagAdjudicatedOutcome type: flagAdjudicatedOutcome
# build_inv_value_map: (40/148) variable: normalPrimaryOutcome type: bool
# build_inv_value_map: (41/148) variable: BayleyIIILanguage type: severity
# build_inv_value_map: (42/148) variable: BayleyIIIMotor type: severity
# build_inv_value_map: (43/148) variable: BayleyIIICognitive type: severity
# build_inv_value_map: (44/148) variable: deathBeforeFollowup type: bool
# build_inv_value_map: (45/148) variable: deathBeforeDischarge type: bool
# build_inv_value_map: (46/148) variable: disabilityLevelSurvivor type: severity
# build_inv_value_map: (47/148) variable: disabilityLevel type: severity
# build_inv_value_map: (48/148) variable: moderateSevereDisabilityOrDeath type: bool
# build_inv_value_map: (49/148) variable: moderateSevereDisabilitySurvivor type: bool
# build_inv_value_map: (50/148) variable: disabilityLevelDeath type: severity
# build_inv_value_map: (51/148) variable: outcomeGroup type: outcomeGroup
# build_inv_value_map: (52/148) variable: pre_NeuroExamLevelConsciousnessScore type: int
# build_inv_value_map: (53/148) variable: pre_NeuroExamSpontaneousActivityScore type: int
# build_inv_value_map: (54/148) variable: pre_NeuroExamPostureScore type: int
# build_inv_value_map: (55/148) variable: pre_NeuroExamToneScore type: int
# build_inv_value_map: (56/148) variable: pre_NeuroExamSuckScore type: int
# build_inv_value_map: (57/148) variable: pre_NeuroExamMoroScore type: int
# build_inv_value_map: (58/148) variable: pre_NeuroExamPupilsScore type: int
# build_inv_value_map: (59/148) variable: pre_NeuroExamHeartRateScore type: int
# build_inv_value_map: (60/148) variable: pre_NeuroExamRespirationScore type: int
# build_inv_value_map: (61/148) variable: pre_NeuroExamReflexScore type: int
# build_inv_value_map: (62/148) variable: pre_NeuroExamANSScore type: int
# build_inv_value_map: (63/148) variable: pre_TotalModifiedSarnatScore type: int
# build_inv_value_map: (64/148) variable: post_NeuroExamLevelConsciousnessScore type: int
# build_inv_value_map: (65/148) variable: post_NeuroExamSpontaneousActivityScore type: int
# build_inv_value_map: (66/148) variable: post_NeuroExamPostureScore type: int
# build_inv_value_map: (67/148) variable: post_NeuroExamToneScore type: int
# build_inv_value_map: (68/148) variable: post_NeuroExamSuckScore type: int
# build_inv_value_map: (69/148) variable: post_NeuroExamMoroScore type: int
# build_inv_value_map: (70/148) variable: post_NeuroExamPupilsScore type: int
# build_inv_value_map: (71/148) variable: post_NeuroExamHeartRateScore type: int
# build_inv_value_map: (72/148) variable: post_NeuroExamRespirationScore type: int
# build_inv_value_map: (73/148) variable: post_NeuroExamReflexScore type: int
# build_inv_value_map: (74/148) variable: post_NeuroExamANSScore type: int
# build_inv_value_map: (75/148) variable: post_TotalModifiedSarnatScore type: int
# build_inv_value_map: (76/148) variable: dischargeNeuroExamLevelConsciousnessScore type: int
# build_inv_value_map: (77/148) variable: dischargeNeuroExamSpontaneousActivityScore type: int
# build_inv_value_map: (78/148) variable: dischargeNeuroExamPostureScore type: int
# build_inv_value_map: (79/148) variable: dischargeNeuroExamToneScore type: int
# build_inv_value_map: (80/148) variable: dischargeNeuroExamSuckScore type: int
# build_inv_value_map: (81/148) variable: dischargeNeuroExamMoroScore type: int
# build_inv_value_map: (82/148) variable: dischargeNeuroExamPupilsScore type: int
# build_inv_value_map: (83/148) variable: dischargeNeuroExamHeartRateScore type: int
# build_inv_value_map: (84/148) variable: dischargeNeuroExamRespirationScore type: int
# build_inv_value_map: (85/148) variable: dischargeNeuroExamReflexScore type: int
# build_inv_value_map: (86/148) variable: dischargeNeuroExamANSScore type: int
# build_inv_value_map: (87/148) variable: dischargeTotalModifiedSarnatScore type: int
# build_inv_value_map: (88/148) variable: MRINRNPatternOfInjuryMerge type: MRINRNPatternOfInjury
# build_inv_value_map: (89/148) variable: MRINRNPatternOfInjuryAvg type: float
# build_inv_value_map: (90/148) variable: MRINRNPatternOfInjuryMax type: float
# build_inv_value_map: (91/148) variable: MRI2LevelPatternOfInjury type: MRI2LevelPatternOfInjury
# build_inv_value_map: (92/148) variable: MRIAge_day type: int
# build_inv_value_map: (93/148) variable: MRIOverallDiagnosis type: MRIOverallDiagnosis
# build_inv_value_map: (94/148) variable: MRINRNPatternOfInjury type: MRINRNPatternOfInjury
# build_inv_value_map: (95/148) variable: MRIDate type: date
# [INFO] _build_inv_value_map: to inv-text: type: date
# build_inv_value_map: (96/148) variable: MRITime type: time
# [INFO] _build_inv_value_map: to inv-text: type: time
# build_inv_value_map: (97/148) variable: MRINotDone type: bool
# build_inv_value_map: (98/148) variable: MRIUnread type: bool
# build_inv_value_map: (99/148) variable: MRIAnalysis type: bool
# build_inv_value_map: (100/148) variable: abnormalMRIResult type: bool
# build_inv_value_map: (101/148) variable: MRINRNPatternOfInjuryWSvsBGTPLIC type: MRINRNPatternOfInjuryWSvsBGT
# build_inv_value_map: (102/148) variable: cerebralLesion type: bool
# build_inv_value_map: (103/148) variable: cerebellarLesion type: lesion
# build_inv_value_map: (104/148) variable: basalGangliaLesion type: lesion
# build_inv_value_map: (105/148) variable: brainstemLesion type: lesion
# build_inv_value_map: (106/148) variable: corpusCallosumLesion type: lesion
# build_inv_value_map: (107/148) variable: cerebralLesionLobe type: lesion
# build_inv_value_map: (108/148) variable: coronaRadiataLesion type: lesion
# build_inv_value_map: (109/148) variable: edema type: lesion
# build_inv_value_map: (110/148) variable: extraAxialLesion type: lesion
# build_inv_value_map: (111/148) variable: extent type: extent
# build_inv_value_map: (112/148) variable: frontalParietalLesion type: lesion
# build_inv_value_map: (113/148) variable: frontalLesion type: lesion
# build_inv_value_map: (114/148) variable: lateralHemisphericDevastation type: lateral
# build_inv_value_map: (115/148) variable: hippocampusLesion type: lesion
# build_inv_value_map: (116/148) variable: hypothalamusLesion type: lesion
# build_inv_value_map: (117/148) variable: insularLesion type: lesion
# build_inv_value_map: (118/148) variable: laterality type: lateral
# build_inv_value_map: (119/148) variable: BGT type: BGT
# build_inv_value_map: (120/148) variable: PLIC type: PLIC
# build_inv_value_map: (121/148) variable: watershed type: watershed
# build_inv_value_map: (122/148) variable: whiteMatterInjury type: whiteMatterInjury
# build_inv_value_map: (123/148) variable: occipitalLesion type: lesion
# build_inv_value_map: (124/148) variable: opticChiasmLesion type: lesion
# build_inv_value_map: (125/148) variable: otherLesion type: lesion
# build_inv_value_map: (126/148) variable: otherCerebralLesion type: lesion
# build_inv_value_map: (127/148) variable: parasagittalLesion type: lesion
# build_inv_value_map: (128/148) variable: parietalLesion type: lesion
# build_inv_value_map: (129/148) variable: preirolandicLesion type: lesion
# build_inv_value_map: (130/148) variable: perisylvianLesion type: lesion
# build_inv_value_map: (131/148) variable: pituitaryLesion type: lesion
# build_inv_value_map: (132/148) variable: parietalOccipitalLesion type: lesion
# build_inv_value_map: (133/148) variable: parietalTemporalLesion type: lesion
# build_inv_value_map: (134/148) variable: scalpLesion type: lesion
# build_inv_value_map: (135/148) variable: thalamusLesion type: lesion
# build_inv_value_map: (136/148) variable: temporalLesion type: lesion
# build_inv_value_map: (137/148) variable: temporalOccipitalLesion type: lesion
# build_inv_value_map: (138/148) variable: cerebralAtrophy type: bool
# build_inv_value_map: (139/148) variable: cererbalAtrophyQualAssessCC type: cererbalAtrophyQualAssessCC
# build_inv_value_map: (140/148) variable: cerebralAtrophyGlobalLocal type: cerebralAtrophyGlobalLocal
# build_inv_value_map: (141/148) variable: vascularTerritoryInfarction type: bool
# build_inv_value_map: (142/148) variable: vascularTerritoryInfarctionLeft type: bool
# build_inv_value_map: (143/148) variable: vascularTerritoryInfarctionRight type: bool
# build_inv_value_map: (144/148) variable: hemisphericDevastation type: bool
# build_inv_value_map: (145/148) variable: ventricularDilatation type: ventricularDilatation
# build_inv_value_map: (146/148) variable: vascularLesion type: lesion
# build_inv_value_map: (147/148) variable: intraventricularLesion type: lesion

# %%
_INV_VALUE_MAP = {
    COMBINE_harmonizer.SHEET_MAIN: _INV_VALUE_MAP_MAIN,
    COMBINE_harmonizer.SHEET_FOLLOW_UP: _INV_VALUE_MAP_FOLLOWUP,
    COMBINE_harmonizer.SHEET_DERIVED_DATA: _INV_VALUE_MAP_ANALYSIS,
}

_FILENAME_INFO_INV_VALUE_MAP = {each['name']: _INV_VALUE_MAP[each['data_dict']] for each in COMBINE_harmonizer.FILENAME_INFOS}

_PREFIX_INV_VALUE_MAP = {COMBINE_harmonizer.flatten_filename_prefix(filename): val for filename, val in _FILENAME_INFO_INV_VALUE_MAP.items()}

# %% [markdown]
# ## Load flatten

# %%
filename = f'{input_dir}/zz-merged-flatten.csv'

# %%
df = pd.read_csv(filename, dtype='O')

# %%
columns = list(df.columns)

# %%
df_columns = pd.DataFrame({'columns': columns})

# %%
df_columns['column_tuple'] = df_columns['columns'].apply(COMBINE_harmonizer.flatten_column_tuple)
df_columns['column_name'] = df_columns['column_tuple'].apply(lambda x: x[1])
df_columns['column_prefix'] = df_columns['column_tuple'].apply(lambda x: x[0])

# %%
df_columns['column_prefix'].unique()
# Out:
# array(['', '01-02', '01-03', '01-04', '01-05', '01-06', '01-07', '01-08',
#        '01-09', '01-10', '01-11', '01-12', '02-01', '02-02', '02-03',
#        '02-04', '02-05', '02-05_s', '02-06_s', '02-07', '02-08', '02-09',
#        '02-11', '02-12', '02-13', '02-14', '02-15', '02-16', '02-17',
#        '03-01', '03-01_s', '03-02', '03-03', '03-04', '03-05', '03-05_s',
#        '04-01', '04-03', '04-04', '04-05', '04-06', '04-07', '04-08',
#        '04-09', '04-10', '04-11', '04-12', '04-02', '04-13', '04-14',
#        '04-15', '04-16', '04-17', '20-00', '20-01', '20-02', '20-03',
#        '20-04', '20-05', '20-06', '20-07', '20-08', '30-01', '30-02',
#        '30-03', '31-02', '31-03', '31-04', '31-05', '31-06', '31-07'],
#       dtype=object)

# %%
df_columns_groupby = df_columns.groupby(['column_name']).agg(count=('column_name', 'count'))

is_invalid = df_columns_groupby['count'] > 1
df_columns_groupby[is_invalid].sort_values(by=['count'], ascending=[False])
# Out:
#                        count
# column_name
# temperatureTimeSlot       87
# axillaryTemperature_C     87
# blanketTemperature_C      87
# servoSetTemperature_C     87
# shiver                    87
# ...                      ...
# maternalHemorrhage         2
# maternalSeizure            2
# maternalTrauma             2
# motherRace                 2
# antibiotics                2
#
# [324 rows x 1 columns]

# %%
def _inv_df(df: pd.DataFrame)-> pd.DataFrame:
    df_inv = df.copy()

    columns = list(df_inv.columns)
    for idx, column in tqdm(enumerate(columns)):
        prefix, var_name, postfix = COMBINE_harmonizer.flatten_column_tuple(column)
        if prefix not in _PREFIX_INV_VALUE_MAP:
            print(f'[WARN] ({idx}/{len(columns)}) not in _PREFIX_INV_VALUE_MAP: column: {column} prefix: {prefix}')
            continue

        inv_value_map = _PREFIX_INV_VALUE_MAP[prefix]
        if var_name not in inv_value_map:
            print(f'[WARN] ({idx}/{len(columns)}) not in _INV_VALUE_MAP: {var_name}')
            continue
        if inv_value_map[var_name] == COMBINE_harmonizer.to_inv_text:
            # print(f'[INFO] ({idx}/{len(columns)}) pass to_inv_text: {var_name}')
            continue
        df_inv[column] = df_inv[column].apply(inv_value_map[var_name])

    return df_inv

# %%
df_inv = _inv_df(df)
# Out:
# 0it [00:00, ?it/s]
# 670it [00:00, 6699.13it/s]
# 1494it [00:00, 7600.21it/s]
# [WARN] (0/6131) not in _PREFIX_INV_VALUE_MAP: column: _study prefix:
# [WARN] (1/6131) not in _PREFIX_INV_VALUE_MAP: column: center prefix:
# [WARN] (2/6131) not in _PREFIX_INV_VALUE_MAP: column: subjectID prefix:
# [WARN] (3/6131) not in _PREFIX_INV_VALUE_MAP: column: uniqueID prefix:
# 2254it [00:00, 7321.77it/s]
# 2988it [00:00, 7004.17it/s]
# 3947it [00:00, 7892.88it/s]
# 4784it [00:00, 8048.44it/s]
# 5593it [00:00, 7844.84it/s]
# 6131it [00:00, 7544.10it/s]
# [WARN] (5307/6131) not in _INV_VALUE_MAP: MRI_ID
# [WARN] (5308/6131) not in _INV_VALUE_MAP: MRI_ID
# [WARN] (5309/6131) not in _INV_VALUE_MAP: MRI_ID
# [WARN] (5499/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5507/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5584/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5651/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5749/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5793/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5798/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5809/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (5910/6131) not in _INV_VALUE_MAP: uniqueFollowupID
# [WARN] (6117/6131) not in _INV_VALUE_MAP: cordMishap
# [WARN] (6118/6131) not in _INV_VALUE_MAP: uterineRupture
# [WARN] (6119/6131) not in _INV_VALUE_MAP: placentalProblem
# [WARN] (6120/6131) not in _INV_VALUE_MAP: shoulderDystocia
# [WARN] (6121/6131) not in _INV_VALUE_MAP: maternalHemorrhage
# [WARN] (6122/6131) not in _INV_VALUE_MAP: maternalTrauma
# [WARN] (6123/6131) not in _INV_VALUE_MAP: maternalCardioRespiratoryArrest
# [WARN] (6124/6131) not in _INV_VALUE_MAP: maternalSeizure
# [WARN] (6128/6131) not in _INV_VALUE_MAP: deliveryMode

# %%
out_filename = f'{out_dir}/zz-merged-flatten-inv.csv'
df_inv.to_csv(out_filename, index=False)
