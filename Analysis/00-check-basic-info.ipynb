# %%
import pandas as pd
pd.options.mode.copy_on_write = True
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
import os

from tqdm import tqdm

import itertools

import COMBINE_harmonizer
from COMBINE_harmonizer import cfg

# %% [markdown]
# ## 01. init

# %%
root_dir = '../'

# %%
COMBINE_harmonizer.init(f'{root_dir}/config.yaml')

# %%
input_dir = f"{cfg.config['out_dir']}/out-publish-normalized"
out_dir = f"{cfg.config['out_dir']}/stats"

# %% [markdown]
# ### 01-1. data-dict

# %%
data_dict_filename = f"{root_dir}/{COMBINE_harmonizer.DATA_DICTIONARY_EXCEL}"
df_data_dict_main = COMBINE_harmonizer.load_data_dict(data_dict_filename, COMBINE_harmonizer.SHEET_MAIN)
df_data_dict_follow_up = COMBINE_harmonizer.load_data_dict(data_dict_filename, COMBINE_harmonizer.SHEET_FOLLOW_UP)
df_data_dict_derived_data = COMBINE_harmonizer.load_data_dict(data_dict_filename, COMBINE_harmonizer.SHEET_DERIVED_DATA)

df_data_dict_main['sheet'] = COMBINE_harmonizer.SHEET_MAIN
df_data_dict_follow_up['sheet'] = COMBINE_harmonizer.SHEET_FOLLOW_UP
df_data_dict_derived_data['sheet'] = COMBINE_harmonizer.SHEET_DERIVED_DATA

for idx in ['LH', 'OC']:
    df_data_dict_main[idx] = df_data_dict_main[idx].astype('O')
    df_data_dict_main[idx] = df_data_dict_main[idx].fillna('')
    df_data_dict_follow_up[idx] = df_data_dict_follow_up[idx].astype('O')
    df_data_dict_follow_up[idx] = df_data_dict_follow_up[idx].fillna('')
    df_data_dict_derived_data[idx] = df_data_dict_derived_data[idx].astype('O')
    df_data_dict_derived_data[idx] = df_data_dict_derived_data[idx].fillna('')

df_data_dict = pd.concat([df_data_dict_main, df_data_dict_follow_up, df_data_dict_derived_data])
df_data_dict = df_data_dict.drop_duplicates(['sheet', COMBINE_harmonizer.DATA_DICT_VAR_NAME])

# %% [markdown]
# ### 01-1-1. var-name => LH / OC map

# %%
def _var_name_map(df):
    LH_map = {each['Standardized_VariableNames_Dictionary']: each['LH'] for idx, each in df.iterrows()}
    OC_map = {each['Standardized_VariableNames_Dictionary']: each['OC'] for idx, each in df.iterrows()}
    the_type_map = {each['Standardized_VariableNames_Dictionary']: each['type'] for idx, each in df.iterrows()}

    return {'LH': LH_map, 'OC': OC_map, 'the_type': the_type_map}

_DATA_DICT_MAP = {
    COMBINE_harmonizer.SHEET_MAIN: _var_name_map(df_data_dict_main),
    COMBINE_harmonizer.SHEET_FOLLOW_UP: _var_name_map(df_data_dict_follow_up),
    COMBINE_harmonizer.SHEET_DERIVED_DATA: _var_name_map(df_data_dict_derived_data),
}

# %% [markdown]
# #### 01-1-1-1. XXX hack for _DATA_DICT_MAP-main

# %%
_data_dict_map_main_LH = {
    '_study': 'LH',
    'pre_TemperatureMinDate': 'L6ARDDT',
    'pre_TemperatureMinTime': 'L6ARDTM',
    'pre_SkinTemperatureMin_C': 'L6ASKINT',
    'pre_AxillaryTemperatureMin_C': 'L6AAXILT',
    'pre_EsophagealTemperatureMin_C': 'L6AESPHT',
    'pre_ServoSetMin_C': 'L6ASVOSP',
    'pre_TemperatureMaxDate': 'L6ARDDT',
    'pre_TemperatureMaxTime': 'L6ARDTM',
    'pre_SkinTemperatureMax_C': 'L6ASKINT',
    'pre_AxillaryTemperatureMax_C': 'L6AAXILT',
    'pre_EsophagealTemperatureMax_C': 'L6AESPHT',
    'pre_ServoSetMax_C': 'L6ASVOSP',

    'pre_CardioDate': 'LH6CVRDT',
    'pre_CardioTime': 'LH6CVRTM',
    'pre_CardioSystolicBloodPressure_mmHg': 'LH6CVBPS',
    'pre_CardioDiastolicBloodPressure_mmHg': 'LH6CVBPD',
    'pre_CardioHeartRate_BPM': 'LH6CVHR',
    'pre_CardioVolumeExpand': 'LH6CVVE',
    'pre_CardioInotropicAgent': 'LH6CVIA',
    'pre_CardioBloodTransfusion': 'LH6CVBT',
    'pre_CardioPlatelets': 'LH6CVPLT',

    'pre_OtherMedTargetDate': 'LH6OMTDT',
    'pre_OtherMedTargetTime': 'LH6OMTTM',
    'pre_Anticonvulsants': 'LH6OMACV',
    'pre_Anticonvulsants1': 'LH6OMAC1',
    'pre_Anticonvulsants2': 'LH6OMAC2',
    'pre_Anticonvulsants3': 'LH6OMAC3',
    'pre_Analgesics': 'LH6OMAGS',
    'pre_AnalgesicsSedatives1': 'LH6OMAG1',
    'pre_AnalgesicsSedatives2': 'LH6OMAG2',
    'pre_AnalgesicsSedatives3': 'LH6OMAG3',
    'pre_Antipyretics': 'LH6OMAPY',
    'pre_Antipyretics1': 'LH6OMAP1',
    'pre_Antipyretics2': 'LH6OMAP2',
    'pre_Antipyretics3': 'LH6OMAP3',
    'pre_Paralytics': 'LH6OMNBA',
    'pre_Paralytics1': 'LH6OMNB1',
    'pre_Paralytics2': 'LH6OMNB2',
    'pre_Paralytics3': 'LH6OMNB3',
    'pre_OtherMedFluidIntake_ccPerKg': 'LH6OMFI',
    'pre_OtherMedUrineOutput_ccPerKg': 'LH6OMUO',

    'pre_HeadSonogram': 'LH9HSONO',
    'pre_HeadSonogramDate': 'LH9HSDAT',
    'pre_HeadSonogramTime': 'LH9HSTIM',
    'pre_HeadSonogramResult1': 'LH9HSREA',
    'pre_HeadSonogramResult2': 'LH9HSREB',
    'pre_HeadSonogramResult3': 'LH9HSREC',
    'pre_HeadSonogramResult4': 'LH9HSRED',
    'pre_HeadSonogramResult5': 'LH9HSREE',
    'pre_HeadSonogramResult6': 'LH9HSREF',
    'pre_HeadSonogramResult7': 'LH9HSREG',
    'pre_HeadSonogramResult8': 'LH9HSREH',
    'pre_HeadSonogramResultText': 'LH9HSRES',
    'pre_HeadCT': 'LH9HCT',
    'pre_HeadCTDate': 'LH9HCDAT',
    'pre_HeadCTTime': 'LH9HCTIM',
    'pre_HeadCTResult1': 'LH9HCREA',
    'pre_HeadCTResult2': 'LH9HCREB',
    'pre_HeadCTResult3': 'LH9HCREC',
    'pre_HeadCTResult4': 'LH9HCRED',
    'pre_HeadCTResult5': 'LH9HCREE',
    'pre_HeadCTResult6': 'LH9HCREF',
    'pre_HeadCTResult7': 'LH9HCREG',
    'pre_HeadCTResult8': 'LH9HCREH',
    'pre_HeadCTResultText': 'LH9HCRES',
    'pre_BrainMRI': 'LH9MRI',
    'pre_BrainMRIDate': 'LH9BMDAT',
    'pre_BrainMRITime': 'LH9BMTIM',
    'pre_BrainMRIResult1': 'LH9BMREA',
    'pre_BrainMRIResult2': 'LH9BMREB',
    'pre_BrainMRIResult3': 'LH9BMREC',
    'pre_BrainMRIResult4': 'LH9BMRED',
    'pre_BrainMRIResult5': 'LH9BMREE',
    'pre_BrainMRIResult6': 'LH9BMREF',
    'pre_BrainMRIResult7': 'LH9BMREG',
    'pre_BrainMRIResult8': 'LH9BMREH',
    'pre_BrainMRIResultText': 'LH9BMRES',

    'positiveCultureNumber': '1',

    'post_HeadSonogram': 'LH9HSONO',
    'post_HeadSonogramDate': 'LH9HSDAT',
    'post_HeadSonogramTime': 'LH9HSTIM',
    'post_HeadSonogramResult1': 'LH9HSREA',
    'post_HeadSonogramResult2': 'LH9HSREB',
    'post_HeadSonogramResult3': 'LH9HSREC',
    'post_HeadSonogramResult4': 'LH9HSRED',
    'post_HeadSonogramResult5': 'LH9HSREE',
    'post_HeadSonogramResult6': 'LH9HSREF',
    'post_HeadSonogramResult7': 'LH9HSREG',
    'post_HeadSonogramResult8': 'LH9HSREH',
    'post_HeadSonogramResultText': 'LH9HSRES',
    'post_HeadCT': 'LH9HCT',
    'post_HeadCTDate': 'LH9HCDAT',
    'post_HeadCTTime': 'LH9HCTIM',
    'post_HeadCTResult1': 'LH9HCREA',
    'post_HeadCTResult2': 'LH9HCREB',
    'post_HeadCTResult3': 'LH9HCREC',
    'post_HeadCTResult4': 'LH9HCRED',
    'post_HeadCTResult5': 'LH9HCREE',
    'post_HeadCTResult6': 'LH9HCREF',
    'post_HeadCTResult7': 'LH9HCREG',
    'post_HeadCTResult8': 'LH9HCREH',
    'post_HeadCTResultText': 'LH9HCRES',
    'post_BrainMRI': 'LH9MRI',
    'post_BrainMRIDate': 'LH9BMDAT',
    'post_BrainMRITime': 'LH9BMTIM',
    'post_BrainMRIResult1': 'LH9BMREA',
    'post_BrainMRIResult2': 'LH9BMREB',
    'post_BrainMRIResult3': 'LH9BMREC',
    'post_BrainMRIResult4': 'LH9BMRED',
    'post_BrainMRIResult5': 'LH9BMREE',
    'post_BrainMRIResult6': 'LH9BMREF',
    'post_BrainMRIResult7': 'LH9BMREG',
    'post_BrainMRIResult8': 'LH9BMREH',
    'post_BrainMRIResultText': 'LH9BMRES',

    'statusDate': 'LH12DCDT\nLH12TRDT\nLH12DTDT',
}

_data_dict_map_main_OC = {
    '_study': 'OC',
    'pre_CardioDate': 'OC7CVDT',
    'pre_CardioTime': 'OC7CVTM',
    'pre_CardioSystolicBloodPressure_mmHg': 'OC7CBPS',
    'pre_CardioDiastolicBloodPressure_mmHg': 'OC7CBPD',
    'pre_CardioHeartRate_BPM': 'OC7CVHR',
    'pre_CardioVolumeExpand': 'OC7CVVE',
    'pre_CardioInotropicAgent': 'OC7CVIA',
    'pre_CardioBloodTransfusion': 'OC7CVBT',
    'pre_CardioPlatelets': 'OC7CPLT',

    'pre_Anticonvulsants1': 'OC8OMAC1',
    'pre_Anticonvulsants2': 'OC8OMAC2',
    'pre_Anticonvulsants3': 'OC8OMAC3',
    'pre_AnalgesicsSedatives1': 'OC8OMAG1',
    'pre_AnalgesicsSedatives2': 'OC8OMAG2',
    'pre_AnalgesicsSedatives3': 'OC8OMAG3',
    'pre_Antipyretics1': 'OC8OMAP1',
    'pre_Antipyretics2': 'OC8OMAP2',
    'pre_Antipyretics3': 'OC8OMAP3',
    'pre_Paralytics1': 'OC8OMNB1',
    'pre_Paralytics2': 'OC8OMNB2',
    'pre_Paralytics3': 'OC8OMNB3',
    'pre_OtherMedFluidIntake_ccPerKg': 'OC8OMFI',
    'pre_OtherMedUrineOutput_ccPerKg': 'OC8OMUO',

    'pre_HeadSonogram': 'OC12HSON',
    'pre_HeadSonogramDate': 'OC12HSDA',
    'pre_HeadSonogramTime': 'OC12HSTM',
    'pre_HeadSonogramResult1': 'OC12HSRA',
    'pre_HeadSonogramResult2': 'OC12HSRB',
    'pre_HeadSonogramResult3': 'OC12HSRC',
    'pre_HeadSonogramResult4': 'OC12HSRD',
    'pre_HeadSonogramResult5': 'OC12HSRE',
    'pre_HeadSonogramResult6': 'OC12HSRF',
    'pre_HeadSonogramResult7': 'OC12HSRG',
    'pre_HeadSonogramResult8': 'OC12HSRH',
    'pre_HeadSonogramResultText': 'OC12HSRS',
    'pre_HeadCT': 'OC12HCT',
    'pre_HeadCTDate': 'OC12HCDA',
    'pre_HeadCTTime': 'OC12HCTM',
    'pre_HeadCTResult1': 'OC12HCRA',
    'pre_HeadCTResult2': 'OC12HCRB',
    'pre_HeadCTResult3': 'OC12HCRC',
    'pre_HeadCTResult4': 'OC12HCRD',
    'pre_HeadCTResult5': 'OC12HCRE',
    'pre_HeadCTResult6': 'OC12HCRF',
    'pre_HeadCTResult7': 'OC12HCRG',
    'pre_HeadCTResult8': 'OC12HCRH',
    'pre_HeadCTResultText': 'OC12HCRS',
    'pre_BrainMRI': 'OC12MRI',
    'pre_BrainMRIDate': 'OC12BMDA',
    'pre_BrainMRITime': 'OC12BMTM',
    'pre_BrainMRIResult1': 'OC12BMRA',
    'pre_BrainMRIResult2': 'OC12BMRB',
    'pre_BrainMRIResult3': 'OC12BMRC',
    'pre_BrainMRIResult4': 'OC12BMRD',
    'pre_BrainMRIResult5': 'OC12BMRE',
    'pre_BrainMRIResult6': 'OC12BMRF',
    'pre_BrainMRIResult7': 'OC12BMRG',
    'pre_BrainMRIResult8': 'OC12BMRH',
    'pre_BrainMRIResultText': 'OC12BMRS',

    'bloodGasTimeSlot': 'OC7INTV',
    'hematologyTimeSlot': 'OC8INTV',
    'hematologyDate': 'OC8RSRDT',
    'hematologyTime': 'OC8RSRTM',
    'otherMedTimeSlot': 'OC8INTV',

    'post_HeadSonogram': 'OC12HSON',
    'post_HeadSonogramDate': 'OC12HSDA',
    'post_HeadSonogramTime': 'OC12HSTM',
    'post_HeadSonogramResult1': 'OC12HSRA',
    'post_HeadSonogramResult2': 'OC12HSRB',
    'post_HeadSonogramResult3': 'OC12HSRC',
    'post_HeadSonogramResult4': 'OC12HSRD',
    'post_HeadSonogramResult5': 'OC12HSRE',
    'post_HeadSonogramResult6': 'OC12HSRF',
    'post_HeadSonogramResult7': 'OC12HSRG',
    'post_HeadSonogramResult8': 'OC12HSRH',
    'post_HeadSonogramResultText': 'OC12HSRS',
    'post_HeadCT': 'OC12HCT',
    'post_HeadCTDate': 'OC12HCDA',
    'post_HeadCTTime': 'OC12HCTM',
    'post_HeadCTResult1': 'OC12HCRA',
    'post_HeadCTResult2': 'OC12HCRB',
    'post_HeadCTResult3': 'OC12HCRC',
    'post_HeadCTResult4': 'OC12HCRD',
    'post_HeadCTResult5': 'OC12HCRE',
    'post_HeadCTResult6': 'OC12HCRF',
    'post_HeadCTResult7': 'OC12HCRG',
    'post_HeadCTResult8': 'OC12HCRH',
    'post_HeadCTResultText': 'OC12HCRS',
    'post_BrainMRI': 'OC12MRI',
    'post_BrainMRIDate': 'OC12BMDA',
    'post_BrainMRITime': 'OC12BMTM',
    'post_BrainMRIResult1': 'OC12BMRA',
    'post_BrainMRIResult2': 'OC12BMRB',
    'post_BrainMRIResult3': 'OC12BMRC',
    'post_BrainMRIResult4': 'OC12BMRD',
    'post_BrainMRIResult5': 'OC12BMRE',
    'post_BrainMRIResult6': 'OC12BMRF',
    'post_BrainMRIResult7': 'OC12BMRG',
    'post_BrainMRIResult8': 'OC12BMRH',
    'post_BrainMRIResultText': 'OC12BMRS',

    'discontinueParentsWithdraw': 'OC6NCEPR',
    'discontinuePhysicianWithdraw': 'OC6NCEPR',
    'discontinueAdverseEvent': 'OC6NCEPR',
    'discontinueECMO': 'OC6NCEPR',
    'discontinueDNR': 'OC6NCEPR',
    'discontinueWdrawSupport': 'OC6NCEPR',
    'discontinueDeath': 'OC6NCEPR',
    'discontinueOther': 'OC6NCEPR',

    'status': 'OC13STAT',
    'transferDate': 'OC13DDAT',
    'transferWeight_g': 'OC13WGHT',
    'transferLength_cm': 'OC13LGTH',
    'transferHeadCircumference_cm': 'OC13CIRC',
}

_DATA_DICT_MAP[COMBINE_harmonizer.SHEET_MAIN]['LH'].update(_data_dict_map_main_LH)
_DATA_DICT_MAP[COMBINE_harmonizer.SHEET_MAIN]['OC'].update(_data_dict_map_main_OC)

# %%
_DATA_DICT_MAP[COMBINE_harmonizer.SHEET_DERIVED_DATA]['LH']
# Out:
# {'center': 'CENTER',
#  'followupCenter': 'fcenter',
#  'subjectID': 'HTHRM_ID',
#  'followupID': 'LHFOLNUM',
#  'acidosis': '',
#  'ageDeath_day': '',
#  'ageRand_hr': '',
#  'baselineAnticonvulsants': '',
#  'dischargeAnticonvulsants': 'any_antic',
#  'inotropicAgent': '',
#  'perinatalSentinelEvent': '',
#  'dischargeSeizure': 'any_seiz',
#  'Apgar10minLt5': '',
#  'Apgar10minLte5': '',
#  'Apgar5minLte5': '',
#  'bloodGasBaseDeficit_mEqPerL': '',
#  'bloodGasPH': '',
#  'emergencyCSection': '',
#  'encephalopathyLevel': '',
#  'inotropicAgentBaseline': '',
#  'maleSex': '',
#  'maternalEducation': '',
#  'motherInsurancePublic': '',
#  'motherRace': '',
#  'treatmentAssignmentDuration_hr': '',
#  'treatmentAssignmentTemperature': '',
#  'bloodGasBaseDeficit_mEqPerLSrc': '',
#  'bloodGasPHSrc': '',
#  'usualCoolingTreatmentGroup': '',
#  'blindness': 'blindness',
#  'moderateSevereCerebralPalsy': 'modsevcp',
#  'cerebralPalsy': 'cp_out',
#  'gastrostomyTube': '',
#  'grossMotorFunctionLevel': 'gross',
#  'hearingImpairedWithAid': 'hear_imp',
#  'hearingImpairedLevel': 'hearing',
#  'multipleImpairment': '',
#  'afterDischargeSeizure': 'seiz_fu',
#  'lengthOfStay_day': '',
#  'flagAdjudicatedOutcome': '',
#  'normalPrimaryOutcome': 'all_norm',
#  'BayleyIIILanguage': '',
#  'BayleyIIIMotor': '',
#  'BayleyIIICognitive': 'bayley3',
#  'deathBeforeFollowup': 'death18',
#  'deathBeforeDischarge': 'hosp_die',
#  'disabilityLevelSurvivor': 'disab_4',
#  'disabilityLevel': 'disab_die4',
#  'moderateSevereDisabilityOrDeath': 'disab_die',
#  'moderateSevereDisabilitySurvivor': 'disab_ms',
#  'disabilityLevelDeath': '',
#  'outcomeGroup': '',
#  'pre_NeuroExamLevelConsciousnessScore': '',
#  'pre_NeuroExamSpontaneousActivityScore': '',
#  'pre_NeuroExamPostureScore': '',
#  'pre_NeuroExamToneScore': '',
#  'pre_NeuroExamSuckScore': '',
#  'pre_NeuroExamMoroScore': '',
#  'pre_NeuroExamPupilsScore': '',
#  'pre_NeuroExamHeartRateScore': '',
#  'pre_NeuroExamRespirationScore': '',
#  'pre_NeuroExamReflexScore': '',
#  'pre_NeuroExamANSScore': '',
#  'pre_TotalModifiedSarnatScore': '',
#  'post_NeuroExamLevelConsciousnessScore': '',
#  'post_NeuroExamSpontaneousActivityScore': '',
#  'post_NeuroExamPostureScore': '',
#  'post_NeuroExamToneScore': '',
#  'post_NeuroExamSuckScore': '',
#  'post_NeuroExamMoroScore': '',
#  'post_NeuroExamPupilsScore': '',
#  'post_NeuroExamHeartRateScore': '',
#  'post_NeuroExamRespirationScore': '',
#  'post_NeuroExamReflexScore': '',
#  'post_NeuroExamANSScore': '',
#  'post_TotalModifiedSarnatScore': '',
#  'dischargeNeuroExamLevelConsciousnessScore': '',
#  'dischargeNeuroExamSpontaneousActivityScore': '',
#  'dischargeNeuroExamPostureScore': '',
#  'dischargeNeuroExamToneScore': '',
#  'dischargeNeuroExamSuckScore': '',
#  'dischargeNeuroExamMoroScore': '',
#  'dischargeNeuroExamPupilsScore': '',
#  'dischargeNeuroExamHeartRateScore': '',
#  'dischargeNeuroExamRespirationScore': '',
#  'dischargeNeuroExamReflexScore': '',
#  'dischargeNeuroExamANSScore': '',
#  'dischargeTotalModifiedSarnatScore': '',
#  'MRINRNPatternOfInjuryMerge': '',
#  'MRINRNPatternOfInjuryAvg': '',
#  'MRINRNPatternOfInjuryMax': '',
#  'MRI2LevelPatternOfInjury': 'MRI_PCLASS',
#  'MRIAge_day': 'MRI_AGED',
#  'MRIOverallDiagnosis': '',
#  'MRINRNPatternOfInjury': 'MRI_PATTERN',
#  'MRIDate': 'MRI_DATE',
#  'MRITime': 'MRI_TIME',
#  'MRINotDone': 'MRI_NOTDONE',
#  'MRIUnread': 'MRI_UNREAD',
#  'MRIAnalysis': '',
#  'abnormalMRIResult': '',
#  'MRINRNPatternOfInjuryWSvsBGTPLIC': '',
#  'cerebralLesion': '',
#  'cerebellarLesion': '',
#  'basalGangliaLesion': '',
#  'brainstemLesion': '',
#  'corpusCallosumLesion': '',
#  'cerebralLesionLobe': '',
#  'coronaRadiataLesion': '',
#  'edema': '',
#  'extraAxialLesion': '',
#  'extent': '',
#  'frontalParietalLesion': '',
#  'frontalLesion': '',
#  'lateralHemisphericDevastation': '',
#  'hippocampusLesion': '',
#  'hypothalamusLesion': '',
#  'insularLesion': '',
#  'laterality': '',
#  'BGT': '',
#  'PLIC': '',
#  'watershed': '',
#  'whiteMatterInjury': '',
#  'occipitalLesion': '',
#  'opticChiasmLesion': '',
#  'otherLesion': '',
#  'otherCerebralLesion': '',
#  'parasagittalLesion': '',
#  'parietalLesion': '',
#  'preirolandicLesion': '',
#  'perisylvianLesion': '',
#  'pituitaryLesion': '',
#  'parietalOccipitalLesion': '',
#  'parietalTemporalLesion': '',
#  'scalpLesion': '',
#  'thalamusLesion': '',
#  'temporalLesion': '',
#  'temporalOccipitalLesion': '',
#  'cerebralAtrophy': '',
#  'cererbalAtrophyQualAssessCC': '',
#  'cerebralAtrophyGlobalLocal': '',
#  'vascularTerritoryInfarction': '',
#  'vascularTerritoryInfarctionLeft': 'MRI_INFARL',
#  'vascularTerritoryInfarctionRight': 'MRI_INFARR',
#  'hemisphericDevastation': '',
#  'ventricularDilatation': '',
#  'vascularLesion': '',
#  'intraventricularLesion': ''}

# %% [markdown]
# ### 01-1-2. type map

# %%
the_types = list(filter(lambda x: not pd.isnull(x), df_data_dict['type'].unique()))
the_types
# Out:
# ['center',
#  'text',
#  'date',
#  'int',
#  'bool',
#  'consentStatus',
#  'time',
#  'treatmentAssign',
#  'blanketType',
#  'race',
#  'ethnicity',
#  'maritalStatus',
#  'education',
#  'insurance',
#  'deliveryMode',
#  'antibiotics',
#  'encephalopathyLevel',
#  'infantAge',
#  'float',
#  'infantSex',
#  'spontaneousRespirationTime',
#  'cordBloodGasSrc',
#  'bloodGasSrc',
#  'targetTreatmentTemperature',
#  'respiratorySupportType',
#  'positiveCultureSrc',
#  'positiveCultureOrganism',
#  'anticonvulsants',
#  'analgesics',
#  'antipyretics',
#  'paralytics',
#  'imaging',
#  'noNeuroExamReason',
#  'signOfHIELvlOfCons',
#  'signOfHIESpontaneousActivity',
#  'signOfHIEPosture',
#  'signOfHIETone',
#  'signOfHIESuck',
#  'signOfHIEMoro',
#  'signOfHIEPupils',
#  'signOfHIEHeartRate',
#  'signOfHIERespiratory',
#  'elevatedTempDevice',
#  'elevatedTempDeviceMode',
#  'elevatedTempNoBathReason',
#  'bradycardiaEKGResult',
#  'bradycardiaDuration',
#  'bradycardiaHeartRateMin',
#  'SAEAttributable',
#  'SAEAction',
#  'SAEOutcome',
#  'SAEAlterationSkinIntegrity',
#  'violationNature',
#  'violationCircumstance',
#  'interruptReason',
#  'coolAfterIntervention',
#  'MRIObtainWindow',
#  'MRINoObtainReason',
#  'MRINRNPatternOfInjury',
#  'MRIReader',
#  'MRIOverallDiagnosis',
#  'MRIAbnormalRegion',
#  'MRIAbnormalSide',
#  'MRIAbnormalGMWM',
#  'MRIAbnormalExtent',
#  'MRIAbnormalType',
#  'MRICerebralAtrophyGlobalLocal',
#  'MRICerebralAtrophyRegion',
#  'MRISeverity',
#  'MRIALICPLICSeverity',
#  'MRIInjurySeverity',
#  'MRINRNPatternOfInjuryExtent',
#  'MRINRNPatternOfInjuryLateral',
#  'status',
#  'transferReason',
#  'transferOutcome',
#  'deathCause',
#  'deathSrc',
#  'dischargeNeuroExamStatus',
#  'surgery',
#  'birthDefect',
#  'relationship',
#  'livingArrange',
#  'totalIncome',
#  'language',
#  'receive',
#  'homeCareLocation',
#  'babysitterRelation',
#  'interviewLocation',
#  'eyeSurgeryReason',
#  'medicationUse',
#  'eye',
#  'vision',
#  'hearing',
#  'hearingImpaired',
#  'hearingAid',
#  'swallow',
#  'passiveMuscleTone',
#  'handPreference',
#  'protectiveReaction',
#  'limbMovement',
#  'deepTendonReflex',
#  'ankleClonus',
#  'plantarReflex',
#  'axisHeadNeck',
#  'axisTrunk',
#  'lowerLimbFunction',
#  'upperLimbFunction',
#  'handFunction',
#  'cerebralPalsyClass',
#  'examQuality',
#  'examFactorAffecting',
#  'grossMotorFunctionLevel',
#  'BayleyIIIReasonNoSuccess',
#  'readmissionTimePeriod',
#  'readmissionPrimaryCause',
#  'readmissionLengthOfStay',
#  'followupStatus',
#  'reasonLossFollowUp',
#  'childHealth',
#  'chartReview',
#  'education2',
#  'race2',
#  'bloodGasSrc2',
#  'severity',
#  'flagAdjudicatedOutcome',
#  'outcomeGroup',
#  'MRI2LevelPatternOfInjury',
#  'MRINRNPatternOfInjuryWSvsBGT',
#  'lesion',
#  'extent',
#  'lateral',
#  'BGT',
#  'PLIC',
#  'watershed',
#  'whiteMatterInjury',
#  'cererbalAtrophyQualAssessCC',
#  'cerebralAtrophyGlobalLocal',
#  'ventricularDilatation']

# %%
excel = pd.ExcelFile(data_dict_filename)

def _type_map(the_type):
    if the_type == 'center':
        return 'text'
    elif the_type == 'text':
        return 'text'
    elif the_type == 'date':
        return 'date'
    elif the_type == 'int':
        return 'number'
    elif the_type == 'bool':
        return 'boolean'
    elif the_type == 'time':
        return 'time'
    elif the_type == 'float':
        return 'number'
    else:
        df_by_type = pd.read_excel(excel, the_type)
        if '_inv' in df_by_type:
            return 'ordinal'
        else:
            return 'nomial'

_TYPE_MAP = {each: _type_map(each) for each in the_types}

# %%
df_data_dict_main
# Out:
#              Category         Subcategory  \
# 0    Pre-intervention            Identity
# 1    Pre-intervention            Identity
# 2    Pre-intervention           Screening
# 3    Pre-intervention           Screening
# 4    Pre-intervention           Screening
# ..                ...                 ...
# 974    NICU Discharge  Limitation of Care
# 975    NICU Discharge  Limitation of Care
# 976    NICU Discharge  Limitation of Care
# 977    NICU Discharge  Limitation of Care
# 978    NICU Discharge  Limitation of Care
#
#      Standardized_VariableNames_Dictionary    type  \
# 0                                   center  center
# 1                                subjectID    text
# 2                                   siteID    text
# 3                                birthDate    date
# 4                              birthNumber     int
# ..                                     ...     ...
# 974     limitCareNoFurtherChestCompression    bool
# 975  limitCareNoFurtherEmergencyMedication    bool
# 976                           limitCareDNR    bool
# 977                       limitCareDNRDate    date
# 978                       limitCareDNRTime    time
#
#                                   Variable_Description #studies w/ this var  \
# 0                                              Center:                    2
# 1                            Hypothermia ID (study id)                    2
# 2                                          Site number                    2
# 3                                           birth date                    2
# 4                                         birth number                    2
# ..                                                 ...                  ...
# 974                      No further chest compressions                    2
# 975  No further use of emergency medications (epi, ...                    2
# 976                             Was there a DNR Order?                    2
# 977                                  Date of DNR order                    2
# 978                                  Time of DNR order                    2
#
#                                          redcap comment        LH        OC  \
# 0                                        center     NaN    CENTER    CENTER
# 1                                    subject_id     NaN  HTHRM_ID  HTHRM_ID
# 2                                       site_id     NaN    SITENM    SITENM
# 3                                    birth_date     NaN   BIRTHDT   BIRTHDT
# 4                                  birth_number     NaN   BIRTHNM   BIRTHNM
# ..                                          ...     ...       ...       ...
# 974     limit_care_no_further_chest_compression     NaN   LH12LCC  OC13NFCC
# 975  limit_care_no_further_emergency_medication     NaN   LH12LEM  OC13NFEM
# 976                              limit_care_dnr     NaN   LH12DNR   OC13DNR
# 977                         limit_care_dnr_date     NaN  LH12DDNR  OC13DNRD
# 978                         limit_care_dnr_time     NaN  LH12TDNR  OC13DNRT
#
#     sheet
# 0    main
# 1    main
# 2    main
# 3    main
# 4    main
# ..    ...
# 974  main
# 975  main
# 976  main
# 977  main
# 978  main
#
# [979 rows x 11 columns]

# %% [markdown]
# ## 02-01. check columns

# %%
def _basic_info(filename_info):
    filename = filename_info['name']
    full_filename = f'{input_dir}/{filename}'
    df = pd.read_csv(full_filename)

    valid_columns = list(filter(lambda x: x not in COMBINE_harmonizer.RESERVED_COLUMNS and x.endswith('.orig') == False, df.columns))
    exclude_columns = filename_info.get('exclude_columns', None)
    if exclude_columns is None:
        exclude_columns = []
    valid_columns = list(filter(lambda x: x not in exclude_columns, valid_columns))

    return {
        'filename': filename,
        'len-columns': len(valid_columns),
        'columns': valid_columns,
    }

valid_filename_infos = list(filter(lambda x: x.get('is_merge', True), COMBINE_harmonizer.FILENAME_INFOS))
df = pd.DataFrame([_basic_info(filename_info) for filename_info in tqdm(valid_filename_infos)])

out_filename = f'{out_dir}/20-01-basic-info-len-columns.csv'
df.to_csv(out_filename, index=False)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
#   7%|▋         | 5/70 [00:00<00:01, 41.75it/s]
#  16%|█▌        | 11/70 [00:00<00:01, 31.40it/s]
#  21%|██▏       | 15/70 [00:00<00:01, 31.02it/s]
#  36%|███▌      | 25/70 [00:00<00:00, 48.64it/s]
#  47%|████▋     | 33/70 [00:00<00:00, 55.47it/s]
#  56%|█████▌    | 39/70 [00:00<00:00, 45.88it/s]
#  69%|██████▊   | 48/70 [00:00<00:00, 56.03it/s]
#  80%|████████  | 56/70 [00:01<00:00, 59.86it/s]
#  93%|█████████▎| 65/70 [00:01<00:00, 65.70it/s]
# 100%|██████████| 70/70 [00:01<00:00, 55.41it/s]

# %%
df
# Out:
#                             filename  len-columns  \
# 0                01-02-screening.csv           32
# 1    01-03-maternal-demographics.csv           12
# 2        01-04-pregnancy-history.csv            9
# 3           01-05-labor-delivery.csv           30
# 4                    01-06-birth.csv           48
# ..                               ...          ...
# 65                     31-03-mri.csv            3
# 66                     31-04-pse.csv            0
# 67  31-05-disability-level-death.csv            1
# 68      31-06-emergency-csection.csv            0
# 69          31-07-length-of-stay.csv            1
#
#                                               columns
# 0   [birthNumber, screenComment, coreTempLess32p5C...
# 1   [motherAge_year, motherRace, motherRaceOther1,...
# 2   [gravida, parity, multipleBirth, numFetus, pre...
# 3   [maternalAdmissionDate, maternalAdmissionTime,...
# 4   [encephalopathyLevel, randomInfantAge, birthWe...
# ..                                                ...
# 65  [MRINRNPatternOfInjuryMerge, MRINRNPatternOfIn...
# 66                                                 []
# 67                             [disabilityLevelDeath]
# 68                                                 []
# 69                                 [lengthOfStay_day]
#
# [70 rows x 3 columns]

# %% [markdown]
# ## 02-02. variable info

# %%
def _variable_infos(filename_info):
    filename = filename_info['name']
    full_filename = f'{input_dir}/{filename}'
    df = pd.read_csv(full_filename, dtype='O')

    valid_columns = list(filter(lambda x: x not in COMBINE_harmonizer.RESERVED_COLUMNS and x.endswith('.orig') == False, df.columns))

    exclude_columns = filename_info.get('exclude_columns', None)
    if exclude_columns is None:
        exclude_columns = []
    valid_columns = list(filter(lambda x: x not in exclude_columns, valid_columns))

    data_dict_type = filename_info['data_dict']

    return [_variable_info_by_column(each, df[each], filename, data_dict_type) for each in valid_columns]

def _variable_info_by_column(column: str, the_series: pd.Series, filename: str, data_dict_type: str)-> dict:
    the_len = len(the_series)
    len_empty = the_series.isnull().sum()
    var_name_map = _DATA_DICT_MAP[data_dict_type]
    LH_name = var_name_map['LH'][column]
    OC_name = var_name_map['OC'][column]
    the_type = var_name_map['the_type'][column]

    display_type = _TYPE_MAP[the_type]

    return {'filename': filename, 'variable': column, 'with-value': the_len - len_empty, 'empty': len_empty, 'total': the_len, 'LH': LH_name, 'OC': OC_name, 'display_type': display_type}

valid_filename_infos = list(filter(lambda x: x.get('is_merge', True), COMBINE_harmonizer.FILENAME_INFOS))
df = pd.DataFrame(itertools.chain.from_iterable([_variable_infos(filename_info) for filename_info in tqdm(valid_filename_infos)]))
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
#   7%|▋         | 5/70 [00:00<00:01, 47.74it/s]
#  17%|█▋        | 12/70 [00:00<00:01, 57.05it/s]
#  29%|██▊       | 20/70 [00:00<00:00, 65.18it/s]
#  39%|███▊      | 27/70 [00:00<00:00, 49.98it/s]
#  50%|█████     | 35/70 [00:00<00:00, 57.68it/s]
#  63%|██████▎   | 44/70 [00:00<00:00, 66.03it/s]
#  73%|███████▎  | 51/70 [00:00<00:00, 66.82it/s]
#  83%|████████▎ | 58/70 [00:01<00:00, 52.97it/s]
#  96%|█████████▌| 67/70 [00:01<00:00, 61.22it/s]
# 100%|██████████| 70/70 [00:01<00:00, 57.46it/s]

# %%
df_filename_info = pd.DataFrame(COMBINE_harmonizer.FILENAME_INFOS).rename(columns={'name': 'filename', 'data_dict': 'sheet'})

for idx in ['is_merge', 'exclude_columns']:
    del df_filename_info[idx]
df_merge = df.merge(df_filename_info, on=['filename'], how='left')

df_merge.columns, df_filename_info.columns
# Out:
# (Index(['filename', 'variable', 'with-value', 'empty', 'total', 'LH', 'OC',
#         'display_type', 'sheet', 'subcategory', 'category', 'summary'],
#        dtype='object'),
#  Index(['filename', 'sheet', 'subcategory', 'category', 'summary'], dtype='object'))

# %%
data_dict_columns = ['sheet', COMBINE_harmonizer.DATA_DICT_VAR_NAME, COMBINE_harmonizer.DATA_DICT_VAR_TYPE]
df_data_dict_columns = df_data_dict[data_dict_columns].rename(columns={COMBINE_harmonizer.DATA_DICT_VAR_NAME: 'variable'})

# XXX we use inner join because we care about only the variables in the data dictionary.
df_merge2 = df_merge.merge(df_data_dict_columns, on=['sheet', 'variable'])

out_filename = f'{out_dir}/20-02-basic-info-variables.csv'
df_merge2.to_csv(out_filename, index=False)

# %%
df
# Out:
#                               filename                      variable  \
# 0                  01-02-screening.csv                   birthNumber
# 1                  01-02-screening.csv                 screenComment
# 2                  01-02-screening.csv  coreTempLess32p5COverEq2Hr_e
# 3                  01-02-screening.csv    coreTempLess33p5COver1Hr_e
# 4                  01-02-screening.csv      coreTempLess34COver1Hr_e
# ...                                ...                           ...
# 1340                     31-03-mri.csv    MRINRNPatternOfInjuryMerge
# 1341                     31-03-mri.csv      MRINRNPatternOfInjuryAvg
# 1342                     31-03-mri.csv      MRINRNPatternOfInjuryMax
# 1343  31-05-disability-level-death.csv          disabilityLevelDeath
# 1344          31-07-length-of-stay.csv              lengthOfStay_day
#
#       with-value  empty  total       LH       OC display_type
# 0            532      0    532  BIRTHNM  BIRTHNM       number
# 1             48    484    532           COMMENT         text
# 2             95    437    532           OC2TMP2      boolean
# 3            269    263    532           OC2TEMP      boolean
# 4            168    364    532  LH2TEMP               boolean
# ...          ...    ...    ...      ...      ...          ...
# 1340         458     74    532                        ordinal
# 1341         441     91    532                         number
# 1342         441     91    532                         number
# 1343         498     34    532                        ordinal
# 1344         529      3    532                         number
#
# [1345 rows x 8 columns]

# %% [markdown]
# ## 03. Check Death and Moderate Severe Disability Distribution

# %%
def _load_df(filename):
    full_filename = f'{input_dir}/{filename}'
    df = pd.read_csv(full_filename)

    return df

# %% [markdown]
# ### 03-01. status

# %%
columns = [
    '_study',
    'center',
    'subjectID',
    'uniqueID',
    '20-01:followupID',

    '04-01:status',

    '04-01:dischargeStatus',

    '30-01:blindness',
    '30-01:grossMotorFunctionLevel',
    '30-01:hearingImpairedWithAid',
    '30-01:hearingImpairedLevel',
    '30-01:afterDischargeSeizure',

    '30-02:normalPrimaryOutcome',
    '30-02:deathBeforeDischarge',
    '30-02:deathBeforeFollowup',
    '30-02:moderateSevereDisabilityOrDeath',
    '30-02:moderateSevereDisabilitySurvivor',
    '30-02:disabilityLevel',
    '30-02:BayleyIIICognitive',

    '31-05:disabilityLevelDeath',
]
df = _load_df('zz-merged-flatten.csv')
# Out:
# /var/folders/84/vxdpc5mx2cqdr6zvp8p_tygc0000gn/T/ipykernel_27228/3823679824.py:3: DtypeWarning: Columns (6,7,8,9,10,15,16,17,22,26,33,34,35,36,40,41,49,54,55,56,57,58,64,65,69,72,77,78,79,82,90,106,107,108,109,110,111,112,119,126,137,138,139,140,141,144,164,165,166,167,168,169,172,175,178,181,183,185,188,190,194,199,202,203,204,205,210,211,214,215,216,217,222,223,226,227,228,229,230,234,236,237,249,278,284,290,302,314,326,713,719,725,737,749,761,1210,1211,1233,1234,1235,1236,1237,1238,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1252,1253,1254,1255,1257,1258,1259,1260,1262,1263,1264,1265,1266,1267,1268,1269,1270,1271,1272,1273,1274,1275,1276,1277,1278,1279,1280,1500,1501,1502,1503,1525,1526,1527,1528,1529,1530,1531,1532,1533,1534,1535,1536,1537,1538,1539,1540,1541,1542,1543,1544,1545,1546,1547,1549,1550,1551,1552,1554,1555,1556,1557,1558,1559,1560,1561,1562,1563,1564,1565,1566,1567,1568,1569,1570,1571,1572,1575,1576,1598,1599,1600,1601,1602,1603,1604,1605,1606,1607,1608,1609,1610,1611,1612,1613,1614,1615,1616,1617,1618,1619,1620,1622,1623,1624,1625,1627,1628,1629,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1640,1641,1642,1643,1644,1645,1865,1866,1867,1868,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1914,1915,1916,1917,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,2003,2004,2005,2006,2007,2831,2832,2833,2834,2835,2836,2837,2838,2839,2840,2841,2842,2843,2844,2845,2846,2847,2848,2849,2850,2851,2852,2853,2854,2855,2856,2857,2858,2859,2860,2861,2862,2863,2864,2865,2866,2867,2868,2869,2870,2871,2872,3050,3051,3052,3053,3054,3055,3056,3057,3058,3059,3232,3235,3236,3239,3242,3244,3245,3246,3248,3249,3250,3252,3263,3264,3265,3273,3274,3278,3279,3280,3281,3283,3288,3289,3290,3292,3303,3304,3305,3308,3310,3311,3312,3313,3314,3315,3318,3319,3320,3321,3322,3338,3339,3340,3341,3428,3432,3433,3434,3440,3458,3460,3461,3462,3463,3464,3465,3466,3467,3468,3470,3472,3473,3474,3480,3482,3486,3487,3585,3586,3587,3588,3589,3590,3591,3592,3593,3594,3595,3596,3597,3598,3599,3600,3601,3602,3603,3604,3605,3606,3607,3608,3609,3610,3611,3612,3613,3614,3615,3616,3620,3621,3622,3623,3624,3626,3628,3629,3630,3631,3632,3633,3634,3635,3636,3637,3638,3639,3640,3641,3642,3643,3644,3645,3646,3647,3648,3649,3650,3651,3652,3653,3654,3655,3656,3657,3658,3659,3660,3661,3665,3666,3667,3668,3669,3671,3673,3674,3720,3721,3722,3723,3724,3725,3726,3727,3728,3729,3730,3731,3732,3733,3734,3735,3736,3737,3738,3739,3740,3741,3742,3743,3744,3745,3746,3747,3748,3749,3750,3751,3755,3756,3757,3758,3759,3761,3763,3764,3765,3766,3767,3768,3769,3770,3771,3772,3773,3774,3775,3776,3777,3778,3779,3780,3781,3782,3783,3784,3785,3786,3787,3788,3789,3790,3791,3792,3793,3794,3795,3796,3800,3801,3802,3803,3804,3806,3808,3809,3900,3901,3902,3903,3904,3905,3906,3907,3908,3909,3910,3911,3912,3913,3914,3915,3916,3917,3918,3919,3920,3921,3922,3923,3924,3925,3926,3927,3928,3929,3930,3931,3935,3936,3937,3938,3939,3941,3943,3944,4449,4450,4451,4452,4453,4454,4455,4456,4457,4458,4459,4460,4461,4462,4463,4464,4465,4466,4467,4468,4479,4480,4481,4482,4483,4484,4485,4486,4487,4488,4489,4490,4491,4492,4493,4494,4495,4496,4497,4498,4499,4509,4529,4530,4531,4532,4533,4534,4535,4536,4537,4549,4550,4554,4555,4559,4560,4564,4565,4574,4575,4584,4585,4589,4590,4594,4595,4609,4610,4624,4625,4629,4630,4634,4635,4649,4650,4664,4665,4666,4669,4670,4671,4679,4680,4681,4684,4685,4686,4694,4698,4699,4703,4704,4708,4719,4723,4735,4736,4737,4740,4741,4742,4745,4746,4747,4750,4751,4752,4765,4766,4767,4779,4784,4789,4804,4825,4826,4827,4829,4830,4831,4837,4838,4839,4845,4846,4847,4849,4850,4851,4860,4861,4866,4867,4868,4869,4885,4886,4890,4891,4892,4893,4894,4895,4896,4904,4905,4906,4907,4908,4909,4910,4939,4943,4944,4945,4952,4958,4963,4964,4967,4968,4969,4975,4976,4983,4984,4985,4986,5005,5007,5008,5010,5011,5013,5014,5016,5017,5021,5024,5025,5027,5028,5030,5033,5036,5039,5040, ...
#   df = pd.read_csv(full_filename)

# %%
df
# Out:
#     _study  center subjectID   uniqueID 01-02:siteID  01-02:birthNumber  \
# 0       LH       3     LH087   03:LH087            3                  1
# 1       LH       3     LH088   03:LH088            3                  1
# 2       LH       3     LH092   03:LH092            3                  1
# 3       LH       3     LH094   03:LH094            3                  1
# 4       LH       3     LH098   03:LH098            3                  1
# ..     ...     ...       ...        ...          ...                ...
# 527     OC      31    OC3411  31:OC3411            A                  1
# 528     OC      31    OC3441  31:OC3441            A                  1
# 529     OC      31    OC3471  31:OC3471            A                  1
# 530     OC      31    OC3551  31:OC3551            A                  1
# 531     OC      31    OC3561  31:OC3561            A                  1
#
#     01-02:screenComment 01-02:coreTempLess32p5COverEq2Hr_e  \
# 0                   NaN                                NaN
# 1                   NaN                                NaN
# 2                   NaN                                NaN
# 3                   NaN                                NaN
# 4                   NaN                                NaN
# ..                  ...                                ...
# 527                 NaN                                NaN
# 528                 NaN                                NaN
# 529                 NaN                              False
# 530                 NaN                              False
# 531                 NaN                              False
#
#     01-02:coreTempLess33p5COver1Hr_e 01-02:coreTempLess34COver1Hr_e  ...  \
# 0                                NaN                          False  ...
# 1                                NaN                          False  ...
# 2                                NaN                          False  ...
# 3                                NaN                          False  ...
# 4                                NaN                          False  ...
# ..                               ...                            ...  ...
# 527                            False                            NaN  ...
# 528                            False                            NaN  ...
# 529                              NaN                            NaN  ...
# 530                              NaN                            NaN  ...
# 531                              NaN                            NaN  ...
#
#     31-04:maternalHemorrhage  31-04:maternalTrauma  \
# 0                      False                 False
# 1                      False                 False
# 2                      False                 False
# 3                      False                 False
# 4                      False                 False
# ..                       ...                   ...
# 527                    False                 False
# 528                    False                 False
# 529                    False                 False
# 530                    False                 False
# 531                    False                 False
#
#      31-04:maternalCardioRespiratoryArrest  31-04:maternalSeizure  \
# 0                                    False                  False
# 1                                    False                  False
# 2                                    False                  False
# 3                                    False                  False
# 4                                    False                  False
# ..                                     ...                    ...
# 527                                  False                  False
# 528                                  False                  False
# 529                                  False                  False
# 530                                  False                  False
# 531                                  False                  False
#
#      31-04:perinatalSentinelEvent 31-05:followupCenter  \
# 0                           False                  NaN
# 1                            True                  3.0
# 2                            True                  3.0
# 3                           False                  3.0
# 4                            True                  3.0
# ..                            ...                  ...
# 527                          True                 31.0
# 528                          True                 31.0
# 529                         False                  NaN
# 530                         False                 31.0
# 531                         False                 31.0
#
#     31-05:disabilityLevelDeath           31-06:deliveryMode  \
# 0                        death            emergent cesarean
# 1                       severe  virginal vertex, unassisted
# 2                       normal  virginal vertex, unassisted
# 3                         mild            emergent cesarean
# 4                       normal  virginal vertex, unassisted
# ..                         ...                          ...
# 527                        NaN            emergent cesarean
# 528                     normal  virginal vertex, unassisted
# 529                      death            emergent cesarean
# 530                     normal  virginal vertex, unassisted
# 531                     normal              virginal breech
#
#     31-06:emergencyCSection 31-07:lengthOfStay_day
# 0                      True                    2.0
# 1                     False                   22.0
# 2                     False                   10.0
# 3                      True                   23.0
# 4                     False                    9.0
# ..                      ...                    ...
# 527                    True                   11.0
# 528                   False                   12.0
# 529                    True                    NaN
# 530                   False                   28.0
# 531                   False                   13.0
#
# [532 rows x 6131 columns]

# %%
valid_columns = list(filter(lambda x: x.startswith('30-01'), df.columns))
valid_columns
# Out:
# ['30-01:followupCenter',
#  '30-01:followupID',
#  '30-01:acidosis',
#  '30-01:ageDeath_day',
#  '30-01:ageRand_hr',
#  '30-01:baselineAnticonvulsants',
#  '30-01:dischargeAnticonvulsants',
#  '30-01:inotropicAgent',
#  '30-01:perinatalSentinelEvent',
#  '30-01:dischargeSeizure',
#  '30-01:Apgar10minLt5',
#  '30-01:Apgar10minLte5',
#  '30-01:Apgar5minLte5',
#  '30-01:bloodGasBaseDeficit_mEqPerL',
#  '30-01:bloodGasPH',
#  '30-01:emergencyCSection',
#  '30-01:encephalopathyLevel',
#  '30-01:inotropicAgentBaseline',
#  '30-01:maleSex',
#  '30-01:maternalEducation',
#  '30-01:motherInsurancePublic',
#  '30-01:motherRace',
#  '30-01:treatmentAssignmentDuration_hr',
#  '30-01:treatmentAssignmentTemperature',
#  '30-01:bloodGasBaseDeficit_mEqPerLSrc',
#  '30-01:bloodGasPHSrc',
#  '30-01:usualCoolingTreatmentGroup',
#  '30-01:blindness',
#  '30-01:moderateSevereCerebralPalsy',
#  '30-01:cerebralPalsy',
#  '30-01:gastrostomyTube',
#  '30-01:grossMotorFunctionLevel',
#  '30-01:hearingImpairedWithAid',
#  '30-01:hearingImpairedLevel',
#  '30-01:multipleImpairment',
#  '30-01:afterDischargeSeizure']

# %%
df = df[columns]

# %%
df
# Out:
#     _study  center subjectID   uniqueID 20-01:followupID    04-01:status  \
# 0       LH       3     LH087   03:LH087              NaN            died
# 1       LH       3     LH088   03:LH088            LHF01  discharge home
# 2       LH       3     LH092   03:LH092            LHF02  discharge home
# 3       LH       3     LH094   03:LH094            LHF03  discharge home
# 4       LH       3     LH098   03:LH098            LHF04  discharge home
# ..     ...     ...       ...        ...              ...             ...
# 527     OC      31    OC3411  31:OC3411          OCF3411  discharge home
# 528     OC      31    OC3441  31:OC3441          OCF3441  discharge home
# 529     OC      31    OC3471  31:OC3471              NaN        transfer
# 530     OC      31    OC3551  31:OC3551          OCF3551  discharge home
# 531     OC      31    OC3561  31:OC3561          OCF3561  discharge home
#
#     04-01:dischargeStatus 30-01:blindness 30-01:grossMotorFunctionLevel  \
# 0                    died             NaN                           NaN
# 1          discharge home           False                        severe
# 2          discharge home           False                        normal
# 3          discharge home           False                        normal
# 4          discharge home           False                        normal
# ..                    ...             ...                           ...
# 527                   NaN             NaN                           NaN
# 528                   NaN           False                        normal
# 529                   NaN             NaN                           NaN
# 530                   NaN           False                        normal
# 531                   NaN           False                        normal
#
#     30-01:hearingImpairedWithAid 30-01:hearingImpairedLevel  \
# 0                            NaN                        NaN
# 1                          False                     normal
# 2                          False                     normal
# 3                          False                     normal
# 4                          False                     normal
# ..                           ...                        ...
# 527                          NaN                        NaN
# 528                        False                     normal
# 529                          NaN                        NaN
# 530                        False                     normal
# 531                        False                     normal
#
#     30-01:afterDischargeSeizure 30-02:normalPrimaryOutcome  \
# 0                           NaN                        NaN
# 1                         False                      False
# 2                         False                       True
# 3                         False                      False
# 4                          True                       True
# ..                          ...                        ...
# 527                         NaN                        NaN
# 528                       False                       True
# 529                         NaN                        NaN
# 530                       False                       True
# 531                       False                       True
#
#     30-02:deathBeforeDischarge 30-02:deathBeforeFollowup  \
# 0                         True                      True
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ..                         ...                       ...
# 527                      False                     False
# 528                      False                     False
# 529                       True                      True
# 530                      False                     False
# 531                      False                     False
#
#     30-02:moderateSevereDisabilityOrDeath  \
# 0                                    True
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
# ..                                    ...
# 527                                   NaN
# 528                                 False
# 529                                  True
# 530                                 False
# 531                                 False
#
#     30-02:moderateSevereDisabilitySurvivor 30-02:disabilityLevel  \
# 0                                      NaN                severe
# 1                                     True                severe
# 2                                    False                normal
# 3                                    False                  mild
# 4                                    False                normal
# ..                                     ...                   ...
# 527                                    NaN                   NaN
# 528                                  False                normal
# 529                                    NaN                severe
# 530                                  False                normal
# 531                                  False                normal
#
#     30-02:BayleyIIICognitive 31-05:disabilityLevelDeath
# 0                        NaN                      death
# 1                     severe                     severe
# 2                     normal                     normal
# 3                   moderate                       mild
# 4                     normal                     normal
# ..                       ...                        ...
# 527                      NaN                        NaN
# 528                   normal                     normal
# 529                      NaN                      death
# 530                   normal                     normal
# 531                   normal                     normal
#
# [532 rows x 20 columns]

# %% [markdown]
# ### 03-02. severe disability

# %%
def _is_severe(x):
    if _is_severe_bayleyIII_cognitive(x):
        return True

    if _is_severe_GMFCS(x):
        return True

    if _is_severe_blindness(x):
        return True

    if _is_severe_hearing_loss(x):
        return True

    if _is_severe_death(x):
        return True

    return False


def _is_severe_bayleyIII_cognitive(x):
    if pd.isnull(x['30-02:BayleyIIICognitive']):
        return False

    return x['30-02:BayleyIIICognitive'] == 'severe'


def _is_severe_GMFCS(x):
    if pd.isnull(x['30-01:grossMotorFunctionLevel']):
        return False

    return x['30-01:grossMotorFunctionLevel'] == 'severe'


def _is_severe_blindness(x):
    if pd.isnull(x['30-01:blindness']):
        return False

    return x['30-01:blindness']


def _is_severe_hearing_loss(x):
    if pd.isnull(x['30-01:hearingImpairedLevel']):
        return False

    return x['30-01:hearingImpairedLevel'] == 'severe'


def _is_severe_death(x):
    if pd.isnull(x['30-02:deathBeforeFollowup']):
        return False

    return x['30-02:deathBeforeFollowup']

df['is_severe'] = df.apply(lambda x: _is_severe(x), axis=1)

# %%
is_invalid_severe_true = (df['is_severe'] == True) & (df['30-02:disabilityLevel'] != 'severe')
is_invalid_severe_false = (df['is_severe'] == False) & (df['30-02:disabilityLevel'] == 'severe')
is_invalid = is_invalid_severe_true | is_invalid_severe_false
columns = ['uniqueID', 'is_severe', '30-02:disabilityLevel', '30-02:deathBeforeFollowup', '30-02:BayleyIIICognitive', '30-01:grossMotorFunctionLevel', '30-01:blindness', '30-01:hearingImpairedLevel']
df[is_invalid].reset_index()[columns]
# Out:
#     uniqueID  is_severe 30-02:disabilityLevel 30-02:deathBeforeFollowup  \
# 0   18:LH095       True                  mild                     False
# 1  05:OC0871      False                severe                     False
#
#   30-02:BayleyIIICognitive 30-01:grossMotorFunctionLevel 30-01:blindness  \
# 0                   normal                        normal           False
# 1                      NaN                           NaN           False
#
#   30-01:hearingImpairedLevel
# 0                     severe
# 1                        NaN

# %% [markdown]
# ### 03-03. moderate disability

# %%
def _is_moderate(x):
    if _is_moderate_bayleyIII_cognitive(x) and _is_moderate_GMFCS(x):
        return True

    '''
    if _is_moderate_seizure(x):
        return True
    '''

    if _is_moderate_hearing_loss(x):
        return True

    return False


def _is_moderate_bayleyIII_cognitive(x):
    if pd.isnull(x['30-02:BayleyIIICognitive']):
        return False

    return x['30-02:BayleyIIICognitive'] == 'moderate'


def _is_moderate_GMFCS(x):
    if pd.isnull(x['30-01:grossMotorFunctionLevel']):
        return False

    return x['30-01:grossMotorFunctionLevel'] == 'moderate'


def _is_moderate_seizure(x):
    if pd.isnull(x['30-01:afterDischargeSeizure']):
        return False

    return x['30-01:afterDischargeSeizure']


def _is_moderate_hearing_loss(x):
    if pd.isnull(x['30-01:hearingImpairedLevel']):
        return False

    return x['30-01:hearingImpairedLevel'] == 'moderate'


df['is_moderate'] = df.apply(lambda x: _is_moderate(x), axis=1)

# %%
is_invalid_moderate_true = (df['is_moderate'] == True) & (df['30-02:disabilityLevel'] != 'moderate')
is_invalid_moderate_false = (df['is_moderate'] == False) & (df['30-02:disabilityLevel'] == 'moderate')
is_invalid = is_invalid_moderate_true | is_invalid_moderate_false
columns = ['uniqueID', 'is_moderate', '30-02:disabilityLevel', '30-02:BayleyIIICognitive', '30-01:grossMotorFunctionLevel', '30-01:afterDischargeSeizure', '30-01:hearingImpairedLevel']
df[is_invalid].reset_index()[columns]
# Out:
#     uniqueID  is_moderate 30-02:disabilityLevel 30-02:BayleyIIICognitive  \
# 0   18:LH105        False              moderate                 moderate
# 1  05:OC0301         True                   NaN                      NaN
# 2  09:OC0651         True                  mild                   normal
# 3  12:OC0351         True                  mild                   normal
# 4  14:OC0211         True                  mild                   normal
# 5  15:OC0181         True                  mild                   normal
# 6  15:OC0251         True                  mild                   normal
#
#   30-01:grossMotorFunctionLevel 30-01:afterDischargeSeizure  \
# 0                        normal                        True
# 1                        normal                       False
# 2                        normal                       False
# 3                        normal                       False
# 4                        normal                       False
# 5                        normal                       False
# 6                        normal                       False
#
#   30-01:hearingImpairedLevel
# 0                     normal
# 1                   moderate
# 2                   moderate
# 3                   moderate
# 4                   moderate
# 5                   moderate
# 6                   moderate

# %% [markdown]
# ### 03-04. mild disability

# %%
def _is_mild(x):
    if _is_moderate_severe(x):
        return False

    if _is_mild_bayleyIII_cognitive(x):
        return True

    if _is_normal_bayleyIII_cognitive(x):
        if _is_mild_GMFCS(x):
            return True

        if _is_moderate_seizure(x):
            return True

        if _is_moderate_hearing_loss(x):
            return True

    return False


def _is_moderate_severe(x):
    return x['is_moderate'] or x['is_severe']


def _is_mild_bayleyIII_cognitive(x):
    if pd.isnull(x['30-02:BayleyIIICognitive']):
        return False

    return x['30-02:BayleyIIICognitive'] == 'mild'


def _is_normal_bayleyIII_cognitive(x):
    if pd.isnull(x['30-02:BayleyIIICognitive']):
        return False

    return x['30-02:BayleyIIICognitive'] == 'normal'


def _is_mild_GMFCS(x):
    if pd.isnull(x['30-01:grossMotorFunctionLevel']):
        return False

    return x['30-01:grossMotorFunctionLevel'] == 'mild'


def _is_moderate_seizure(x):
    if pd.isnull(x['30-01:afterDischargeSeizure']):
        return False

    return x['30-01:afterDischargeSeizure']


def _is_moderate_hearing_loss(x):
    if pd.isnull(x['30-01:hearingImpairedLevel']):
        return False

    return x['30-01:hearingImpairedLevel'] in ['mild', 'moderate']


df['is_mild'] = df.apply(lambda x: _is_mild(x), axis=1)

# %%
is_invalid_mild_true = (df['is_mild'] == True) & (df['30-02:disabilityLevel'] != 'mild')
is_invalid_mild_false = (df['is_mild'] == False) & (df['30-02:disabilityLevel'] == 'mild')
is_invalid = is_invalid_mild_true | is_invalid_mild_false
columns = ['uniqueID', 'is_mild', '30-02:disabilityLevel', '30-02:BayleyIIICognitive', '30-01:grossMotorFunctionLevel', '30-01:afterDischargeSeizure', '30-01:hearingImpairedLevel']
df[is_invalid].reset_index()[columns]
# Out:
#      uniqueID  is_mild 30-02:disabilityLevel 30-02:BayleyIIICognitive  \
# 0    03:LH094    False                  mild                 moderate
# 1    03:LH098     True                normal                   normal
# 2    04:LH063    False                  mild                 moderate
# 3    04:LH068    False                  mild                 moderate
# 4    04:LH070     True                normal                   normal
# ..        ...      ...                   ...                      ...
# 76  27:OC8561    False                  mild                 moderate
# 77  28:OC0031    False                  mild                   normal
# 78  28:OC0101    False                  mild                   normal
# 79  28:OC3051    False                  mild                 moderate
# 80  29:OC0161    False                  mild                 moderate
#
#    30-01:grossMotorFunctionLevel 30-01:afterDischargeSeizure  \
# 0                         normal                       False
# 1                         normal                        True
# 2                         normal                       False
# 3                         normal                       False
# 4                         normal                        True
# ..                           ...                         ...
# 76                        normal                       False
# 77                        normal                       False
# 78                        normal                       False
# 79                        normal                       False
# 80                        normal                       False
#
#    30-01:hearingImpairedLevel
# 0                      normal
# 1                      normal
# 2                      normal
# 3                      normal
# 4                      normal
# ..                        ...
# 76                     normal
# 77                     normal
# 78                     normal
# 79                     normal
# 80                     normal
#
# [81 rows x 7 columns]

# %%
# is_valid = df['30-01:normalPrimaryOutcome'].isnull()
is_invalid = df['04-01:dischargeStatus'] != df['04-01:status']
df[is_invalid]
# Out:
#     _study  center subjectID   uniqueID 20-01:followupID    04-01:status  \
# 84      LH      15     LH002   15:LH002              NaN            died
# 168     OC       3    OC3261  03:OC3261          OCF0003  discharge home
# 169     OC       3    OC3281  03:OC3281          OCF0002  discharge home
# 170     OC       3    OC3291  03:OC3291          OCF0001  discharge home
# 171     OC       3    OC3331  03:OC3331          OCF0004  discharge home
# ..     ...     ...       ...        ...              ...             ...
# 527     OC      31    OC3411  31:OC3411          OCF3411  discharge home
# 528     OC      31    OC3441  31:OC3441          OCF3441  discharge home
# 529     OC      31    OC3471  31:OC3471              NaN        transfer
# 530     OC      31    OC3551  31:OC3551          OCF3551  discharge home
# 531     OC      31    OC3561  31:OC3561          OCF3561  discharge home
#
#               04-01:dischargeStatus 30-01:blindness  \
# 84   remain in hospital at 6 months             NaN
# 168                             NaN           False
# 169                             NaN           False
# 170                             NaN           False
# 171                             NaN           False
# ..                              ...             ...
# 527                             NaN             NaN
# 528                             NaN           False
# 529                             NaN             NaN
# 530                             NaN           False
# 531                             NaN           False
#
#     30-01:grossMotorFunctionLevel 30-01:hearingImpairedWithAid  ...  \
# 84                            NaN                          NaN  ...
# 168                        severe                        False  ...
# 169                        normal                        False  ...
# 170                        normal                        False  ...
# 171                        normal                        False  ...
# ..                            ...                          ...  ...
# 527                           NaN                          NaN  ...
# 528                        normal                        False  ...
# 529                           NaN                          NaN  ...
# 530                        normal                        False  ...
# 531                        normal                        False  ...
#
#     30-02:deathBeforeDischarge 30-02:deathBeforeFollowup  \
# 84                        True                      True
# 168                      False                     False
# 169                      False                     False
# 170                      False                     False
# 171                      False                     False
# ..                         ...                       ...
# 527                      False                     False
# 528                      False                     False
# 529                       True                      True
# 530                      False                     False
# 531                      False                     False
#
#     30-02:moderateSevereDisabilityOrDeath  \
# 84                                   True
# 168                                  True
# 169                                 False
# 170                                 False
# 171                                  True
# ..                                    ...
# 527                                   NaN
# 528                                 False
# 529                                  True
# 530                                 False
# 531                                 False
#
#     30-02:moderateSevereDisabilitySurvivor 30-02:disabilityLevel  \
# 84                                     NaN                severe
# 168                                   True                severe
# 169                                  False                normal
# 170                                  False                  mild
# 171                                   True                severe
# ..                                     ...                   ...
# 527                                    NaN                   NaN
# 528                                  False                normal
# 529                                    NaN                severe
# 530                                  False                normal
# 531                                  False                normal
#
#     30-02:BayleyIIICognitive 31-05:disabilityLevelDeath is_severe is_moderate  \
# 84                       NaN                      death      True       False
# 168                   severe                     severe      True       False
# 169                   normal                     normal     False       False
# 170                 moderate                       mild     False       False
# 171                   severe                     severe      True       False
# ..                       ...                        ...       ...         ...
# 527                      NaN                        NaN     False       False
# 528                   normal                     normal     False       False
# 529                      NaN                      death      True       False
# 530                   normal                     normal     False       False
# 531                   normal                     normal     False       False
#
#     is_mild
# 84    False
# 168   False
# 169   False
# 170   False
# 171   False
# ..      ...
# 527   False
# 528   False
# 529   False
# 530   False
# 531   False
#
# [365 rows x 23 columns]

# %% [markdown]
# ### 03-04. death or disability distribution.

# %%
df['deathDisabilityLevel'] = df['30-02:disabilityLevel'].copy()
is_death = df['30-02:deathBeforeFollowup'] == True
df.loc[is_death, 'deathDisabilityLevel'] = 'death'

df_groupby = df.groupby(['_study', 'deathDisabilityLevel']).agg({'deathDisabilityLevel': 'count'}).rename(columns={'deathDisabilityLevel': '_count'}).reset_index(drop=False)

out_filename = f'{out_dir}/20-03-basic-info-death-disability-distribution.csv'
df_groupby.to_csv(out_filename, index=False)

df_groupby
# Out:
#   _study deathDisabilityLevel  _count
# 0     LH                death      18
# 1     LH                 mild      28
# 2     LH             moderate       2
# 3     LH               normal      88
# 4     LH               severe      21
# 5     OC                death      56
# 6     OC                 mild      71
# 7     OC             moderate       4
# 8     OC               normal     160
# 9     OC               severe      50

# %%
df.columns
# Out:
# Index(['_study', 'center', 'subjectID', 'uniqueID', '20-01:followupID',
#        '04-01:status', '04-01:dischargeStatus', '30-01:blindness',
#        '30-01:grossMotorFunctionLevel', '30-01:hearingImpairedWithAid',
#        '30-01:hearingImpairedLevel', '30-01:afterDischargeSeizure',
#        '30-02:normalPrimaryOutcome', '30-02:deathBeforeDischarge',
#        '30-02:deathBeforeFollowup', '30-02:moderateSevereDisabilityOrDeath',
#        '30-02:moderateSevereDisabilitySurvivor', '30-02:disabilityLevel',
#        '30-02:BayleyIIICognitive', '31-05:disabilityLevelDeath', 'is_severe',
#        'is_moderate', 'is_mild', 'deathDisabilityLevel'],
#       dtype='object')

# %%
is_both_null = df['deathDisabilityLevel'].isnull() & df['31-05:disabilityLevelDeath'].isnull()
is_ne_disability_level_death = df['deathDisabilityLevel'] != df['31-05:disabilityLevelDeath']
is_invalid = (is_both_null == False) & is_ne_disability_level_death

# %%
columns = ['_study', 'uniqueID', 'deathDisabilityLevel', '31-05:disabilityLevelDeath', '30-02:deathBeforeFollowup', '30-02:disabilityLevel']
df[is_invalid][columns]
# Out:
# Empty DataFrame
# Columns: [_study, uniqueID, deathDisabilityLevel, 31-05:disabilityLevelDeath, 30-02:deathBeforeFollowup, 30-02:disabilityLevel]
# Index: []

# %%
df[is_both_null][columns]
# Out:
#     _study   uniqueID deathDisabilityLevel 31-05:disabilityLevelDeath  \
# 23      LH   04:LH598                  NaN                        NaN
# 33      LH   05:LH167                  NaN                        NaN
# 42      LH   09:LH110                  NaN                        NaN
# 57      LH   12:LH038                  NaN                        NaN
# 81      LH   14:LH115                  NaN                        NaN
# 94      LH   15:LH071                  NaN                        NaN
# 109     LH   18:LH078                  NaN                        NaN
# 116     LH   18:LH139                  NaN                        NaN
# 162     LH   30:LH009                  NaN                        NaN
# 163     LH   30:LH010                  NaN                        NaN
# 166     LH   30:LH014                  NaN                        NaN
# 216     OC  05:OC0301                  NaN                        NaN
# 219     OC  05:OC0421                  NaN                        NaN
# 222     OC  05:OC0541                  NaN                        NaN
# 228     OC  05:OC0651                  NaN                        NaN
# 239     OC  05:OC0891                  NaN                        NaN
# 243     OC  09:OC0161                  NaN                        NaN
# 266     OC  09:OC0681                  NaN                        NaN
# 273     OC  11:OC0031                  NaN                        NaN
# 314     OC  14:OC0081                  NaN                        NaN
# 330     OC  14:OC0631                  NaN                        NaN
# 331     OC  14:OC0661                  NaN                        NaN
# 371     OC  18:OC0371                  NaN                        NaN
# 396     OC  19:OC0381                  NaN                        NaN
# 398     OC  19:OC0411                  NaN                        NaN
# 399     OC  19:OC0421                  NaN                        NaN
# 410     OC  19:OC9431                  NaN                        NaN
# 412     OC  19:OC9451                  NaN                        NaN
# 432     OC  24:OC1241                  NaN                        NaN
# 474     OC  28:OC3061                  NaN                        NaN
# 500     OC  30:OC0131                  NaN                        NaN
# 511     OC  30:OC0331                  NaN                        NaN
# 526     OC  31:OC3381                  NaN                        NaN
# 527     OC  31:OC3411                  NaN                        NaN
#
#     30-02:deathBeforeFollowup 30-02:disabilityLevel
# 23                      False                   NaN
# 33                      False                   NaN
# 42                      False                   NaN
# 57                      False                   NaN
# 81                        NaN                   NaN
# 94                        NaN                   NaN
# 109                     False                   NaN
# 116                       NaN                   NaN
# 162                     False                   NaN
# 163                     False                   NaN
# 166                     False                   NaN
# 216                     False                   NaN
# 219                     False                   NaN
# 222                     False                   NaN
# 228                     False                   NaN
# 239                     False                   NaN
# 243                       NaN                   NaN
# 266                       NaN                   NaN
# 273                       NaN                   NaN
# 314                     False                   NaN
# 330                       NaN                   NaN
# 331                       NaN                   NaN
# 371                       NaN                   NaN
# 396                     False                   NaN
# 398                       NaN                   NaN
# 399                       NaN                   NaN
# 410                       NaN                   NaN
# 412                       NaN                   NaN
# 432                     False                   NaN
# 474                     False                   NaN
# 500                     False                   NaN
# 511                     False                   NaN
# 526                     False                   NaN
# 527                     False                   NaN
