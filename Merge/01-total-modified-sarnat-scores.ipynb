# %%
import pandas as pd
pd.options.mode.copy_on_write = True
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

import COMBINE_harmonizer
from COMBINE_harmonizer import cfg

# %% [markdown]
# ## 01. init

# %%
root_dir = '../'

# %%
COMBINE_harmonizer.init(f'{root_dir}/config.yaml')

# %%
data_dict_filename = f"{root_dir}/{COMBINE_harmonizer.DATA_DICTIONARY_EXCEL}"
out_dir = cfg.config['out_dir']

# %% [markdown]
# ### 01-01. init numeric value mapping

# %%
COMBINE_harmonizer.init_rank_mapping(data_dict_filename)

_NUMERIC_VALUE_MAP_MAIN = COMBINE_harmonizer.build_numeric_value_map(data_dict_filename, COMBINE_harmonizer.SHEET_MAIN)
# Out:
# build_numeric_value_map: (0/1108) variable: center type: center
# [INFO] _build_numeric_value_map: to inv-text: type: center
# build_numeric_value_map: (1/1108) variable: subjectID type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (2/1108) variable: siteID type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (3/1108) variable: birthDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (4/1108) variable: birthNumber type: int
# build_numeric_value_map: (5/1108) variable: screenComment type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (6/1108) variable: coreTempLess32p5CGreaterEq2Hr_e type: bool
# build_numeric_value_map: (7/1108) variable: coreTempLess33p5CGreater1Hr_e type: bool
# build_numeric_value_map: (8/1108) variable: coreTempLess34CGreater1Hr_e type: bool
# build_numeric_value_map: (9/1108) variable: first6HrCoolByClinicalProtocol_e type: bool
# build_numeric_value_map: (10/1108) variable: chromosomalAbnormality_e type: bool
# build_numeric_value_map: (11/1108) variable: majorCongenitalAnomaly_e type: bool
# build_numeric_value_map: (12/1108) variable: birthWeightLessEq1800g_e type: bool
# build_numeric_value_map: (13/1108) variable: infantUnlikelySurvive_e type: bool
# build_numeric_value_map: (14/1108) variable: first60MinAllBloodGasPHGreater7p15BaseDeficitLess10mEqPerL_e type: bool
# build_numeric_value_map: (15/1108) variable: postnatalAgeLess6HrOrGreater24Hr_e type: bool
# build_numeric_value_map: (16/1108) variable: enrolledConflictingTrial_e type: bool
# build_numeric_value_map: (17/1108) variable: first60MinAnyBloodGasPHLessEq7_i type: bool
# build_numeric_value_map: (18/1108) variable: first60MinAnyBloodGasBaseDeficitGreaterEq16mEqPerL_i type: bool
# build_numeric_value_map: (19/1108) variable: historyPerinatalEvent_i type: bool
# build_numeric_value_map: (20/1108) variable: at10MinApgarLessEq5OrVent_i type: bool
# build_numeric_value_map: (21/1108) variable: randomEligible type: bool
# build_numeric_value_map: (22/1108) variable: consentStatus type: consentStatus
# [INFO] _build_numeric_value_map: to inv-text: type: consentStatus
# build_numeric_value_map: (23/1108) variable: noConsentReason type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (24/1108) variable: noInStudyReason type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (25/1108) variable: random type: bool
# build_numeric_value_map: (26/1108) variable: noRandomReason type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (27/1108) variable: noRandomReasonText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (28/1108) variable: randomDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (29/1108) variable: randomTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (30/1108) variable: ageRand_hr type: float
# build_numeric_value_map: (31/1108) variable: randomNumber type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (32/1108) variable: randomTreatmentAssign type: treatmentAssign
# [INFO] _build_numeric_value_map: to inv-text: type: treatmentAssign
# build_numeric_value_map: (33/1108) variable: randomTreatmentReceive type: bool
# build_numeric_value_map: (34/1108) variable: treatmentBlanketType type: blanketType
# build_numeric_value_map: (35/1108) variable: treatmentAssignmentDuration_hr type: int
# build_numeric_value_map: (36/1108) variable: treatmentAssignmentTemperature type: float
# build_numeric_value_map: (37/1108) variable: usualCoolingTreatmentGroup type: bool
# build_numeric_value_map: (38/1108) variable: inOtherTrial type: bool
# build_numeric_value_map: (39/1108) variable: inOtherTrialText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (40/1108) variable: consideredForHypothermia type: bool
# build_numeric_value_map: (41/1108) variable: hypothermia type: bool
# build_numeric_value_map: (42/1108) variable: noHypothermiaReason type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (43/1108) variable: noHypothermiaReasonOther type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (44/1108) variable: hypothermiaStandard type: bool
# build_numeric_value_map: (45/1108) variable: hypothermiaDeviationOther type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (46/1108) variable: motherAge_year type: int
# build_numeric_value_map: (47/1108) variable: motherRace type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (48/1108) variable: motherRaceOther1 type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (49/1108) variable: motherRaceOther2 type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (50/1108) variable: motherRaceOther3 type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (51/1108) variable: motherRaceOther4 type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (52/1108) variable: motherRaceOther5 type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (53/1108) variable: motherRaceOther6 type: race
# [INFO] _build_numeric_value_map: to inv-text: type: race
# build_numeric_value_map: (54/1108) variable: motherRace2 type: race2
# build_numeric_value_map: (55/1108) variable: motherEthnicity type: ethnicity
# [INFO] _build_numeric_value_map: to inv-text: type: ethnicity
# build_numeric_value_map: (56/1108) variable: motherMaritalStatus type: maritalStatus
# [INFO] _build_numeric_value_map: to inv-text: type: maritalStatus
# build_numeric_value_map: (57/1108) variable: motherEducation type: education
# build_numeric_value_map: (58/1108) variable: motherEducation2 type: education2
# build_numeric_value_map: (59/1108) variable: motherInsurance type: insurance
# build_numeric_value_map: (60/1108) variable: motherInsurancePublic type: bool
# build_numeric_value_map: (61/1108) variable: gravida type: int
# build_numeric_value_map: (62/1108) variable: parity type: int
# build_numeric_value_map: (63/1108) variable: multipleBirth type: bool
# build_numeric_value_map: (64/1108) variable: numFetus type: int
# build_numeric_value_map: (65/1108) variable: prenatalCare type: bool
# build_numeric_value_map: (66/1108) variable: hypertensionEclampsia type: bool
# build_numeric_value_map: (67/1108) variable: antepartumHemorrhage type: bool
# build_numeric_value_map: (68/1108) variable: thyroidMalfunction type: bool
# build_numeric_value_map: (69/1108) variable: diabetes type: bool
# build_numeric_value_map: (70/1108) variable: maternalAdmissionDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (71/1108) variable: maternalAdmissionTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (72/1108) variable: ruptureDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (73/1108) variable: ruptureTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (74/1108) variable: ruptureGreater18Hr type: bool
# build_numeric_value_map: (75/1108) variable: ruptureBeforeDelivery type: bool
# build_numeric_value_map: (76/1108) variable: labor type: bool
# build_numeric_value_map: (77/1108) variable: laborOnsetDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (78/1108) variable: laborOnsetTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (79/1108) variable: deliveryMode type: deliveryMode
# [INFO] _build_numeric_value_map: to inv-text: type: deliveryMode
# build_numeric_value_map: (80/1108) variable: fetalDecelerate type: bool
# build_numeric_value_map: (81/1108) variable: cordMishap type: bool
# build_numeric_value_map: (82/1108) variable: uterineRupture type: bool
# build_numeric_value_map: (83/1108) variable: shoulderDystocia type: bool
# build_numeric_value_map: (84/1108) variable: placentalProblem type: bool
# build_numeric_value_map: (85/1108) variable: maternalHemorrhage type: bool
# build_numeric_value_map: (86/1108) variable: maternalTrauma type: bool
# build_numeric_value_map: (87/1108) variable: maternalCardioRespiratoryArrest type: bool
# build_numeric_value_map: (88/1108) variable: maternalSeizure type: bool
# build_numeric_value_map: (89/1108) variable: perinatalSentinelEvent type: bool
# build_numeric_value_map: (90/1108) variable: pyrexiaGreater37p6C type: bool
# build_numeric_value_map: (91/1108) variable: chorioamnionitis type: bool
# build_numeric_value_map: (92/1108) variable: placentalPathologyPerformed type: bool
# build_numeric_value_map: (93/1108) variable: histologicChorioamionitis type: bool
# build_numeric_value_map: (94/1108) variable: laborAntibiotics type: bool
# build_numeric_value_map: (95/1108) variable: laborAntibioticsCode1 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (96/1108) variable: laborAntibioticsCode2 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (97/1108) variable: laborAntibioticsCode3 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (98/1108) variable: laborAntibioticsCode4 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (99/1108) variable: laborAntibioticsCode5 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (100/1108) variable: laborAntibioticsCode6 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (101/1108) variable: emergencyCSection type: bool
# build_numeric_value_map: (102/1108) variable: encephalopathyLevel type: encephalopathyLevel
# build_numeric_value_map: (103/1108) variable: randomInfantAge type: infantAge
# build_numeric_value_map: (104/1108) variable: birthDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (105/1108) variable: birthTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (106/1108) variable: birthWeight_g type: float
# build_numeric_value_map: (107/1108) variable: birthLength_cm type: float
# build_numeric_value_map: (108/1108) variable: birthHeadCircumference_cm type: float
# build_numeric_value_map: (109/1108) variable: birthGestationalAge_week type: int
# build_numeric_value_map: (110/1108) variable: infantSex type: infantSex
# build_numeric_value_map: (111/1108) variable: maleSex type: bool
# build_numeric_value_map: (112/1108) variable: infantOutborn type: bool
# build_numeric_value_map: (113/1108) variable: outbornInHospital type: bool
# build_numeric_value_map: (114/1108) variable: outbornOutHospital type: bool
# build_numeric_value_map: (115/1108) variable: neonateAdmissionDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (116/1108) variable: neonateAdmissionTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (117/1108) variable: Apgar1min type: int
# build_numeric_value_map: (118/1108) variable: Apgar5min type: int
# build_numeric_value_map: (119/1108) variable: Apgar10min type: int
# build_numeric_value_map: (120/1108) variable: Apgar15min type: int
# build_numeric_value_map: (121/1108) variable: Apgar20min type: int
# build_numeric_value_map: (122/1108) variable: deliveryResuscitation type: bool
# build_numeric_value_map: (123/1108) variable: deliveryOxygen type: bool
# build_numeric_value_map: (124/1108) variable: deliveryBaggingAndMask type: bool
# build_numeric_value_map: (125/1108) variable: deliveryChestCompression type: bool
# build_numeric_value_map: (126/1108) variable: deliveryIntubation type: bool
# build_numeric_value_map: (127/1108) variable: deliveryDrug type: bool
# build_numeric_value_map: (128/1108) variable: at10MinContinueResuscitation type: bool
# build_numeric_value_map: (129/1108) variable: at10MinOxygen type: bool
# build_numeric_value_map: (130/1108) variable: at10MinBaggingAndMask type: bool
# build_numeric_value_map: (131/1108) variable: at10MinChestCompression type: bool
# build_numeric_value_map: (132/1108) variable: at10MinIntubation type: bool
# build_numeric_value_map: (133/1108) variable: at10MinDrug type: bool
# build_numeric_value_map: (134/1108) variable: spontaneousRespirationTime type: spontaneousRespirationTime
# build_numeric_value_map: (135/1108) variable: cordBloodGas type: bool
# build_numeric_value_map: (136/1108) variable: cordBloodGasSrc type: cordBloodGasSrc
# [INFO] _build_numeric_value_map: to inv-text: type: cordBloodGasSrc
# build_numeric_value_map: (137/1108) variable: cordBloodGasPH type: float
# build_numeric_value_map: (138/1108) variable: cordBloodGasPCO2_mmHg type: float
# build_numeric_value_map: (139/1108) variable: cordBloodGasPO2_mmHg type: float
# build_numeric_value_map: (140/1108) variable: cordBloodGasHCO3_mEqPerL type: float
# build_numeric_value_map: (141/1108) variable: cordBloodGasBaseDeficit_mEqPerL type: float
# build_numeric_value_map: (142/1108) variable: firstPostnatalBloodGas type: bool
# build_numeric_value_map: (143/1108) variable: firstPostnatalBloodGasSrc type: bloodGasSrc
# [INFO] _build_numeric_value_map: to inv-text: type: bloodGasSrc
# build_numeric_value_map: (144/1108) variable: firstPostnatalBloodGasDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (145/1108) variable: firstPostnatalBloodGasTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (146/1108) variable: firstPostnatalBloodGasPH type: float
# build_numeric_value_map: (147/1108) variable: firstPostnatalBloodGasPCO2_mmHg type: float
# build_numeric_value_map: (148/1108) variable: firstPostnatalBloodGasPO2_mmHg type: float
# build_numeric_value_map: (149/1108) variable: firstPostnatalBloodGasHCO3_mEqPerL type: float
# build_numeric_value_map: (150/1108) variable: firstPostnatalBloodGasBaseDeficit_mEqPerL type: float
# build_numeric_value_map: (151/1108) variable: acidosis type: bool
# build_numeric_value_map: (152/1108) variable: Apgar10minLess5 type: bool
# build_numeric_value_map: (153/1108) variable: Apgar10minLessEq5 type: bool
# build_numeric_value_map: (154/1108) variable: Apgar5minLessEq5 type: bool
# build_numeric_value_map: (155/1108) variable: initBloodGasBaseDeficit_mEqPerL type: float
# build_numeric_value_map: (156/1108) variable: initBloodGasBaseDeficit_mEqPerLSrc type: initBloodGasSrc
# [INFO] _build_numeric_value_map: to inv-text: type: initBloodGasSrc
# build_numeric_value_map: (157/1108) variable: initBloodGasPH type: float
# build_numeric_value_map: (158/1108) variable: initBloodGasPHSrc type: initBloodGasSrc
# [INFO] _build_numeric_value_map: to inv-text: type: initBloodGasSrc
# build_numeric_value_map: (159/1108) variable: targetTreatmentTemperature_C type: targetTreatmentTemperature
# [INFO] _build_numeric_value_map: to inv-text: type: targetTreatmentTemperature
# build_numeric_value_map: (160/1108) variable: pre_CoolInitiate type: bool
# build_numeric_value_map: (161/1108) variable: pre_CoolbyIceGelPack type: bool
# build_numeric_value_map: (162/1108) variable: pre_CoolPassively type: bool
# build_numeric_value_map: (163/1108) variable: pre_CoolClinically type: bool
# build_numeric_value_map: (164/1108) variable: pre_CoolInitiateDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (165/1108) variable: pre_CoolInitiateTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (166/1108) variable: pre_AfterOvershootReach33p5C type: bool
# build_numeric_value_map: (167/1108) variable: pre_AfterOvershootReach33p5CDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (168/1108) variable: pre_AfterOvershootReach33p5CTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (169/1108) variable: pre_TemperatureMinDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (170/1108) variable: pre_TemperatureMinTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (171/1108) variable: pre_SkinTemperatureMin_C type: float
# build_numeric_value_map: (172/1108) variable: pre_AxillaryTemperatureMin_C type: float
# build_numeric_value_map: (173/1108) variable: pre_EsophagealTemperatureMin_C type: float
# build_numeric_value_map: (174/1108) variable: pre_ServoSetMin_C type: float
# build_numeric_value_map: (175/1108) variable: pre_TemperatureMaxDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (176/1108) variable: pre_TemperatureMaxTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (177/1108) variable: pre_SkinTemperatureMax_C type: float
# build_numeric_value_map: (178/1108) variable: pre_AxillaryTemperatureMax_C type: float
# build_numeric_value_map: (179/1108) variable: pre_EsophagealTemperatureMax_C type: float
# build_numeric_value_map: (180/1108) variable: pre_ServoSetMax_C type: float
# build_numeric_value_map: (181/1108) variable: pre_CardioDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (182/1108) variable: pre_CardioTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (183/1108) variable: pre_CardioSystolicBloodPressure_mmHg type: float
# build_numeric_value_map: (184/1108) variable: pre_CardioDiastolicBloodPressure_mmHg type: float
# build_numeric_value_map: (185/1108) variable: pre_CardioHeartRate_BPM type: float
# build_numeric_value_map: (186/1108) variable: pre_CardioVolumeExpand type: bool
# build_numeric_value_map: (187/1108) variable: pre_CardioInotropicAgent type: bool
# build_numeric_value_map: (188/1108) variable: pre_CardioBloodTransfusion type: bool
# build_numeric_value_map: (189/1108) variable: pre_CardioPlatelets type: bool
# build_numeric_value_map: (190/1108) variable: pre_InotropicAgent type: bool
# build_numeric_value_map: (191/1108) variable: pre_RespiratoryDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (192/1108) variable: pre_RespiratoryTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (193/1108) variable: pre_RespiratorySupportType type: respiratorySupportType
# [INFO] _build_numeric_value_map: to inv-text: type: respiratorySupportType
# build_numeric_value_map: (194/1108) variable: pre_RespiratoryFiO2 type: float
# build_numeric_value_map: (195/1108) variable: pre_RespiratoryRate_Hz type: float
# build_numeric_value_map: (196/1108) variable: pre_RespiratoryPIP_cmH2O type: float
# build_numeric_value_map: (197/1108) variable: pre_RespiratoryMAP_cmH2O type: float
# build_numeric_value_map: (198/1108) variable: pre_RespiratoryPEEP_cmH2O type: float
# build_numeric_value_map: (199/1108) variable: pre_BloodGasDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (200/1108) variable: pre_BloodGasTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (201/1108) variable: pre_BloodGasSrc type: bloodGasSrc
# [INFO] _build_numeric_value_map: to inv-text: type: bloodGasSrc
# build_numeric_value_map: (202/1108) variable: pre_BloodGasPH type: float
# build_numeric_value_map: (203/1108) variable: pre_BloodGasPCO2_mmHg type: float
# build_numeric_value_map: (204/1108) variable: pre_BloodGasPO2_mmHg type: float
# build_numeric_value_map: (205/1108) variable: pre_BloodGasHCO3_mEqPerL type: float
# build_numeric_value_map: (206/1108) variable: pre_BloodGasBaseDeficit_mEqPerL type: float
# build_numeric_value_map: (207/1108) variable: pre_BloodGasPHCorrect type: float
# build_numeric_value_map: (208/1108) variable: pre_BloodGasPCO2Correct_mmHg type: float
# build_numeric_value_map: (209/1108) variable: pre_BloodGasPO2Correct_mmHg type: float
# build_numeric_value_map: (210/1108) variable: pre_BloodGasHCO3Correct_mEqPerL type: float
# build_numeric_value_map: (211/1108) variable: pre_BloodGasBaseDeficitCorrect_mEqPerL type: float
# build_numeric_value_map: (212/1108) variable: pre_Hematology type: bool
# build_numeric_value_map: (213/1108) variable: pre_HematologyDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (214/1108) variable: pre_HematologyTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (215/1108) variable: pre_HematologyWBC_cPermuL type: float
# build_numeric_value_map: (216/1108) variable: pre_HematologyHemoglobin_gPerdL type: float
# build_numeric_value_map: (217/1108) variable: pre_HematologyPolymorphNeutrophils_cPermuL type: float
# build_numeric_value_map: (218/1108) variable: pre_HematologyMonocytes_cPermuL type: float
# build_numeric_value_map: (219/1108) variable: pre_HematologyLymphocytes_cPermuL type: float
# build_numeric_value_map: (220/1108) variable: pre_HematologyPlateletCount_cPermuL type: float
# build_numeric_value_map: (221/1108) variable: pre_HematologyPT_s type: float
# build_numeric_value_map: (222/1108) variable: pre_HematologyPTT_s type: float
# build_numeric_value_map: (223/1108) variable: pre_PositiveCulture type: bool
# build_numeric_value_map: (224/1108) variable: pre_PositiveCultureSrc type: positiveCultureSrc
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureSrc
# build_numeric_value_map: (225/1108) variable: pre_PositiveCultureDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (226/1108) variable: pre_PositiveCultureTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (227/1108) variable: pre_PositiveCultureOrganismCode1 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (228/1108) variable: pre_PositiveCultureOrganismCode2 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (229/1108) variable: pre_PositiveCultureOrganismCode3 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (230/1108) variable: pre_Antibiotics type: bool
# build_numeric_value_map: (231/1108) variable: pre_AntibioticsCode1 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (232/1108) variable: pre_AntibioticsCode2 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (233/1108) variable: pre_AntibioticsCode3 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (234/1108) variable: pre_OtherMedTargetDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (235/1108) variable: pre_OtherMedTargetTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (236/1108) variable: pre_Anticonvulsants type: anticonvulsants
# [INFO] _build_numeric_value_map: to inv-text: type: anticonvulsants
# build_numeric_value_map: (237/1108) variable: pre_Anticonvulsants1 type: anticonvulsants
# [INFO] _build_numeric_value_map: to inv-text: type: anticonvulsants
# build_numeric_value_map: (238/1108) variable: pre_Anticonvulsants2 type: anticonvulsants
# [INFO] _build_numeric_value_map: to inv-text: type: anticonvulsants
# build_numeric_value_map: (239/1108) variable: pre_Anticonvulsants3 type: anticonvulsants
# [INFO] _build_numeric_value_map: to inv-text: type: anticonvulsants
# build_numeric_value_map: (240/1108) variable: pre_Anticonvulsants_b type: bool
# build_numeric_value_map: (241/1108) variable: pre_AnalgesicsSedatives type: analgesics
# [INFO] _build_numeric_value_map: to inv-text: type: analgesics
# build_numeric_value_map: (242/1108) variable: pre_AnalgesicsSedatives1 type: analgesics
# [INFO] _build_numeric_value_map: to inv-text: type: analgesics
# build_numeric_value_map: (243/1108) variable: pre_AnalgesicsSedatives2 type: analgesics
# [INFO] _build_numeric_value_map: to inv-text: type: analgesics
# build_numeric_value_map: (244/1108) variable: pre_AnalgesicsSedatives3 type: analgesics
# [INFO] _build_numeric_value_map: to inv-text: type: analgesics
# build_numeric_value_map: (245/1108) variable: pre_Antipyretics1 type: antipyretics
# [INFO] _build_numeric_value_map: to inv-text: type: antipyretics
# build_numeric_value_map: (246/1108) variable: pre_Antipyretics2 type: antipyretics
# [INFO] _build_numeric_value_map: to inv-text: type: antipyretics
# build_numeric_value_map: (247/1108) variable: pre_Antipyretics3 type: antipyretics
# [INFO] _build_numeric_value_map: to inv-text: type: antipyretics
# build_numeric_value_map: (248/1108) variable: pre_Paralytics1 type: paralytics
# [INFO] _build_numeric_value_map: to inv-text: type: paralytics
# build_numeric_value_map: (249/1108) variable: pre_Paralytics2 type: paralytics
# [INFO] _build_numeric_value_map: to inv-text: type: paralytics
# build_numeric_value_map: (250/1108) variable: pre_Paralytics3 type: paralytics
# [INFO] _build_numeric_value_map: to inv-text: type: paralytics
# build_numeric_value_map: (251/1108) variable: pre_OtherMedFluidIntake_ccPerKg type: float
# build_numeric_value_map: (252/1108) variable: pre_OtherMedUrineOutput_ccPerKg type: float
# build_numeric_value_map: (253/1108) variable: pre_HeadSonogram type: bool
# build_numeric_value_map: (254/1108) variable: pre_HeadSonogramDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (255/1108) variable: pre_HeadSonogramTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (256/1108) variable: pre_HeadSonogramResult1 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (257/1108) variable: pre_HeadSonogramResult2 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (258/1108) variable: pre_HeadSonogramResult3 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (259/1108) variable: pre_HeadSonogramResult4 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (260/1108) variable: pre_HeadSonogramResult5 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (261/1108) variable: pre_HeadSonogramResult6 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (262/1108) variable: pre_HeadSonogramResult7 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (263/1108) variable: pre_HeadSonogramResult8 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (264/1108) variable: pre_HeadSonogramResultText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (265/1108) variable: pre_HeadCT type: bool
# build_numeric_value_map: (266/1108) variable: pre_HeadCTDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (267/1108) variable: pre_HeadCTTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (268/1108) variable: pre_HeadCTResult1 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (269/1108) variable: pre_HeadCTResult2 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (270/1108) variable: pre_HeadCTResult3 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (271/1108) variable: pre_HeadCTResult4 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (272/1108) variable: pre_HeadCTResult5 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (273/1108) variable: pre_HeadCTResult6 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (274/1108) variable: pre_HeadCTResult7 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (275/1108) variable: pre_HeadCTResult8 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (276/1108) variable: pre_HeadCTResultText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (277/1108) variable: pre_BrainMRI type: bool
# build_numeric_value_map: (278/1108) variable: pre_BrainMRIDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (279/1108) variable: pre_BrainMRITime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (280/1108) variable: pre_BrainMRIResult1 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (281/1108) variable: pre_BrainMRIResult2 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (282/1108) variable: pre_BrainMRIResult3 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (283/1108) variable: pre_BrainMRIResult4 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (284/1108) variable: pre_BrainMRIResult5 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (285/1108) variable: pre_BrainMRIResult6 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (286/1108) variable: pre_BrainMRIResult7 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (287/1108) variable: pre_BrainMRIResult8 type: imaging
# [INFO] _build_numeric_value_map: to inv-text: type: imaging
# build_numeric_value_map: (288/1108) variable: pre_BrainMRIResultText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (289/1108) variable: pre_NeuroExam type: bool
# build_numeric_value_map: (290/1108) variable: pre_NoNeuroExamReason type: noNeuroExamReason
# [INFO] _build_numeric_value_map: to inv-text: type: noNeuroExamReason
# build_numeric_value_map: (291/1108) variable: pre_NeuroExamSignModerateSevereHIE3Category type: bool
# build_numeric_value_map: (292/1108) variable: pre_NeuroExamLevelConsciousness type: signOfHIELvlOfCons
# build_numeric_value_map: (293/1108) variable: pre_NeuroExamSpontaneousActivity type: signOfHIESpontaneousActivity
# build_numeric_value_map: (294/1108) variable: pre_NeuroExamPosture type: signOfHIEPosture
# build_numeric_value_map: (295/1108) variable: pre_NeuroExamTone type: signOfHIETone
# build_numeric_value_map: (296/1108) variable: pre_NeuroExamSuck type: signOfHIESuck
# build_numeric_value_map: (297/1108) variable: pre_NeuroExamMoro type: signOfHIEMoro
# build_numeric_value_map: (298/1108) variable: pre_NeuroExamPupils type: signOfHIEPupils
# build_numeric_value_map: (299/1108) variable: pre_NeuroExamHeartRate type: signOfHIEHeartRate
# build_numeric_value_map: (300/1108) variable: pre_NeuroExamRespiration type: signOfHIERespiratory
# build_numeric_value_map: (301/1108) variable: pre_NeuroExamLevelConsciousnessScore type: int
# build_numeric_value_map: (302/1108) variable: pre_NeuroExamSpontaneousActivityScore type: int
# build_numeric_value_map: (303/1108) variable: pre_NeuroExamPostureScore type: int
# build_numeric_value_map: (304/1108) variable: pre_NeuroExamToneScore type: int
# build_numeric_value_map: (305/1108) variable: pre_NeuroExamSuckScore type: int
# build_numeric_value_map: (306/1108) variable: pre_NeuroExamMoroScore type: int
# build_numeric_value_map: (307/1108) variable: pre_NeuroExamPupilsScore type: int
# build_numeric_value_map: (308/1108) variable: pre_NeuroExamHeartRateScore type: int
# build_numeric_value_map: (309/1108) variable: pre_NeuroExamRespirationScore type: int
# build_numeric_value_map: (310/1108) variable: pre_NeuroExamReflexScore type: int
# build_numeric_value_map: (311/1108) variable: pre_NeuroExamANSScore type: int
# build_numeric_value_map: (312/1108) variable: pre_TotalModifiedSarnatScore type: int
# build_numeric_value_map: (313/1108) variable: pre_NeuroExamDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (314/1108) variable: pre_NeuroExamTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (315/1108) variable: pre_NeuroExamSedate type: bool
# build_numeric_value_map: (316/1108) variable: pre_NeuroExamSeizure type: bool
# build_numeric_value_map: (317/1108) variable: temperatureTimeSlot_min type: int
# build_numeric_value_map: (318/1108) variable: temperatureTimeSlotNoForm type: bool
# build_numeric_value_map: (319/1108) variable: temperatureDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (320/1108) variable: temperatureTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (321/1108) variable: skinTemperature_C type: float
# build_numeric_value_map: (322/1108) variable: axillaryTemperature_C type: float
# build_numeric_value_map: (323/1108) variable: esophagealTemperature_C type: float
# build_numeric_value_map: (324/1108) variable: blanketTemperature_C type: float
# build_numeric_value_map: (325/1108) variable: servoSetTemperature_C type: float
# build_numeric_value_map: (326/1108) variable: alterationSkinIntegrity type: bool
# build_numeric_value_map: (327/1108) variable: shiver type: bool
# build_numeric_value_map: (328/1108) variable: cardioTimeSlot_min type: int
# build_numeric_value_map: (329/1108) variable: cardioDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (330/1108) variable: cardioTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (331/1108) variable: cardioSystolicBloodPressure_mmHg type: float
# build_numeric_value_map: (332/1108) variable: cardioDiastolicBloodPressure_mmHg type: float
# build_numeric_value_map: (333/1108) variable: cardioHeartRate_BPM type: float
# build_numeric_value_map: (334/1108) variable: cardioVolumeExpand type: bool
# build_numeric_value_map: (335/1108) variable: cardioInotropicAgent type: bool
# build_numeric_value_map: (336/1108) variable: cardioBloodTransfusion type: bool
# build_numeric_value_map: (337/1108) variable: cardioPlatelets type: bool
# build_numeric_value_map: (338/1108) variable: respiratoryTimeSlot_min type: int
# build_numeric_value_map: (339/1108) variable: respiratoryDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (340/1108) variable: respiratoryTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (341/1108) variable: respiratorySupportType type: respiratorySupportType
# [INFO] _build_numeric_value_map: to inv-text: type: respiratorySupportType
# build_numeric_value_map: (342/1108) variable: respiratoryFiO2 type: float
# build_numeric_value_map: (343/1108) variable: respiratoryRate_Hz type: float
# build_numeric_value_map: (344/1108) variable: respiratoryPIP_cmH2O type: float
# build_numeric_value_map: (345/1108) variable: respiratoryMAP_cmH2O type: float
# build_numeric_value_map: (346/1108) variable: respiratoryPEEP_cmH2O type: float
# build_numeric_value_map: (347/1108) variable: bloodGasTimeSlot_min type: int
# build_numeric_value_map: (348/1108) variable: bloodGasDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (349/1108) variable: bloodGasTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (350/1108) variable: bloodGasSrc type: bloodGasSrc
# [INFO] _build_numeric_value_map: to inv-text: type: bloodGasSrc
# build_numeric_value_map: (351/1108) variable: bloodGasPH type: float
# build_numeric_value_map: (352/1108) variable: bloodGasPCO2_mmHg type: float
# build_numeric_value_map: (353/1108) variable: bloodGasPO2_mmHg type: float
# build_numeric_value_map: (354/1108) variable: bloodGasHCO3_mEqPerL type: float
# build_numeric_value_map: (355/1108) variable: bloodGasBaseDeficit_mEqPerL type: float
# build_numeric_value_map: (356/1108) variable: bloodGasPHCorrect type: float
# build_numeric_value_map: (357/1108) variable: bloodGasPCO2Correct_mmHg type: float
# build_numeric_value_map: (358/1108) variable: bloodGasPO2Correct_mmHg type: float
# build_numeric_value_map: (359/1108) variable: bloodGasHCO3Correct_mEqPerL type: float
# build_numeric_value_map: (360/1108) variable: bloodGasBaseDeficitCorrect_mEqPerL type: float
# build_numeric_value_map: (361/1108) variable: hematology type: bool
# build_numeric_value_map: (362/1108) variable: hematologyTimeSlot_min type: int
# build_numeric_value_map: (363/1108) variable: hematologyDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (364/1108) variable: hematologyTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (365/1108) variable: hematologyWBC_cPermuL type: float
# build_numeric_value_map: (366/1108) variable: hematologyWBCMin_cPermuL type: float
# build_numeric_value_map: (367/1108) variable: hematologyWBCMax_cPermuL type: float
# build_numeric_value_map: (368/1108) variable: hematologyHemoglobin_gPerdL type: float
# build_numeric_value_map: (369/1108) variable: hematologyPolymorphNeutrophils_cPermuL type: float
# build_numeric_value_map: (370/1108) variable: hematologyMonocytes_cPermuL type: float
# build_numeric_value_map: (371/1108) variable: hematologyLymphocytes_cPermuL type: float
# build_numeric_value_map: (372/1108) variable: hematologyPlatelet_cPermuL type: float
# build_numeric_value_map: (373/1108) variable: hematologyPT_s type: float
# build_numeric_value_map: (374/1108) variable: hematologyPTT_s type: float
# build_numeric_value_map: (375/1108) variable: hematologyHematocritMin type: float
# build_numeric_value_map: (376/1108) variable: hematologyHematocritMinDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (377/1108) variable: hematologyHematocritMax type: float
# build_numeric_value_map: (378/1108) variable: hematologyHematocritMaxDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (379/1108) variable: hematologyPlateletMin_cPermuL type: float
# build_numeric_value_map: (380/1108) variable: hematologyPlateletMin_cPermuLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (381/1108) variable: bloodValueBunBaseline_mgPerdL type: float
# build_numeric_value_map: (382/1108) variable: bloodValueBunBaseline_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (383/1108) variable: bloodValueCreatinineBaseline_mgPerdL type: float
# build_numeric_value_map: (384/1108) variable: bloodValueCreatinineBaseline_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (385/1108) variable: bloodValueASTSGOTBaseline_UPerL type: float
# build_numeric_value_map: (386/1108) variable: bloodValueASTSGOTBaseline_UPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (387/1108) variable: bloodValueALTSGPTBaseline_UPerL type: float
# build_numeric_value_map: (388/1108) variable: bloodValueALTSGPTBaseline_UPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (389/1108) variable: bloodValueTotalBilirubinBaseline_mgPerdL type: float
# build_numeric_value_map: (390/1108) variable: bloodValueTotalBilirubinBaseline_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (391/1108) variable: bloodValuePHMin type: float
# build_numeric_value_map: (392/1108) variable: bloodValuePHMinDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (393/1108) variable: bloodValueHCO3Min_mEqPerL type: float
# build_numeric_value_map: (394/1108) variable: bloodValueHCO3Min_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (395/1108) variable: bloodValueSerumNaMin_mEqPerL type: float
# build_numeric_value_map: (396/1108) variable: bloodValueSerumNaMin_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (397/1108) variable: bloodValueSerumKMin_mEqPerL type: float
# build_numeric_value_map: (398/1108) variable: bloodValueSerumKMin_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (399/1108) variable: bloodValueClMin_mEqPerL type: float
# build_numeric_value_map: (400/1108) variable: bloodValueClMin_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (401/1108) variable: bloodValueGlucoseMin_mgPerdL type: float
# build_numeric_value_map: (402/1108) variable: bloodValueGlucoseMin_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (403/1108) variable: bloodValueTotalCaMin_mgPerdL type: float
# build_numeric_value_map: (404/1108) variable: bloodValueTotalCaMin_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (405/1108) variable: bloodValueIonCaMin_mgPerdL type: float
# build_numeric_value_map: (406/1108) variable: bloodValueIonCaMin_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (407/1108) variable: bloodValueASTSGOTMin_UPerL type: float
# build_numeric_value_map: (408/1108) variable: bloodValueASTSGOTMin_UPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (409/1108) variable: bloodValueALTSGPTMin_UPerL type: float
# build_numeric_value_map: (410/1108) variable: bloodValueALTSGPTMin_UPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (411/1108) variable: bloodValueTotalBilirubinMin_mgPerdL type: float
# build_numeric_value_map: (412/1108) variable: bloodValueTotalBilirubinMin_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (413/1108) variable: bloodValuePHMax type: float
# build_numeric_value_map: (414/1108) variable: bloodValuePHMaxDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (415/1108) variable: bloodValueBaseDeficitMax_mEqPerL type: float
# build_numeric_value_map: (416/1108) variable: bloodValueBaseDeficitMax_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (417/1108) variable: bloodValueSerumNaMax_mEqPerL type: float
# build_numeric_value_map: (418/1108) variable: bloodValueSerumNaMax_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (419/1108) variable: bloodValueSerumKMax_mEqPerL type: float
# build_numeric_value_map: (420/1108) variable: bloodValueSerumKMax_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (421/1108) variable: bloodValueClMax_mEqPerL type: float
# build_numeric_value_map: (422/1108) variable: bloodValueClMax_mEqPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (423/1108) variable: bloodValueBunMax_mgPerdL type: float
# build_numeric_value_map: (424/1108) variable: bloodValueBunMax_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (425/1108) variable: bloodValueCreatinineMax_mgPerdL type: float
# build_numeric_value_map: (426/1108) variable: bloodValueCreatinineMax_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (427/1108) variable: bloodValueGlucoseMax_mgPerdL type: float
# build_numeric_value_map: (428/1108) variable: bloodValueGlucoseMax_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (429/1108) variable: bloodValueTotalCaMax_mgPerdL type: float
# build_numeric_value_map: (430/1108) variable: bloodValueTotalCaMax_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (431/1108) variable: bloodValueIonCaMax_mgPerdL type: float
# build_numeric_value_map: (432/1108) variable: bloodValueIonCaMax_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (433/1108) variable: bloodValueASTSGOTMax_UPerL type: float
# build_numeric_value_map: (434/1108) variable: bloodValueASTSGOTMax_UPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (435/1108) variable: bloodValueALTSGPTMax_UPerL type: float
# build_numeric_value_map: (436/1108) variable: bloodValueALTSGPTMax_UPerLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (437/1108) variable: bloodValueTotalBilirubinMax_mgPerdL type: float
# build_numeric_value_map: (438/1108) variable: bloodValueTotalBilirubinMax_mgPerdLDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (439/1108) variable: positiveCultureNumber type: int
# build_numeric_value_map: (440/1108) variable: positiveCulture type: bool
# build_numeric_value_map: (441/1108) variable: positiveCultureSrc type: positiveCultureSrc
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureSrc
# build_numeric_value_map: (442/1108) variable: positiveCultureDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (443/1108) variable: positiveCultureTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (444/1108) variable: positiveCultureOrganismCode1 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (445/1108) variable: positiveCultureOrganismCode2 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (446/1108) variable: positiveCultureOrganismCode3 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (447/1108) variable: antibiotics type: bool
# build_numeric_value_map: (448/1108) variable: antibioticsCode1 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (449/1108) variable: antibioticsCode2 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (450/1108) variable: antibioticsCode3 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (451/1108) variable: rewarmingAntibiotics type: bool
# build_numeric_value_map: (452/1108) variable: rewarmingAntibioticsCode1 type: antibiotics
# [INFO] _build_numeric_value_map: to inv-text: type: antibiotics
# build_numeric_value_map: (453/1108) variable: rewarmingAntibioticsCode2 type: antibiotics
# ...
# build_numeric_value_map: (957/1108) variable: dischargeCardiacIschemiaByEKG type: bool
# build_numeric_value_map: (958/1108) variable: dischargeHypotension type: bool
# build_numeric_value_map: (959/1108) variable: dischargeArrhythmia type: bool
# build_numeric_value_map: (960/1108) variable: dischargeInotropicAgent type: bool
# build_numeric_value_map: (961/1108) variable: dischargeMeconiumAspirationSyndrome type: bool
# build_numeric_value_map: (962/1108) variable: dischargePPHN type: bool
# build_numeric_value_map: (963/1108) variable: dischargePulmonaryHemorrhage type: bool
# build_numeric_value_map: (964/1108) variable: dischargePenumonia type: bool
# build_numeric_value_map: (965/1108) variable: dischargeChronicLungDisease type: bool
# build_numeric_value_map: (966/1108) variable: dischargeECMO type: bool
# build_numeric_value_map: (967/1108) variable: dischargeINO type: bool
# build_numeric_value_map: (968/1108) variable: dischargeVentilator_day type: int
# build_numeric_value_map: (969/1108) variable: dischargeOxygen_day type: int
# build_numeric_value_map: (970/1108) variable: dischargeCPAP_day type: int
# build_numeric_value_map: (971/1108) variable: dischargePulmonaryStartDate1 type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (972/1108) variable: dischargePulmonaryStartTime1 type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (973/1108) variable: dischargePulmonaryEndDate1 type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (974/1108) variable: dischargePulmonaryEndTime1 type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (975/1108) variable: dischargePulmonaryStartDate2 type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (976/1108) variable: dischargePulmonaryStartTime2 type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (977/1108) variable: dischargePulmonaryEndDate2 type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (978/1108) variable: dischargePulmonaryEndTime2 type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (979/1108) variable: dischargePulmonaryStartDate3 type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (980/1108) variable: dischargePulmonaryStartTime3 type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (981/1108) variable: dischargePulmonaryEndDate3 type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (982/1108) variable: dischargePulmonaryEndTime3 type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (983/1108) variable: dischargeDIC type: bool
# build_numeric_value_map: (984/1108) variable: dischargeHypoglycemia type: bool
# build_numeric_value_map: (985/1108) variable: dischargeHypocalcemia type: bool
# build_numeric_value_map: (986/1108) variable: dischargeHypomagnesemia type: bool
# build_numeric_value_map: (987/1108) variable: dischargeOliguria type: bool
# build_numeric_value_map: (988/1108) variable: dischargeAnuria type: bool
# build_numeric_value_map: (989/1108) variable: dischargeDialysis type: bool
# build_numeric_value_map: (990/1108) variable: dischargeEnteralFeedStart_day type: int
# build_numeric_value_map: (991/1108) variable: dischargeTubeFeedingDuration_day type: int
# build_numeric_value_map: (992/1108) variable: dischargeFullNippleFeed type: bool
# build_numeric_value_map: (993/1108) variable: dischargeFullNippleFeed_day type: int
# build_numeric_value_map: (994/1108) variable: dischargeNEC type: bool
# build_numeric_value_map: (995/1108) variable: dischargeHepaticDysfunction type: bool
# build_numeric_value_map: (996/1108) variable: dischargeAlteredSkinItegrityPostIntervention type: bool
# build_numeric_value_map: (997/1108) variable: dischargeErythema type: bool
# build_numeric_value_map: (998/1108) variable: dischargeErythemaOnsetDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (999/1108) variable: dischargeErythemaResolveDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1000/1108) variable: dischargeSclerema type: bool
# build_numeric_value_map: (1001/1108) variable: dischargeScleremaOnsetDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1002/1108) variable: dischargeScleremaResolveDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1003/1108) variable: dischargeCyanosis type: bool
# build_numeric_value_map: (1004/1108) variable: dischargeCyanosisOnsetDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1005/1108) variable: dischargeCyanosisResolveDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1006/1108) variable: dischargeSubFatNecrosis type: bool
# build_numeric_value_map: (1007/1108) variable: dischargeSubFatNecrosisOnsetDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1008/1108) variable: dischargeSubFatNecrosisResolveDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1009/1108) variable: dischargeHearingTest type: bool
# build_numeric_value_map: (1010/1108) variable: dischargeHearingTestNormal type: bool
# build_numeric_value_map: (1011/1108) variable: dischargeMajorSurgery type: bool
# build_numeric_value_map: (1012/1108) variable: dischargeSurgeryCode1 type: surgery
# [INFO] _build_numeric_value_map: to inv-text: type: surgery
# build_numeric_value_map: (1013/1108) variable: dischargeSurgeryCode2 type: surgery
# [INFO] _build_numeric_value_map: to inv-text: type: surgery
# build_numeric_value_map: (1014/1108) variable: dischargeSurgeryCode3 type: surgery
# [INFO] _build_numeric_value_map: to inv-text: type: surgery
# build_numeric_value_map: (1015/1108) variable: dischargeSepticemia type: bool
# build_numeric_value_map: (1016/1108) variable: dischargeSepticemiaOrganismCode1 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (1017/1108) variable: dischargeSepticemiaOrganismCode2 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (1018/1108) variable: dischargeSepticemiaOrganismCode3 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (1019/1108) variable: dischargeMeningitisEncephalitis type: bool
# build_numeric_value_map: (1020/1108) variable: dischargeMeningitisOrganismCode1 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (1021/1108) variable: dischargeMeningitisOrganismCode2 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (1022/1108) variable: dischargeMeningitisOrganismCode3 type: positiveCultureOrganism
# [INFO] _build_numeric_value_map: to inv-text: type: positiveCultureOrganism
# build_numeric_value_map: (1023/1108) variable: dischargeNeuroExam type: bool
# build_numeric_value_map: (1024/1108) variable: dischargeNeuroExamStatus type: dischargeNeuroExamStatus
# [INFO] _build_numeric_value_map: to inv-text: type: dischargeNeuroExamStatus
# build_numeric_value_map: (1025/1108) variable: dischargeNeuroExamDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1026/1108) variable: dischargeNeuroExamTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (1027/1108) variable: dischargeNeuroExamLevelConsciousness type: signOfHIELvlOfCons
# build_numeric_value_map: (1028/1108) variable: dischargeNeuroExamSpontaneousActivity type: signOfHIESpontaneousActivity
# build_numeric_value_map: (1029/1108) variable: dischargeNeuroExamPosture type: signOfHIEPosture
# build_numeric_value_map: (1030/1108) variable: dischargeNeuroExamTone type: signOfHIETone
# build_numeric_value_map: (1031/1108) variable: dischargeNeuroExamSuck type: signOfHIESuck
# build_numeric_value_map: (1032/1108) variable: dischargeNeuroExamMoro type: signOfHIEMoro
# build_numeric_value_map: (1033/1108) variable: dischargeNeuroExamPupils type: signOfHIEPupils
# build_numeric_value_map: (1034/1108) variable: dischargeNeuroExamHeartRate type: signOfHIEHeartRate
# build_numeric_value_map: (1035/1108) variable: dischargeNeuroExamRespiration type: signOfHIERespiratory
# build_numeric_value_map: (1036/1108) variable: dischargeNeuroExamSeizure type: bool
# build_numeric_value_map: (1037/1108) variable: dischargeNeuroExamClonusSustained type: bool
# build_numeric_value_map: (1038/1108) variable: dischargeNeuroExamFistedHand type: bool
# build_numeric_value_map: (1039/1108) variable: dischargeNeuroExamAbnormalMovement type: bool
# build_numeric_value_map: (1040/1108) variable: dischargeNeuroExamGagReflexAbsent type: bool
# build_numeric_value_map: (1041/1108) variable: dischargeNeuroExamSedate type: bool
# build_numeric_value_map: (1042/1108) variable: dischargeNeuroExamHypertonia type: bool
# build_numeric_value_map: (1043/1108) variable: dischargeNeuroExamAsymTonicNeckReflex type: bool
# build_numeric_value_map: (1044/1108) variable: dischargeNeuroExamLevelConsciousnessScore type: int
# build_numeric_value_map: (1045/1108) variable: dischargeNeuroExamSpontaneousActivityScore type: int
# build_numeric_value_map: (1046/1108) variable: dischargeNeuroExamPostureScore type: int
# build_numeric_value_map: (1047/1108) variable: dischargeNeuroExamToneScore type: int
# build_numeric_value_map: (1048/1108) variable: dischargeNeuroExamSuckScore type: int
# build_numeric_value_map: (1049/1108) variable: dischargeNeuroExamMoroScore type: int
# build_numeric_value_map: (1050/1108) variable: dischargeNeuroExamPupilsScore type: int
# build_numeric_value_map: (1051/1108) variable: dischargeNeuroExamHeartRateScore type: int
# build_numeric_value_map: (1052/1108) variable: dischargeNeuroExamRespirationScore type: int
# build_numeric_value_map: (1053/1108) variable: dischargeNeuroExamReflexScore type: int
# build_numeric_value_map: (1054/1108) variable: dischargeNeuroExamANSScore type: int
# build_numeric_value_map: (1055/1108) variable: dischargeTotalModifiedSarnatScore type: int
# build_numeric_value_map: (1056/1108) variable: dischargeSeizure type: bool
# build_numeric_value_map: (1057/1108) variable: dischargeSeizurePreIntervention type: bool
# build_numeric_value_map: (1058/1108) variable: dischargeSeizureAfterBaseline type: bool
# build_numeric_value_map: (1059/1108) variable: dischargeSeizureMaintenance type: bool
# build_numeric_value_map: (1060/1108) variable: dischargeSeizureRewarming type: bool
# build_numeric_value_map: (1061/1108) variable: dischargeSeizurePostIntervention type: bool
# build_numeric_value_map: (1062/1108) variable: dischargeEEG type: bool
# build_numeric_value_map: (1063/1108) variable: dischargeEEGFindingConsistentWithSeizure type: bool
# build_numeric_value_map: (1064/1108) variable: dischargeEEGFindingConsistentWithSeizureDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1065/1108) variable: dischargeEEGFindingConsistentWithSeizureTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (1066/1108) variable: dischargeEEGAbnormalBackgroundActivity type: bool
# build_numeric_value_map: (1067/1108) variable: dischargeEEGAbnormalBackgroundActivityDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1068/1108) variable: dischargeEEGAbnormalBackgroundActivityTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (1069/1108) variable: dischargeAnticonvulsantsGreater72H type: bool
# build_numeric_value_map: (1070/1108) variable: dischargeAnticonvulsants type: bool
# build_numeric_value_map: (1071/1108) variable: dischargeSyndromeMalformation type: bool
# build_numeric_value_map: (1072/1108) variable: dischargeBirthDefectCode1 type: birthDefect
# [INFO] _build_numeric_value_map: to inv-text: type: birthDefect
# build_numeric_value_map: (1073/1108) variable: dischargeBirthDefectCode2 type: birthDefect
# [INFO] _build_numeric_value_map: to inv-text: type: birthDefect
# build_numeric_value_map: (1074/1108) variable: dischargeBirthDefectCode3 type: birthDefect
# [INFO] _build_numeric_value_map: to inv-text: type: birthDefect
# build_numeric_value_map: (1075/1108) variable: dischargeHomeTherapy type: bool
# build_numeric_value_map: (1076/1108) variable: dischargeHomeTherapyVentilator type: bool
# build_numeric_value_map: (1077/1108) variable: dischargeHomeTherapyOxygen type: bool
# build_numeric_value_map: (1078/1108) variable: dischargeHomeTherapyGavageTubeFeed type: bool
# build_numeric_value_map: (1079/1108) variable: dischargeHomeTherapyGastrostomyTubeFeed type: bool
# build_numeric_value_map: (1080/1108) variable: dischargeHomeTherapyTemperatureBlanket type: bool
# build_numeric_value_map: (1081/1108) variable: dischargeHomeTherapyAnticonvulsantMedication type: bool
# build_numeric_value_map: (1082/1108) variable: dischargeHomeTherapyOther type: bool
# build_numeric_value_map: (1083/1108) variable: dischargeHomeTherapyOtherText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (1084/1108) variable: wdrawSupport type: bool
# build_numeric_value_map: (1085/1108) variable: wdrawSupportDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1086/1108) variable: wdrawSupportTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time
# build_numeric_value_map: (1087/1108) variable: wdrawSupportDiscussedWithFamily type: bool
# build_numeric_value_map: (1088/1108) variable: wdrawSupportRecommendSolelyByClinicalTeam type: bool
# build_numeric_value_map: (1089/1108) variable: wdrawSupportNeurologicalExam type: bool
# build_numeric_value_map: (1090/1108) variable: wdrawSupportImagingStudy type: bool
# build_numeric_value_map: (1091/1108) variable: wdrawSupportEEGFinding type: bool
# build_numeric_value_map: (1092/1108) variable: wdrawSupportMultisystemOrganFailureOtherThanCNS type: bool
# build_numeric_value_map: (1093/1108) variable: wdrawSupportBrainBloodFlowScan type: bool
# build_numeric_value_map: (1094/1108) variable: wdrawSupportParentWish type: bool
# build_numeric_value_map: (1095/1108) variable: wdrawSupportOther type: bool
# build_numeric_value_map: (1096/1108) variable: wdrawSupportOtherText type: text
# [INFO] _build_numeric_value_map: to inv-text: type: text
# build_numeric_value_map: (1097/1108) variable: limitCareDiscussedWithFamily type: bool
# build_numeric_value_map: (1098/1108) variable: limitCareRecommendSolelyByClinicalTeam type: bool
# build_numeric_value_map: (1099/1108) variable: limitCareAgreedByFamilyAndCareTeam type: bool
# build_numeric_value_map: (1100/1108) variable: limitCareNoFurtherMechanicalVentilationAndIntubation type: bool
# build_numeric_value_map: (1101/1108) variable: limitCareNoFurtherVentilationWithBagAndMask type: bool
# build_numeric_value_map: (1102/1108) variable: limitCareNoFurtherMedicationsToSupportBP type: bool
# build_numeric_value_map: (1103/1108) variable: limitCareNoFurtherChestCompression type: bool
# build_numeric_value_map: (1104/1108) variable: limitCareNoFurtherEmergencyMedication type: bool
# build_numeric_value_map: (1105/1108) variable: limitCareDNR type: bool
# build_numeric_value_map: (1106/1108) variable: limitCareDNRDate type: date
# [INFO] _build_numeric_value_map: to inv-text: type: date
# build_numeric_value_map: (1107/1108) variable: limitCareDNRTime type: time
# [INFO] _build_numeric_value_map: to inv-text: type: time

# %% [markdown]
# ## 02-00. Total Modified Sarnat Scores

# %%
def _total_modified_sarnat_scores(base_filename, prefix):
    base_core_columns = [
        f'{prefix}NeuroExamLevelConsciousnessScore',
        f'{prefix}NeuroExamSpontaneousActivityScore',
        f'{prefix}NeuroExamPostureScore',
        f'{prefix}NeuroExamToneScore',
    ]
    base_reflex_columns = [
        f'{prefix}NeuroExamSuckScore',
        f'{prefix}NeuroExamMoroScore',
    ]
    base_ans_columns = [
        f'{prefix}NeuroExamPupilsScore',
        f'{prefix}NeuroExamHeartRateScore',
        f'{prefix}NeuroExamRespirationScore',
    ]

    base_columns = list(map(lambda x: x[:-5], base_core_columns + base_reflex_columns + base_ans_columns))
    total_modified_sarnat_score_columns = base_core_columns + [
        f'{prefix}NeuroExamReflexScore',
        f'{prefix}NeuroExamANSScore',
    ]

    full_filename = f'{out_dir}/out-merged-normalized/{base_filename}'

    df = pd.read_csv(full_filename)

    columns = COMBINE_harmonizer.RESERVED_COLUMNS + base_columns

    df = COMBINE_harmonizer.valid_columns(df, columns)

    df_numeric = COMBINE_harmonizer.numeric_values(df, _NUMERIC_VALUE_MAP_MAIN)

    column_map = {
        f'{prefix}NeuroExamLevelConsciousness':  f'{prefix}NeuroExamLevelConsciousnessScore',
        f'{prefix}NeuroExamSpontaneousActivity': f'{prefix}NeuroExamSpontaneousActivityScore',
        f'{prefix}NeuroExamPosture': f'{prefix}NeuroExamPostureScore',
        f'{prefix}NeuroExamTone': f'{prefix}NeuroExamToneScore',

        f'{prefix}NeuroExamSuck': f'{prefix}NeuroExamSuckScore',
        f'{prefix}NeuroExamMoro': f'{prefix}NeuroExamMoroScore',

        f'{prefix}NeuroExamPupils': f'{prefix}NeuroExamPupilsScore',
        f'{prefix}NeuroExamHeartRate': f'{prefix}NeuroExamHeartRateScore',
        f'{prefix}NeuroExamRespiration': f'{prefix}NeuroExamRespirationScore',
    }

    df_numeric = df_numeric.rename(columns=column_map)

    # if any neuro exam score: default to 1 (normal) for the rest of the scores.
    is_invalid_level_consciousness = df_numeric[f'{prefix}NeuroExamLevelConsciousnessScore'].isnull()
    is_invalid_spontaneous_activity = df_numeric[f'{prefix}NeuroExamSpontaneousActivityScore'].isnull()
    is_invalid_posture = df_numeric[f'{prefix}NeuroExamPostureScore'].isnull()
    is_invalid_tone = df_numeric[f'{prefix}NeuroExamToneScore'].isnull()
    is_invalid_suck = df_numeric[f'{prefix}NeuroExamSuckScore'].isnull()
    is_invalid_moro = df_numeric[f'{prefix}NeuroExamMoroScore'].isnull()
    is_invalid_pupils = df_numeric[f'{prefix}NeuroExamPupilsScore'].isnull()
    is_invalid_heart_rate = df_numeric[f'{prefix}NeuroExamHeartRateScore'].isnull()
    is_invalid_respiration = df_numeric[f'{prefix}NeuroExamRespirationScore'].isnull()
    is_invalid_all = is_invalid_level_consciousness & is_invalid_spontaneous_activity & is_invalid_posture & is_invalid_tone & is_invalid_suck & is_invalid_moro & is_invalid_pupils & is_invalid_heart_rate & is_invalid_respiration
    is_valid_any = is_invalid_all == False

    df_numeric.loc[is_invalid_level_consciousness & is_valid_any, f'{prefix}NeuroExamLevelConsciousnessScore'] = 1
    df_numeric.loc[is_invalid_spontaneous_activity & is_valid_any, f'{prefix}NeuroExamSpontaneousActivityScore'] = 1
    df_numeric.loc[is_invalid_posture & is_valid_any, f'{prefix}NeuroExamPostureScore'] = 1
    df_numeric.loc[is_invalid_tone & is_valid_any, f'{prefix}NeuroExamToneScore'] = 1
    df_numeric.loc[is_invalid_suck & is_valid_any, f'{prefix}NeuroExamSuckScore'] = 1
    df_numeric.loc[is_invalid_moro & is_valid_any, f'{prefix}NeuroExamMoroScore'] = 1
    df_numeric.loc[is_invalid_pupils & is_valid_any, f'{prefix}NeuroExamPupilsScore'] = 1
    df_numeric.loc[is_invalid_heart_rate & is_valid_any, f'{prefix}NeuroExamHeartRateScore'] = 1
    df_numeric.loc[is_invalid_respiration & is_valid_any, f'{prefix}NeuroExamRespirationScore'] = 1

    df_numeric[f'{prefix}NeuroExamReflexScore'] = df_numeric.apply(lambda x: COMBINE_harmonizer.safe_max([x[column] for column in base_reflex_columns]), axis=1)

    df_numeric[f'{prefix}NeuroExamANSScore'] = df_numeric.apply(lambda x: COMBINE_harmonizer.safe_max([x[column] for column in base_ans_columns]), axis=1)

    df_numeric[f'{prefix}TotalModifiedSarnatScore'] = COMBINE_harmonizer.total_modified_sarnat_score(df_numeric, total_modified_sarnat_score_columns)
    df_numeric = COMBINE_harmonizer.postprocess(df_numeric)

    return df_numeric

# %% [markdown]
# ## 02-01. Pre-intervention

# %%
base_filename = '01-12-neuro-exam.csv'
prefix = 'pre_'

df_pre = _total_modified_sarnat_scores(base_filename, prefix)

out_filename = f'{out_dir}/out-merged-normalized/01-12_1-total-modified-sarnat.csv'
df_pre.to_csv(out_filename, index=False)
# Out:
# (4/18) MRI_ID not in df
# (5/18) followupCenter not in df
# (6/18) followupID not in df
# (7/18) uniqueFollowupID not in df
# (8/18) _flatten_index not in df
# [WARN] (0/13) not in numeric_value_map: _study
# [INFO] (1/13) to numeric value: column: center var_name: center
# [INFO] (2/13) to numeric value: column: subjectID var_name: subjectID
# [WARN] (3/13) not in numeric_value_map: uniqueID
# [INFO] (4/13) to numeric value: column: pre_NeuroExamLevelConsciousness var_name: pre_NeuroExamLevelConsciousness
# [INFO] (5/13) to numeric value: column: pre_NeuroExamSpontaneousActivity var_name: pre_NeuroExamSpontaneousActivity
# [INFO] (6/13) to numeric value: column: pre_NeuroExamPosture var_name: pre_NeuroExamPosture
# [INFO] (7/13) to numeric value: column: pre_NeuroExamTone var_name: pre_NeuroExamTone
# [INFO] (8/13) to numeric value: column: pre_NeuroExamSuck var_name: pre_NeuroExamSuck
# [INFO] (9/13) to numeric value: column: pre_NeuroExamMoro var_name: pre_NeuroExamMoro
# [INFO] (10/13) to numeric value: column: pre_NeuroExamPupils var_name: pre_NeuroExamPupils
# [INFO] (11/13) to numeric value: column: pre_NeuroExamHeartRate var_name: pre_NeuroExamHeartRate
# [INFO] (12/13) to numeric value: column: pre_NeuroExamRespiration var_name: pre_NeuroExamRespiration
# [INFO] (0/6) column: pre_NeuroExamLevelConsciousnessScore (object) valid: (530/532)
# [INFO] (1/6) column: pre_NeuroExamSpontaneousActivityScore (object) valid: (530/532)
# [INFO] (2/6) column: pre_NeuroExamPostureScore (object) valid: (530/532)
# [INFO] (3/6) column: pre_NeuroExamToneScore (object) valid: (530/532)
# [INFO] (4/6) column: pre_NeuroExamReflexScore (float64) valid: (530/532)
# [INFO] (5/6) column: pre_NeuroExamANSScore (float64) valid: (530/532)

# %% [markdown]
# ## 02-02. Post-normothermia

# %%
base_filename = '03-04-post-neuro-exam.csv'
prefix = 'post_'

df_post = _total_modified_sarnat_scores(base_filename, prefix)

out_filename = f'{out_dir}/out-merged-normalized/03-04_1-total-modified-sarnat.csv'
df_post.to_csv(out_filename, index=False)
# Out:
# (4/18) MRI_ID not in df
# (5/18) followupCenter not in df
# (6/18) followupID not in df
# (7/18) uniqueFollowupID not in df
# (8/18) _flatten_index not in df
# [WARN] (0/13) not in numeric_value_map: _study
# [INFO] (1/13) to numeric value: column: center var_name: center
# [INFO] (2/13) to numeric value: column: subjectID var_name: subjectID
# [WARN] (3/13) not in numeric_value_map: uniqueID
# [INFO] (4/13) to numeric value: column: post_NeuroExamLevelConsciousness var_name: post_NeuroExamLevelConsciousness
# [INFO] (5/13) to numeric value: column: post_NeuroExamSpontaneousActivity var_name: post_NeuroExamSpontaneousActivity
# [INFO] (6/13) to numeric value: column: post_NeuroExamPosture var_name: post_NeuroExamPosture
# [INFO] (7/13) to numeric value: column: post_NeuroExamTone var_name: post_NeuroExamTone
# [INFO] (8/13) to numeric value: column: post_NeuroExamSuck var_name: post_NeuroExamSuck
# [INFO] (9/13) to numeric value: column: post_NeuroExamMoro var_name: post_NeuroExamMoro
# [INFO] (10/13) to numeric value: column: post_NeuroExamPupils var_name: post_NeuroExamPupils
# [INFO] (11/13) to numeric value: column: post_NeuroExamHeartRate var_name: post_NeuroExamHeartRate
# [INFO] (12/13) to numeric value: column: post_NeuroExamRespiration var_name: post_NeuroExamRespiration
# [INFO] (0/6) column: post_NeuroExamLevelConsciousnessScore (object) valid: (460/527)
# [INFO] (1/6) column: post_NeuroExamSpontaneousActivityScore (object) valid: (460/527)
# [INFO] (2/6) column: post_NeuroExamPostureScore (object) valid: (460/527)
# [INFO] (3/6) column: post_NeuroExamToneScore (object) valid: (460/527)
# [INFO] (4/6) column: post_NeuroExamReflexScore (float64) valid: (460/527)
# [INFO] (5/6) column: post_NeuroExamANSScore (float64) valid: (460/527)

# %% [markdown]
# ## 02-03. Discharge

# %%
base_filename = '04-12-neuro-exam.csv'
prefix = 'discharge'

df_discharge = _total_modified_sarnat_scores(base_filename, prefix)

out_filename = f'{out_dir}/out-merged-normalized/04-12_1-total-modified-sarnat.csv'
df_discharge.to_csv(out_filename, index=False)
# Out:
# (4/18) MRI_ID not in df
# (5/18) followupCenter not in df
# (6/18) followupID not in df
# (7/18) uniqueFollowupID not in df
# (8/18) _flatten_index not in df
# [WARN] (0/13) not in numeric_value_map: _study
# [INFO] (1/13) to numeric value: column: center var_name: center
# [INFO] (2/13) to numeric value: column: subjectID var_name: subjectID
# [WARN] (3/13) not in numeric_value_map: uniqueID
# [INFO] (4/13) to numeric value: column: dischargeNeuroExamLevelConsciousness var_name: dischargeNeuroExamLevelConsciousness
# [INFO] (5/13) to numeric value: column: dischargeNeuroExamSpontaneousActivity var_name: dischargeNeuroExamSpontaneousActivity
# [INFO] (6/13) to numeric value: column: dischargeNeuroExamPosture var_name: dischargeNeuroExamPosture
# [INFO] (7/13) to numeric value: column: dischargeNeuroExamTone var_name: dischargeNeuroExamTone
# [INFO] (8/13) to numeric value: column: dischargeNeuroExamSuck var_name: dischargeNeuroExamSuck
# [INFO] (9/13) to numeric value: column: dischargeNeuroExamMoro var_name: dischargeNeuroExamMoro
# [INFO] (10/13) to numeric value: column: dischargeNeuroExamPupils var_name: dischargeNeuroExamPupils
# [INFO] (11/13) to numeric value: column: dischargeNeuroExamHeartRate var_name: dischargeNeuroExamHeartRate
# [INFO] (12/13) to numeric value: column: dischargeNeuroExamRespiration var_name: dischargeNeuroExamRespiration
# [INFO] (0/6) column: dischargeNeuroExamLevelConsciousnessScore (object) valid: (490/532)
# [INFO] (1/6) column: dischargeNeuroExamSpontaneousActivityScore (object) valid: (490/532)
# [INFO] (2/6) column: dischargeNeuroExamPostureScore (object) valid: (490/532)
# [INFO] (3/6) column: dischargeNeuroExamToneScore (object) valid: (490/532)
# [INFO] (4/6) column: dischargeNeuroExamReflexScore (float64) valid: (490/532)
# [INFO] (5/6) column: dischargeNeuroExamANSScore (float64) valid: (490/532)
