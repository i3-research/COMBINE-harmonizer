# %%
import pandas as pd
pd.options.mode.copy_on_write = True
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

import os
import re
import pydoc

import COMBINE_harmonizer
from COMBINE_harmonizer import cfg

# %% [markdown]
# ## 00-0. Variables

# %%
study_name = COMBINE_harmonizer.STUDY_OC
sheet_name = COMBINE_harmonizer.SHEET_FOLLOW_UP

root_dir = '..'

# %%
COMBINE_harmonizer.init(f'{root_dir}/config.yaml')

# %%
input_dir = f"{cfg.config['out_dir']}/out-{study_name}"
data_dict_filename = f"{root_dir}/{COMBINE_harmonizer.DATA_DICTIONARY_EXCEL}"
out_dir = f"{cfg.config['out_dir']}/out-{study_name}-normalized"

os.makedirs(out_dir, exist_ok=True)

# %%
COMBINE_harmonizer.init_mapping(data_dict_filename, study_name)
_VALUE_MAP = COMBINE_harmonizer.build_value_map(data_dict_filename, sheet_name)
# Out:
# [INFO] init_mapping (0/125): signOfHIETone
# [INFO] init_mapping (1/125): signOfHIELvlOfCons
# [INFO] init_mapping (2/125): signOfHIEPosture
# [INFO] init_mapping (3/125): signOfHIEMoro
# [INFO] init_mapping (4/125): signOfHIESuck
# [INFO] init_mapping (5/125): signOfHIERespiratory
# [INFO] init_mapping (6/125): signOfHIEHeartRate
# [INFO] init_mapping (7/125): signOfHIEPupils
# [INFO] init_mapping (8/125): signOfHIESpontaneousActivity
# [INFO] init_mapping (9/125): noNeuroExamReason
# [INFO] init_mapping (10/125): consentStatus
# [INFO] init_mapping (11/125): treatmentAssign
# [INFO] init_mapping (12/125): targetTreatmentTemperature
# [INFO] init_mapping (13/125): blanketType
# [INFO] init_mapping (14/125): encephalopathyLevel
# [INFO] init_mapping (15/125): infantAge
# [INFO] init_mapping (16/125): infantSex
# [INFO] init_mapping (17/125): ethnicity
# [INFO] init_mapping (18/125): education
# [INFO] init_mapping (19/125): insurance
# [INFO] init_mapping (20/125): race
# [INFO] init_mapping (21/125): maritalStatus
# [INFO] init_mapping (22/125): deliveryMode
# [INFO] init_mapping (23/125): spontaneousRespirationTime
# [INFO] init_mapping (24/125): cordBloodGasSrc
# [INFO] init_mapping (25/125): bloodGasSrc
# [INFO] init_mapping (26/125): antibiotics
# [INFO] init_mapping (27/125): positiveCultureOrganism
# [INFO] init_mapping (28/125): positiveCultureSrc
# [INFO] init_mapping (29/125): surgery
# [INFO] init_mapping (30/125): birthDefect
# [INFO] init_mapping (31/125): anticonvulsants
# [INFO] init_mapping (32/125): analgesics
# [INFO] init_mapping (33/125): antipyretics
# [INFO] init_mapping (34/125): paralytics
# [INFO] init_mapping (35/125): respiratorySupportType
# [INFO] init_mapping (36/125): coolAfterIntervention
# [INFO] init_mapping (37/125): noCoolToEndPeriodReason
# [INFO] init_mapping (38/125): imaging
# [INFO] init_mapping (39/125): MRIReader
# [INFO] init_mapping (40/125): MRIObtainWindow
# [INFO] init_mapping (41/125): MRINoObtainReason
# [INFO] init_mapping (42/125): MRICerebralAtrophyGlobalLocal
# [INFO] init_mapping (43/125): MRICerebralAtrophyRegion
# [INFO] init_mapping (44/125): MRISeverity
# [INFO] init_mapping (45/125): MRIALICPLICSeverity
# [INFO] init_mapping (46/125): MRIInjurySeverity
# [WARN] possible conflicting setup: sheet_name: MRIInjurySeverity value: 4 value_float: 4.0 name: nan map: nan
# [WARN] possible conflicting setup: sheet_name: MRIInjurySeverity value: 4 value_int: 4 name: nan map: nan
# [INFO] init_mapping (47/125): MRINRNPatternOfInjury
# [INFO] init_mapping (48/125): MRINRNPatternOfInjuryExtent
# [INFO] init_mapping (49/125): MRINRNPatternOfInjuryLateral
# [INFO] init_mapping (50/125): MRIAbnormalRegion
# [INFO] init_mapping (51/125): MRIAbnormalSide
# [INFO] init_mapping (52/125): MRIAbnormalGMWM
# [INFO] init_mapping (53/125): MRIAbnormalExtent
# [INFO] init_mapping (54/125): MRIAbnormalType
# [INFO] init_mapping (55/125): elevatedTempDevice
# [INFO] init_mapping (56/125): elevatedTempDeviceMode
# [INFO] init_mapping (57/125): elevatedTempNoBathReason
# [INFO] init_mapping (58/125): bradycardiaEKGResult
# [INFO] init_mapping (59/125): bradycardiaDuration
# [INFO] init_mapping (60/125): bradycardiaHeartRateMin
# [INFO] init_mapping (61/125): SAEAlterationSkinIntegrity
# [INFO] init_mapping (62/125): SAEAttributable
# [INFO] init_mapping (63/125): SAEAction
# [INFO] init_mapping (64/125): SAEOutcome
# [INFO] init_mapping (65/125): deathCause
# [INFO] init_mapping (66/125): deathSrc
# [INFO] init_mapping (67/125): experimentStatus
# [INFO] init_mapping (68/125): status
# [INFO] init_mapping (69/125): transferReason
# [INFO] init_mapping (70/125): transferOutcome
# [INFO] init_mapping (71/125): dischargeNeuroExamStatus
# [INFO] init_mapping (72/125): violationCircumstance
# [INFO] init_mapping (73/125): violationNature
# [INFO] init_mapping (74/125): interruptReason
# [INFO] init_mapping (75/125): relationship
# [INFO] init_mapping (76/125): receive
# [INFO] init_mapping (77/125): totalIncome
# [INFO] init_mapping (78/125): language
# [INFO] init_mapping (79/125): homeCareLocation
# [INFO] init_mapping (80/125): babysitterRelation
# [INFO] init_mapping (81/125): interviewLocation
# [INFO] init_mapping (82/125): livingArrange
# [INFO] init_mapping (83/125): medicationUse
# [INFO] init_mapping (84/125): eyeSurgeryReason
# [INFO] init_mapping (85/125): readmissionTimePeriod
# [INFO] init_mapping (86/125): readmissionLengthOfStay
# [INFO] init_mapping (87/125): readmissionPrimaryCause
# [INFO] init_mapping (88/125): eye
# [INFO] init_mapping (89/125): vision
# [INFO] init_mapping (90/125): hearing
# [INFO] init_mapping (91/125): hearingImpaired
# [INFO] init_mapping (92/125): hearingAid
# [INFO] init_mapping (93/125): swallow
# [INFO] init_mapping (94/125): passiveMuscleTone
# [INFO] init_mapping (95/125): grossMotorFunctionLevel
# [INFO] init_mapping (96/125): handPreference
# [INFO] init_mapping (97/125): protectiveReaction
# [INFO] init_mapping (98/125): limbMovement
# [INFO] init_mapping (99/125): deepTendonReflex
# [INFO] init_mapping (100/125): ankleClonus
# [INFO] init_mapping (101/125): plantarReflex
# [INFO] init_mapping (102/125): axisHeadNeck
# [INFO] init_mapping (103/125): axisTrunk
# [INFO] init_mapping (104/125): lowerLimbFunction
# [INFO] init_mapping (105/125): upperLimbFunction
# [INFO] init_mapping (106/125): handFunction
# [INFO] init_mapping (107/125): cerebralPalsyClass
# [INFO] init_mapping (108/125): examQuality
# [INFO] init_mapping (109/125): examFactorAffecting
# [INFO] init_mapping (110/125): BayleyIIIReasonNoSuccess
# [INFO] init_mapping (111/125): followupStatus
# [INFO] init_mapping (112/125): severity
# [INFO] init_mapping (113/125): reasonLossFollowUp
# [INFO] init_mapping (114/125): childHealth
# [INFO] init_mapping (115/125): chartReview
# [INFO] init_mapping (116/125): education2
# [INFO] init_mapping (117/125): race2
# [INFO] init_mapping (118/125): flagAdjudicatedOutcome
# [INFO] init_mapping (119/125): MRILesion
# [INFO] init_mapping (120/125): MRI2LevelPatternOfInjury
# [INFO] init_mapping (121/125): MRIOverallDiagnosis
# [INFO] init_mapping (122/125): MRINRNPatternOfInjuryWSvsBGT
# [INFO] init_mapping (123/125): outcomeGroup
# [INFO] init_mapping (124/125): initBloodGasSrc
# [INFO] init_mapping (cfg_dict_map) (0/1): MRIReader
# build_value_map: (1108/377) variable: followupCenter type: center
# build_value_map: (1109/377) variable: siteID type: text
# build_value_map: (1110/377) variable: birthDate type: date
# build_value_map: (1111/377) variable: visitDate type: date
# build_value_map: (1112/377) variable: birthNumber type: int
# build_value_map: (1113/377) variable: center type: center
# build_value_map: (1114/377) variable: subjectID type: text
# build_value_map: (1115/377) variable: followupID type: text
# build_value_map: (1116/377) variable: center_orig type: text
# build_value_map: (1117/377) variable: SESVisitDate type: date
# build_value_map: (1118/377) variable: SESBirthDate type: date
# build_value_map: (1119/377) variable: chronologicalAge_mo type: int
# build_value_map: (1120/377) variable: correctedAge_mo type: int
# build_value_map: (1121/377) variable: underStateSupervision type: bool
# build_value_map: (1122/377) variable: primaryCaretaker type: relationship
# build_value_map: (1123/377) variable: otherCaretaker type: relationship
# build_value_map: (1124/377) variable: maritalStatusPrimaryCaretaker type: maritalStatus
# build_value_map: (1125/377) variable: livingArrangementChild type: livingArrange
# build_value_map: (1126/377) variable: numberPeopleInChildHousehold type: int
# build_value_map: (1127/377) variable: otherContributeMoneyToChildHousehold type: bool
# build_value_map: (1128/377) variable: educationPrimaryCaretaker type: education
# build_value_map: (1129/377) variable: educationOtherCaretaker type: education
# build_value_map: (1130/377) variable: workPrimaryCaretaker type: bool
# build_value_map: (1131/377) variable: workOtherCaretaker type: bool
# build_value_map: (1132/377) variable: inSchoolPrimaryCaretaker type: bool
# build_value_map: (1133/377) variable: inSchoolOtherCaretaker type: bool
# build_value_map: (1134/377) variable: totalIncomeChildHousehold type: totalIncome
# build_value_map: (1135/377) variable: medicalInsuranceChild type: insurance
# build_value_map: (1136/377) variable: primaryLanguageChild type: language
# build_value_map: (1137/377) variable: primaryLanguageChildOtherText type: text
# build_value_map: (1138/377) variable: isSecondaryLanguageChild type: bool
# build_value_map: (1139/377) variable: secondaryLanguageChild type: language
# build_value_map: (1140/377) variable: secondaryLanguageChildOtherText type: text
# build_value_map: (1141/377) variable: numberPlaceChildLive type: int
# build_value_map: (1142/377) variable: zipcode type: int
# build_value_map: (1143/377) variable: visitingNurseReceive type: receive
# build_value_map: (1144/377) variable: visitingNurseNeed type: bool
# build_value_map: (1145/377) variable: homeNurseReceive type: receive
# build_value_map: (1146/377) variable: homeNurseNeed type: bool
# build_value_map: (1147/377) variable: otPtReceive type: receive
# build_value_map: (1148/377) variable: otPtNeed type: bool
# build_value_map: (1149/377) variable: speechTherapyReceive type: receive
# build_value_map: (1150/377) variable: speechTherapyNeed type: bool
# build_value_map: (1151/377) variable: earlyInterventionReceive type: receive
# build_value_map: (1152/377) variable: earlyInterventionNeed type: bool
# build_value_map: (1153/377) variable: socialWorkForChildReceive type: receive
# build_value_map: (1154/377) variable: socialWorkForChildNeed type: bool
# build_value_map: (1155/377) variable: specialClinicReceive type: receive
# build_value_map: (1156/377) variable: specialClinicNeed type: bool
# build_value_map: (1157/377) variable: pulmonaryReceive type: receive
# build_value_map: (1158/377) variable: pulmonaryNeed type: bool
# build_value_map: (1159/377) variable: ophthalmologicReceive type: receive
# build_value_map: (1160/377) variable: ophthalmologicNeed type: bool
# build_value_map: (1161/377) variable: gastrointestinalReceive type: receive
# build_value_map: (1162/377) variable: gastrointestinalNeed type: bool
# build_value_map: (1163/377) variable: audiologicReceive type: receive
# build_value_map: (1164/377) variable: audiologicNeed type: bool
# build_value_map: (1165/377) variable: neurologicReceive type: receive
# build_value_map: (1166/377) variable: neurologicNeed type: bool
# build_value_map: (1167/377) variable: otherReceive type: receive
# build_value_map: (1168/377) variable: otherNeed type: bool
# build_value_map: (1169/377) variable: otherNeedText type: text
# build_value_map: (1170/377) variable: neurodevelopmentReceive type: receive
# build_value_map: (1171/377) variable: neurodevelopmentNeed type: bool
# build_value_map: (1172/377) variable: prematureFollowupClinicReceive type: receive
# build_value_map: (1173/377) variable: prematureFollowupClinicNeed type: bool
# build_value_map: (1174/377) variable: regularDoctor type: bool
# build_value_map: (1175/377) variable: resideChronicCareFacility type: bool
# build_value_map: (1176/377) variable: takenCareOfByOther type: bool
# build_value_map: (1177/377) variable: traditionalCenterCare type: bool
# build_value_map: (1178/377) variable: traditionalCenterCareAvgHrPerWeek type: int
# build_value_map: (1179/377) variable: medicalChildCare type: bool
# build_value_map: (1180/377) variable: medicalChildCareAvgHrPerWeek type: int
# build_value_map: (1181/377) variable: medicalChildCareWhere type: homeCareLocation
# build_value_map: (1182/377) variable: traditionalHomeCare type: bool
# build_value_map: (1183/377) variable: traditionalHomeCareAvgHrPerWeek type: int
# build_value_map: (1184/377) variable: traditionalHomeCareWhose type: homeCareLocation
# build_value_map: (1185/377) variable: babysitter type: bool
# build_value_map: (1186/377) variable: babysitterAvgHrPerWeek type: int
# build_value_map: (1187/377) variable: babysitterRelation type: babysitterRelation
# build_value_map: (1188/377) variable: SESInterviewWhere type: interviewLocation
# build_value_map: (1189/377) variable: SESInterviewDate type: date
# build_value_map: (1190/377) variable: rehospitalize type: bool
# build_value_map: (1191/377) variable: numberRehospitalize type: int
# build_value_map: (1192/377) variable: operation type: bool
# build_value_map: (1193/377) variable: operationTypanostomyTube type: bool
# build_value_map: (1194/377) variable: operationTracheostomy type: bool
# build_value_map: (1195/377) variable: operationEyeSurgery type: bool
# build_value_map: (1196/377) variable: operationEyeSurgeryReason type: eyeSurgeryReason
# build_value_map: (1197/377) variable: operationHerniaSurgery type: bool
# build_value_map: (1198/377) variable: operationGastrostomyTube type: bool
# build_value_map: (1199/377) variable: operationFundoplication type: bool
# build_value_map: (1200/377) variable: operationShuntForHydrocephalus type: bool
# build_value_map: (1201/377) variable: operationReanastomosisOfLargeOrSmallIntenstine type: bool
# build_value_map: (1202/377) variable: operationPDALigation type: bool
# build_value_map: (1203/377) variable: operationBrochoscopy type: bool
# build_value_map: (1204/377) variable: operationHypospadiusRepair type: bool
# build_value_map: (1205/377) variable: operationOther type: bool
# build_value_map: (1206/377) variable: operationOtherText type: text
# build_value_map: (1207/377) variable: medication type: bool
# build_value_map: (1208/377) variable: vitaminMineralSupplement type: medicationUse
# build_value_map: (1209/377) variable: highCaloricFormula type: medicationUse
# build_value_map: (1210/377) variable: diuretics type: medicationUse
# build_value_map: (1211/377) variable: antiRefluxMedication type: medicationUse
# build_value_map: (1212/377) variable: bronchodilator type: medicationUse
# build_value_map: (1213/377) variable: inhaledSteroid type: medicationUse
# build_value_map: (1214/377) variable: oralIvSteroid type: medicationUse
# build_value_map: (1215/377) variable: otherAsthmaMedication type: medicationUse
# build_value_map: (1216/377) variable: decongestantColdAllergyMedication type: medicationUse
# build_value_map: (1217/377) variable: anticonvulsantMedication type: medicationUse
# build_value_map: (1218/377) variable: prophylaticAntibiotics type: medicationUse
# build_value_map: (1219/377) variable: antibiotics type: medicationUse
# build_value_map: (1220/377) variable: constipationMedication type: medicationUse
# build_value_map: (1221/377) variable: bloodPressureMedication type: medicationUse
# build_value_map: (1222/377) variable: thyroidMedication type: medicationUse
# build_value_map: (1223/377) variable: muscleRelaxants type: medicationUse
# build_value_map: (1224/377) variable: botox type: medicationUse
# build_value_map: (1225/377) variable: otherMedication type: medicationUse
# build_value_map: (1226/377) variable: otherMedicationText type: text
# build_value_map: (1227/377) variable: seizure type: bool
# build_value_map: (1228/377) variable: medicalEquipmentHomeUse type: bool
# build_value_map: (1229/377) variable: apneaMonitor type: medicationUse
# build_value_map: (1230/377) variable: oxygen type: medicationUse
# build_value_map: (1231/377) variable: ventilatorCPAP type: medicationUse
# build_value_map: (1232/377) variable: gastrostomyTube type: medicationUse
# build_value_map: (1233/377) variable: tracheostomy type: medicationUse
# build_value_map: (1234/377) variable: pulseOximeter type: medicationUse
# build_value_map: (1235/377) variable: fluShot type: bool
# build_value_map: (1236/377) variable: RSVProphylaxis type: bool
# build_value_map: (1237/377) variable: independentFeedSelf type: bool
# build_value_map: (1238/377) variable: assistedEatByMouth type: bool
# build_value_map: (1239/377) variable: tubeFeed type: bool
# build_value_map: (1240/377) variable: TPN type: bool
# build_value_map: (1241/377) variable: dietMilk type: bool
# build_value_map: (1242/377) variable: dietTableFood type: bool
# build_value_map: (1243/377) variable: dietSoftFood type: bool
# build_value_map: (1244/377) variable: dietLiquid type: bool
# build_value_map: (1245/377) variable: dietThickendLiquid type: bool
# build_value_map: (1246/377) variable: subcutaneousFatNecrosis type: bool
# build_value_map: (1247/377) variable: equipmentForStanding type: bool
# build_value_map: (1248/377) variable: adaptedStroller type: bool
# build_value_map: (1249/377) variable: bracesOrthotics type: bool
# build_value_map: (1250/377) variable: walker type: bool
# build_value_map: (1251/377) variable: stander type: bool
# build_value_map: (1252/377) variable: cornerChairTumblerForm type: bool
# build_value_map: (1253/377) variable: weight_cm type: float
# build_value_map: (1254/377) variable: length_cm type: float
# build_value_map: (1255/377) variable: headCircumference_cm type: float
# build_value_map: (1256/377) variable: strabismusRight type: eye
# build_value_map: (1257/377) variable: strabismusLeft type: eye
# build_value_map: (1258/377) variable: nystagmusRight type: eye
# build_value_map: (1259/377) variable: nystagmusLeft type: eye
# build_value_map: (1260/377) variable: rovingEyeMovementRight type: eye
# build_value_map: (1261/377) variable: rovingEyeMovementLeft type: eye
# build_value_map: (1262/377) variable: eyeTrackRight type: eye
# build_value_map: (1263/377) variable: eyeTrackLeft type: eye
# build_value_map: (1264/377) variable: visionRight type: vision
# build_value_map: (1265/377) variable: visionLeft type: vision
# build_value_map: (1266/377) variable: audiologicAssessment type: bool
# build_value_map: (1267/377) variable: audiologicPendingForAssessment type: bool
# build_value_map: (1268/377) variable: visualReinforcementAudiometry type: bool
# build_value_map: (1269/377) variable: VRARight type: hearing
# build_value_map: (1270/377) variable: VRALeft type: hearing
# build_value_map: (1271/377) variable: VRASoundField type: hearing
# build_value_map: (1272/377) variable: ABR type: bool
# build_value_map: (1273/377) variable: ABRRight type: hearing
# build_value_map: (1274/377) variable: ABRLeft type: hearing
# build_value_map: (1275/377) variable: hearingTestUnknown type: bool
# build_value_map: (1276/377) variable: hearingTestUnknownRight type: hearing
# build_value_map: (1277/377) variable: hearingTestUnknownLeft type: hearing
# build_value_map: (1278/377) variable: hearingImpaired type: hearingImpaired
# build_value_map: (1279/377) variable: hearingAidRequirement type: hearingAid
# build_value_map: (1280/377) variable: hearingImplant type: hearingAid
# build_value_map: (1281/377) variable: swallowing type: swallow
# build_value_map: (1282/377) variable: dysphagia type: bool
# build_value_map: (1283/377) variable: aspiration type: bool
# build_value_map: (1284/377) variable: abnormalVoice type: bool
# build_value_map: (1285/377) variable: drooling type: bool
# build_value_map: (1286/377) variable: nothingByMouth type: bool
# build_value_map: (1287/377) variable: observedAbnormalMovement type: bool
# build_value_map: (1288/377) variable: observedAbnormalMovementShortJerky type: bool
# build_value_map: (1289/377) variable: observedAbnormalMovementSlowWrithing type: bool
# build_value_map: (1290/377) variable: observedAbnormalMovementTremor type: bool
# build_value_map: (1291/377) variable: passiveMuscleToneNeckTrunk type: passiveMuscleTone
# build_value_map: (1292/377) variable: upperExtremityMuscleToneRight type: passiveMuscleTone
# build_value_map: (1293/377) variable: upperExtremityMuscleToneLeft type: passiveMuscleTone
# build_value_map: (1294/377) variable: lowerExtremityMuscleToneHipKneeRight type: passiveMuscleTone
# build_value_map: (1295/377) variable: lowerExtremityMuscleToneHipKneeLeft type: passiveMuscleTone
# build_value_map: (1296/377) variable: lowerExtremityMuscleToneAnkleRight type: passiveMuscleTone
# build_value_map: (1297/377) variable: lowerExtremityMuscleToneAnkleLeft type: passiveMuscleTone
# build_value_map: (1298/377) variable: scissoringLegs type: bool
# build_value_map: (1299/377) variable: handPreference type: handPreference
# build_value_map: (1300/377) variable: protectiveReaction type: protectiveReaction
# build_value_map: (1301/377) variable: limbMovementUpperLimb type: limbMovement
# build_value_map: (1302/377) variable: limbMovementLowerLimb type: limbMovement
# build_value_map: (1303/377) variable: deepTendonReflexUpperExtremityRight type: deepTendonReflex
# build_value_map: (1304/377) variable: deepTendonReflexUpperExtremityLeft type: deepTendonReflex
# build_value_map: (1305/377) variable: deepTendonReflexKneeRight type: deepTendonReflex
# build_value_map: (1306/377) variable: deepTendonReflexKneeLeft type: deepTendonReflex
# build_value_map: (1307/377) variable: deepTendonReflexAnkleRight type: deepTendonReflex
# build_value_map: (1308/377) variable: deepTendonReflexAnkleLeft type: deepTendonReflex
# build_value_map: (1309/377) variable: ankleClonusRight type: ankleClonus
# build_value_map: (1310/377) variable: ankleClonusLeft type: ankleClonus
# build_value_map: (1311/377) variable: plantarReflexRight type: plantarReflex
# build_value_map: (1312/377) variable: plantarReflexLeft type: plantarReflex
# build_value_map: (1313/377) variable: axisHeadNeck type: axisHeadNeck
# build_value_map: (1314/377) variable: axisTrunk type: axisTrunk
# build_value_map: (1315/377) variable: lowerLimbFunction type: lowerLimbFunction
# build_value_map: (1316/377) variable: upperLimbFunction type: upperLimbFunction
# build_value_map: (1317/377) variable: handFunctionRight type: handFunction
# build_value_map: (1318/377) variable: handFunctionLeft type: handFunction
# build_value_map: (1319/377) variable: neuralNormal type: bool
# build_value_map: (1320/377) variable: generalizedHypotonia type: bool
# build_value_map: (1321/377) variable: hypertonia type: bool
# build_value_map: (1322/377) variable: neuralOther type: bool
# build_value_map: (1323/377) variable: neuralOtherText type: text
# build_value_map: (1324/377) variable: spasticDiplegia type: bool
# build_value_map: (1325/377) variable: spasticHemiplegiaRight type: bool
# build_value_map: (1326/377) variable: spasticHemiplegiaLeft type: bool
# build_value_map: (1327/377) variable: spasticQuadriplegia type: bool
# build_value_map: (1328/377) variable: spasticTriplegia type: bool
# build_value_map: (1329/377) variable: dystonia type: bool
# build_value_map: (1330/377) variable: athetosis type: bool
# build_value_map: (1331/377) variable: athetosisDystonia type: bool
# build_value_map: (1332/377) variable: hypotoniaAtaxia type: bool
# build_value_map: (1333/377) variable: spasticMonoplegia type: bool
# build_value_map: (1334/377) variable: mixedCerebralPalsy type: bool
# build_value_map: (1335/377) variable: cerebralPalsyUnclassified type: bool
# build_value_map: (1336/377) variable: cerebralPalsyUnclassifiedText type: text
# build_value_map: (1337/377) variable: cerebralPalsy type: bool
# build_value_map: (1338/377) variable: cerebralPalsyClass type: cerebralPalsyClass
# build_value_map: (1339/377) variable: abrnomalityAffectingNeuroAssessment type: bool
# build_value_map: (1340/377) variable: abrnomalityAffectingNeuroAssessmentText type: text
# build_value_map: (1341/377) variable: examWhere type: interviewLocation
# build_value_map: (1342/377) variable: examWhereOtherText type: text
# build_value_map: (1343/377) variable: examQuality type: examQuality
# build_value_map: (1344/377) variable: examFactorAffecting type: examFactorAffecting
# build_value_map: (1345/377) variable: examFactorAffectingText type: text
# build_value_map: (1346/377) variable: examCompleteDate type: date
# build_value_map: (1347/377) variable: grossMotorFunctionLevel type: grossMotorFunctionLevel
# build_value_map: (1348/377) variable: BayleyIIICognitiveSubtest type: bool
# build_value_map: (1349/377) variable: BayleyIIIReasonNoSuccessCognitiveSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1350/377) variable: BayleyIIIReasonNoSuccessCognitiveSubtestText type: text
# build_value_map: (1351/377) variable: BayleyIIILanguageReceptiveSubtest type: bool
# build_value_map: (1352/377) variable: BayleyIIIReasonNoSuccessLanguageReceptiveSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1353/377) variable: BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText type: text
# build_value_map: (1354/377) variable: BayleyIIILanguageExpressiveSubtest type: bool
# build_value_map: (1355/377) variable: BayleyIIIReasonNoSuccessLanguageExpressiveSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1356/377) variable: BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText type: text
# build_value_map: (1357/377) variable: BayleyIIIMotorFineSubtest type: bool
# build_value_map: (1358/377) variable: BayleyIIIReasonNoSuccessMotorFineSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1359/377) variable: BayleyIIIReasonNoSuccessMotorFineSubtestText type: text
# build_value_map: (1360/377) variable: BayleyIIIMotorGrossSubtest type: bool
# build_value_map: (1361/377) variable: BayleyIIIReasonNoSuccessMotorGrossSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1362/377) variable: BayleyIIIReasonNoSuccessMotorGrossSubtestText type: text
# build_value_map: (1363/377) variable: BayleyIIIAdjustedAgeForCognitiveTest type: int
# build_value_map: (1364/377) variable: BayleyIIIAdjustedAgeForReceptiveCommunication type: int
# build_value_map: (1365/377) variable: BayleyIIIAdjustedAgeForExpressiveCommunication type: int
# build_value_map: (1366/377) variable: BayleyIIIAdjustedAgeForMotorFineSubtest type: int
# build_value_map: (1367/377) variable: BayleyIIIAdjustedAgeForMotorGrossSubtest type: int
# build_value_map: (1368/377) variable: BayleyIIICognitiveRaw type: int
# build_value_map: (1369/377) variable: BayleyIIICognitiveScale type: int
# build_value_map: (1370/377) variable: BayleyIIICognitiveComposite type: int
# build_value_map: (1371/377) variable: BayleyIIIReceptiveRaw type: int
# build_value_map: (1372/377) variable: BayleyIIIReceptiveScale type: int
# build_value_map: (1373/377) variable: BayleyIIIExpressiveRaw type: int
# build_value_map: (1374/377) variable: BayleyIIIExpressiveScale type: int
# build_value_map: (1375/377) variable: BayleyIIISumLanguageScore type: int
# build_value_map: (1376/377) variable: BayleyIIILanguageComposite type: int
# build_value_map: (1377/377) variable: BayleyIIIMotorFineRaw type: int
# build_value_map: (1378/377) variable: BayleyIIIMotorFineScale type: int
# build_value_map: (1379/377) variable: BayleyIIIMotorGrossRaw type: int
# build_value_map: (1380/377) variable: BayleyIIIMotorGrossScale type: int
# build_value_map: (1381/377) variable: BayleyIIISumMotorScore type: int
# build_value_map: (1382/377) variable: BayleyIIIMotorComposite type: int
# build_value_map: (1383/377) variable: BayleyIIIInEnglish type: bool
# build_value_map: (1384/377) variable: BayleyIIIRequireInterpreter type: bool
# build_value_map: (1385/377) variable: BayleyIIIAdministratorMaskedToChildHistory type: bool
# build_value_map: (1386/377) variable: BayleyIIIWhere type: interviewLocation
# build_value_map: (1387/377) variable: BayleyIIIDate type: date
# build_value_map: (1388/377) variable: dischargeDate type: date
# build_value_map: (1389/377) variable: birthdate type: date
# build_value_map: (1390/377) variable: readmissionNumber type: int
# build_value_map: (1391/377) variable: readmissionTimePeriod type: readmissionTimePeriod
# build_value_map: (1392/377) variable: readmissionPrimaryCause type: readmissionPrimaryCause
# build_value_map: (1393/377) variable: readmissionPrimaryCauseOtherText type: text
# build_value_map: (1394/377) variable: readmissionLengthOfStay type: readmissionLengthOfStay
# build_value_map: (1395/377) variable: readmissionICU type: bool
# build_value_map: (1396/377) variable: readmissionInterviewWhere type: interviewLocation
# build_value_map: (1397/377) variable: readmissionDateObtain type: date
# build_value_map: (1398/377) variable: statusVisitDate type: date
# build_value_map: (1399/377) variable: statusBirthDate type: date
# build_value_map: (1400/377) variable: childFinalStatus type: followupStatus
# build_value_map: (1401/377) variable: deathDate type: date
# build_value_map: (1402/377) variable: deathCause type: deathCause
# build_value_map: (1403/377) variable: reasonLossFollowUp type: reasonLossFollowUp
# build_value_map: (1404/377) variable: firstVisitDate type: date
# build_value_map: (1405/377) variable: finalVisitDate type: date
# build_value_map: (1406/377) variable: lostFollowUpInformationAvailableIndirectSrc type: bool
# build_value_map: (1407/377) variable: lostFollowUpLastContactDate type: date
# build_value_map: (1408/377) variable: lostFollowUpFormCompleteDate type: date
# build_value_map: (1409/377) variable: lostFollowUpChildAlive type: bool
# build_value_map: (1410/377) variable: lostFollowUpLastKnownAliveCorrectedAge_mo type: int
# build_value_map: (1411/377) variable: lostFollowUpDeathDate type: date
# build_value_map: (1412/377) variable: lostFollowUpInterview type: bool
# build_value_map: (1413/377) variable: lostFollowUpInterviewDate type: date
# build_value_map: (1414/377) variable: lostFollowUpInterviewCorrectedAge_mo type: int
# build_value_map: (1415/377) variable: lostFollowUpAnyQuestionCompleteChartReview type: bool
# build_value_map: (1416/377) variable: lostFollowUpChartReviewDate type: date
# build_value_map: (1417/377) variable: lostFollowUpChartReviewCorrectedAge_mo type: int
# build_value_map: (1418/377) variable: interviewChildHealth type: childHealth
# build_value_map: (1419/377) variable: interviewWalkAlone type: bool
# build_value_map: (1420/377) variable: interviewWalkAloneAge_mo type: int
# build_value_map: (1421/377) variable: interviewSittingAlong type: bool
# build_value_map: (1422/377) variable: interviewHeadControl type: bool
# build_value_map: (1423/377) variable: interviewSee type: bool
# build_value_map: (1424/377) variable: interviewEyeExam type: bool
# build_value_map: (1425/377) variable: interviewNeedWearGlasses type: bool
# build_value_map: (1426/377) variable: interviewHear type: bool
# build_value_map: (1427/377) variable: interviewHearExam type: bool
# build_value_map: (1428/377) variable: interviewNeedWearHearingAid type: bool
# build_value_map: (1429/377) variable: interviewNumberWordVocabulary type: int
# build_value_map: (1430/377) variable: interviewCombine2Words type: bool
# build_value_map: (1431/377) variable: interviewCombine3Words type: bool
# build_value_map: (1432/377) variable: interviewHydrocephalusShunt type: bool
# build_value_map: (1433/377) variable: interviewCerebralPalsy type: bool
# build_value_map: (1434/377) variable: interviewDevelopmentalDelay type: bool
# build_value_map: (1435/377) variable: interviewLanguageDelay type: bool
# build_value_map: (1436/377) variable: interviewPoorWeightGain type: bool
# build_value_map: (1437/377) variable: interviewSeizure type: bool
# build_value_map: (1438/377) variable: interviewBlindness type: bool
# build_value_map: (1439/377) variable: interviewOtherBehaviorProblem type: bool
# build_value_map: (1440/377) variable: interviewOtherBehaviorProblemText type: text
# build_value_map: (1441/377) variable: interviewOtherMajorMedicalProblem type: bool
# build_value_map: (1442/377) variable: interviewOtherMajorMedicalProblemText type: text
# build_value_map: (1443/377) variable: interviewOtherNeuraldevelopmentalProblem type: bool
# build_value_map: (1444/377) variable: interviewOtherNeuraldevelopmentalProblemText type: text
# build_value_map: (1445/377) variable: interviewMotorGrossFunctionLevel type: grossMotorFunctionLevel
# build_value_map: (1446/377) variable: chartReviewEyeExam type: chartReview
# build_value_map: (1447/377) variable: chartReviewHearingExam type: chartReview
# build_value_map: (1448/377) variable: chartReviewNeedWearHearingAid type: chartReview
# build_value_map: (1449/377) variable: chartReviewHydrocephalusShunt type: chartReview
# build_value_map: (1450/377) variable: chartReviewCerebralPalsy type: chartReview
# build_value_map: (1451/377) variable: chartReviewDevelopmentalDelay type: chartReview
# build_value_map: (1452/377) variable: chartReviewLanguageDelay type: chartReview
# build_value_map: (1453/377) variable: chartReviewPoorWeightGain type: chartReview
# build_value_map: (1454/377) variable: chartReviewSeizure type: chartReview
# build_value_map: (1455/377) variable: chartReviewBlindness type: chartReview
# build_value_map: (1456/377) variable: chartReviewOtherBehaviorProblem type: chartReview
# build_value_map: (1457/377) variable: chartReviewOtherBehaviorProblemText type: text
# build_value_map: (1458/377) variable: chartReviewOtherMajorMedicalProblem type: chartReview
# build_value_map: (1459/377) variable: chartReviewOtherMajorMedicalProblemText type: text
# build_value_map: (1460/377) variable: chartReviewOtherNeuraldevelopmentalProblem type: chartReview
# build_value_map: (1461/377) variable: chartReviewOtherNeuraldevelopmentalProblemText type: text
# build_value_map: (1462/377) variable: chartReviewMotorGrossFunctionLevel type: grossMotorFunctionLevel
# build_value_map: (1463/377) variable: blindness type: bool
# build_value_map: (1464/377) variable: moderateSevereCerebralPalsy type: bool
# build_value_map: (1465/377) variable: cerebralPalsyMerge type: bool
# build_value_map: (1466/377) variable: gastrostomyTube_b type: bool
# build_value_map: (1467/377) variable: grossMotorFunctionLevelSeverity type: severity
# build_value_map: (1468/377) variable: hearingImpairedWithAid type: bool
# build_value_map: (1469/377) variable: hearingImpairedLevel type: severity
# build_value_map: (1470/377) variable: multipleImpairment type: bool
# build_value_map: (1471/377) variable: afterDischargeSeizure type: bool
# build_value_map: (1472/377) variable: flagAdjudicatedOutcome type: flagAdjudicatedOutcome
# build_value_map: (1473/377) variable: normalPrimaryOutcome type: bool
# build_value_map: (1474/377) variable: BayleyIIILanguage type: severity
# build_value_map: (1475/377) variable: BayleyIIIMotor type: severity
# build_value_map: (1476/377) variable: BayleyIIICognitive type: severity
# build_value_map: (1477/377) variable: deathBeforeFollowup type: bool
# build_value_map: (1478/377) variable: deathBeforeDischarge type: bool
# build_value_map: (1479/377) variable: disabilityLevelSurvivor type: severity
# build_value_map: (1480/377) variable: disabilityLevelDeath4Category type: severity
# build_value_map: (1481/377) variable: moderateSevereDisabilityOrDeath type: bool
# build_value_map: (1482/377) variable: moderateSevereDisabilitySurvivor type: bool
# build_value_map: (1483/377) variable: disabilityLevelDeath type: severity
# build_value_map: (1484/377) variable: outcomeGroup type: outcomeGroup

# %%
_ORDER_MAP = COMBINE_harmonizer.build_variable_order_map(data_dict_filename, sheet_name)

# %% [markdown]
# ## 20-00-follow-up

# %%
base_filename = '20-00-follow-up.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/10) normalize_value: column: center
# (1/10) normalize_value: column: subjectID
# (2/10) normalize_value: column: uniqueID
# (3/10) normalize_value: column: followupCenter
# (4/10) normalize_value: column: followupID
# (5/10) normalize_value: column: siteID
# (6/10) normalize_value: column: birthDate
# (7/10) normalize_value: column: visitDate
# (8/10) normalize_value: column: birthNumber
# (9/10) normalize_value: column: center_orig

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/21) center: (315/0)
# (1/21) subjectID: (315/0)
# (2/21) uniqueID: (315/0)
# (3/21) followupCenter: (315/0)
# (4/21) followupID: (315/0)
# (5/21) uniqueFollowupID: (315/0)
# (6/21) center.orig: (315/0)
# (7/21) subjectID.orig: (315/0)
# (8/21) uniqueID.orig: (315/0)
# (9/21) followupCenter.orig: (315/0)
# (10/21) followupID.orig: (315/0)
# (11/21) siteID: (315/0)
# (12/21) siteID.orig: (315/0)
# (13/21) birthDate: (315/0)
# (14/21) birthDate.orig: (315/0)
# (15/21) visitDate: (315/0)
# (16/21) visitDate.orig: (291/24)
# (17/21) birthNumber: (315/0)
# (18/21) birthNumber.orig: (0/315)
# (19/21) center_orig: (315/0)
# (20/21) center_orig.orig: (6/309)

# %% [markdown]
# ## 20-01-ses

# %%
base_filename = '20-01-ses.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/73) normalize_value: column: center
# (1/73) normalize_value: column: subjectID
# (2/73) normalize_value: column: uniqueID
# (3/73) normalize_value: column: followupCenter
# (4/73) normalize_value: column: followupID
# (5/73) normalize_value: column: siteID
# (6/73) normalize_value: column: underStateSupervision
# (7/73) normalize_value: column: otherContributeMoneyToChildHousehold
# (8/73) normalize_value: column: workPrimaryCaretaker
# (9/73) normalize_value: column: workOtherCaretaker
# [WARN] unable to bool: val: (**/<class 'str'>)
# (10/73) normalize_value: column: inSchoolPrimaryCaretaker
# (11/73) normalize_value: column: inSchoolOtherCaretaker
# [WARN] unable to bool: val: (**/<class 'str'>)
# (12/73) normalize_value: column: primaryLanguageChildOtherText
# (13/73) normalize_value: column: isSecondaryLanguageChild
# (14/73) normalize_value: column: secondaryLanguageChildOtherText
# (15/73) normalize_value: column: visitingNurseNeed
# (16/73) normalize_value: column: homeNurseNeed
# (17/73) normalize_value: column: otPtNeed
# (18/73) normalize_value: column: speechTherapyNeed
# (19/73) normalize_value: column: earlyInterventionNeed
# (20/73) normalize_value: column: socialWorkForChildNeed
# (21/73) normalize_value: column: pulmonaryNeed
# (22/73) normalize_value: column: ophthalmologicNeed
# (23/73) normalize_value: column: gastrointestinalNeed
# (24/73) normalize_value: column: audiologicNeed
# (25/73) normalize_value: column: neurologicNeed
# (26/73) normalize_value: column: otherNeed
# (27/73) normalize_value: column: otherNeedText
# (28/73) normalize_value: column: neurodevelopmentNeed
# (29/73) normalize_value: column: regularDoctor
# (30/73) normalize_value: column: resideChronicCareFacility
# (31/73) normalize_value: column: takenCareOfByOther
# (32/73) normalize_value: column: traditionalCenterCare
# (33/73) normalize_value: column: medicalChildCare
# (34/73) normalize_value: column: traditionalHomeCare
# (35/73) normalize_value: column: babysitter
# (36/73) normalize_value: column: SESVisitDate
# (37/73) normalize_value: column: SESBirthDate
# (38/73) normalize_value: column: chronologicalAge_mo
# (39/73) normalize_value: column: correctedAge_mo
# (40/73) normalize_value: column: primaryCaretaker
# (41/73) normalize_value: column: otherCaretaker
# (42/73) normalize_value: column: maritalStatusPrimaryCaretaker
# (43/73) normalize_value: column: livingArrangementChild
# (44/73) normalize_value: column: numberPeopleInChildHousehold
# (45/73) normalize_value: column: educationPrimaryCaretaker
# (46/73) normalize_value: column: educationOtherCaretaker
# (47/73) normalize_value: column: medicalInsuranceChild
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# (48/73) normalize_value: column: primaryLanguageChild
# (49/73) normalize_value: column: secondaryLanguageChild
# (50/73) normalize_value: column: numberPlaceChildLive
# (51/73) normalize_value: column: visitingNurseReceive
# (52/73) normalize_value: column: homeNurseReceive
# (53/73) normalize_value: column: otPtReceive
# (54/73) normalize_value: column: speechTherapyReceive
# (55/73) normalize_value: column: earlyInterventionReceive
# (56/73) normalize_value: column: socialWorkForChildReceive
# (57/73) normalize_value: column: pulmonaryReceive
# (58/73) normalize_value: column: ophthalmologicReceive
# (59/73) normalize_value: column: gastrointestinalReceive
# (60/73) normalize_value: column: audiologicReceive
# (61/73) normalize_value: column: neurologicReceive
# (62/73) normalize_value: column: otherReceive
# (63/73) normalize_value: column: neurodevelopmentReceive
# (64/73) normalize_value: column: traditionalCenterCareAvgHrPerWeek
# (65/73) normalize_value: column: medicalChildCareAvgHrPerWeek
# (66/73) normalize_value: column: medicalChildCareWhere
# (67/73) normalize_value: column: traditionalHomeCareAvgHrPerWeek
# (68/73) normalize_value: column: traditionalHomeCareWhose
# (69/73) normalize_value: column: babysitterAvgHrPerWeek
# (70/73) normalize_value: column: babysitterRelation
# (71/73) normalize_value: column: SESInterviewWhere
# (72/73) normalize_value: column: SESInterviewDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/147) center: (315/0)
# (1/147) subjectID: (315/0)
# (2/147) uniqueID: (315/0)
# (3/147) followupCenter: (315/0)
# (4/147) followupID: (315/0)
# (5/147) uniqueFollowupID: (315/0)
# (6/147) center.orig: (315/0)
# (7/147) subjectID.orig: (315/0)
# (8/147) uniqueID.orig: (315/0)
# (9/147) followupCenter.orig: (315/0)
# (10/147) followupID.orig: (315/0)
# (11/147) siteID: (315/0)
# (12/147) siteID.orig: (315/0)
# (13/147) SESVisitDate: (315/0)
# (14/147) SESVisitDate.orig: (287/28)
# (15/147) SESBirthDate: (315/0)
# (16/147) SESBirthDate.orig: (288/27)
# (17/147) chronologicalAge_mo: (315/0)
# (18/147) chronologicalAge_mo.orig: (288/27)
# (19/147) correctedAge_mo: (315/0)
# (20/147) correctedAge_mo.orig: (285/30)
# (21/147) underStateSupervision: (315/0)
# (22/147) underStateSupervision.orig: (288/27)
# (23/147) primaryCaretaker: (315/0)
# (24/147) primaryCaretaker.orig: (288/27)
# (25/147) otherCaretaker: (315/0)
# (26/147) otherCaretaker.orig: (255/60)
# (27/147) maritalStatusPrimaryCaretaker: (315/0)
# (28/147) maritalStatusPrimaryCaretaker.orig: (288/27)
# (29/147) livingArrangementChild: (315/0)
# (30/147) livingArrangementChild.orig: (288/27)
# (31/147) numberPeopleInChildHousehold: (315/0)
# (32/147) numberPeopleInChildHousehold.orig: (288/27)
# (33/147) otherContributeMoneyToChildHousehold: (315/0)
# (34/147) otherContributeMoneyToChildHousehold.orig: (288/27)
# (35/147) educationPrimaryCaretaker: (315/0)
# (36/147) educationPrimaryCaretaker.orig: (287/28)
# (37/147) educationOtherCaretaker: (315/0)
# (38/147) educationOtherCaretaker.orig: (253/62)
# (39/147) workPrimaryCaretaker: (315/0)
# (40/147) workPrimaryCaretaker.orig: (288/27)
# (41/147) workOtherCaretaker: (315/0)
# (42/147) workOtherCaretaker.orig: (254/61)
# (43/147) inSchoolPrimaryCaretaker: (315/0)
# (44/147) inSchoolPrimaryCaretaker.orig: (288/27)
# (45/147) inSchoolOtherCaretaker: (315/0)
# (46/147) inSchoolOtherCaretaker.orig: (254/61)
# (47/147) medicalInsuranceChild: (315/0)
# (48/147) medicalInsuranceChild.orig: (287/28)
# (49/147) primaryLanguageChild: (315/0)
# (50/147) primaryLanguageChild.orig: (288/27)
# (51/147) primaryLanguageChildOtherText: (315/0)
# (52/147) primaryLanguageChildOtherText.orig: (15/300)
# (53/147) isSecondaryLanguageChild: (315/0)
# (54/147) isSecondaryLanguageChild.orig: (288/27)
# (55/147) secondaryLanguageChild: (315/0)
# (56/147) secondaryLanguageChild.orig: (80/235)
# (57/147) secondaryLanguageChildOtherText: (315/0)
# (58/147) secondaryLanguageChildOtherText.orig: (22/293)
# (59/147) numberPlaceChildLive: (315/0)
# (60/147) numberPlaceChildLive.orig: (285/30)
# (61/147) visitingNurseReceive: (315/0)
# (62/147) visitingNurseReceive.orig: (288/27)
# (63/147) visitingNurseNeed: (315/0)
# (64/147) visitingNurseNeed.orig: (288/27)
# (65/147) homeNurseReceive: (315/0)
# (66/147) homeNurseReceive.orig: (288/27)
# (67/147) homeNurseNeed: (315/0)
# (68/147) homeNurseNeed.orig: (288/27)
# (69/147) otPtReceive: (315/0)
# (70/147) otPtReceive.orig: (288/27)
# (71/147) otPtNeed: (315/0)
# (72/147) otPtNeed.orig: (288/27)
# (73/147) speechTherapyReceive: (315/0)
# (74/147) speechTherapyReceive.orig: (288/27)
# (75/147) speechTherapyNeed: (315/0)
# (76/147) speechTherapyNeed.orig: (288/27)
# (77/147) earlyInterventionReceive: (315/0)
# (78/147) earlyInterventionReceive.orig: (288/27)
# (79/147) earlyInterventionNeed: (315/0)
# (80/147) earlyInterventionNeed.orig: (288/27)
# (81/147) socialWorkForChildReceive: (315/0)
# (82/147) socialWorkForChildReceive.orig: (288/27)
# (83/147) socialWorkForChildNeed: (315/0)
# (84/147) socialWorkForChildNeed.orig: (288/27)
# (85/147) pulmonaryReceive: (315/0)
# (86/147) pulmonaryReceive.orig: (288/27)
# (87/147) pulmonaryNeed: (315/0)
# (88/147) pulmonaryNeed.orig: (288/27)
# (89/147) ophthalmologicReceive: (315/0)
# (90/147) ophthalmologicReceive.orig: (288/27)
# (91/147) ophthalmologicNeed: (315/0)
# (92/147) ophthalmologicNeed.orig: (288/27)
# (93/147) gastrointestinalReceive: (315/0)
# (94/147) gastrointestinalReceive.orig: (288/27)
# (95/147) gastrointestinalNeed: (315/0)
# (96/147) gastrointestinalNeed.orig: (288/27)
# (97/147) audiologicReceive: (315/0)
# (98/147) audiologicReceive.orig: (288/27)
# (99/147) audiologicNeed: (315/0)
# (100/147) audiologicNeed.orig: (288/27)
# (101/147) neurologicReceive: (315/0)
# (102/147) neurologicReceive.orig: (288/27)
# (103/147) neurologicNeed: (315/0)
# (104/147) neurologicNeed.orig: (288/27)
# (105/147) otherReceive: (315/0)
# (106/147) otherReceive.orig: (287/28)
# (107/147) otherNeed: (315/0)
# (108/147) otherNeed.orig: (288/27)
# (109/147) otherNeedText: (315/0)
# (110/147) otherNeedText.orig: (93/222)
# (111/147) neurodevelopmentReceive: (315/0)
# (112/147) neurodevelopmentReceive.orig: (287/28)
# (113/147) neurodevelopmentNeed: (315/0)
# (114/147) neurodevelopmentNeed.orig: (288/27)
# (115/147) regularDoctor: (315/0)
# (116/147) regularDoctor.orig: (288/27)
# (117/147) resideChronicCareFacility: (315/0)
# (118/147) resideChronicCareFacility.orig: (288/27)
# (119/147) takenCareOfByOther: (315/0)
# (120/147) takenCareOfByOther.orig: (288/27)
# (121/147) traditionalCenterCare: (315/0)
# (122/147) traditionalCenterCare.orig: (134/181)
# (123/147) traditionalCenterCareAvgHrPerWeek: (315/0)
# (124/147) traditionalCenterCareAvgHrPerWeek.orig: (54/261)
# (125/147) medicalChildCare: (315/0)
# (126/147) medicalChildCare.orig: (134/181)
# (127/147) medicalChildCareAvgHrPerWeek: (315/0)
# (128/147) medicalChildCareAvgHrPerWeek.orig: (5/310)
# (129/147) medicalChildCareWhere: (315/0)
# (130/147) medicalChildCareWhere.orig: (5/310)
# (131/147) traditionalHomeCare: (315/0)
# (132/147) traditionalHomeCare.orig: (134/181)
# (133/147) traditionalHomeCareAvgHrPerWeek: (315/0)
# (134/147) traditionalHomeCareAvgHrPerWeek.orig: (23/292)
# (135/147) traditionalHomeCareWhose: (315/0)
# (136/147) traditionalHomeCareWhose.orig: (23/292)
# (137/147) babysitter: (315/0)
# (138/147) babysitter.orig: (134/181)
# (139/147) babysitterAvgHrPerWeek: (315/0)
# (140/147) babysitterAvgHrPerWeek.orig: (60/255)
# (141/147) babysitterRelation: (315/0)
# (142/147) babysitterRelation.orig: (62/253)
# (143/147) SESInterviewWhere: (315/0)
# (144/147) SESInterviewWhere.orig: (288/27)
# (145/147) SESInterviewDate: (315/0)
# (146/147) SESInterviewDate.orig: (288/27)

# %% [markdown]
# ## 20-02-medical-history

# %%
base_filename = '20-02-medical-history.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/69) normalize_value: column: center
# (1/69) normalize_value: column: subjectID
# (2/69) normalize_value: column: uniqueID
# (3/69) normalize_value: column: followupCenter
# (4/69) normalize_value: column: followupID
# (5/69) normalize_value: column: siteID
# (6/69) normalize_value: column: rehospitalize
# (7/69) normalize_value: column: operation
# (8/69) normalize_value: column: operationTypanostomyTube
# (9/69) normalize_value: column: operationTracheostomy
# (10/69) normalize_value: column: operationEyeSurgery
# (11/69) normalize_value: column: operationHerniaSurgery
# (12/69) normalize_value: column: operationGastrostomyTube
# (13/69) normalize_value: column: operationFundoplication
# (14/69) normalize_value: column: operationShuntForHydrocephalus
# (15/69) normalize_value: column: operationReanastomosisOfLargeOrSmallIntenstine
# (16/69) normalize_value: column: operationPDALigation
# (17/69) normalize_value: column: operationBrochoscopy
# (18/69) normalize_value: column: operationHypospadiusRepair
# (19/69) normalize_value: column: operationOther
# (20/69) normalize_value: column: operationOtherText
# (21/69) normalize_value: column: medication
# (22/69) normalize_value: column: otherMedicationText
# (23/69) normalize_value: column: seizure
# (24/69) normalize_value: column: medicalEquipmentHomeUse
# (25/69) normalize_value: column: fluShot
# (26/69) normalize_value: column: RSVProphylaxis
# (27/69) normalize_value: column: independentFeedSelf
# (28/69) normalize_value: column: assistedEatByMouth
# (29/69) normalize_value: column: tubeFeed
# (30/69) normalize_value: column: TPN
# (31/69) normalize_value: column: dietMilk
# (32/69) normalize_value: column: dietTableFood
# (33/69) normalize_value: column: dietSoftFood
# (34/69) normalize_value: column: dietLiquid
# (35/69) normalize_value: column: dietThickendLiquid
# (36/69) normalize_value: column: equipmentForStanding
# (37/69) normalize_value: column: adaptedStroller
# (38/69) normalize_value: column: bracesOrthotics
# (39/69) normalize_value: column: walker
# (40/69) normalize_value: column: stander
# (41/69) normalize_value: column: cornerChairTumblerForm
# (42/69) normalize_value: column: subcutaneousFatNecrosis
# (43/69) normalize_value: column: numberRehospitalize
# (44/69) normalize_value: column: operationEyeSurgeryReason
# (45/69) normalize_value: column: vitaminMineralSupplement
# (46/69) normalize_value: column: highCaloricFormula
# (47/69) normalize_value: column: diuretics
# (48/69) normalize_value: column: antiRefluxMedication
# (49/69) normalize_value: column: bronchodilator
# (50/69) normalize_value: column: inhaledSteroid
# (51/69) normalize_value: column: oralIvSteroid
# (52/69) normalize_value: column: otherAsthmaMedication
# (53/69) normalize_value: column: decongestantColdAllergyMedication
# (54/69) normalize_value: column: anticonvulsantMedication
# (55/69) normalize_value: column: prophylaticAntibiotics
# (56/69) normalize_value: column: antibiotics
# (57/69) normalize_value: column: constipationMedication
# (58/69) normalize_value: column: bloodPressureMedication
# (59/69) normalize_value: column: thyroidMedication
# (60/69) normalize_value: column: muscleRelaxants
# (61/69) normalize_value: column: botox
# (62/69) normalize_value: column: otherMedication
# (63/69) normalize_value: column: apneaMonitor
# (64/69) normalize_value: column: oxygen
# (65/69) normalize_value: column: ventilatorCPAP
# (66/69) normalize_value: column: gastrostomyTube
# (67/69) normalize_value: column: tracheostomy
# (68/69) normalize_value: column: pulseOximeter

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/139) center: (315/0)
# (1/139) subjectID: (315/0)
# (2/139) uniqueID: (315/0)
# (3/139) followupCenter: (315/0)
# (4/139) followupID: (315/0)
# (5/139) uniqueFollowupID: (315/0)
# (6/139) center.orig: (315/0)
# (7/139) subjectID.orig: (315/0)
# (8/139) uniqueID.orig: (315/0)
# (9/139) followupCenter.orig: (315/0)
# (10/139) followupID.orig: (315/0)
# (11/139) siteID: (315/0)
# (12/139) siteID.orig: (315/0)
# (13/139) rehospitalize: (315/0)
# (14/139) rehospitalize.orig: (287/28)
# (15/139) numberRehospitalize: (315/0)
# (16/139) numberRehospitalize.orig: (65/250)
# (17/139) operation: (315/0)
# (18/139) operation.orig: (287/28)
# (19/139) operationTypanostomyTube: (315/0)
# (20/139) operationTypanostomyTube.orig: (62/253)
# (21/139) operationTracheostomy: (315/0)
# (22/139) operationTracheostomy.orig: (62/253)
# (23/139) operationEyeSurgery: (315/0)
# (24/139) operationEyeSurgery.orig: (62/253)
# (25/139) operationEyeSurgeryReason: (315/0)
# (26/139) operationEyeSurgeryReason.orig: (2/313)
# (27/139) operationHerniaSurgery: (315/0)
# (28/139) operationHerniaSurgery.orig: (62/253)
# (29/139) operationGastrostomyTube: (315/0)
# (30/139) operationGastrostomyTube.orig: (62/253)
# (31/139) operationFundoplication: (315/0)
# (32/139) operationFundoplication.orig: (62/253)
# (33/139) operationShuntForHydrocephalus: (315/0)
# (34/139) operationShuntForHydrocephalus.orig: (62/253)
# (35/139) operationReanastomosisOfLargeOrSmallIntenstine: (315/0)
# (36/139) operationReanastomosisOfLargeOrSmallIntenstine.orig: (62/253)
# (37/139) operationPDALigation: (315/0)
# (38/139) operationPDALigation.orig: (62/253)
# (39/139) operationBrochoscopy: (315/0)
# (40/139) operationBrochoscopy.orig: (62/253)
# (41/139) operationHypospadiusRepair: (315/0)
# (42/139) operationHypospadiusRepair.orig: (62/253)
# (43/139) operationOther: (315/0)
# (44/139) operationOther.orig: (62/253)
# (45/139) operationOtherText: (315/0)
# (46/139) operationOtherText.orig: (29/286)
# (47/139) medication: (315/0)
# (48/139) medication.orig: (287/28)
# (49/139) vitaminMineralSupplement: (315/0)
# (50/139) vitaminMineralSupplement.orig: (158/157)
# (51/139) highCaloricFormula: (315/0)
# (52/139) highCaloricFormula.orig: (158/157)
# (53/139) diuretics: (315/0)
# (54/139) diuretics.orig: (158/157)
# (55/139) antiRefluxMedication: (315/0)
# (56/139) antiRefluxMedication.orig: (158/157)
# (57/139) bronchodilator: (315/0)
# (58/139) bronchodilator.orig: (158/157)
# (59/139) inhaledSteroid: (315/0)
# (60/139) inhaledSteroid.orig: (158/157)
# (61/139) oralIvSteroid: (315/0)
# (62/139) oralIvSteroid.orig: (158/157)
# (63/139) otherAsthmaMedication: (315/0)
# (64/139) otherAsthmaMedication.orig: (158/157)
# (65/139) decongestantColdAllergyMedication: (315/0)
# (66/139) decongestantColdAllergyMedication.orig: (158/157)
# (67/139) anticonvulsantMedication: (315/0)
# (68/139) anticonvulsantMedication.orig: (158/157)
# (69/139) prophylaticAntibiotics: (315/0)
# (70/139) prophylaticAntibiotics.orig: (158/157)
# (71/139) antibiotics: (315/0)
# (72/139) antibiotics.orig: (158/157)
# (73/139) constipationMedication: (315/0)
# (74/139) constipationMedication.orig: (158/157)
# (75/139) bloodPressureMedication: (315/0)
# (76/139) bloodPressureMedication.orig: (158/157)
# (77/139) thyroidMedication: (315/0)
# (78/139) thyroidMedication.orig: (158/157)
# (79/139) muscleRelaxants: (315/0)
# (80/139) muscleRelaxants.orig: (158/157)
# (81/139) botox: (315/0)
# (82/139) botox.orig: (158/157)
# (83/139) otherMedication: (315/0)
# (84/139) otherMedication.orig: (158/157)
# (85/139) otherMedicationText: (315/0)
# (86/139) otherMedicationText.orig: (19/296)
# (87/139) seizure: (315/0)
# (88/139) seizure.orig: (287/28)
# (89/139) medicalEquipmentHomeUse: (315/0)
# (90/139) medicalEquipmentHomeUse.orig: (287/28)
# (91/139) apneaMonitor: (315/0)
# (92/139) apneaMonitor.orig: (52/263)
# (93/139) oxygen: (315/0)
# (94/139) oxygen.orig: (52/263)
# (95/139) ventilatorCPAP: (315/0)
# (96/139) ventilatorCPAP.orig: (52/263)
# (97/139) gastrostomyTube: (315/0)
# (98/139) gastrostomyTube.orig: (52/263)
# (99/139) tracheostomy: (315/0)
# (100/139) tracheostomy.orig: (52/263)
# (101/139) pulseOximeter: (315/0)
# (102/139) pulseOximeter.orig: (52/263)
# (103/139) fluShot: (315/0)
# (104/139) fluShot.orig: (287/28)
# (105/139) RSVProphylaxis: (315/0)
# (106/139) RSVProphylaxis.orig: (287/28)
# (107/139) independentFeedSelf: (315/0)
# (108/139) independentFeedSelf.orig: (287/28)
# (109/139) assistedEatByMouth: (315/0)
# (110/139) assistedEatByMouth.orig: (287/28)
# (111/139) tubeFeed: (315/0)
# (112/139) tubeFeed.orig: (287/28)
# (113/139) TPN: (315/0)
# (114/139) TPN.orig: (287/28)
# (115/139) dietMilk: (315/0)
# (116/139) dietMilk.orig: (287/28)
# (117/139) dietTableFood: (315/0)
# (118/139) dietTableFood.orig: (287/28)
# (119/139) dietSoftFood: (315/0)
# (120/139) dietSoftFood.orig: (287/28)
# (121/139) dietLiquid: (315/0)
# (122/139) dietLiquid.orig: (287/28)
# (123/139) dietThickendLiquid: (315/0)
# (124/139) dietThickendLiquid.orig: (287/28)
# (125/139) subcutaneousFatNecrosis: (315/0)
# (126/139) subcutaneousFatNecrosis.orig: (196/119)
# (127/139) equipmentForStanding: (315/0)
# (128/139) equipmentForStanding.orig: (287/28)
# (129/139) adaptedStroller: (315/0)
# (130/139) adaptedStroller.orig: (37/278)
# (131/139) bracesOrthotics: (315/0)
# (132/139) bracesOrthotics.orig: (37/278)
# (133/139) walker: (315/0)
# (134/139) walker.orig: (37/278)
# (135/139) stander: (315/0)
# (136/139) stander.orig: (37/278)
# (137/139) cornerChairTumblerForm: (315/0)
# (138/139) cornerChairTumblerForm.orig: (37/278)

# %% [markdown]
# ## 20-03-medical-exam

# %%
base_filename = '20-03-medical-exam.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/96) normalize_value: column: center
# (1/96) normalize_value: column: subjectID
# (2/96) normalize_value: column: uniqueID
# (3/96) normalize_value: column: followupCenter
# (4/96) normalize_value: column: followupID
# (5/96) normalize_value: column: siteID
# (6/96) normalize_value: column: audiologicAssessment
# (7/96) normalize_value: column: audiologicPendingForAssessment
# (8/96) normalize_value: column: visualReinforcementAudiometry
# (9/96) normalize_value: column: ABR
# (10/96) normalize_value: column: hearingTestUnknown
# (11/96) normalize_value: column: dysphagia
# (12/96) normalize_value: column: aspiration
# (13/96) normalize_value: column: abnormalVoice
# (14/96) normalize_value: column: drooling
# (15/96) normalize_value: column: nothingByMouth
# (16/96) normalize_value: column: observedAbnormalMovement
# (17/96) normalize_value: column: observedAbnormalMovementShortJerky
# (18/96) normalize_value: column: observedAbnormalMovementSlowWrithing
# (19/96) normalize_value: column: observedAbnormalMovementTremor
# (20/96) normalize_value: column: scissoringLegs
# (21/96) normalize_value: column: neuralNormal
# (22/96) normalize_value: column: generalizedHypotonia
# (23/96) normalize_value: column: hypertonia
# (24/96) normalize_value: column: neuralOther
# (25/96) normalize_value: column: neuralOtherText
# (26/96) normalize_value: column: spasticQuadriplegia
# (27/96) normalize_value: column: spasticDiplegia
# (28/96) normalize_value: column: spasticHemiplegiaRight
# (29/96) normalize_value: column: spasticHemiplegiaLeft
# (30/96) normalize_value: column: dystonia
# (31/96) normalize_value: column: athetosis
# (32/96) normalize_value: column: hypotoniaAtaxia
# (33/96) normalize_value: column: cerebralPalsyUnclassified
# (34/96) normalize_value: column: cerebralPalsyUnclassifiedText
# (35/96) normalize_value: column: cerebralPalsy
# (36/96) normalize_value: column: cerebralPalsyClass
# (37/96) normalize_value: column: abrnomalityAffectingNeuroAssessment
# (38/96) normalize_value: column: abrnomalityAffectingNeuroAssessmentText
# (39/96) normalize_value: column: examWhereOtherText
# (40/96) normalize_value: column: examFactorAffectingText
# (41/96) normalize_value: column: weight_cm
# (42/96) normalize_value: column: length_cm
# (43/96) normalize_value: column: headCircumference_cm
# (44/96) normalize_value: column: strabismusRight
# (45/96) normalize_value: column: strabismusLeft
# (46/96) normalize_value: column: nystagmusRight
# (47/96) normalize_value: column: nystagmusLeft
# (48/96) normalize_value: column: rovingEyeMovementRight
# (49/96) normalize_value: column: rovingEyeMovementLeft
# (50/96) normalize_value: column: eyeTrackRight
# (51/96) normalize_value: column: eyeTrackLeft
# (52/96) normalize_value: column: visionRight
# (53/96) normalize_value: column: visionLeft
# (54/96) normalize_value: column: VRARight
# (55/96) normalize_value: column: VRALeft
# (56/96) normalize_value: column: VRASoundField
# (57/96) normalize_value: column: ABRRight
# (58/96) normalize_value: column: ABRLeft
# (59/96) normalize_value: column: hearingTestUnknownRight
# (60/96) normalize_value: column: hearingTestUnknownLeft
# (61/96) normalize_value: column: hearingImpaired
# (62/96) normalize_value: column: hearingAidRequirement
# (63/96) normalize_value: column: hearingImplant
# (64/96) normalize_value: column: swallowing
# (65/96) normalize_value: column: passiveMuscleToneNeckTrunk
# (66/96) normalize_value: column: upperExtremityMuscleToneRight
# (67/96) normalize_value: column: upperExtremityMuscleToneLeft
# (68/96) normalize_value: column: lowerExtremityMuscleToneHipKneeRight
# (69/96) normalize_value: column: lowerExtremityMuscleToneHipKneeLeft
# (70/96) normalize_value: column: lowerExtremityMuscleToneAnkleRight
# (71/96) normalize_value: column: lowerExtremityMuscleToneAnkleLeft
# (72/96) normalize_value: column: handPreference
# (73/96) normalize_value: column: protectiveReaction
# (74/96) normalize_value: column: limbMovementUpperLimb
# (75/96) normalize_value: column: limbMovementLowerLimb
# (76/96) normalize_value: column: deepTendonReflexUpperExtremityRight
# (77/96) normalize_value: column: deepTendonReflexUpperExtremityLeft
# (78/96) normalize_value: column: deepTendonReflexKneeRight
# (79/96) normalize_value: column: deepTendonReflexKneeLeft
# (80/96) normalize_value: column: deepTendonReflexAnkleRight
# (81/96) normalize_value: column: deepTendonReflexAnkleLeft
# (82/96) normalize_value: column: ankleClonusRight
# (83/96) normalize_value: column: ankleClonusLeft
# (84/96) normalize_value: column: plantarReflexRight
# (85/96) normalize_value: column: plantarReflexLeft
# (86/96) normalize_value: column: axisHeadNeck
# (87/96) normalize_value: column: axisTrunk
# (88/96) normalize_value: column: lowerLimbFunction
# (89/96) normalize_value: column: upperLimbFunction
# (90/96) normalize_value: column: handFunctionRight
# (91/96) normalize_value: column: handFunctionLeft
# (92/96) normalize_value: column: examWhere
# (93/96) normalize_value: column: examQuality
# (94/96) normalize_value: column: examFactorAffecting
# (95/96) normalize_value: column: examCompleteDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/193) center: (315/0)
# (1/193) subjectID: (315/0)
# (2/193) uniqueID: (315/0)
# (3/193) followupCenter: (315/0)
# (4/193) followupID: (315/0)
# (5/193) uniqueFollowupID: (315/0)
# (6/193) center.orig: (315/0)
# (7/193) subjectID.orig: (315/0)
# (8/193) uniqueID.orig: (315/0)
# (9/193) followupCenter.orig: (315/0)
# (10/193) followupID.orig: (315/0)
# (11/193) siteID: (315/0)
# (12/193) siteID.orig: (315/0)
# (13/193) weight_cm: (315/0)
# (14/193) weight_cm.orig: (284/31)
# (15/193) length_cm: (315/0)
# (16/193) length_cm.orig: (280/35)
# (17/193) headCircumference_cm: (315/0)
# (18/193) headCircumference_cm.orig: (280/35)
# (19/193) strabismusRight: (315/0)
# (20/193) strabismusRight.orig: (283/32)
# (21/193) strabismusLeft: (315/0)
# (22/193) strabismusLeft.orig: (284/31)
# (23/193) nystagmusRight: (315/0)
# (24/193) nystagmusRight.orig: (284/31)
# (25/193) nystagmusLeft: (315/0)
# (26/193) nystagmusLeft.orig: (284/31)
# (27/193) rovingEyeMovementRight: (315/0)
# (28/193) rovingEyeMovementRight.orig: (284/31)
# (29/193) rovingEyeMovementLeft: (315/0)
# (30/193) rovingEyeMovementLeft.orig: (284/31)
# (31/193) eyeTrackRight: (315/0)
# (32/193) eyeTrackRight.orig: (284/31)
# (33/193) eyeTrackLeft: (315/0)
# (34/193) eyeTrackLeft.orig: (284/31)
# (35/193) visionRight: (315/0)
# (36/193) visionRight.orig: (285/30)
# (37/193) visionLeft: (315/0)
# (38/193) visionLeft.orig: (285/30)
# (39/193) audiologicAssessment: (315/0)
# (40/193) audiologicAssessment.orig: (285/30)
# (41/193) audiologicPendingForAssessment: (315/0)
# (42/193) audiologicPendingForAssessment.orig: (152/163)
# (43/193) visualReinforcementAudiometry: (315/0)
# (44/193) visualReinforcementAudiometry.orig: (90/225)
# (45/193) VRARight: (315/0)
# (46/193) VRARight.orig: (28/287)
# (47/193) VRALeft: (315/0)
# (48/193) VRALeft.orig: (28/287)
# (49/193) VRASoundField: (315/0)
# (50/193) VRASoundField.orig: (33/282)
# (51/193) ABR: (315/0)
# (52/193) ABR.orig: (90/225)
# (53/193) ABRRight: (315/0)
# (54/193) ABRRight.orig: (32/283)
# (55/193) ABRLeft: (315/0)
# (56/193) ABRLeft.orig: (32/283)
# (57/193) hearingTestUnknown: (315/0)
# (58/193) hearingTestUnknown.orig: (133/182)
# (59/193) hearingTestUnknownRight: (315/0)
# (60/193) hearingTestUnknownRight.orig: (43/272)
# (61/193) hearingTestUnknownLeft: (315/0)
# (62/193) hearingTestUnknownLeft.orig: (43/272)
# (63/193) hearingImpaired: (315/0)
# (64/193) hearingImpaired.orig: (285/30)
# (65/193) hearingAidRequirement: (315/0)
# (66/193) hearingAidRequirement.orig: (285/30)
# (67/193) hearingImplant: (315/0)
# (68/193) hearingImplant.orig: (285/30)
# (69/193) swallowing: (315/0)
# (70/193) swallowing.orig: (285/30)
# (71/193) dysphagia: (315/0)
# (72/193) dysphagia.orig: (285/30)
# (73/193) aspiration: (315/0)
# (74/193) aspiration.orig: (285/30)
# (75/193) abnormalVoice: (315/0)
# (76/193) abnormalVoice.orig: (285/30)
# (77/193) drooling: (315/0)
# (78/193) drooling.orig: (285/30)
# (79/193) nothingByMouth: (315/0)
# (80/193) nothingByMouth.orig: (285/30)
# (81/193) observedAbnormalMovement: (315/0)
# (82/193) observedAbnormalMovement.orig: (285/30)
# (83/193) observedAbnormalMovementShortJerky: (315/0)
# (84/193) observedAbnormalMovementShortJerky.orig: (19/296)
# (85/193) observedAbnormalMovementSlowWrithing: (315/0)
# (86/193) observedAbnormalMovementSlowWrithing.orig: (19/296)
# (87/193) observedAbnormalMovementTremor: (315/0)
# (88/193) observedAbnormalMovementTremor.orig: (19/296)
# (89/193) passiveMuscleToneNeckTrunk: (315/0)
# (90/193) passiveMuscleToneNeckTrunk.orig: (285/30)
# (91/193) upperExtremityMuscleToneRight: (315/0)
# (92/193) upperExtremityMuscleToneRight.orig: (285/30)
# (93/193) upperExtremityMuscleToneLeft: (315/0)
# (94/193) upperExtremityMuscleToneLeft.orig: (285/30)
# (95/193) lowerExtremityMuscleToneHipKneeRight: (315/0)
# (96/193) lowerExtremityMuscleToneHipKneeRight.orig: (285/30)
# (97/193) lowerExtremityMuscleToneHipKneeLeft: (315/0)
# (98/193) lowerExtremityMuscleToneHipKneeLeft.orig: (285/30)
# (99/193) lowerExtremityMuscleToneAnkleRight: (315/0)
# (100/193) lowerExtremityMuscleToneAnkleRight.orig: (285/30)
# (101/193) lowerExtremityMuscleToneAnkleLeft: (315/0)
# (102/193) lowerExtremityMuscleToneAnkleLeft.orig: (285/30)
# (103/193) scissoringLegs: (315/0)
# (104/193) scissoringLegs.orig: (285/30)
# (105/193) handPreference: (315/0)
# (106/193) handPreference.orig: (284/31)
# (107/193) protectiveReaction: (315/0)
# (108/193) protectiveReaction.orig: (282/33)
# (109/193) limbMovementUpperLimb: (315/0)
# (110/193) limbMovementUpperLimb.orig: (285/30)
# (111/193) limbMovementLowerLimb: (315/0)
# (112/193) limbMovementLowerLimb.orig: (285/30)
# (113/193) deepTendonReflexUpperExtremityRight: (315/0)
# (114/193) deepTendonReflexUpperExtremityRight.orig: (275/40)
# (115/193) deepTendonReflexUpperExtremityLeft: (315/0)
# (116/193) deepTendonReflexUpperExtremityLeft.orig: (275/40)
# (117/193) deepTendonReflexKneeRight: (315/0)
# (118/193) deepTendonReflexKneeRight.orig: (281/34)
# (119/193) deepTendonReflexKneeLeft: (315/0)
# (120/193) deepTendonReflexKneeLeft.orig: (281/34)
# (121/193) deepTendonReflexAnkleRight: (315/0)
# (122/193) deepTendonReflexAnkleRight.orig: (280/35)
# (123/193) deepTendonReflexAnkleLeft: (315/0)
# (124/193) deepTendonReflexAnkleLeft.orig: (280/35)
# (125/193) ankleClonusRight: (315/0)
# (126/193) ankleClonusRight.orig: (284/31)
# (127/193) ankleClonusLeft: (315/0)
# (128/193) ankleClonusLeft.orig: (284/31)
# (129/193) plantarReflexRight: (315/0)
# (130/193) plantarReflexRight.orig: (285/30)
# (131/193) plantarReflexLeft: (315/0)
# (132/193) plantarReflexLeft.orig: (285/30)
# (133/193) axisHeadNeck: (315/0)
# (134/193) axisHeadNeck.orig: (285/30)
# (135/193) axisTrunk: (315/0)
# (136/193) axisTrunk.orig: (285/30)
# (137/193) lowerLimbFunction: (315/0)
# (138/193) lowerLimbFunction.orig: (285/30)
# (139/193) upperLimbFunction: (315/0)
# (140/193) upperLimbFunction.orig: (285/30)
# (141/193) handFunctionRight: (315/0)
# (142/193) handFunctionRight.orig: (285/30)
# (143/193) handFunctionLeft: (315/0)
# (144/193) handFunctionLeft.orig: (285/30)
# (145/193) neuralNormal: (315/0)
# (146/193) neuralNormal.orig: (285/30)
# (147/193) generalizedHypotonia: (315/0)
# (148/193) generalizedHypotonia.orig: (54/261)
# (149/193) hypertonia: (315/0)
# (150/193) hypertonia.orig: (54/261)
# (151/193) neuralOther: (315/0)
# (152/193) neuralOther.orig: (54/261)
# (153/193) neuralOtherText: (315/0)
# (154/193) neuralOtherText.orig: (17/298)
# (155/193) spasticDiplegia: (315/0)
# (156/193) spasticDiplegia.orig: (55/260)
# (157/193) spasticHemiplegiaRight: (315/0)
# (158/193) spasticHemiplegiaRight.orig: (55/260)
# (159/193) spasticHemiplegiaLeft: (315/0)
# (160/193) spasticHemiplegiaLeft.orig: (55/260)
# (161/193) spasticQuadriplegia: (315/0)
# (162/193) spasticQuadriplegia.orig: (55/260)
# (163/193) dystonia: (315/0)
# (164/193) dystonia.orig: (55/260)
# (165/193) athetosis: (315/0)
# (166/193) athetosis.orig: (55/260)
# (167/193) hypotoniaAtaxia: (315/0)
# (168/193) hypotoniaAtaxia.orig: (55/260)
# (169/193) cerebralPalsyUnclassified: (315/0)
# (170/193) cerebralPalsyUnclassified.orig: (55/260)
# (171/193) cerebralPalsyUnclassifiedText: (315/0)
# (172/193) cerebralPalsyUnclassifiedText.orig: (4/311)
# (173/193) cerebralPalsy: (315/0)
# (174/193) cerebralPalsy.orig: (285/30)
# (175/193) cerebralPalsyClass: (315/0)
# (176/193) cerebralPalsyClass.orig: (44/271)
# (177/193) abrnomalityAffectingNeuroAssessment: (315/0)
# (178/193) abrnomalityAffectingNeuroAssessment.orig: (285/30)
# (179/193) abrnomalityAffectingNeuroAssessmentText: (315/0)
# (180/193) abrnomalityAffectingNeuroAssessmentText.orig: (22/293)
# (181/193) examWhere: (315/0)
# (182/193) examWhere.orig: (285/30)
# (183/193) examWhereOtherText: (315/0)
# (184/193) examWhereOtherText.orig: (7/308)
# (185/193) examQuality: (315/0)
# (186/193) examQuality.orig: (285/30)
# (187/193) examFactorAffecting: (315/0)
# (188/193) examFactorAffecting.orig: (30/285)
# (189/193) examFactorAffectingText: (315/0)
# (190/193) examFactorAffectingText.orig: (1/314)
# (191/193) examCompleteDate: (315/0)
# (192/193) examCompleteDate.orig: (285/30)

# %% [markdown]
# ## 20-04-bayley-iii

# %%
base_filename = '20-04-bayley-iii.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/46) normalize_value: column: center
# (1/46) normalize_value: column: subjectID
# (2/46) normalize_value: column: uniqueID
# (3/46) normalize_value: column: followupCenter
# (4/46) normalize_value: column: followupID
# (5/46) normalize_value: column: siteID
# (6/46) normalize_value: column: BayleyIIICognitiveSubtest
# (7/46) normalize_value: column: BayleyIIIReasonNoSuccessCognitiveSubtestText
# (8/46) normalize_value: column: BayleyIIILanguageReceptiveSubtest
# (9/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText
# (10/46) normalize_value: column: BayleyIIILanguageExpressiveSubtest
# (11/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText
# (12/46) normalize_value: column: BayleyIIIMotorFineSubtest
# (13/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorFineSubtestText
# (14/46) normalize_value: column: BayleyIIIMotorGrossSubtest
# (15/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorGrossSubtestText
# (16/46) normalize_value: column: BayleyIIIInEnglish
# (17/46) normalize_value: column: BayleyIIIRequireInterpreter
# (18/46) normalize_value: column: BayleyIIIAdministratorMaskedToChildHistory
# (19/46) normalize_value: column: BayleyIIIReasonNoSuccessCognitiveSubtest
# (20/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageReceptiveSubtest
# (21/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageExpressiveSubtest
# (22/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorFineSubtest
# (23/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorGrossSubtest
# (24/46) normalize_value: column: BayleyIIIAdjustedAgeForCognitiveTest
# (25/46) normalize_value: column: BayleyIIIAdjustedAgeForReceptiveCommunication
# (26/46) normalize_value: column: BayleyIIIAdjustedAgeForExpressiveCommunication
# (27/46) normalize_value: column: BayleyIIIAdjustedAgeForMotorFineSubtest
# (28/46) normalize_value: column: BayleyIIIAdjustedAgeForMotorGrossSubtest
# (29/46) normalize_value: column: BayleyIIICognitiveRaw
# (30/46) normalize_value: column: BayleyIIICognitiveScale
# (31/46) normalize_value: column: BayleyIIICognitiveComposite
# (32/46) normalize_value: column: BayleyIIIReceptiveRaw
# (33/46) normalize_value: column: BayleyIIIReceptiveScale
# (34/46) normalize_value: column: BayleyIIIExpressiveRaw
# (35/46) normalize_value: column: BayleyIIIExpressiveScale
# (36/46) normalize_value: column: BayleyIIISumLanguageScore
# (37/46) normalize_value: column: BayleyIIILanguageComposite
# (38/46) normalize_value: column: BayleyIIIMotorFineRaw
# (39/46) normalize_value: column: BayleyIIIMotorFineScale
# (40/46) normalize_value: column: BayleyIIIMotorGrossRaw
# (41/46) normalize_value: column: BayleyIIIMotorGrossScale
# (42/46) normalize_value: column: BayleyIIISumMotorScore
# (43/46) normalize_value: column: BayleyIIIMotorComposite
# (44/46) normalize_value: column: BayleyIIIWhere
# (45/46) normalize_value: column: BayleyIIIDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/93) center: (315/0)
# (1/93) subjectID: (315/0)
# (2/93) uniqueID: (315/0)
# (3/93) followupCenter: (315/0)
# (4/93) followupID: (315/0)
# (5/93) uniqueFollowupID: (315/0)
# (6/93) center.orig: (315/0)
# (7/93) subjectID.orig: (315/0)
# (8/93) uniqueID.orig: (315/0)
# (9/93) followupCenter.orig: (315/0)
# (10/93) followupID.orig: (315/0)
# (11/93) siteID: (315/0)
# (12/93) siteID.orig: (315/0)
# (13/93) BayleyIIICognitiveSubtest: (315/0)
# (14/93) BayleyIIICognitiveSubtest.orig: (287/28)
# (15/93) BayleyIIIReasonNoSuccessCognitiveSubtest: (315/0)
# (16/93) BayleyIIIReasonNoSuccessCognitiveSubtest.orig: (17/298)
# (17/93) BayleyIIIReasonNoSuccessCognitiveSubtestText: (315/0)
# (18/93) BayleyIIIReasonNoSuccessCognitiveSubtestText.orig: (0/315)
# (19/93) BayleyIIILanguageReceptiveSubtest: (315/0)
# (20/93) BayleyIIILanguageReceptiveSubtest.orig: (287/28)
# (21/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtest: (315/0)
# (22/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtest.orig: (22/293)
# (23/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText: (315/0)
# (24/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText.orig: (0/315)
# (25/93) BayleyIIILanguageExpressiveSubtest: (315/0)
# (26/93) BayleyIIILanguageExpressiveSubtest.orig: (287/28)
# (27/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtest: (315/0)
# (28/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtest.orig: (24/291)
# (29/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText: (315/0)
# (30/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText.orig: (0/315)
# (31/93) BayleyIIIMotorFineSubtest: (315/0)
# (32/93) BayleyIIIMotorFineSubtest.orig: (287/28)
# (33/93) BayleyIIIReasonNoSuccessMotorFineSubtest: (315/0)
# (34/93) BayleyIIIReasonNoSuccessMotorFineSubtest.orig: (18/297)
# (35/93) BayleyIIIReasonNoSuccessMotorFineSubtestText: (315/0)
# (36/93) BayleyIIIReasonNoSuccessMotorFineSubtestText.orig: (0/315)
# (37/93) BayleyIIIMotorGrossSubtest: (315/0)
# (38/93) BayleyIIIMotorGrossSubtest.orig: (287/28)
# (39/93) BayleyIIIReasonNoSuccessMotorGrossSubtest: (315/0)
# (40/93) BayleyIIIReasonNoSuccessMotorGrossSubtest.orig: (21/294)
# (41/93) BayleyIIIReasonNoSuccessMotorGrossSubtestText: (315/0)
# (42/93) BayleyIIIReasonNoSuccessMotorGrossSubtestText.orig: (0/315)
# (43/93) BayleyIIIAdjustedAgeForCognitiveTest: (315/0)
# (44/93) BayleyIIIAdjustedAgeForCognitiveTest.orig: (283/32)
# (45/93) BayleyIIIAdjustedAgeForReceptiveCommunication: (315/0)
# (46/93) BayleyIIIAdjustedAgeForReceptiveCommunication.orig: (278/37)
# (47/93) BayleyIIIAdjustedAgeForExpressiveCommunication: (315/0)
# (48/93) BayleyIIIAdjustedAgeForExpressiveCommunication.orig: (276/39)
# (49/93) BayleyIIIAdjustedAgeForMotorFineSubtest: (315/0)
# (50/93) BayleyIIIAdjustedAgeForMotorFineSubtest.orig: (282/33)
# (51/93) BayleyIIIAdjustedAgeForMotorGrossSubtest: (315/0)
# (52/93) BayleyIIIAdjustedAgeForMotorGrossSubtest.orig: (279/36)
# (53/93) BayleyIIICognitiveRaw: (315/0)
# (54/93) BayleyIIICognitiveRaw.orig: (269/46)
# (55/93) BayleyIIICognitiveScale: (315/0)
# (56/93) BayleyIIICognitiveScale.orig: (270/45)
# (57/93) BayleyIIICognitiveComposite: (315/0)
# (58/93) BayleyIIICognitiveComposite.orig: (283/32)
# (59/93) BayleyIIIReceptiveRaw: (315/0)
# (60/93) BayleyIIIReceptiveRaw.orig: (264/51)
# (61/93) BayleyIIIReceptiveScale: (315/0)
# (62/93) BayleyIIIReceptiveScale.orig: (265/50)
# (63/93) BayleyIIIExpressiveRaw: (315/0)
# (64/93) BayleyIIIExpressiveRaw.orig: (262/53)
# (65/93) BayleyIIIExpressiveScale: (315/0)
# (66/93) BayleyIIIExpressiveScale.orig: (263/52)
# (67/93) BayleyIIISumLanguageScore: (315/0)
# (68/93) BayleyIIISumLanguageScore.orig: (262/53)
# (69/93) BayleyIIILanguageComposite: (315/0)
# (70/93) BayleyIIILanguageComposite.orig: (275/40)
# (71/93) BayleyIIIMotorFineRaw: (315/0)
# (72/93) BayleyIIIMotorFineRaw.orig: (268/47)
# (73/93) BayleyIIIMotorFineScale: (315/0)
# (74/93) BayleyIIIMotorFineScale.orig: (269/46)
# (75/93) BayleyIIIMotorGrossRaw: (315/0)
# (76/93) BayleyIIIMotorGrossRaw.orig: (264/51)
# (77/93) BayleyIIIMotorGrossScale: (315/0)
# (78/93) BayleyIIIMotorGrossScale.orig: (265/50)
# (79/93) BayleyIIISumMotorScore: (315/0)
# (80/93) BayleyIIISumMotorScore.orig: (264/51)
# (81/93) BayleyIIIMotorComposite: (315/0)
# (82/93) BayleyIIIMotorComposite.orig: (277/38)
# (83/93) BayleyIIIInEnglish: (315/0)
# (84/93) BayleyIIIInEnglish.orig: (283/32)
# (85/93) BayleyIIIRequireInterpreter: (315/0)
# (86/93) BayleyIIIRequireInterpreter.orig: (27/288)
# (87/93) BayleyIIIAdministratorMaskedToChildHistory: (315/0)
# (88/93) BayleyIIIAdministratorMaskedToChildHistory.orig: (283/32)
# (89/93) BayleyIIIWhere: (315/0)
# (90/93) BayleyIIIWhere.orig: (282/33)
# (91/93) BayleyIIIDate: (315/0)
# (92/93) BayleyIIIDate.orig: (283/32)

# %% [markdown]
# ## 20-05. GMFCS

# %%
base_filename = '20-05-gmfcs.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/7) normalize_value: column: center
# (1/7) normalize_value: column: subjectID
# (2/7) normalize_value: column: uniqueID
# (3/7) normalize_value: column: followupCenter
# (4/7) normalize_value: column: followupID
# (5/7) normalize_value: column: siteID
# (6/7) normalize_value: column: grossMotorFunctionLevel

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/15) center: (315/0)
# (1/15) subjectID: (315/0)
# (2/15) uniqueID: (315/0)
# (3/15) followupCenter: (315/0)
# (4/15) followupID: (315/0)
# (5/15) uniqueFollowupID: (315/0)
# (6/15) center.orig: (315/0)
# (7/15) subjectID.orig: (315/0)
# (8/15) uniqueID.orig: (315/0)
# (9/15) followupCenter.orig: (315/0)
# (10/15) followupID.orig: (315/0)
# (11/15) siteID: (315/0)
# (12/15) siteID.orig: (315/0)
# (13/15) grossMotorFunctionLevel: (315/0)
# (14/15) grossMotorFunctionLevel.orig: (285/30)

# %% [markdown]
# ## 20-06. Status

# %%
base_filename = '20-06-status.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/14) normalize_value: column: center
# (1/14) normalize_value: column: subjectID
# (2/14) normalize_value: column: uniqueID
# (3/14) normalize_value: column: followupCenter
# (4/14) normalize_value: column: followupID
# (5/14) normalize_value: column: siteID
# (6/14) normalize_value: column: statusBirthDate
# (7/14) normalize_value: column: statusVisitDate
# (8/14) normalize_value: column: childFinalStatus
# (9/14) normalize_value: column: deathDate
# (10/14) normalize_value: column: deathCause
# (11/14) normalize_value: column: reasonLossFollowUp
# (12/14) normalize_value: column: firstVisitDate
# (13/14) normalize_value: column: finalVisitDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/29) center: (315/0)
# (1/29) subjectID: (315/0)
# (2/29) uniqueID: (315/0)
# (3/29) followupCenter: (315/0)
# (4/29) followupID: (315/0)
# (5/29) uniqueFollowupID: (315/0)
# (6/29) center.orig: (315/0)
# (7/29) subjectID.orig: (315/0)
# (8/29) uniqueID.orig: (315/0)
# (9/29) followupCenter.orig: (315/0)
# (10/29) followupID.orig: (315/0)
# (11/29) siteID: (315/0)
# (12/29) siteID.orig: (315/0)
# (13/29) statusVisitDate: (315/0)
# (14/29) statusVisitDate.orig: (0/315)
# (15/29) statusBirthDate: (315/0)
# (16/29) statusBirthDate.orig: (315/0)
# (17/29) childFinalStatus: (315/0)
# (18/29) childFinalStatus.orig: (315/0)
# (19/29) deathDate: (315/0)
# (20/29) deathDate.orig: (7/308)
# (21/29) deathCause: (315/0)
# (22/29) deathCause.orig: (7/308)
# (23/29) reasonLossFollowUp: (315/0)
# (24/29) reasonLossFollowUp.orig: (21/294)
# (25/29) firstVisitDate: (315/0)
# (26/29) firstVisitDate.orig: (291/24)
# (27/29) finalVisitDate: (315/0)
# (28/29) finalVisitDate.orig: (292/23)

# %% [markdown]
# ## 20-08. Lost Follow-up

# %%
base_filename = '20-08-lost.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/63) normalize_value: column: center
# (1/63) normalize_value: column: subjectID
# (2/63) normalize_value: column: uniqueID
# (3/63) normalize_value: column: followupCenter
# (4/63) normalize_value: column: followupID
# (5/63) normalize_value: column: siteID
# (6/63) normalize_value: column: lostFollowUpInformationAvailableIndirectSrc
# (7/63) normalize_value: column: lostFollowUpChildAlive
# (8/63) normalize_value: column: lostFollowUpInterview
# (9/63) normalize_value: column: lostFollowUpAnyQuestionCompleteChartReview
# (10/63) normalize_value: column: interviewWalkAlone
# (11/63) normalize_value: column: interviewSittingAlong
# (12/63) normalize_value: column: interviewHeadControl
# (13/63) normalize_value: column: interviewSee
# (14/63) normalize_value: column: interviewEyeExam
# (15/63) normalize_value: column: interviewNeedWearGlasses
# (16/63) normalize_value: column: interviewHear
# (17/63) normalize_value: column: interviewHearExam
# (18/63) normalize_value: column: interviewNeedWearHearingAid
# (19/63) normalize_value: column: interviewCombine2Words
# (20/63) normalize_value: column: interviewCombine3Words
# (21/63) normalize_value: column: interviewHydrocephalusShunt
# (22/63) normalize_value: column: interviewCerebralPalsy
# (23/63) normalize_value: column: interviewDevelopmentalDelay
# (24/63) normalize_value: column: interviewLanguageDelay
# (25/63) normalize_value: column: interviewPoorWeightGain
# (26/63) normalize_value: column: interviewSeizure
# (27/63) normalize_value: column: interviewBlindness
# (28/63) normalize_value: column: interviewOtherBehaviorProblem
# (29/63) normalize_value: column: interviewOtherBehaviorProblemText
# (30/63) normalize_value: column: interviewOtherMajorMedicalProblem
# (31/63) normalize_value: column: interviewOtherMajorMedicalProblemText
# (32/63) normalize_value: column: interviewOtherNeuraldevelopmentalProblem
# (33/63) normalize_value: column: interviewOtherNeuraldevelopmentalProblemText
# (34/63) normalize_value: column: chartReviewOtherBehaviorProblemText
# (35/63) normalize_value: column: chartReviewOtherMajorMedicalProblemText
# (36/63) normalize_value: column: chartReviewOtherNeuraldevelopmentalProblemText
# (37/63) normalize_value: column: lostFollowUpLastContactDate
# (38/63) normalize_value: column: lostFollowUpFormCompleteDate
# (39/63) normalize_value: column: lostFollowUpLastKnownAliveCorrectedAge_mo
# (40/63) normalize_value: column: lostFollowUpDeathDate
# (41/63) normalize_value: column: lostFollowUpInterviewDate
# (42/63) normalize_value: column: lostFollowUpInterviewCorrectedAge_mo
# (43/63) normalize_value: column: lostFollowUpChartReviewDate
# (44/63) normalize_value: column: lostFollowUpChartReviewCorrectedAge_mo
# (45/63) normalize_value: column: interviewChildHealth
# (46/63) normalize_value: column: interviewWalkAloneAge_mo
# (47/63) normalize_value: column: interviewNumberWordVocabulary
# (48/63) normalize_value: column: interviewMotorGrossFunctionLevel
# (49/63) normalize_value: column: chartReviewEyeExam
# (50/63) normalize_value: column: chartReviewHearingExam
# (51/63) normalize_value: column: chartReviewNeedWearHearingAid
# (52/63) normalize_value: column: chartReviewHydrocephalusShunt
# (53/63) normalize_value: column: chartReviewCerebralPalsy
# (54/63) normalize_value: column: chartReviewDevelopmentalDelay
# (55/63) normalize_value: column: chartReviewLanguageDelay
# (56/63) normalize_value: column: chartReviewPoorWeightGain
# (57/63) normalize_value: column: chartReviewSeizure
# (58/63) normalize_value: column: chartReviewBlindness
# (59/63) normalize_value: column: chartReviewOtherBehaviorProblem
# (60/63) normalize_value: column: chartReviewOtherMajorMedicalProblem
# (61/63) normalize_value: column: chartReviewOtherNeuraldevelopmentalProblem
# (62/63) normalize_value: column: chartReviewMotorGrossFunctionLevel

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/127) center: (315/0)
# (1/127) subjectID: (315/0)
# (2/127) uniqueID: (315/0)
# (3/127) followupCenter: (315/0)
# (4/127) followupID: (315/0)
# (5/127) uniqueFollowupID: (315/0)
# (6/127) center.orig: (315/0)
# (7/127) subjectID.orig: (315/0)
# (8/127) uniqueID.orig: (315/0)
# (9/127) followupCenter.orig: (315/0)
# (10/127) followupID.orig: (315/0)
# (11/127) siteID: (315/0)
# (12/127) siteID.orig: (315/0)
# (13/127) lostFollowUpInformationAvailableIndirectSrc: (315/0)
# (14/127) lostFollowUpInformationAvailableIndirectSrc.orig: (24/291)
# (15/127) lostFollowUpLastContactDate: (315/0)
# (16/127) lostFollowUpLastContactDate.orig: (9/306)
# (17/127) lostFollowUpFormCompleteDate: (315/0)
# (18/127) lostFollowUpFormCompleteDate.orig: (10/305)
# (19/127) lostFollowUpChildAlive: (315/0)
# (20/127) lostFollowUpChildAlive.orig: (14/301)
# (21/127) lostFollowUpLastKnownAliveCorrectedAge_mo: (315/0)
# (22/127) lostFollowUpLastKnownAliveCorrectedAge_mo.orig: (13/302)
# (23/127) lostFollowUpDeathDate: (315/0)
# (24/127) lostFollowUpDeathDate.orig: (1/314)
# (25/127) lostFollowUpInterview: (315/0)
# (26/127) lostFollowUpInterview.orig: (13/302)
# (27/127) lostFollowUpInterviewDate: (315/0)
# (28/127) lostFollowUpInterviewDate.orig: (5/310)
# (29/127) lostFollowUpInterviewCorrectedAge_mo: (315/0)
# (30/127) lostFollowUpInterviewCorrectedAge_mo.orig: (5/310)
# (31/127) lostFollowUpAnyQuestionCompleteChartReview: (315/0)
# (32/127) lostFollowUpAnyQuestionCompleteChartReview.orig: (13/302)
# (33/127) lostFollowUpChartReviewDate: (315/0)
# (34/127) lostFollowUpChartReviewDate.orig: (9/306)
# (35/127) lostFollowUpChartReviewCorrectedAge_mo: (315/0)
# (36/127) lostFollowUpChartReviewCorrectedAge_mo.orig: (9/306)
# (37/127) interviewChildHealth: (315/0)
# (38/127) interviewChildHealth.orig: (5/310)
# (39/127) interviewWalkAlone: (315/0)
# (40/127) interviewWalkAlone.orig: (5/310)
# (41/127) interviewWalkAloneAge_mo: (315/0)
# (42/127) interviewWalkAloneAge_mo.orig: (2/313)
# (43/127) interviewSittingAlong: (315/0)
# (44/127) interviewSittingAlong.orig: (2/313)
# (45/127) interviewHeadControl: (315/0)
# (46/127) interviewHeadControl.orig: (2/313)
# (47/127) interviewSee: (315/0)
# (48/127) interviewSee.orig: (5/310)
# (49/127) interviewEyeExam: (315/0)
# (50/127) interviewEyeExam.orig: (5/310)
# (51/127) interviewNeedWearGlasses: (315/0)
# (52/127) interviewNeedWearGlasses.orig: (5/310)
# (53/127) interviewHear: (315/0)
# (54/127) interviewHear.orig: (5/310)
# (55/127) interviewHearExam: (315/0)
# (56/127) interviewHearExam.orig: (5/310)
# (57/127) interviewNeedWearHearingAid: (315/0)
# (58/127) interviewNeedWearHearingAid.orig: (5/310)
# (59/127) interviewNumberWordVocabulary: (315/0)
# (60/127) interviewNumberWordVocabulary.orig: (3/312)
# (61/127) interviewCombine2Words: (315/0)
# (62/127) interviewCombine2Words.orig: (5/310)
# (63/127) interviewCombine3Words: (315/0)
# (64/127) interviewCombine3Words.orig: (5/310)
# (65/127) interviewHydrocephalusShunt: (315/0)
# (66/127) interviewHydrocephalusShunt.orig: (5/310)
# (67/127) interviewCerebralPalsy: (315/0)
# (68/127) interviewCerebralPalsy.orig: (5/310)
# (69/127) interviewDevelopmentalDelay: (315/0)
# (70/127) interviewDevelopmentalDelay.orig: (5/310)
# (71/127) interviewLanguageDelay: (315/0)
# (72/127) interviewLanguageDelay.orig: (5/310)
# (73/127) interviewPoorWeightGain: (315/0)
# (74/127) interviewPoorWeightGain.orig: (5/310)
# (75/127) interviewSeizure: (315/0)
# (76/127) interviewSeizure.orig: (5/310)
# (77/127) interviewBlindness: (315/0)
# (78/127) interviewBlindness.orig: (5/310)
# (79/127) interviewOtherBehaviorProblem: (315/0)
# (80/127) interviewOtherBehaviorProblem.orig: (5/310)
# (81/127) interviewOtherBehaviorProblemText: (315/0)
# (82/127) interviewOtherBehaviorProblemText.orig: (1/314)
# (83/127) interviewOtherMajorMedicalProblem: (315/0)
# (84/127) interviewOtherMajorMedicalProblem.orig: (5/310)
# (85/127) interviewOtherMajorMedicalProblemText: (315/0)
# (86/127) interviewOtherMajorMedicalProblemText.orig: (2/313)
# (87/127) interviewOtherNeuraldevelopmentalProblem: (315/0)
# (88/127) interviewOtherNeuraldevelopmentalProblem.orig: (5/310)
# (89/127) interviewOtherNeuraldevelopmentalProblemText: (315/0)
# (90/127) interviewOtherNeuraldevelopmentalProblemText.orig: (1/314)
# (91/127) interviewMotorGrossFunctionLevel: (315/0)
# (92/127) interviewMotorGrossFunctionLevel.orig: (4/311)
# (93/127) chartReviewEyeExam: (315/0)
# (94/127) chartReviewEyeExam.orig: (9/306)
# (95/127) chartReviewHearingExam: (315/0)
# (96/127) chartReviewHearingExam.orig: (9/306)
# (97/127) chartReviewNeedWearHearingAid: (315/0)
# (98/127) chartReviewNeedWearHearingAid.orig: (9/306)
# (99/127) chartReviewHydrocephalusShunt: (315/0)
# (100/127) chartReviewHydrocephalusShunt.orig: (9/306)
# (101/127) chartReviewCerebralPalsy: (315/0)
# (102/127) chartReviewCerebralPalsy.orig: (9/306)
# (103/127) chartReviewDevelopmentalDelay: (315/0)
# (104/127) chartReviewDevelopmentalDelay.orig: (9/306)
# (105/127) chartReviewLanguageDelay: (315/0)
# (106/127) chartReviewLanguageDelay.orig: (9/306)
# (107/127) chartReviewPoorWeightGain: (315/0)
# (108/127) chartReviewPoorWeightGain.orig: (9/306)
# (109/127) chartReviewSeizure: (315/0)
# (110/127) chartReviewSeizure.orig: (9/306)
# (111/127) chartReviewBlindness: (315/0)
# (112/127) chartReviewBlindness.orig: (9/306)
# (113/127) chartReviewOtherBehaviorProblem: (315/0)
# (114/127) chartReviewOtherBehaviorProblem.orig: (9/306)
# (115/127) chartReviewOtherBehaviorProblemText: (315/0)
# (116/127) chartReviewOtherBehaviorProblemText.orig: (2/313)
# (117/127) chartReviewOtherMajorMedicalProblem: (315/0)
# (118/127) chartReviewOtherMajorMedicalProblem.orig: (9/306)
# (119/127) chartReviewOtherMajorMedicalProblemText: (315/0)
# (120/127) chartReviewOtherMajorMedicalProblemText.orig: (4/311)
# (121/127) chartReviewOtherNeuraldevelopmentalProblem: (315/0)
# (122/127) chartReviewOtherNeuraldevelopmentalProblem.orig: (9/306)
# (123/127) chartReviewOtherNeuraldevelopmentalProblemText: (315/0)
# (124/127) chartReviewOtherNeuraldevelopmentalProblemText.orig: (2/313)
# (125/127) chartReviewMotorGrossFunctionLevel: (315/0)
# (126/127) chartReviewMotorGrossFunctionLevel.orig: (6/309)

# %% [markdown]
# ## 20-09. Secondary Analysis

# %%
base_filename = '20-09-secondary.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/14) normalize_value: column: center
# (1/14) normalize_value: column: subjectID
# (2/14) normalize_value: column: uniqueID
# (3/14) normalize_value: column: followupID
# (4/14) normalize_value: column: followupCenter
# (5/14) normalize_value: column: blindness
# (6/14) normalize_value: column: hearingImpairedLevel
# (7/14) normalize_value: column: hearingImpairedWithAid
# (8/14) normalize_value: column: grossMotorFunctionLevelSeverity
# (9/14) normalize_value: column: cerebralPalsyMerge
# (10/14) normalize_value: column: moderateSevereCerebralPalsy
# (11/14) normalize_value: column: multipleImpairment
# (12/14) normalize_value: column: gastrostomyTube_b
# (13/14) normalize_value: column: afterDischargeSeizure

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/29) center: (364/0)
# (1/29) subjectID: (364/0)
# (2/29) uniqueID: (364/0)
# (3/29) followupCenter: (364/0)
# (4/29) followupID: (364/0)
# (5/29) uniqueFollowupID: (364/0)
# (6/29) center.orig: (364/0)
# (7/29) subjectID.orig: (364/0)
# (8/29) uniqueID.orig: (364/0)
# (9/29) followupCenter.orig: (315/49)
# (10/29) followupID.orig: (315/49)
# (11/29) blindness: (364/0)
# (12/29) blindness.orig: (294/70)
# (13/29) moderateSevereCerebralPalsy: (364/0)
# (14/29) moderateSevereCerebralPalsy.orig: (294/70)
# (15/29) cerebralPalsyMerge: (364/0)
# (16/29) cerebralPalsyMerge.orig: (294/70)
# (17/29) gastrostomyTube_b: (364/0)
# (18/29) gastrostomyTube_b.orig: (287/77)
# (19/29) grossMotorFunctionLevelSeverity: (364/0)
# (20/29) grossMotorFunctionLevelSeverity.orig: (285/79)
# (21/29) hearingImpairedWithAid: (364/0)
# (22/29) hearingImpairedWithAid.orig: (294/70)
# (23/29) hearingImpairedLevel: (364/0)
# (24/29) hearingImpairedLevel.orig: (285/79)
# (25/29) multipleImpairment: (364/0)
# (26/29) multipleImpairment.orig: (294/70)
# (27/29) afterDischargeSeizure: (364/0)
# (28/29) afterDischargeSeizure.orig: (293/71)

# %% [markdown]
# ## 20-10. Outcome

# %%
base_filename = '20-10-outcome.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/17) normalize_value: column: center
# (1/17) normalize_value: column: subjectID
# (2/17) normalize_value: column: uniqueID
# (3/17) normalize_value: column: followupID
# (4/17) normalize_value: column: followupCenter
# (5/17) normalize_value: column: BayleyIIICognitive
# (6/17) normalize_value: column: BayleyIIILanguage
# (7/17) normalize_value: column: BayleyIIIMotor
# (8/17) normalize_value: column: deathBeforeFollowup
# (9/17) normalize_value: column: normalPrimaryOutcome
# (10/17) normalize_value: column: flagAdjudicatedOutcome
# (11/17) normalize_value: column: deathBeforeDischarge
# (12/17) normalize_value: column: moderateSevereDisabilitySurvivor
# (13/17) normalize_value: column: disabilityLevelSurvivor
# (14/17) normalize_value: column: moderateSevereDisabilityOrDeath
# (15/17) normalize_value: column: disabilityLevelDeath4Category
# (16/17) normalize_value: column: outcomeGroup

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/35) center: (364/0)
# (1/35) subjectID: (364/0)
# (2/35) uniqueID: (364/0)
# (3/35) followupCenter: (364/0)
# (4/35) followupID: (364/0)
# (5/35) uniqueFollowupID: (364/0)
# (6/35) center.orig: (364/0)
# (7/35) subjectID.orig: (364/0)
# (8/35) uniqueID.orig: (364/0)
# (9/35) followupCenter.orig: (315/49)
# (10/35) followupID.orig: (315/49)
# (11/35) flagAdjudicatedOutcome: (364/0)
# (12/35) flagAdjudicatedOutcome.orig: (9/355)
# (13/35) normalPrimaryOutcome: (364/0)
# (14/35) normalPrimaryOutcome.orig: (285/79)
# (15/35) BayleyIIILanguage: (364/0)
# (16/35) BayleyIIILanguage.orig: (275/89)
# (17/35) BayleyIIIMotor: (364/0)
# (18/35) BayleyIIIMotor.orig: (277/87)
# (19/35) BayleyIIICognitive: (364/0)
# (20/35) BayleyIIICognitive.orig: (283/81)
# (21/35) deathBeforeFollowup: (364/0)
# (22/35) deathBeforeFollowup.orig: (354/10)
# (23/35) deathBeforeDischarge: (364/0)
# (24/35) deathBeforeDischarge.orig: (364/0)
# (25/35) disabilityLevelSurvivor: (364/0)
# (26/35) disabilityLevelSurvivor.orig: (285/79)
# (27/35) disabilityLevelDeath4Category: (364/0)
# (28/35) disabilityLevelDeath4Category.orig: (341/23)
# (29/35) moderateSevereDisabilityOrDeath: (364/0)
# (30/35) moderateSevereDisabilityOrDeath.orig: (347/17)
# (31/35) moderateSevereDisabilitySurvivor: (364/0)
# (32/35) moderateSevereDisabilitySurvivor.orig: (291/73)
# (33/35) outcomeGroup: (364/0)
# (34/35) outcomeGroup.orig: (347/17)

# %% [markdown]
# ## 20-07-readmission

# %%
_FLATTEN_IDS = ['readmissionNumber']
base_filename = '20-07-readmission.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, _FLATTEN_IDS,  order_map=_ORDER_MAP)

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/11) normalize_value: column: center
# (1/11) normalize_value: column: subjectID
# (2/11) normalize_value: column: uniqueID
# (3/11) normalize_value: column: followupCenter
# (4/11) normalize_value: column: followupID
# (5/11) normalize_value: column: readmissionPrimaryCauseOtherText
# (6/11) normalize_value: column: readmissionICU
# (7/11) normalize_value: column: readmissionNumber
# (8/11) normalize_value: column: readmissionTimePeriod
# (9/11) normalize_value: column: readmissionPrimaryCause
# (10/11) normalize_value: column: readmissionLengthOfStay
# flatten_index: flatten_ids: ['readmissionNumber'] unique_id_map: {np.int64(1): np.int64(1), np.int64(2): np.int64(2), np.int64(3): np.int64(3), np.int64(4): np.int64(4), np.int64(5): np.int64(5), np.int64(6): np.int64(6), np.int64(7): np.int64(7), np.int64(8): np.int64(8), np.int64(9): np.int64(9), np.int64(10): np.int64(10), np.int64(11): np.int64(11), np.int64(12): np.int64(12), np.int64(13): np.int64(13), np.int64(14): np.int64(14)} the_type: int64

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/23) center: (147/0)
# (1/23) center.orig: (147/0)
# (2/23) subjectID: (147/0)
# (3/23) subjectID.orig: (147/0)
# (4/23) uniqueID: (147/0)
# (5/23) uniqueID.orig: (147/0)
# (6/23) followupCenter: (147/0)
# (7/23) followupCenter.orig: (147/0)
# (8/23) followupID: (147/0)
# (9/23) followupID.orig: (147/0)
# (10/23) _flatten_index: (147/0)
# (11/23) readmissionNumber: (147/0)
# (12/23) readmissionNumber.orig: (147/0)
# (13/23) readmissionTimePeriod: (147/0)
# (14/23) readmissionTimePeriod.orig: (147/0)
# (15/23) readmissionPrimaryCause: (147/0)
# (16/23) readmissionPrimaryCause.orig: (147/0)
# (17/23) readmissionPrimaryCauseOtherText: (147/0)
# (18/23) readmissionPrimaryCauseOtherText.orig: (11/136)
# (19/23) readmissionLengthOfStay: (147/0)
# (20/23) readmissionLengthOfStay.orig: (147/0)
# (21/23) readmissionICU: (147/0)
# (22/23) readmissionICU.orig: (147/0)
