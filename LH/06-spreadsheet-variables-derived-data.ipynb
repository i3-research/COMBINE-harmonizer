# %%
import pandas as pd
pd.options.mode.copy_on_write = True
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
import os

import COMBINE_harmonizer
from COMBINE_harmonizer import cfg

# %% [markdown]
# ## 01. init

# %%
study_name = COMBINE_harmonizer.STUDY_LH
sheet_name = COMBINE_harmonizer.SHEET_DERIVED_DATA

root_dir = '..'

# %%
COMBINE_harmonizer.init(f'{root_dir}/config.yaml')

# %% [markdown]
# ## 02. Dictionary

# %%
data_dict_filename = f'{root_dir}/Dictionary_HIE_clinical_variables.xlsx'

# %%
df_dict = COMBINE_harmonizer.load_data_dict(data_dict_filename, sheet_name)

# %%
dict_columns = list(df_dict[study_name].unique())

# %% [markdown]
# ## 03. LH

# %%
the_dir = cfg.config[f'{study_name}_analysis_dir']

# %%
filenames = os.listdir(the_dir)
filenames.sort()

# %%
dfs = [pd.read_csv(os.sep.join([the_dir, each_filename])) for each_filename in filenames]

# %% [markdown]
# ### 03.1. check columns in each file

# %%
for idx, each_df in enumerate(dfs):
    print(f'({idx}/{len(dfs)}) filename: {filenames[idx]} columns: {list(each_df.columns)}')
# Out:
# (0/2) filename: analysis.csv columns: ['HTHRM_ID', 'CENTER', 'fcenter', 'blindness', 'hearing', 'hear_imp', 'gross', 'cp_out', 'modsevcp', 'bayley3', 'death18', 'all_norm', 'hosp_die', 'any_antic', 'LHFOLNUM', 'any_seiz', 'seiz_fu', 'disab_ms', 'disab_4', 'disab_die', 'disab_die4', 'MRI_DATE', 'MRI_TIME', 'MRI_AGED', 'MRI_UNREAD', 'MRI_RDATE_PB', 'MRI_RDATE_NR', 'MRI_RDATE_WG', 'MRI_RDATE_LC', 'MRI_PATTERN', 'MRI_PATTERN_PB', 'MRI_PATTERN_NR', 'MRI_PATTERN_WG', 'MRI_PATTERN_LC', 'MRI_PCLASS', 'MRI_PCLASS_PB', 'MRI_PCLASS_NR', 'MRI_PCLASS_WG', 'MRI_PCLASS_LC', 'MRI_INFARL', 'MRI_INFARL_PB', 'MRI_INFARL_NR', 'MRI_INFARL_WG', 'MRI_INFARR', 'MRI_INFARR_PB', 'MRI_INFARR_NR', 'MRI_INFARR_WG', 'MRI_NOTDONE']
# (1/2) filename: mrilh.csv columns: ['HTHRM_ID', 'CENTER', 'fcenter', 'blindness', 'hearing', 'hear_imp', 'gross', 'cp_out', 'modsevcp', 'bayley3', 'death18', 'all_norm', 'hosp_die', 'any_antic', 'LHFOLNUM', 'any_seiz', 'seiz_fu', 'disab_ms', 'disab_4', 'disab_die', 'disab_die4', 'MRI_DATE', 'MRI_TIME', 'MRI_AGED', 'MRI_UNREAD', 'MRI_RDATE_PB', 'MRI_RDATE_NR', 'MRI_RDATE_WG', 'MRI_RDATE_LC', 'MRI_PATTERN', 'MRI_PATTERN_PB', 'MRI_PATTERN_NR', 'MRI_PATTERN_WG', 'MRI_PATTERN_LC', 'MRI_PCLASS', 'MRI_PCLASS_PB', 'MRI_PCLASS_NR', 'MRI_PCLASS_WG', 'MRI_PCLASS_LC', 'MRI_INFARL', 'MRI_INFARL_PB', 'MRI_INFARL_NR', 'MRI_INFARL_WG', 'MRI_INFARR', 'MRI_INFARR_PB', 'MRI_INFARR_NR', 'MRI_INFARR_WG', 'MRI_NOTDONE']

# %% [markdown]
# ### 03.2. all columns

# %%
all_columns = []
for idx, each_df in enumerate(dfs):
    all_columns += list(map(lambda x: {'column': x, 'idx': idx, 'filename': filenames[idx]}, list(each_df.columns)))
df_columns = pd.DataFrame(all_columns)
df_columns['column:filename'] = df_columns.apply(lambda x: f"{x['column']}:{x['filename']}", axis=1)
df_columns['column:filename:idx'] = df_columns.apply(lambda x: f"{x['column']}:{x['filename']}:{x['idx']}", axis=1)
df_columns.sort_values(by=['filename', 'column'], inplace=True)

# %%
df_columns
# Out:
#       column  idx      filename        column:filename  \
# 1     CENTER    0  analysis.csv    CENTER:analysis.csv
# 0   HTHRM_ID    0  analysis.csv  HTHRM_ID:analysis.csv
# 14  LHFOLNUM    0  analysis.csv  LHFOLNUM:analysis.csv
# 23  MRI_AGED    0  analysis.csv  MRI_AGED:analysis.csv
# 21  MRI_DATE    0  analysis.csv  MRI_DATE:analysis.csv
# ..       ...  ...           ...                    ...
# 53  hear_imp    1     mrilh.csv     hear_imp:mrilh.csv
# 52   hearing    1     mrilh.csv      hearing:mrilh.csv
# 60  hosp_die    1     mrilh.csv     hosp_die:mrilh.csv
# 56  modsevcp    1     mrilh.csv     modsevcp:mrilh.csv
# 64   seiz_fu    1     mrilh.csv      seiz_fu:mrilh.csv
#
#         column:filename:idx
# 1     CENTER:analysis.csv:0
# 0   HTHRM_ID:analysis.csv:0
# 14  LHFOLNUM:analysis.csv:0
# 23  MRI_AGED:analysis.csv:0
# 21  MRI_DATE:analysis.csv:0
# ..                      ...
# 53     hear_imp:mrilh.csv:1
# 52      hearing:mrilh.csv:1
# 60     hosp_die:mrilh.csv:1
# 56     modsevcp:mrilh.csv:1
# 64      seiz_fu:mrilh.csv:1
#
# [96 rows x 5 columns]

# %%
df_columns_count = df_columns.groupby(['column']).agg(count=('column', 'count')).sort_values(by=['count'], ascending=False)
df_columns_count.head(20)
# Out:
#               count
# column
# CENTER            2
# HTHRM_ID          2
# MRI_RDATE_PB      2
# MRI_RDATE_WG      2
# MRI_TIME          2
# MRI_UNREAD        2
# all_norm          2
# any_antic         2
# any_seiz          2
# bayley3           2
# blindness         2
# cp_out            2
# death18           2
# disab_4           2
# disab_die         2
# disab_die4        2
# disab_ms          2
# fcenter           2
# gross             2
# hear_imp          2

# %% [markdown]
# ##### column not in dict

# %%
is_not_in_dict = df_columns['column'].isin(dict_columns) == False
df_columns_not_in_dict = df_columns[is_not_in_dict]
df_columns_not_in_dict
# Out:
#             column  idx      filename              column:filename  \
# 41   MRI_INFARL_NR    0  analysis.csv   MRI_INFARL_NR:analysis.csv
# 40   MRI_INFARL_PB    0  analysis.csv   MRI_INFARL_PB:analysis.csv
# 42   MRI_INFARL_WG    0  analysis.csv   MRI_INFARL_WG:analysis.csv
# 45   MRI_INFARR_NR    0  analysis.csv   MRI_INFARR_NR:analysis.csv
# 44   MRI_INFARR_PB    0  analysis.csv   MRI_INFARR_PB:analysis.csv
# 46   MRI_INFARR_WG    0  analysis.csv   MRI_INFARR_WG:analysis.csv
# 33  MRI_PATTERN_LC    0  analysis.csv  MRI_PATTERN_LC:analysis.csv
# 31  MRI_PATTERN_NR    0  analysis.csv  MRI_PATTERN_NR:analysis.csv
# 30  MRI_PATTERN_PB    0  analysis.csv  MRI_PATTERN_PB:analysis.csv
# 32  MRI_PATTERN_WG    0  analysis.csv  MRI_PATTERN_WG:analysis.csv
# 38   MRI_PCLASS_LC    0  analysis.csv   MRI_PCLASS_LC:analysis.csv
# 36   MRI_PCLASS_NR    0  analysis.csv   MRI_PCLASS_NR:analysis.csv
# 35   MRI_PCLASS_PB    0  analysis.csv   MRI_PCLASS_PB:analysis.csv
# 37   MRI_PCLASS_WG    0  analysis.csv   MRI_PCLASS_WG:analysis.csv
# 28    MRI_RDATE_LC    0  analysis.csv    MRI_RDATE_LC:analysis.csv
# 26    MRI_RDATE_NR    0  analysis.csv    MRI_RDATE_NR:analysis.csv
# 25    MRI_RDATE_PB    0  analysis.csv    MRI_RDATE_PB:analysis.csv
# 27    MRI_RDATE_WG    0  analysis.csv    MRI_RDATE_WG:analysis.csv
# 89   MRI_INFARL_NR    1     mrilh.csv      MRI_INFARL_NR:mrilh.csv
# 88   MRI_INFARL_PB    1     mrilh.csv      MRI_INFARL_PB:mrilh.csv
# 90   MRI_INFARL_WG    1     mrilh.csv      MRI_INFARL_WG:mrilh.csv
# 93   MRI_INFARR_NR    1     mrilh.csv      MRI_INFARR_NR:mrilh.csv
# 92   MRI_INFARR_PB    1     mrilh.csv      MRI_INFARR_PB:mrilh.csv
# 94   MRI_INFARR_WG    1     mrilh.csv      MRI_INFARR_WG:mrilh.csv
# 81  MRI_PATTERN_LC    1     mrilh.csv     MRI_PATTERN_LC:mrilh.csv
# 79  MRI_PATTERN_NR    1     mrilh.csv     MRI_PATTERN_NR:mrilh.csv
# 78  MRI_PATTERN_PB    1     mrilh.csv     MRI_PATTERN_PB:mrilh.csv
# 80  MRI_PATTERN_WG    1     mrilh.csv     MRI_PATTERN_WG:mrilh.csv
# 86   MRI_PCLASS_LC    1     mrilh.csv      MRI_PCLASS_LC:mrilh.csv
# 84   MRI_PCLASS_NR    1     mrilh.csv      MRI_PCLASS_NR:mrilh.csv
# 83   MRI_PCLASS_PB    1     mrilh.csv      MRI_PCLASS_PB:mrilh.csv
# 85   MRI_PCLASS_WG    1     mrilh.csv      MRI_PCLASS_WG:mrilh.csv
# 76    MRI_RDATE_LC    1     mrilh.csv       MRI_RDATE_LC:mrilh.csv
# 74    MRI_RDATE_NR    1     mrilh.csv       MRI_RDATE_NR:mrilh.csv
# 73    MRI_RDATE_PB    1     mrilh.csv       MRI_RDATE_PB:mrilh.csv
# 75    MRI_RDATE_WG    1     mrilh.csv       MRI_RDATE_WG:mrilh.csv
#
#               column:filename:idx
# 41   MRI_INFARL_NR:analysis.csv:0
# 40   MRI_INFARL_PB:analysis.csv:0
# 42   MRI_INFARL_WG:analysis.csv:0
# 45   MRI_INFARR_NR:analysis.csv:0
# 44   MRI_INFARR_PB:analysis.csv:0
# 46   MRI_INFARR_WG:analysis.csv:0
# 33  MRI_PATTERN_LC:analysis.csv:0
# 31  MRI_PATTERN_NR:analysis.csv:0
# 30  MRI_PATTERN_PB:analysis.csv:0
# 32  MRI_PATTERN_WG:analysis.csv:0
# 38   MRI_PCLASS_LC:analysis.csv:0
# 36   MRI_PCLASS_NR:analysis.csv:0
# 35   MRI_PCLASS_PB:analysis.csv:0
# 37   MRI_PCLASS_WG:analysis.csv:0
# 28    MRI_RDATE_LC:analysis.csv:0
# 26    MRI_RDATE_NR:analysis.csv:0
# 25    MRI_RDATE_PB:analysis.csv:0
# 27    MRI_RDATE_WG:analysis.csv:0
# 89      MRI_INFARL_NR:mrilh.csv:1
# 88      MRI_INFARL_PB:mrilh.csv:1
# 90      MRI_INFARL_WG:mrilh.csv:1
# 93      MRI_INFARR_NR:mrilh.csv:1
# 92      MRI_INFARR_PB:mrilh.csv:1
# 94      MRI_INFARR_WG:mrilh.csv:1
# 81     MRI_PATTERN_LC:mrilh.csv:1
# 79     MRI_PATTERN_NR:mrilh.csv:1
# 78     MRI_PATTERN_PB:mrilh.csv:1
# 80     MRI_PATTERN_WG:mrilh.csv:1
# 86      MRI_PCLASS_LC:mrilh.csv:1
# 84      MRI_PCLASS_NR:mrilh.csv:1
# 83      MRI_PCLASS_PB:mrilh.csv:1
# 85      MRI_PCLASS_WG:mrilh.csv:1
# 76       MRI_RDATE_LC:mrilh.csv:1
# 74       MRI_RDATE_NR:mrilh.csv:1
# 73       MRI_RDATE_PB:mrilh.csv:1
# 75       MRI_RDATE_WG:mrilh.csv:1

# %%
columns_not_in_dict = list(df_columns_not_in_dict['column:filename:idx'].unique())
# columns_not_in_dict.sort()
columns_not_in_dict
# Out:
# ['MRI_INFARL_NR:analysis.csv:0',
#  'MRI_INFARL_PB:analysis.csv:0',
#  'MRI_INFARL_WG:analysis.csv:0',
#  'MRI_INFARR_NR:analysis.csv:0',
#  'MRI_INFARR_PB:analysis.csv:0',
#  'MRI_INFARR_WG:analysis.csv:0',
#  'MRI_PATTERN_LC:analysis.csv:0',
#  'MRI_PATTERN_NR:analysis.csv:0',
#  'MRI_PATTERN_PB:analysis.csv:0',
#  'MRI_PATTERN_WG:analysis.csv:0',
#  'MRI_PCLASS_LC:analysis.csv:0',
#  'MRI_PCLASS_NR:analysis.csv:0',
#  'MRI_PCLASS_PB:analysis.csv:0',
#  'MRI_PCLASS_WG:analysis.csv:0',
#  'MRI_RDATE_LC:analysis.csv:0',
#  'MRI_RDATE_NR:analysis.csv:0',
#  'MRI_RDATE_PB:analysis.csv:0',
#  'MRI_RDATE_WG:analysis.csv:0',
#  'MRI_INFARL_NR:mrilh.csv:1',
#  'MRI_INFARL_PB:mrilh.csv:1',
#  'MRI_INFARL_WG:mrilh.csv:1',
#  'MRI_INFARR_NR:mrilh.csv:1',
#  'MRI_INFARR_PB:mrilh.csv:1',
#  'MRI_INFARR_WG:mrilh.csv:1',
#  'MRI_PATTERN_LC:mrilh.csv:1',
#  'MRI_PATTERN_NR:mrilh.csv:1',
#  'MRI_PATTERN_PB:mrilh.csv:1',
#  'MRI_PATTERN_WG:mrilh.csv:1',
#  'MRI_PCLASS_LC:mrilh.csv:1',
#  'MRI_PCLASS_NR:mrilh.csv:1',
#  'MRI_PCLASS_PB:mrilh.csv:1',
#  'MRI_PCLASS_WG:mrilh.csv:1',
#  'MRI_RDATE_LC:mrilh.csv:1',
#  'MRI_RDATE_NR:mrilh.csv:1',
#  'MRI_RDATE_PB:mrilh.csv:1',
#  'MRI_RDATE_WG:mrilh.csv:1']

# %% [markdown]
# #### dict not in column

# %%
is_dict_not_in_columns = (df_dict[study_name].isin(df_columns['column']) == False) & (df_dict[study_name].isnull() == False)
df_dict_not_in_columns = df_dict[is_dict_not_in_columns]
df_dict_not_in_columns
# Out:
# Empty DataFrame
# Columns: [Category, Subcategory, Standardized_VariableNames_Dictionary, type, Variable_Description, #studies w/ this var, redcap, comment, LH, OC]
# Index: []

# %% [markdown]
# ## 04. show column values

# %%
# XXX no show due to data privacy concern.

'''
for idx, each_df in enumerate(dfs):
    for idx2, column in enumerate(each_df.columns):
        print(f'({idx}/{len(dfs)}/{filenames[idx]}) ({idx2}/{len(each_df.columns)} column: {column} value: {list(each_df[column].unique())}')
    print()
'''
# Out:
# "\nfor idx, each_df in enumerate(dfs):\n    for idx2, column in enumerate(each_df.columns):\n        print(f'({idx}/{len(dfs)}/{filenames[idx]}) ({idx2}/{len(each_df.columns)} column: {column} value: {list(each_df[column].unique())}')\n    print()\n"
