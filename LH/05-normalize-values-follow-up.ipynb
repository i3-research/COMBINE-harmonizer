# %%
import pandas as pd
pd.options.mode.copy_on_write = True
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

import os

import COMBINE_harmonizer
from COMBINE_harmonizer import cfg

# %% [markdown]
# ## 00-0. Variables

# %%
study_name = COMBINE_harmonizer.STUDY_LH
sheet_name = COMBINE_harmonizer.SHEET_FOLLOW_UP

root_dir = '..'

# %%
COMBINE_harmonizer.init(f'{root_dir}/config.yaml')

# %%
input_dir = f"{cfg.config['out_dir']}/out-{study_name}"
data_dict_filename = f"{root_dir}/{COMBINE_harmonizer.DATA_DICTIONARY_EXCEL}"
out_dir = f"{cfg.config['out_dir']}/out-{study_name}-normalized"

os.makedirs(out_dir, exist_ok=True)

# %%
COMBINE_harmonizer.init_mapping(data_dict_filename, study_name)
_VALUE_MAP = COMBINE_harmonizer.build_value_map(data_dict_filename, sheet_name)
# Out:
# [INFO] init_mapping (0/125): signOfHIETone
# [INFO] init_mapping (1/125): signOfHIELvlOfCons
# [INFO] init_mapping (2/125): signOfHIEPosture
# [INFO] init_mapping (3/125): signOfHIEMoro
# [INFO] init_mapping (4/125): signOfHIESuck
# [INFO] init_mapping (5/125): signOfHIERespiratory
# [INFO] init_mapping (6/125): signOfHIEHeartRate
# [INFO] init_mapping (7/125): signOfHIEPupils
# [INFO] init_mapping (8/125): signOfHIESpontaneousActivity
# [INFO] init_mapping (9/125): noNeuroExamReason
# [INFO] init_mapping (10/125): consentStatus
# [INFO] init_mapping (11/125): treatmentAssign
# [INFO] init_mapping (12/125): targetTreatmentTemperature
# [INFO] init_mapping (13/125): blanketType
# [INFO] init_mapping (14/125): encephalopathyLevel
# [INFO] init_mapping (15/125): infantAge
# [INFO] init_mapping (16/125): infantSex
# [INFO] init_mapping (17/125): ethnicity
# [INFO] init_mapping (18/125): education
# [INFO] init_mapping (19/125): insurance
# [INFO] init_mapping (20/125): race
# [INFO] init_mapping (21/125): maritalStatus
# [INFO] init_mapping (22/125): deliveryMode
# [INFO] init_mapping (23/125): spontaneousRespirationTime
# [INFO] init_mapping (24/125): cordBloodGasSrc
# [INFO] init_mapping (25/125): bloodGasSrc
# [INFO] init_mapping (26/125): antibiotics
# [INFO] init_mapping (27/125): positiveCultureOrganism
# [INFO] init_mapping (28/125): positiveCultureSrc
# [INFO] init_mapping (29/125): surgery
# [INFO] init_mapping (30/125): birthDefect
# [INFO] init_mapping (31/125): anticonvulsants
# [INFO] init_mapping (32/125): analgesics
# [INFO] init_mapping (33/125): antipyretics
# [INFO] init_mapping (34/125): paralytics
# [INFO] init_mapping (35/125): respiratorySupportType
# [INFO] init_mapping (36/125): coolAfterIntervention
# [INFO] init_mapping (37/125): noCoolToEndPeriodReason
# [INFO] init_mapping (38/125): imaging
# [INFO] init_mapping (39/125): MRIReader
# [INFO] init_mapping (40/125): MRIObtainWindow
# [INFO] init_mapping (41/125): MRINoObtainReason
# [INFO] init_mapping (42/125): MRICerebralAtrophyGlobalLocal
# [INFO] init_mapping (43/125): MRICerebralAtrophyRegion
# [INFO] init_mapping (44/125): MRISeverity
# [INFO] init_mapping (45/125): MRIALICPLICSeverity
# [INFO] init_mapping (46/125): MRIInjurySeverity
# [INFO] init_mapping (47/125): MRINRNPatternOfInjury
# [INFO] init_mapping (48/125): MRINRNPatternOfInjuryExtent
# [INFO] init_mapping (49/125): MRINRNPatternOfInjuryLateral
# [INFO] init_mapping (50/125): MRIAbnormalRegion
# [INFO] init_mapping (51/125): MRIAbnormalSide
# [INFO] init_mapping (52/125): MRIAbnormalGMWM
# [INFO] init_mapping (53/125): MRIAbnormalExtent
# [INFO] init_mapping (54/125): MRIAbnormalType
# [INFO] init_mapping (55/125): elevatedTempDevice
# [INFO] init_mapping (56/125): elevatedTempDeviceMode
# [INFO] init_mapping (57/125): elevatedTempNoBathReason
# [INFO] init_mapping (58/125): bradycardiaEKGResult
# [INFO] init_mapping (59/125): bradycardiaDuration
# [INFO] init_mapping (60/125): bradycardiaHeartRateMin
# [INFO] init_mapping (61/125): SAEAlterationSkinIntegrity
# [INFO] init_mapping (62/125): SAEAttributable
# [INFO] init_mapping (63/125): SAEAction
# [INFO] init_mapping (64/125): SAEOutcome
# [INFO] init_mapping (65/125): deathCause
# [INFO] init_mapping (66/125): deathSrc
# [INFO] init_mapping (67/125): experimentStatus
# [INFO] init_mapping (68/125): status
# [INFO] init_mapping (69/125): transferReason
# [INFO] init_mapping (70/125): transferOutcome
# [INFO] init_mapping (71/125): dischargeNeuroExamStatus
# [INFO] init_mapping (72/125): violationCircumstance
# [INFO] init_mapping (73/125): violationNature
# [INFO] init_mapping (74/125): interruptReason
# [INFO] init_mapping (75/125): relationship
# [INFO] init_mapping (76/125): receive
# [INFO] init_mapping (77/125): totalIncome
# [INFO] init_mapping (78/125): language
# [INFO] init_mapping (79/125): homeCareLocation
# [INFO] init_mapping (80/125): babysitterRelation
# [INFO] init_mapping (81/125): interviewLocation
# [INFO] init_mapping (82/125): livingArrange
# [INFO] init_mapping (83/125): medicationUse
# [INFO] init_mapping (84/125): eyeSurgeryReason
# [INFO] init_mapping (85/125): readmissionTimePeriod
# [INFO] init_mapping (86/125): readmissionLengthOfStay
# [INFO] init_mapping (87/125): readmissionPrimaryCause
# [INFO] init_mapping (88/125): eye
# [INFO] init_mapping (89/125): vision
# [INFO] init_mapping (90/125): hearing
# [INFO] init_mapping (91/125): hearingImpaired
# [INFO] init_mapping (92/125): hearingAid
# [INFO] init_mapping (93/125): swallow
# [INFO] init_mapping (94/125): passiveMuscleTone
# [INFO] init_mapping (95/125): grossMotorFunctionLevel
# [INFO] init_mapping (96/125): handPreference
# [INFO] init_mapping (97/125): protectiveReaction
# [INFO] init_mapping (98/125): limbMovement
# [INFO] init_mapping (99/125): deepTendonReflex
# [INFO] init_mapping (100/125): ankleClonus
# [INFO] init_mapping (101/125): plantarReflex
# [INFO] init_mapping (102/125): axisHeadNeck
# [INFO] init_mapping (103/125): axisTrunk
# [INFO] init_mapping (104/125): lowerLimbFunction
# [INFO] init_mapping (105/125): upperLimbFunction
# [INFO] init_mapping (106/125): handFunction
# [INFO] init_mapping (107/125): cerebralPalsyClass
# [INFO] init_mapping (108/125): examQuality
# [INFO] init_mapping (109/125): examFactorAffecting
# [INFO] init_mapping (110/125): BayleyIIIReasonNoSuccess
# [INFO] init_mapping (111/125): followupStatus
# [INFO] init_mapping (112/125): severity
# [INFO] init_mapping (113/125): reasonLossFollowUp
# [INFO] init_mapping (114/125): childHealth
# [INFO] init_mapping (115/125): chartReview
# [INFO] init_mapping (116/125): education2
# [INFO] init_mapping (117/125): race2
# [INFO] init_mapping (118/125): flagAdjudicatedOutcome
# [INFO] init_mapping (119/125): MRILesion
# [INFO] init_mapping (120/125): MRI2LevelPatternOfInjury
# [INFO] init_mapping (121/125): MRIOverallDiagnosis
# [INFO] init_mapping (122/125): MRINRNPatternOfInjuryWSvsBGT
# [INFO] init_mapping (123/125): outcomeGroup
# [INFO] init_mapping (124/125): initBloodGasSrc
# [INFO] init_mapping (cfg_dict_map) (0/1): MRIReader
# build_value_map: (1108/377) variable: followupCenter type: center
# build_value_map: (1109/377) variable: siteID type: text
# build_value_map: (1110/377) variable: birthDate type: date
# build_value_map: (1111/377) variable: visitDate type: date
# build_value_map: (1112/377) variable: birthNumber type: int
# build_value_map: (1113/377) variable: center type: center
# build_value_map: (1114/377) variable: subjectID type: text
# build_value_map: (1115/377) variable: followupID type: text
# build_value_map: (1116/377) variable: center_orig type: text
# build_value_map: (1117/377) variable: SESVisitDate type: date
# build_value_map: (1118/377) variable: SESBirthDate type: date
# build_value_map: (1119/377) variable: chronologicalAge_mo type: int
# build_value_map: (1120/377) variable: correctedAge_mo type: int
# build_value_map: (1121/377) variable: underStateSupervision type: bool
# build_value_map: (1122/377) variable: primaryCaretaker type: relationship
# build_value_map: (1123/377) variable: otherCaretaker type: relationship
# build_value_map: (1124/377) variable: maritalStatusPrimaryCaretaker type: maritalStatus
# build_value_map: (1125/377) variable: livingArrangementChild type: livingArrange
# build_value_map: (1126/377) variable: numberPeopleInChildHousehold type: int
# build_value_map: (1127/377) variable: otherContributeMoneyToChildHousehold type: bool
# build_value_map: (1128/377) variable: educationPrimaryCaretaker type: education
# build_value_map: (1129/377) variable: educationOtherCaretaker type: education
# build_value_map: (1130/377) variable: workPrimaryCaretaker type: bool
# build_value_map: (1131/377) variable: workOtherCaretaker type: bool
# build_value_map: (1132/377) variable: inSchoolPrimaryCaretaker type: bool
# build_value_map: (1133/377) variable: inSchoolOtherCaretaker type: bool
# build_value_map: (1134/377) variable: totalIncomeChildHousehold type: totalIncome
# build_value_map: (1135/377) variable: medicalInsuranceChild type: insurance
# build_value_map: (1136/377) variable: primaryLanguageChild type: language
# build_value_map: (1137/377) variable: primaryLanguageChildOtherText type: text
# build_value_map: (1138/377) variable: isSecondaryLanguageChild type: bool
# build_value_map: (1139/377) variable: secondaryLanguageChild type: language
# build_value_map: (1140/377) variable: secondaryLanguageChildOtherText type: text
# build_value_map: (1141/377) variable: numberPlaceChildLive type: int
# build_value_map: (1142/377) variable: zipcode type: int
# build_value_map: (1143/377) variable: visitingNurseReceive type: receive
# build_value_map: (1144/377) variable: visitingNurseNeed type: bool
# build_value_map: (1145/377) variable: homeNurseReceive type: receive
# build_value_map: (1146/377) variable: homeNurseNeed type: bool
# build_value_map: (1147/377) variable: otPtReceive type: receive
# build_value_map: (1148/377) variable: otPtNeed type: bool
# build_value_map: (1149/377) variable: speechTherapyReceive type: receive
# build_value_map: (1150/377) variable: speechTherapyNeed type: bool
# build_value_map: (1151/377) variable: earlyInterventionReceive type: receive
# build_value_map: (1152/377) variable: earlyInterventionNeed type: bool
# build_value_map: (1153/377) variable: socialWorkForChildReceive type: receive
# build_value_map: (1154/377) variable: socialWorkForChildNeed type: bool
# build_value_map: (1155/377) variable: specialClinicReceive type: receive
# build_value_map: (1156/377) variable: specialClinicNeed type: bool
# build_value_map: (1157/377) variable: pulmonaryReceive type: receive
# build_value_map: (1158/377) variable: pulmonaryNeed type: bool
# build_value_map: (1159/377) variable: ophthalmologicReceive type: receive
# build_value_map: (1160/377) variable: ophthalmologicNeed type: bool
# build_value_map: (1161/377) variable: gastrointestinalReceive type: receive
# build_value_map: (1162/377) variable: gastrointestinalNeed type: bool
# build_value_map: (1163/377) variable: audiologicReceive type: receive
# build_value_map: (1164/377) variable: audiologicNeed type: bool
# build_value_map: (1165/377) variable: neurologicReceive type: receive
# build_value_map: (1166/377) variable: neurologicNeed type: bool
# build_value_map: (1167/377) variable: otherReceive type: receive
# build_value_map: (1168/377) variable: otherNeed type: bool
# build_value_map: (1169/377) variable: otherNeedText type: text
# build_value_map: (1170/377) variable: neurodevelopmentReceive type: receive
# build_value_map: (1171/377) variable: neurodevelopmentNeed type: bool
# build_value_map: (1172/377) variable: prematureFollowupClinicReceive type: receive
# build_value_map: (1173/377) variable: prematureFollowupClinicNeed type: bool
# build_value_map: (1174/377) variable: regularDoctor type: bool
# build_value_map: (1175/377) variable: resideChronicCareFacility type: bool
# build_value_map: (1176/377) variable: takenCareOfByOther type: bool
# build_value_map: (1177/377) variable: traditionalCenterCare type: bool
# build_value_map: (1178/377) variable: traditionalCenterCareAvgHrPerWeek type: int
# build_value_map: (1179/377) variable: medicalChildCare type: bool
# build_value_map: (1180/377) variable: medicalChildCareAvgHrPerWeek type: int
# build_value_map: (1181/377) variable: medicalChildCareWhere type: homeCareLocation
# build_value_map: (1182/377) variable: traditionalHomeCare type: bool
# build_value_map: (1183/377) variable: traditionalHomeCareAvgHrPerWeek type: int
# build_value_map: (1184/377) variable: traditionalHomeCareWhose type: homeCareLocation
# build_value_map: (1185/377) variable: babysitter type: bool
# build_value_map: (1186/377) variable: babysitterAvgHrPerWeek type: int
# build_value_map: (1187/377) variable: babysitterRelation type: babysitterRelation
# build_value_map: (1188/377) variable: SESInterviewWhere type: interviewLocation
# build_value_map: (1189/377) variable: SESInterviewDate type: date
# build_value_map: (1190/377) variable: rehospitalize type: bool
# build_value_map: (1191/377) variable: numberRehospitalize type: int
# build_value_map: (1192/377) variable: operation type: bool
# build_value_map: (1193/377) variable: operationTypanostomyTube type: bool
# build_value_map: (1194/377) variable: operationTracheostomy type: bool
# build_value_map: (1195/377) variable: operationEyeSurgery type: bool
# build_value_map: (1196/377) variable: operationEyeSurgeryReason type: eyeSurgeryReason
# build_value_map: (1197/377) variable: operationHerniaSurgery type: bool
# build_value_map: (1198/377) variable: operationGastrostomyTube type: bool
# build_value_map: (1199/377) variable: operationFundoplication type: bool
# build_value_map: (1200/377) variable: operationShuntForHydrocephalus type: bool
# build_value_map: (1201/377) variable: operationReanastomosisOfLargeOrSmallIntenstine type: bool
# build_value_map: (1202/377) variable: operationPDALigation type: bool
# build_value_map: (1203/377) variable: operationBrochoscopy type: bool
# build_value_map: (1204/377) variable: operationHypospadiusRepair type: bool
# build_value_map: (1205/377) variable: operationOther type: bool
# build_value_map: (1206/377) variable: operationOtherText type: text
# build_value_map: (1207/377) variable: medication type: bool
# build_value_map: (1208/377) variable: vitaminMineralSupplement type: medicationUse
# build_value_map: (1209/377) variable: highCaloricFormula type: medicationUse
# build_value_map: (1210/377) variable: diuretics type: medicationUse
# build_value_map: (1211/377) variable: antiRefluxMedication type: medicationUse
# build_value_map: (1212/377) variable: bronchodilator type: medicationUse
# build_value_map: (1213/377) variable: inhaledSteroid type: medicationUse
# build_value_map: (1214/377) variable: oralIvSteroid type: medicationUse
# build_value_map: (1215/377) variable: otherAsthmaMedication type: medicationUse
# build_value_map: (1216/377) variable: decongestantColdAllergyMedication type: medicationUse
# build_value_map: (1217/377) variable: anticonvulsantMedication type: medicationUse
# build_value_map: (1218/377) variable: prophylaticAntibiotics type: medicationUse
# build_value_map: (1219/377) variable: antibiotics type: medicationUse
# build_value_map: (1220/377) variable: constipationMedication type: medicationUse
# build_value_map: (1221/377) variable: bloodPressureMedication type: medicationUse
# build_value_map: (1222/377) variable: thyroidMedication type: medicationUse
# build_value_map: (1223/377) variable: muscleRelaxants type: medicationUse
# build_value_map: (1224/377) variable: botox type: medicationUse
# build_value_map: (1225/377) variable: otherMedication type: medicationUse
# build_value_map: (1226/377) variable: otherMedicationText type: text
# build_value_map: (1227/377) variable: seizure type: bool
# build_value_map: (1228/377) variable: medicalEquipmentHomeUse type: bool
# build_value_map: (1229/377) variable: apneaMonitor type: medicationUse
# build_value_map: (1230/377) variable: oxygen type: medicationUse
# build_value_map: (1231/377) variable: ventilatorCPAP type: medicationUse
# build_value_map: (1232/377) variable: gastrostomyTube type: medicationUse
# build_value_map: (1233/377) variable: tracheostomy type: medicationUse
# build_value_map: (1234/377) variable: pulseOximeter type: medicationUse
# build_value_map: (1235/377) variable: fluShot type: bool
# build_value_map: (1236/377) variable: RSVProphylaxis type: bool
# build_value_map: (1237/377) variable: independentFeedSelf type: bool
# build_value_map: (1238/377) variable: assistedEatByMouth type: bool
# build_value_map: (1239/377) variable: tubeFeed type: bool
# build_value_map: (1240/377) variable: TPN type: bool
# build_value_map: (1241/377) variable: dietMilk type: bool
# build_value_map: (1242/377) variable: dietTableFood type: bool
# build_value_map: (1243/377) variable: dietSoftFood type: bool
# build_value_map: (1244/377) variable: dietLiquid type: bool
# build_value_map: (1245/377) variable: dietThickendLiquid type: bool
# build_value_map: (1246/377) variable: subcutaneousFatNecrosis type: bool
# build_value_map: (1247/377) variable: equipmentForStanding type: bool
# build_value_map: (1248/377) variable: adaptedStroller type: bool
# build_value_map: (1249/377) variable: bracesOrthotics type: bool
# build_value_map: (1250/377) variable: walker type: bool
# build_value_map: (1251/377) variable: stander type: bool
# build_value_map: (1252/377) variable: cornerChairTumblerForm type: bool
# build_value_map: (1253/377) variable: weight_kg type: float
# build_value_map: (1254/377) variable: length_cm type: float
# build_value_map: (1255/377) variable: headCircumference_cm type: float
# build_value_map: (1256/377) variable: strabismusRight type: eye
# build_value_map: (1257/377) variable: strabismusLeft type: eye
# build_value_map: (1258/377) variable: nystagmusRight type: eye
# build_value_map: (1259/377) variable: nystagmusLeft type: eye
# build_value_map: (1260/377) variable: rovingEyeMovementRight type: eye
# build_value_map: (1261/377) variable: rovingEyeMovementLeft type: eye
# build_value_map: (1262/377) variable: eyeTrackRight type: eye
# build_value_map: (1263/377) variable: eyeTrackLeft type: eye
# build_value_map: (1264/377) variable: visionRight type: vision
# build_value_map: (1265/377) variable: visionLeft type: vision
# build_value_map: (1266/377) variable: audiologicAssessment type: bool
# build_value_map: (1267/377) variable: audiologicPendingForAssessment type: bool
# build_value_map: (1268/377) variable: visualReinforcementAudiometry type: bool
# build_value_map: (1269/377) variable: VRARight type: hearing
# build_value_map: (1270/377) variable: VRALeft type: hearing
# build_value_map: (1271/377) variable: VRASoundField type: hearing
# build_value_map: (1272/377) variable: ABR type: bool
# build_value_map: (1273/377) variable: ABRRight type: hearing
# build_value_map: (1274/377) variable: ABRLeft type: hearing
# build_value_map: (1275/377) variable: hearingTestUnknown type: bool
# build_value_map: (1276/377) variable: hearingTestUnknownRight type: hearing
# build_value_map: (1277/377) variable: hearingTestUnknownLeft type: hearing
# build_value_map: (1278/377) variable: hearingImpaired type: hearingImpaired
# build_value_map: (1279/377) variable: hearingAidRequirement type: hearingAid
# build_value_map: (1280/377) variable: hearingImplant type: hearingAid
# build_value_map: (1281/377) variable: swallowing type: swallow
# build_value_map: (1282/377) variable: dysphagia type: bool
# build_value_map: (1283/377) variable: aspiration type: bool
# build_value_map: (1284/377) variable: abnormalVoice type: bool
# build_value_map: (1285/377) variable: drooling type: bool
# build_value_map: (1286/377) variable: nothingByMouth type: bool
# build_value_map: (1287/377) variable: observedAbnormalMovement type: bool
# build_value_map: (1288/377) variable: observedAbnormalMovementShortJerky type: bool
# build_value_map: (1289/377) variable: observedAbnormalMovementSlowWrithing type: bool
# build_value_map: (1290/377) variable: observedAbnormalMovementTremor type: bool
# build_value_map: (1291/377) variable: passiveMuscleToneNeckTrunk type: passiveMuscleTone
# build_value_map: (1292/377) variable: upperExtremityMuscleToneRight type: passiveMuscleTone
# build_value_map: (1293/377) variable: upperExtremityMuscleToneLeft type: passiveMuscleTone
# build_value_map: (1294/377) variable: lowerExtremityMuscleToneHipKneeRight type: passiveMuscleTone
# build_value_map: (1295/377) variable: lowerExtremityMuscleToneHipKneeLeft type: passiveMuscleTone
# build_value_map: (1296/377) variable: lowerExtremityMuscleToneAnkleRight type: passiveMuscleTone
# build_value_map: (1297/377) variable: lowerExtremityMuscleToneAnkleLeft type: passiveMuscleTone
# build_value_map: (1298/377) variable: scissoringLegs type: bool
# build_value_map: (1299/377) variable: handPreference type: handPreference
# build_value_map: (1300/377) variable: protectiveReaction type: protectiveReaction
# build_value_map: (1301/377) variable: limbMovementUpperLimb type: limbMovement
# build_value_map: (1302/377) variable: limbMovementLowerLimb type: limbMovement
# build_value_map: (1303/377) variable: deepTendonReflexUpperExtremityRight type: deepTendonReflex
# build_value_map: (1304/377) variable: deepTendonReflexUpperExtremityLeft type: deepTendonReflex
# build_value_map: (1305/377) variable: deepTendonReflexKneeRight type: deepTendonReflex
# build_value_map: (1306/377) variable: deepTendonReflexKneeLeft type: deepTendonReflex
# build_value_map: (1307/377) variable: deepTendonReflexAnkleRight type: deepTendonReflex
# build_value_map: (1308/377) variable: deepTendonReflexAnkleLeft type: deepTendonReflex
# build_value_map: (1309/377) variable: ankleClonusRight type: ankleClonus
# build_value_map: (1310/377) variable: ankleClonusLeft type: ankleClonus
# build_value_map: (1311/377) variable: plantarReflexRight type: plantarReflex
# build_value_map: (1312/377) variable: plantarReflexLeft type: plantarReflex
# build_value_map: (1313/377) variable: axisHeadNeck type: axisHeadNeck
# build_value_map: (1314/377) variable: axisTrunk type: axisTrunk
# build_value_map: (1315/377) variable: lowerLimbFunction type: lowerLimbFunction
# build_value_map: (1316/377) variable: upperLimbFunction type: upperLimbFunction
# build_value_map: (1317/377) variable: handFunctionRight type: handFunction
# build_value_map: (1318/377) variable: handFunctionLeft type: handFunction
# build_value_map: (1319/377) variable: neuralNormal type: bool
# build_value_map: (1320/377) variable: generalizedHypotonia type: bool
# build_value_map: (1321/377) variable: hypertonia type: bool
# build_value_map: (1322/377) variable: neuralOther type: bool
# build_value_map: (1323/377) variable: neuralOtherText type: text
# build_value_map: (1324/377) variable: spasticDiplegia type: bool
# build_value_map: (1325/377) variable: spasticHemiplegiaRight type: bool
# build_value_map: (1326/377) variable: spasticHemiplegiaLeft type: bool
# build_value_map: (1327/377) variable: spasticQuadriplegia type: bool
# build_value_map: (1328/377) variable: spasticTriplegia type: bool
# build_value_map: (1329/377) variable: dystonia type: bool
# build_value_map: (1330/377) variable: athetosis type: bool
# build_value_map: (1331/377) variable: athetosisDystonia type: bool
# build_value_map: (1332/377) variable: hypotoniaAtaxia type: bool
# build_value_map: (1333/377) variable: spasticMonoplegia type: bool
# build_value_map: (1334/377) variable: mixedCerebralPalsy type: bool
# build_value_map: (1335/377) variable: cerebralPalsyUnclassified type: bool
# build_value_map: (1336/377) variable: cerebralPalsyUnclassifiedText type: text
# build_value_map: (1337/377) variable: cerebralPalsy type: bool
# build_value_map: (1338/377) variable: cerebralPalsyClass type: cerebralPalsyClass
# build_value_map: (1339/377) variable: abrnomalityAffectingNeuroAssessment type: bool
# build_value_map: (1340/377) variable: abrnomalityAffectingNeuroAssessmentText type: text
# build_value_map: (1341/377) variable: examWhere type: interviewLocation
# build_value_map: (1342/377) variable: examWhereOtherText type: text
# build_value_map: (1343/377) variable: examQuality type: examQuality
# build_value_map: (1344/377) variable: examFactorAffecting type: examFactorAffecting
# build_value_map: (1345/377) variable: examFactorAffectingText type: text
# build_value_map: (1346/377) variable: examCompleteDate type: date
# build_value_map: (1347/377) variable: grossMotorFunctionLevel type: grossMotorFunctionLevel
# build_value_map: (1348/377) variable: BayleyIIICognitiveSubtest type: bool
# build_value_map: (1349/377) variable: BayleyIIIReasonNoSuccessCognitiveSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1350/377) variable: BayleyIIIReasonNoSuccessCognitiveSubtestText type: text
# build_value_map: (1351/377) variable: BayleyIIILanguageReceptiveSubtest type: bool
# build_value_map: (1352/377) variable: BayleyIIIReasonNoSuccessLanguageReceptiveSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1353/377) variable: BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText type: text
# build_value_map: (1354/377) variable: BayleyIIILanguageExpressiveSubtest type: bool
# build_value_map: (1355/377) variable: BayleyIIIReasonNoSuccessLanguageExpressiveSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1356/377) variable: BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText type: text
# build_value_map: (1357/377) variable: BayleyIIIMotorFineSubtest type: bool
# build_value_map: (1358/377) variable: BayleyIIIReasonNoSuccessMotorFineSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1359/377) variable: BayleyIIIReasonNoSuccessMotorFineSubtestText type: text
# build_value_map: (1360/377) variable: BayleyIIIMotorGrossSubtest type: bool
# build_value_map: (1361/377) variable: BayleyIIIReasonNoSuccessMotorGrossSubtest type: BayleyIIIReasonNoSuccess
# build_value_map: (1362/377) variable: BayleyIIIReasonNoSuccessMotorGrossSubtestText type: text
# build_value_map: (1363/377) variable: BayleyIIIAdjustedAgeForCognitiveTest type: int
# build_value_map: (1364/377) variable: BayleyIIIAdjustedAgeForReceptiveCommunication type: int
# build_value_map: (1365/377) variable: BayleyIIIAdjustedAgeForExpressiveCommunication type: int
# build_value_map: (1366/377) variable: BayleyIIIAdjustedAgeForMotorFineSubtest type: int
# build_value_map: (1367/377) variable: BayleyIIIAdjustedAgeForMotorGrossSubtest type: int
# build_value_map: (1368/377) variable: BayleyIIICognitiveRaw type: int
# build_value_map: (1369/377) variable: BayleyIIICognitiveScale type: int
# build_value_map: (1370/377) variable: BayleyIIICognitiveComposite type: int
# build_value_map: (1371/377) variable: BayleyIIIReceptiveRaw type: int
# build_value_map: (1372/377) variable: BayleyIIIReceptiveScale type: int
# build_value_map: (1373/377) variable: BayleyIIIExpressiveRaw type: int
# build_value_map: (1374/377) variable: BayleyIIIExpressiveScale type: int
# build_value_map: (1375/377) variable: BayleyIIISumLanguageScore type: int
# build_value_map: (1376/377) variable: BayleyIIILanguageComposite type: int
# build_value_map: (1377/377) variable: BayleyIIIMotorFineRaw type: int
# build_value_map: (1378/377) variable: BayleyIIIMotorFineScale type: int
# build_value_map: (1379/377) variable: BayleyIIIMotorGrossRaw type: int
# build_value_map: (1380/377) variable: BayleyIIIMotorGrossScale type: int
# build_value_map: (1381/377) variable: BayleyIIISumMotorScore type: int
# build_value_map: (1382/377) variable: BayleyIIIMotorComposite type: int
# build_value_map: (1383/377) variable: BayleyIIIInEnglish type: bool
# build_value_map: (1384/377) variable: BayleyIIIRequireInterpreter type: bool
# build_value_map: (1385/377) variable: BayleyIIIAdministratorMaskedToChildHistory type: bool
# build_value_map: (1386/377) variable: BayleyIIIWhere type: interviewLocation
# build_value_map: (1387/377) variable: BayleyIIIDate type: date
# build_value_map: (1388/377) variable: dischargeDate type: date
# build_value_map: (1389/377) variable: birthdate type: date
# build_value_map: (1390/377) variable: readmissionNumber type: int
# build_value_map: (1391/377) variable: readmissionTimePeriod type: readmissionTimePeriod
# build_value_map: (1392/377) variable: readmissionPrimaryCause type: readmissionPrimaryCause
# build_value_map: (1393/377) variable: readmissionPrimaryCauseOtherText type: text
# build_value_map: (1394/377) variable: readmissionLengthOfStay type: readmissionLengthOfStay
# build_value_map: (1395/377) variable: readmissionICU type: bool
# build_value_map: (1396/377) variable: readmissionInterviewWhere type: interviewLocation
# build_value_map: (1397/377) variable: readmissionDateObtain type: date
# build_value_map: (1398/377) variable: statusVisitDate type: date
# build_value_map: (1399/377) variable: statusBirthDate type: date
# build_value_map: (1400/377) variable: childFinalStatus type: followupStatus
# build_value_map: (1401/377) variable: deathDate type: date
# build_value_map: (1402/377) variable: deathCause type: deathCause
# build_value_map: (1403/377) variable: reasonLossFollowUp type: reasonLossFollowUp
# build_value_map: (1404/377) variable: firstVisitDate type: date
# build_value_map: (1405/377) variable: finalVisitDate type: date
# build_value_map: (1406/377) variable: lostFollowUpInformationAvailableIndirectSrc type: bool
# build_value_map: (1407/377) variable: lostFollowUpLastContactDate type: date
# build_value_map: (1408/377) variable: lostFollowUpFormCompleteDate type: date
# build_value_map: (1409/377) variable: lostFollowUpChildAlive type: bool
# build_value_map: (1410/377) variable: lostFollowUpLastKnownAliveCorrectedAge_mo type: int
# build_value_map: (1411/377) variable: lostFollowUpDeathDate type: date
# build_value_map: (1412/377) variable: lostFollowUpInterview type: bool
# build_value_map: (1413/377) variable: lostFollowUpInterviewDate type: date
# build_value_map: (1414/377) variable: lostFollowUpInterviewCorrectedAge_mo type: int
# build_value_map: (1415/377) variable: lostFollowUpAnyQuestionCompleteChartReview type: bool
# build_value_map: (1416/377) variable: lostFollowUpChartReviewDate type: date
# build_value_map: (1417/377) variable: lostFollowUpChartReviewCorrectedAge_mo type: int
# build_value_map: (1418/377) variable: interviewChildHealth type: childHealth
# build_value_map: (1419/377) variable: interviewWalkAlone type: bool
# build_value_map: (1420/377) variable: interviewWalkAloneAge_mo type: int
# build_value_map: (1421/377) variable: interviewSittingAlong type: bool
# build_value_map: (1422/377) variable: interviewHeadControl type: bool
# build_value_map: (1423/377) variable: interviewSee type: bool
# build_value_map: (1424/377) variable: interviewEyeExam type: bool
# build_value_map: (1425/377) variable: interviewNeedWearGlasses type: bool
# build_value_map: (1426/377) variable: interviewHear type: bool
# build_value_map: (1427/377) variable: interviewHearExam type: bool
# build_value_map: (1428/377) variable: interviewNeedWearHearingAid type: bool
# build_value_map: (1429/377) variable: interviewNumberWordVocabulary type: int
# build_value_map: (1430/377) variable: interviewCombine2Words type: bool
# build_value_map: (1431/377) variable: interviewCombine3Words type: bool
# build_value_map: (1432/377) variable: interviewHydrocephalusShunt type: bool
# build_value_map: (1433/377) variable: interviewCerebralPalsy type: bool
# build_value_map: (1434/377) variable: interviewDevelopmentalDelay type: bool
# build_value_map: (1435/377) variable: interviewLanguageDelay type: bool
# build_value_map: (1436/377) variable: interviewPoorWeightGain type: bool
# build_value_map: (1437/377) variable: interviewSeizure type: bool
# build_value_map: (1438/377) variable: interviewBlindness type: bool
# build_value_map: (1439/377) variable: interviewOtherBehaviorProblem type: bool
# build_value_map: (1440/377) variable: interviewOtherBehaviorProblemText type: text
# build_value_map: (1441/377) variable: interviewOtherMajorMedicalProblem type: bool
# build_value_map: (1442/377) variable: interviewOtherMajorMedicalProblemText type: text
# build_value_map: (1443/377) variable: interviewOtherNeuraldevelopmentalProblem type: bool
# build_value_map: (1444/377) variable: interviewOtherNeuraldevelopmentalProblemText type: text
# build_value_map: (1445/377) variable: interviewMotorGrossFunctionLevel type: grossMotorFunctionLevel
# build_value_map: (1446/377) variable: chartReviewEyeExam type: chartReview
# build_value_map: (1447/377) variable: chartReviewHearingExam type: chartReview
# build_value_map: (1448/377) variable: chartReviewNeedWearHearingAid type: chartReview
# build_value_map: (1449/377) variable: chartReviewHydrocephalusShunt type: chartReview
# build_value_map: (1450/377) variable: chartReviewCerebralPalsy type: chartReview
# build_value_map: (1451/377) variable: chartReviewDevelopmentalDelay type: chartReview
# build_value_map: (1452/377) variable: chartReviewLanguageDelay type: chartReview
# build_value_map: (1453/377) variable: chartReviewPoorWeightGain type: chartReview
# build_value_map: (1454/377) variable: chartReviewSeizure type: chartReview
# build_value_map: (1455/377) variable: chartReviewBlindness type: chartReview
# build_value_map: (1456/377) variable: chartReviewOtherBehaviorProblem type: chartReview
# build_value_map: (1457/377) variable: chartReviewOtherBehaviorProblemText type: text
# build_value_map: (1458/377) variable: chartReviewOtherMajorMedicalProblem type: chartReview
# build_value_map: (1459/377) variable: chartReviewOtherMajorMedicalProblemText type: text
# build_value_map: (1460/377) variable: chartReviewOtherNeuraldevelopmentalProblem type: chartReview
# build_value_map: (1461/377) variable: chartReviewOtherNeuraldevelopmentalProblemText type: text
# build_value_map: (1462/377) variable: chartReviewMotorGrossFunctionLevel type: grossMotorFunctionLevel
# build_value_map: (1463/377) variable: blindness type: bool
# build_value_map: (1464/377) variable: moderateSevereCerebralPalsy type: bool
# build_value_map: (1465/377) variable: cerebralPalsyMerge type: bool
# build_value_map: (1466/377) variable: gastrostomyTube_b type: bool
# build_value_map: (1467/377) variable: grossMotorFunctionLevelSeverity type: severity
# build_value_map: (1468/377) variable: hearingImpairedWithAid type: bool
# build_value_map: (1469/377) variable: hearingImpairedLevel type: severity
# build_value_map: (1470/377) variable: multipleImpairment type: bool
# build_value_map: (1471/377) variable: afterDischargeSeizure type: bool
# build_value_map: (1472/377) variable: flagAdjudicatedOutcome type: flagAdjudicatedOutcome
# build_value_map: (1473/377) variable: normalPrimaryOutcome type: bool
# build_value_map: (1474/377) variable: BayleyIIILanguage type: severity
# build_value_map: (1475/377) variable: BayleyIIIMotor type: severity
# build_value_map: (1476/377) variable: BayleyIIICognitive type: severity
# build_value_map: (1477/377) variable: deathBeforeFollowup type: bool
# build_value_map: (1478/377) variable: deathBeforeDischarge type: bool
# build_value_map: (1479/377) variable: disabilityLevelSurvivor type: severity
# build_value_map: (1480/377) variable: disabilityLevelDeath4Category type: severity
# build_value_map: (1481/377) variable: moderateSevereDisabilityOrDeath type: bool
# build_value_map: (1482/377) variable: moderateSevereDisabilitySurvivor type: bool
# build_value_map: (1483/377) variable: disabilityLevelDeath type: severity
# build_value_map: (1484/377) variable: outcomeGroup type: outcomeGroup

# %%
_ORDER_MAP = COMBINE_harmonizer.build_variable_order_map(data_dict_filename, sheet_name)

# %% [markdown]
# ## 20-00-follow-up

# %%
base_filename = '20-00-follow-up.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/10) normalize_value: column: center
# (1/10) normalize_value: column: subjectID
# (2/10) normalize_value: column: uniqueID
# (3/10) normalize_value: column: followupCenter
# (4/10) normalize_value: column: followupID
# (5/10) normalize_value: column: siteID
# (6/10) normalize_value: column: birthDate
# (7/10) normalize_value: column: visitDate
# (8/10) normalize_value: column: birthNumber
# (9/10) normalize_value: column: center_orig

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/21) center: (152/0)
# (1/21) subjectID: (152/0)
# (2/21) uniqueID: (152/0)
# (3/21) followupCenter: (152/0)
# (4/21) followupID: (152/0)
# (5/21) uniqueFollowupID: (152/0)
# (6/21) center.orig: (152/0)
# (7/21) subjectID.orig: (152/0)
# (8/21) uniqueID.orig: (152/0)
# (9/21) followupCenter.orig: (152/0)
# (10/21) followupID.orig: (152/0)
# (11/21) siteID: (152/0)
# (12/21) siteID.orig: (152/0)
# (13/21) birthDate: (152/0)
# (14/21) birthDate.orig: (152/0)
# (15/21) visitDate: (152/0)
# (16/21) visitDate.orig: (145/7)
# (17/21) birthNumber: (152/0)
# (18/21) birthNumber.orig: (144/8)
# (19/21) center_orig: (152/0)
# (20/21) center_orig.orig: (3/149)

# %% [markdown]
# ## 20-01-ses

# %%
base_filename = '20-01-ses.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/79) normalize_value: column: center
# (1/79) normalize_value: column: subjectID
# (2/79) normalize_value: column: uniqueID
# (3/79) normalize_value: column: followupCenter
# (4/79) normalize_value: column: followupID
# (5/79) normalize_value: column: siteID
# (6/79) normalize_value: column: underStateSupervision
# (7/79) normalize_value: column: otherContributeMoneyToChildHousehold
# (8/79) normalize_value: column: workPrimaryCaretaker
# (9/79) normalize_value: column: workOtherCaretaker
# (10/79) normalize_value: column: inSchoolPrimaryCaretaker
# (11/79) normalize_value: column: inSchoolOtherCaretaker
# [WARN] unable to bool: val: (**/<class 'str'>)
# (12/79) normalize_value: column: primaryLanguageChildOtherText
# (13/79) normalize_value: column: isSecondaryLanguageChild
# (14/79) normalize_value: column: secondaryLanguageChildOtherText
# (15/79) normalize_value: column: visitingNurseNeed
# (16/79) normalize_value: column: homeNurseNeed
# (17/79) normalize_value: column: otPtNeed
# (18/79) normalize_value: column: speechTherapyNeed
# (19/79) normalize_value: column: earlyInterventionNeed
# (20/79) normalize_value: column: socialWorkForChildNeed
# (21/79) normalize_value: column: specialClinicNeed
# (22/79) normalize_value: column: pulmonaryNeed
# (23/79) normalize_value: column: ophthalmologicNeed
# (24/79) normalize_value: column: gastrointestinalNeed
# (25/79) normalize_value: column: audiologicNeed
# (26/79) normalize_value: column: neurologicNeed
# (27/79) normalize_value: column: otherNeed
# (28/79) normalize_value: column: otherNeedText
# (29/79) normalize_value: column: neurodevelopmentNeed
# (30/79) normalize_value: column: prematureFollowupClinicNeed
# (31/79) normalize_value: column: regularDoctor
# (32/79) normalize_value: column: resideChronicCareFacility
# (33/79) normalize_value: column: takenCareOfByOther
# (34/79) normalize_value: column: traditionalCenterCare
# (35/79) normalize_value: column: medicalChildCare
# (36/79) normalize_value: column: traditionalHomeCare
# (37/79) normalize_value: column: babysitter
# (38/79) normalize_value: column: SESVisitDate
# (39/79) normalize_value: column: SESBirthDate
# (40/79) normalize_value: column: chronologicalAge_mo
# (41/79) normalize_value: column: correctedAge_mo
# (42/79) normalize_value: column: primaryCaretaker
# (43/79) normalize_value: column: otherCaretaker
# (44/79) normalize_value: column: maritalStatusPrimaryCaretaker
# (45/79) normalize_value: column: livingArrangementChild
# (46/79) normalize_value: column: numberPeopleInChildHousehold
# (47/79) normalize_value: column: educationPrimaryCaretaker
# (48/79) normalize_value: column: educationOtherCaretaker
# (49/79) normalize_value: column: totalIncomeChildHousehold
# (50/79) normalize_value: column: medicalInsuranceChild
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 4 value_float: 4.0 value_int: 4
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 3 value_float: 3.0 value_int: 3
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# [WARN] unable to get value: sheet_name: insurance value: 2 value_float: 2.0 value_int: 2
# [WARN] unable to get value: sheet_name: insurance value: 1 value_float: 1.0 value_int: 1
# (51/79) normalize_value: column: primaryLanguageChild
# (52/79) normalize_value: column: secondaryLanguageChild
# (53/79) normalize_value: column: numberPlaceChildLive
# (54/79) normalize_value: column: zipcode
# (55/79) normalize_value: column: visitingNurseReceive
# (56/79) normalize_value: column: homeNurseReceive
# (57/79) normalize_value: column: otPtReceive
# (58/79) normalize_value: column: speechTherapyReceive
# (59/79) normalize_value: column: earlyInterventionReceive
# (60/79) normalize_value: column: socialWorkForChildReceive
# (61/79) normalize_value: column: specialClinicReceive
# (62/79) normalize_value: column: pulmonaryReceive
# (63/79) normalize_value: column: ophthalmologicReceive
# (64/79) normalize_value: column: gastrointestinalReceive
# (65/79) normalize_value: column: audiologicReceive
# (66/79) normalize_value: column: neurologicReceive
# (67/79) normalize_value: column: otherReceive
# (68/79) normalize_value: column: neurodevelopmentReceive
# (69/79) normalize_value: column: prematureFollowupClinicReceive
# (70/79) normalize_value: column: traditionalCenterCareAvgHrPerWeek
# (71/79) normalize_value: column: medicalChildCareAvgHrPerWeek
# (72/79) normalize_value: column: medicalChildCareWhere
# (73/79) normalize_value: column: traditionalHomeCareAvgHrPerWeek
# (74/79) normalize_value: column: traditionalHomeCareWhose
# (75/79) normalize_value: column: babysitterAvgHrPerWeek
# (76/79) normalize_value: column: babysitterRelation
# (77/79) normalize_value: column: SESInterviewWhere
# (78/79) normalize_value: column: SESInterviewDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/159) center: (152/0)
# (1/159) subjectID: (152/0)
# (2/159) uniqueID: (152/0)
# (3/159) followupCenter: (152/0)
# (4/159) followupID: (152/0)
# (5/159) uniqueFollowupID: (152/0)
# (6/159) center.orig: (152/0)
# (7/159) subjectID.orig: (152/0)
# (8/159) uniqueID.orig: (152/0)
# (9/159) followupCenter.orig: (152/0)
# (10/159) followupID.orig: (152/0)
# (11/159) siteID: (152/0)
# (12/159) siteID.orig: (152/0)
# (13/159) SESVisitDate: (152/0)
# (14/159) SESVisitDate.orig: (142/10)
# (15/159) SESBirthDate: (152/0)
# (16/159) SESBirthDate.orig: (142/10)
# (17/159) chronologicalAge_mo: (152/0)
# (18/159) chronologicalAge_mo.orig: (142/10)
# (19/159) correctedAge_mo: (152/0)
# (20/159) correctedAge_mo.orig: (141/11)
# (21/159) underStateSupervision: (152/0)
# (22/159) underStateSupervision.orig: (142/10)
# (23/159) primaryCaretaker: (152/0)
# (24/159) primaryCaretaker.orig: (142/10)
# (25/159) otherCaretaker: (152/0)
# (26/159) otherCaretaker.orig: (128/24)
# (27/159) maritalStatusPrimaryCaretaker: (152/0)
# (28/159) maritalStatusPrimaryCaretaker.orig: (142/10)
# (29/159) livingArrangementChild: (152/0)
# (30/159) livingArrangementChild.orig: (142/10)
# (31/159) numberPeopleInChildHousehold: (152/0)
# (32/159) numberPeopleInChildHousehold.orig: (142/10)
# (33/159) otherContributeMoneyToChildHousehold: (152/0)
# (34/159) otherContributeMoneyToChildHousehold.orig: (142/10)
# (35/159) educationPrimaryCaretaker: (152/0)
# (36/159) educationPrimaryCaretaker.orig: (142/10)
# (37/159) educationOtherCaretaker: (152/0)
# (38/159) educationOtherCaretaker.orig: (128/24)
# (39/159) workPrimaryCaretaker: (152/0)
# (40/159) workPrimaryCaretaker.orig: (142/10)
# (41/159) workOtherCaretaker: (152/0)
# (42/159) workOtherCaretaker.orig: (127/25)
# (43/159) inSchoolPrimaryCaretaker: (152/0)
# (44/159) inSchoolPrimaryCaretaker.orig: (142/10)
# (45/159) inSchoolOtherCaretaker: (152/0)
# (46/159) inSchoolOtherCaretaker.orig: (127/25)
# (47/159) totalIncomeChildHousehold: (152/0)
# (48/159) totalIncomeChildHousehold.orig: (132/20)
# (49/159) medicalInsuranceChild: (152/0)
# (50/159) medicalInsuranceChild.orig: (142/10)
# (51/159) primaryLanguageChild: (152/0)
# (52/159) primaryLanguageChild.orig: (142/10)
# (53/159) primaryLanguageChildOtherText: (152/0)
# (54/159) primaryLanguageChildOtherText.orig: (7/145)
# (55/159) isSecondaryLanguageChild: (152/0)
# (56/159) isSecondaryLanguageChild.orig: (142/10)
# (57/159) secondaryLanguageChild: (152/0)
# (58/159) secondaryLanguageChild.orig: (33/119)
# (59/159) secondaryLanguageChildOtherText: (152/0)
# (60/159) secondaryLanguageChildOtherText.orig: (5/147)
# (61/159) numberPlaceChildLive: (152/0)
# (62/159) numberPlaceChildLive.orig: (142/10)
# (63/159) zipcode: (152/0)
# (64/159) zipcode.orig: (141/11)
# (65/159) visitingNurseReceive: (152/0)
# (66/159) visitingNurseReceive.orig: (141/11)
# (67/159) visitingNurseNeed: (152/0)
# (68/159) visitingNurseNeed.orig: (142/10)
# (69/159) homeNurseReceive: (152/0)
# (70/159) homeNurseReceive.orig: (141/11)
# (71/159) homeNurseNeed: (152/0)
# (72/159) homeNurseNeed.orig: (142/10)
# (73/159) otPtReceive: (152/0)
# (74/159) otPtReceive.orig: (142/10)
# (75/159) otPtNeed: (152/0)
# (76/159) otPtNeed.orig: (142/10)
# (77/159) speechTherapyReceive: (152/0)
# (78/159) speechTherapyReceive.orig: (142/10)
# (79/159) speechTherapyNeed: (152/0)
# (80/159) speechTherapyNeed.orig: (142/10)
# (81/159) earlyInterventionReceive: (152/0)
# (82/159) earlyInterventionReceive.orig: (142/10)
# (83/159) earlyInterventionNeed: (152/0)
# (84/159) earlyInterventionNeed.orig: (142/10)
# (85/159) socialWorkForChildReceive: (152/0)
# (86/159) socialWorkForChildReceive.orig: (141/11)
# (87/159) socialWorkForChildNeed: (152/0)
# (88/159) socialWorkForChildNeed.orig: (142/10)
# (89/159) specialClinicReceive: (152/0)
# (90/159) specialClinicReceive.orig: (141/11)
# (91/159) specialClinicNeed: (152/0)
# (92/159) specialClinicNeed.orig: (142/10)
# (93/159) pulmonaryReceive: (152/0)
# (94/159) pulmonaryReceive.orig: (142/10)
# (95/159) pulmonaryNeed: (152/0)
# (96/159) pulmonaryNeed.orig: (142/10)
# (97/159) ophthalmologicReceive: (152/0)
# (98/159) ophthalmologicReceive.orig: (141/11)
# (99/159) ophthalmologicNeed: (152/0)
# (100/159) ophthalmologicNeed.orig: (142/10)
# (101/159) gastrointestinalReceive: (152/0)
# (102/159) gastrointestinalReceive.orig: (141/11)
# (103/159) gastrointestinalNeed: (152/0)
# (104/159) gastrointestinalNeed.orig: (142/10)
# (105/159) audiologicReceive: (152/0)
# (106/159) audiologicReceive.orig: (141/11)
# (107/159) audiologicNeed: (152/0)
# (108/159) audiologicNeed.orig: (142/10)
# (109/159) neurologicReceive: (152/0)
# (110/159) neurologicReceive.orig: (142/10)
# (111/159) neurologicNeed: (152/0)
# (112/159) neurologicNeed.orig: (142/10)
# (113/159) otherReceive: (152/0)
# (114/159) otherReceive.orig: (141/11)
# (115/159) otherNeed: (152/0)
# (116/159) otherNeed.orig: (142/10)
# (117/159) otherNeedText: (152/0)
# (118/159) otherNeedText.orig: (34/118)
# (119/159) neurodevelopmentReceive: (152/0)
# (120/159) neurodevelopmentReceive.orig: (141/11)
# (121/159) neurodevelopmentNeed: (152/0)
# (122/159) neurodevelopmentNeed.orig: (142/10)
# (123/159) prematureFollowupClinicReceive: (152/0)
# (124/159) prematureFollowupClinicReceive.orig: (139/13)
# (125/159) prematureFollowupClinicNeed: (152/0)
# (126/159) prematureFollowupClinicNeed.orig: (142/10)
# (127/159) regularDoctor: (152/0)
# (128/159) regularDoctor.orig: (142/10)
# (129/159) resideChronicCareFacility: (152/0)
# (130/159) resideChronicCareFacility.orig: (142/10)
# (131/159) takenCareOfByOther: (152/0)
# (132/159) takenCareOfByOther.orig: (142/10)
# (133/159) traditionalCenterCare: (152/0)
# (134/159) traditionalCenterCare.orig: (68/84)
# (135/159) traditionalCenterCareAvgHrPerWeek: (152/0)
# (136/159) traditionalCenterCareAvgHrPerWeek.orig: (20/132)
# (137/159) medicalChildCare: (152/0)
# (138/159) medicalChildCare.orig: (68/84)
# (139/159) medicalChildCareAvgHrPerWeek: (152/0)
# (140/159) medicalChildCareAvgHrPerWeek.orig: (1/151)
# (141/159) medicalChildCareWhere: (152/0)
# (142/159) medicalChildCareWhere.orig: (1/151)
# (143/159) traditionalHomeCare: (152/0)
# (144/159) traditionalHomeCare.orig: (68/84)
# (145/159) traditionalHomeCareAvgHrPerWeek: (152/0)
# (146/159) traditionalHomeCareAvgHrPerWeek.orig: (22/130)
# (147/159) traditionalHomeCareWhose: (152/0)
# (148/159) traditionalHomeCareWhose.orig: (21/131)
# (149/159) babysitter: (152/0)
# (150/159) babysitter.orig: (68/84)
# (151/159) babysitterAvgHrPerWeek: (152/0)
# (152/159) babysitterAvgHrPerWeek.orig: (30/122)
# (153/159) babysitterRelation: (152/0)
# (154/159) babysitterRelation.orig: (30/122)
# (155/159) SESInterviewWhere: (152/0)
# (156/159) SESInterviewWhere.orig: (142/10)
# (157/159) SESInterviewDate: (152/0)
# (158/159) SESInterviewDate.orig: (142/10)

# %% [markdown]
# ## 20-02-medical-history

# %%
base_filename = '20-02-medical-history.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/68) normalize_value: column: center
# (1/68) normalize_value: column: subjectID
# (2/68) normalize_value: column: uniqueID
# (3/68) normalize_value: column: followupCenter
# (4/68) normalize_value: column: followupID
# (5/68) normalize_value: column: siteID
# (6/68) normalize_value: column: rehospitalize
# (7/68) normalize_value: column: operation
# (8/68) normalize_value: column: operationTypanostomyTube
# (9/68) normalize_value: column: operationTracheostomy
# (10/68) normalize_value: column: operationEyeSurgery
# (11/68) normalize_value: column: operationHerniaSurgery
# (12/68) normalize_value: column: operationGastrostomyTube
# (13/68) normalize_value: column: operationFundoplication
# (14/68) normalize_value: column: operationShuntForHydrocephalus
# (15/68) normalize_value: column: operationReanastomosisOfLargeOrSmallIntenstine
# (16/68) normalize_value: column: operationPDALigation
# (17/68) normalize_value: column: operationBrochoscopy
# (18/68) normalize_value: column: operationHypospadiusRepair
# (19/68) normalize_value: column: operationOther
# (20/68) normalize_value: column: operationOtherText
# (21/68) normalize_value: column: medication
# (22/68) normalize_value: column: otherMedicationText
# (23/68) normalize_value: column: seizure
# (24/68) normalize_value: column: medicalEquipmentHomeUse
# (25/68) normalize_value: column: fluShot
# (26/68) normalize_value: column: RSVProphylaxis
# (27/68) normalize_value: column: independentFeedSelf
# (28/68) normalize_value: column: assistedEatByMouth
# (29/68) normalize_value: column: tubeFeed
# (30/68) normalize_value: column: TPN
# (31/68) normalize_value: column: dietMilk
# (32/68) normalize_value: column: dietTableFood
# (33/68) normalize_value: column: dietSoftFood
# (34/68) normalize_value: column: dietLiquid
# (35/68) normalize_value: column: dietThickendLiquid
# (36/68) normalize_value: column: equipmentForStanding
# (37/68) normalize_value: column: adaptedStroller
# (38/68) normalize_value: column: bracesOrthotics
# (39/68) normalize_value: column: walker
# (40/68) normalize_value: column: stander
# (41/68) normalize_value: column: cornerChairTumblerForm
# (42/68) normalize_value: column: numberRehospitalize
# (43/68) normalize_value: column: operationEyeSurgeryReason
# (44/68) normalize_value: column: vitaminMineralSupplement
# (45/68) normalize_value: column: highCaloricFormula
# (46/68) normalize_value: column: diuretics
# (47/68) normalize_value: column: antiRefluxMedication
# (48/68) normalize_value: column: bronchodilator
# (49/68) normalize_value: column: inhaledSteroid
# (50/68) normalize_value: column: oralIvSteroid
# (51/68) normalize_value: column: otherAsthmaMedication
# (52/68) normalize_value: column: decongestantColdAllergyMedication
# (53/68) normalize_value: column: anticonvulsantMedication
# (54/68) normalize_value: column: prophylaticAntibiotics
# (55/68) normalize_value: column: antibiotics
# (56/68) normalize_value: column: constipationMedication
# (57/68) normalize_value: column: bloodPressureMedication
# (58/68) normalize_value: column: thyroidMedication
# (59/68) normalize_value: column: muscleRelaxants
# (60/68) normalize_value: column: botox
# (61/68) normalize_value: column: otherMedication
# (62/68) normalize_value: column: apneaMonitor
# (63/68) normalize_value: column: oxygen
# (64/68) normalize_value: column: ventilatorCPAP
# (65/68) normalize_value: column: gastrostomyTube
# (66/68) normalize_value: column: tracheostomy
# (67/68) normalize_value: column: pulseOximeter

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/137) center: (152/0)
# (1/137) subjectID: (152/0)
# (2/137) uniqueID: (152/0)
# (3/137) followupCenter: (152/0)
# (4/137) followupID: (152/0)
# (5/137) uniqueFollowupID: (152/0)
# (6/137) center.orig: (152/0)
# (7/137) subjectID.orig: (152/0)
# (8/137) uniqueID.orig: (152/0)
# (9/137) followupCenter.orig: (152/0)
# (10/137) followupID.orig: (152/0)
# (11/137) siteID: (152/0)
# (12/137) siteID.orig: (152/0)
# (13/137) rehospitalize: (152/0)
# (14/137) rehospitalize.orig: (143/9)
# (15/137) numberRehospitalize: (152/0)
# (16/137) numberRehospitalize.orig: (35/117)
# (17/137) operation: (152/0)
# (18/137) operation.orig: (143/9)
# (19/137) operationTypanostomyTube: (152/0)
# (20/137) operationTypanostomyTube.orig: (25/127)
# (21/137) operationTracheostomy: (152/0)
# (22/137) operationTracheostomy.orig: (25/127)
# (23/137) operationEyeSurgery: (152/0)
# (24/137) operationEyeSurgery.orig: (25/127)
# (25/137) operationEyeSurgeryReason: (152/0)
# (26/137) operationEyeSurgeryReason.orig: (2/150)
# (27/137) operationHerniaSurgery: (152/0)
# (28/137) operationHerniaSurgery.orig: (25/127)
# (29/137) operationGastrostomyTube: (152/0)
# (30/137) operationGastrostomyTube.orig: (25/127)
# (31/137) operationFundoplication: (152/0)
# (32/137) operationFundoplication.orig: (25/127)
# (33/137) operationShuntForHydrocephalus: (152/0)
# (34/137) operationShuntForHydrocephalus.orig: (25/127)
# (35/137) operationReanastomosisOfLargeOrSmallIntenstine: (152/0)
# (36/137) operationReanastomosisOfLargeOrSmallIntenstine.orig: (25/127)
# (37/137) operationPDALigation: (152/0)
# (38/137) operationPDALigation.orig: (25/127)
# (39/137) operationBrochoscopy: (152/0)
# (40/137) operationBrochoscopy.orig: (25/127)
# (41/137) operationHypospadiusRepair: (152/0)
# (42/137) operationHypospadiusRepair.orig: (25/127)
# (43/137) operationOther: (152/0)
# (44/137) operationOther.orig: (25/127)
# (45/137) operationOtherText: (152/0)
# (46/137) operationOtherText.orig: (12/140)
# (47/137) medication: (152/0)
# (48/137) medication.orig: (143/9)
# (49/137) vitaminMineralSupplement: (152/0)
# (50/137) vitaminMineralSupplement.orig: (84/68)
# (51/137) highCaloricFormula: (152/0)
# (52/137) highCaloricFormula.orig: (84/68)
# (53/137) diuretics: (152/0)
# (54/137) diuretics.orig: (84/68)
# (55/137) antiRefluxMedication: (152/0)
# (56/137) antiRefluxMedication.orig: (84/68)
# (57/137) bronchodilator: (152/0)
# (58/137) bronchodilator.orig: (84/68)
# (59/137) inhaledSteroid: (152/0)
# (60/137) inhaledSteroid.orig: (84/68)
# (61/137) oralIvSteroid: (152/0)
# (62/137) oralIvSteroid.orig: (84/68)
# (63/137) otherAsthmaMedication: (152/0)
# (64/137) otherAsthmaMedication.orig: (84/68)
# (65/137) decongestantColdAllergyMedication: (152/0)
# (66/137) decongestantColdAllergyMedication.orig: (84/68)
# (67/137) anticonvulsantMedication: (152/0)
# (68/137) anticonvulsantMedication.orig: (84/68)
# (69/137) prophylaticAntibiotics: (152/0)
# (70/137) prophylaticAntibiotics.orig: (84/68)
# (71/137) antibiotics: (152/0)
# (72/137) antibiotics.orig: (84/68)
# (73/137) constipationMedication: (152/0)
# (74/137) constipationMedication.orig: (84/68)
# (75/137) bloodPressureMedication: (152/0)
# (76/137) bloodPressureMedication.orig: (84/68)
# (77/137) thyroidMedication: (152/0)
# (78/137) thyroidMedication.orig: (84/68)
# (79/137) muscleRelaxants: (152/0)
# (80/137) muscleRelaxants.orig: (84/68)
# (81/137) botox: (152/0)
# (82/137) botox.orig: (84/68)
# (83/137) otherMedication: (152/0)
# (84/137) otherMedication.orig: (84/68)
# (85/137) otherMedicationText: (152/0)
# (86/137) otherMedicationText.orig: (7/145)
# (87/137) seizure: (152/0)
# (88/137) seizure.orig: (143/9)
# (89/137) medicalEquipmentHomeUse: (152/0)
# (90/137) medicalEquipmentHomeUse.orig: (143/9)
# (91/137) apneaMonitor: (152/0)
# (92/137) apneaMonitor.orig: (12/140)
# (93/137) oxygen: (152/0)
# (94/137) oxygen.orig: (12/140)
# (95/137) ventilatorCPAP: (152/0)
# (96/137) ventilatorCPAP.orig: (12/140)
# (97/137) gastrostomyTube: (152/0)
# (98/137) gastrostomyTube.orig: (12/140)
# (99/137) tracheostomy: (152/0)
# (100/137) tracheostomy.orig: (12/140)
# (101/137) pulseOximeter: (152/0)
# (102/137) pulseOximeter.orig: (12/140)
# (103/137) fluShot: (152/0)
# (104/137) fluShot.orig: (143/9)
# (105/137) RSVProphylaxis: (152/0)
# (106/137) RSVProphylaxis.orig: (143/9)
# (107/137) independentFeedSelf: (152/0)
# (108/137) independentFeedSelf.orig: (143/9)
# (109/137) assistedEatByMouth: (152/0)
# (110/137) assistedEatByMouth.orig: (143/9)
# (111/137) tubeFeed: (152/0)
# (112/137) tubeFeed.orig: (143/9)
# (113/137) TPN: (152/0)
# (114/137) TPN.orig: (143/9)
# (115/137) dietMilk: (152/0)
# (116/137) dietMilk.orig: (143/9)
# (117/137) dietTableFood: (152/0)
# (118/137) dietTableFood.orig: (143/9)
# (119/137) dietSoftFood: (152/0)
# (120/137) dietSoftFood.orig: (143/9)
# (121/137) dietLiquid: (152/0)
# (122/137) dietLiquid.orig: (143/9)
# (123/137) dietThickendLiquid: (152/0)
# (124/137) dietThickendLiquid.orig: (143/9)
# (125/137) equipmentForStanding: (152/0)
# (126/137) equipmentForStanding.orig: (143/9)
# (127/137) adaptedStroller: (152/0)
# (128/137) adaptedStroller.orig: (18/134)
# (129/137) bracesOrthotics: (152/0)
# (130/137) bracesOrthotics.orig: (18/134)
# (131/137) walker: (152/0)
# (132/137) walker.orig: (18/134)
# (133/137) stander: (152/0)
# (134/137) stander.orig: (18/134)
# (135/137) cornerChairTumblerForm: (152/0)
# (136/137) cornerChairTumblerForm.orig: (18/134)

# %% [markdown]
# ## 20-03-medical-exam

# %%
base_filename = '20-03-medical-exam.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/97) normalize_value: column: center
# (1/97) normalize_value: column: subjectID
# (2/97) normalize_value: column: uniqueID
# (3/97) normalize_value: column: followupCenter
# (4/97) normalize_value: column: followupID
# (5/97) normalize_value: column: siteID
# (6/97) normalize_value: column: audiologicAssessment
# (7/97) normalize_value: column: audiologicPendingForAssessment
# (8/97) normalize_value: column: visualReinforcementAudiometry
# (9/97) normalize_value: column: ABR
# (10/97) normalize_value: column: hearingTestUnknown
# (11/97) normalize_value: column: dysphagia
# (12/97) normalize_value: column: aspiration
# (13/97) normalize_value: column: abnormalVoice
# (14/97) normalize_value: column: drooling
# (15/97) normalize_value: column: nothingByMouth
# (16/97) normalize_value: column: observedAbnormalMovement
# (17/97) normalize_value: column: observedAbnormalMovementShortJerky
# (18/97) normalize_value: column: observedAbnormalMovementSlowWrithing
# (19/97) normalize_value: column: observedAbnormalMovementTremor
# (20/97) normalize_value: column: scissoringLegs
# (21/97) normalize_value: column: neuralNormal
# (22/97) normalize_value: column: generalizedHypotonia
# (23/97) normalize_value: column: hypertonia
# (24/97) normalize_value: column: neuralOther
# (25/97) normalize_value: column: neuralOtherText
# (26/97) normalize_value: column: spasticDiplegia
# (27/97) normalize_value: column: spasticHemiplegiaRight
# (28/97) normalize_value: column: spasticHemiplegiaLeft
# (29/97) normalize_value: column: spasticQuadriplegia
# (30/97) normalize_value: column: spasticTriplegia
# (31/97) normalize_value: column: athetosisDystonia
# (32/97) normalize_value: column: hypotoniaAtaxia
# (33/97) normalize_value: column: spasticMonoplegia
# (34/97) normalize_value: column: mixedCerebralPalsy
# (35/97) normalize_value: column: cerebralPalsyUnclassified
# (36/97) normalize_value: column: cerebralPalsyUnclassifiedText
# (37/97) normalize_value: column: cerebralPalsy
# (38/97) normalize_value: column: abrnomalityAffectingNeuroAssessment
# (39/97) normalize_value: column: abrnomalityAffectingNeuroAssessmentText
# (40/97) normalize_value: column: examWhereOtherText
# (41/97) normalize_value: column: examFactorAffectingText
# (42/97) normalize_value: column: weight_kg
# (43/97) normalize_value: column: length_cm
# (44/97) normalize_value: column: headCircumference_cm
# (45/97) normalize_value: column: strabismusRight
# (46/97) normalize_value: column: strabismusLeft
# (47/97) normalize_value: column: nystagmusRight
# (48/97) normalize_value: column: nystagmusLeft
# (49/97) normalize_value: column: rovingEyeMovementRight
# (50/97) normalize_value: column: rovingEyeMovementLeft
# (51/97) normalize_value: column: eyeTrackRight
# (52/97) normalize_value: column: eyeTrackLeft
# (53/97) normalize_value: column: visionRight
# (54/97) normalize_value: column: visionLeft
# (55/97) normalize_value: column: VRARight
# (56/97) normalize_value: column: VRALeft
# (57/97) normalize_value: column: VRASoundField
# (58/97) normalize_value: column: ABRRight
# (59/97) normalize_value: column: ABRLeft
# (60/97) normalize_value: column: hearingTestUnknownRight
# (61/97) normalize_value: column: hearingTestUnknownLeft
# (62/97) normalize_value: column: hearingImpaired
# (63/97) normalize_value: column: hearingAidRequirement
# (64/97) normalize_value: column: swallowing
# (65/97) normalize_value: column: passiveMuscleToneNeckTrunk
# (66/97) normalize_value: column: upperExtremityMuscleToneRight
# (67/97) normalize_value: column: upperExtremityMuscleToneLeft
# (68/97) normalize_value: column: lowerExtremityMuscleToneHipKneeRight
# (69/97) normalize_value: column: lowerExtremityMuscleToneHipKneeLeft
# (70/97) normalize_value: column: lowerExtremityMuscleToneAnkleRight
# (71/97) normalize_value: column: lowerExtremityMuscleToneAnkleLeft
# (72/97) normalize_value: column: handPreference
# (73/97) normalize_value: column: protectiveReaction
# (74/97) normalize_value: column: limbMovementUpperLimb
# (75/97) normalize_value: column: limbMovementLowerLimb
# (76/97) normalize_value: column: deepTendonReflexUpperExtremityRight
# (77/97) normalize_value: column: deepTendonReflexUpperExtremityLeft
# (78/97) normalize_value: column: deepTendonReflexKneeRight
# (79/97) normalize_value: column: deepTendonReflexKneeLeft
# (80/97) normalize_value: column: deepTendonReflexAnkleRight
# (81/97) normalize_value: column: deepTendonReflexAnkleLeft
# (82/97) normalize_value: column: ankleClonusRight
# (83/97) normalize_value: column: ankleClonusLeft
# (84/97) normalize_value: column: plantarReflexRight
# (85/97) normalize_value: column: plantarReflexLeft
# (86/97) normalize_value: column: axisHeadNeck
# (87/97) normalize_value: column: axisTrunk
# (88/97) normalize_value: column: lowerLimbFunction
# (89/97) normalize_value: column: upperLimbFunction
# (90/97) normalize_value: column: handFunctionRight
# (91/97) normalize_value: column: handFunctionLeft
# (92/97) normalize_value: column: cerebralPalsyClass
# (93/97) normalize_value: column: examWhere
# (94/97) normalize_value: column: examQuality
# (95/97) normalize_value: column: examFactorAffecting
# (96/97) normalize_value: column: examCompleteDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/195) center: (152/0)
# (1/195) subjectID: (152/0)
# (2/195) uniqueID: (152/0)
# (3/195) followupCenter: (152/0)
# (4/195) followupID: (152/0)
# (5/195) uniqueFollowupID: (152/0)
# (6/195) center.orig: (152/0)
# (7/195) subjectID.orig: (152/0)
# (8/195) uniqueID.orig: (152/0)
# (9/195) followupCenter.orig: (152/0)
# (10/195) followupID.orig: (152/0)
# (11/195) siteID: (152/0)
# (12/195) siteID.orig: (152/0)
# (13/195) weight_kg: (152/0)
# (14/195) weight_kg.orig: (141/11)
# (15/195) length_cm: (152/0)
# (16/195) length_cm.orig: (141/11)
# (17/195) headCircumference_cm: (152/0)
# (18/195) headCircumference_cm.orig: (141/11)
# (19/195) strabismusRight: (152/0)
# (20/195) strabismusRight.orig: (141/11)
# (21/195) strabismusLeft: (152/0)
# (22/195) strabismusLeft.orig: (141/11)
# (23/195) nystagmusRight: (152/0)
# (24/195) nystagmusRight.orig: (141/11)
# (25/195) nystagmusLeft: (152/0)
# (26/195) nystagmusLeft.orig: (141/11)
# (27/195) rovingEyeMovementRight: (152/0)
# (28/195) rovingEyeMovementRight.orig: (141/11)
# (29/195) rovingEyeMovementLeft: (152/0)
# (30/195) rovingEyeMovementLeft.orig: (141/11)
# (31/195) eyeTrackRight: (152/0)
# (32/195) eyeTrackRight.orig: (141/11)
# (33/195) eyeTrackLeft: (152/0)
# (34/195) eyeTrackLeft.orig: (141/11)
# (35/195) visionRight: (152/0)
# (36/195) visionRight.orig: (141/11)
# (37/195) visionLeft: (152/0)
# (38/195) visionLeft.orig: (141/11)
# (39/195) audiologicAssessment: (152/0)
# (40/195) audiologicAssessment.orig: (141/11)
# (41/195) audiologicPendingForAssessment: (152/0)
# (42/195) audiologicPendingForAssessment.orig: (90/62)
# (43/195) visualReinforcementAudiometry: (152/0)
# (44/195) visualReinforcementAudiometry.orig: (36/116)
# (45/195) VRARight: (152/0)
# (46/195) VRARight.orig: (21/131)
# (47/195) VRALeft: (152/0)
# (48/195) VRALeft.orig: (21/131)
# (49/195) VRASoundField: (152/0)
# (50/195) VRASoundField.orig: (5/147)
# (51/195) ABR: (152/0)
# (52/195) ABR.orig: (36/116)
# (53/195) ABRRight: (152/0)
# (54/195) ABRRight.orig: (9/143)
# (55/195) ABRLeft: (152/0)
# (56/195) ABRLeft.orig: (9/143)
# (57/195) hearingTestUnknown: (152/0)
# (58/195) hearingTestUnknown.orig: (51/101)
# (59/195) hearingTestUnknownRight: (152/0)
# (60/195) hearingTestUnknownRight.orig: (15/137)
# (61/195) hearingTestUnknownLeft: (152/0)
# (62/195) hearingTestUnknownLeft.orig: (15/137)
# (63/195) hearingImpaired: (152/0)
# (64/195) hearingImpaired.orig: (141/11)
# (65/195) hearingAidRequirement: (152/0)
# (66/195) hearingAidRequirement.orig: (141/11)
# (67/195) swallowing: (152/0)
# (68/195) swallowing.orig: (141/11)
# (69/195) dysphagia: (152/0)
# (70/195) dysphagia.orig: (141/11)
# (71/195) aspiration: (152/0)
# (72/195) aspiration.orig: (141/11)
# (73/195) abnormalVoice: (152/0)
# (74/195) abnormalVoice.orig: (141/11)
# (75/195) drooling: (152/0)
# (76/195) drooling.orig: (141/11)
# (77/195) nothingByMouth: (152/0)
# (78/195) nothingByMouth.orig: (141/11)
# (79/195) observedAbnormalMovement: (152/0)
# (80/195) observedAbnormalMovement.orig: (141/11)
# (81/195) observedAbnormalMovementShortJerky: (152/0)
# (82/195) observedAbnormalMovementShortJerky.orig: (6/146)
# (83/195) observedAbnormalMovementSlowWrithing: (152/0)
# (84/195) observedAbnormalMovementSlowWrithing.orig: (6/146)
# (85/195) observedAbnormalMovementTremor: (152/0)
# (86/195) observedAbnormalMovementTremor.orig: (6/146)
# (87/195) passiveMuscleToneNeckTrunk: (152/0)
# (88/195) passiveMuscleToneNeckTrunk.orig: (141/11)
# (89/195) upperExtremityMuscleToneRight: (152/0)
# (90/195) upperExtremityMuscleToneRight.orig: (140/12)
# (91/195) upperExtremityMuscleToneLeft: (152/0)
# (92/195) upperExtremityMuscleToneLeft.orig: (140/12)
# (93/195) lowerExtremityMuscleToneHipKneeRight: (152/0)
# (94/195) lowerExtremityMuscleToneHipKneeRight.orig: (140/12)
# (95/195) lowerExtremityMuscleToneHipKneeLeft: (152/0)
# (96/195) lowerExtremityMuscleToneHipKneeLeft.orig: (140/12)
# (97/195) lowerExtremityMuscleToneAnkleRight: (152/0)
# (98/195) lowerExtremityMuscleToneAnkleRight.orig: (141/11)
# (99/195) lowerExtremityMuscleToneAnkleLeft: (152/0)
# (100/195) lowerExtremityMuscleToneAnkleLeft.orig: (141/11)
# (101/195) scissoringLegs: (152/0)
# (102/195) scissoringLegs.orig: (141/11)
# (103/195) handPreference: (152/0)
# (104/195) handPreference.orig: (141/11)
# (105/195) protectiveReaction: (152/0)
# (106/195) protectiveReaction.orig: (139/13)
# (107/195) limbMovementUpperLimb: (152/0)
# (108/195) limbMovementUpperLimb.orig: (141/11)
# (109/195) limbMovementLowerLimb: (152/0)
# (110/195) limbMovementLowerLimb.orig: (141/11)
# (111/195) deepTendonReflexUpperExtremityRight: (152/0)
# (112/195) deepTendonReflexUpperExtremityRight.orig: (138/14)
# (113/195) deepTendonReflexUpperExtremityLeft: (152/0)
# (114/195) deepTendonReflexUpperExtremityLeft.orig: (137/15)
# (115/195) deepTendonReflexKneeRight: (152/0)
# (116/195) deepTendonReflexKneeRight.orig: (139/13)
# (117/195) deepTendonReflexKneeLeft: (152/0)
# (118/195) deepTendonReflexKneeLeft.orig: (140/12)
# (119/195) deepTendonReflexAnkleRight: (152/0)
# (120/195) deepTendonReflexAnkleRight.orig: (140/12)
# (121/195) deepTendonReflexAnkleLeft: (152/0)
# (122/195) deepTendonReflexAnkleLeft.orig: (140/12)
# (123/195) ankleClonusRight: (152/0)
# (124/195) ankleClonusRight.orig: (140/12)
# (125/195) ankleClonusLeft: (152/0)
# (126/195) ankleClonusLeft.orig: (140/12)
# (127/195) plantarReflexRight: (152/0)
# (128/195) plantarReflexRight.orig: (140/12)
# (129/195) plantarReflexLeft: (152/0)
# (130/195) plantarReflexLeft.orig: (140/12)
# (131/195) axisHeadNeck: (152/0)
# (132/195) axisHeadNeck.orig: (141/11)
# (133/195) axisTrunk: (152/0)
# (134/195) axisTrunk.orig: (141/11)
# (135/195) lowerLimbFunction: (152/0)
# (136/195) lowerLimbFunction.orig: (141/11)
# (137/195) upperLimbFunction: (152/0)
# (138/195) upperLimbFunction.orig: (141/11)
# (139/195) handFunctionRight: (152/0)
# (140/195) handFunctionRight.orig: (141/11)
# (141/195) handFunctionLeft: (152/0)
# (142/195) handFunctionLeft.orig: (141/11)
# (143/195) neuralNormal: (152/0)
# (144/195) neuralNormal.orig: (141/11)
# (145/195) generalizedHypotonia: (152/0)
# (146/195) generalizedHypotonia.orig: (31/121)
# (147/195) hypertonia: (152/0)
# (148/195) hypertonia.orig: (31/121)
# (149/195) neuralOther: (152/0)
# (150/195) neuralOther.orig: (31/121)
# (151/195) neuralOtherText: (152/0)
# (152/195) neuralOtherText.orig: (13/139)
# (153/195) spasticDiplegia: (152/0)
# (154/195) spasticDiplegia.orig: (32/120)
# (155/195) spasticHemiplegiaRight: (152/0)
# (156/195) spasticHemiplegiaRight.orig: (32/120)
# (157/195) spasticHemiplegiaLeft: (152/0)
# (158/195) spasticHemiplegiaLeft.orig: (0/152)
# (159/195) spasticQuadriplegia: (152/0)
# (160/195) spasticQuadriplegia.orig: (32/120)
# (161/195) spasticTriplegia: (152/0)
# (162/195) spasticTriplegia.orig: (32/120)
# (163/195) athetosisDystonia: (152/0)
# (164/195) athetosisDystonia.orig: (32/120)
# (165/195) hypotoniaAtaxia: (152/0)
# (166/195) hypotoniaAtaxia.orig: (32/120)
# (167/195) spasticMonoplegia: (152/0)
# (168/195) spasticMonoplegia.orig: (32/120)
# (169/195) mixedCerebralPalsy: (152/0)
# (170/195) mixedCerebralPalsy.orig: (32/120)
# (171/195) cerebralPalsyUnclassified: (152/0)
# (172/195) cerebralPalsyUnclassified.orig: (32/120)
# (173/195) cerebralPalsyUnclassifiedText: (152/0)
# (174/195) cerebralPalsyUnclassifiedText.orig: (1/151)
# (175/195) cerebralPalsy: (152/0)
# (176/195) cerebralPalsy.orig: (141/11)
# (177/195) cerebralPalsyClass: (152/0)
# (178/195) cerebralPalsyClass.orig: (25/127)
# (179/195) abrnomalityAffectingNeuroAssessment: (152/0)
# (180/195) abrnomalityAffectingNeuroAssessment.orig: (141/11)
# (181/195) abrnomalityAffectingNeuroAssessmentText: (152/0)
# (182/195) abrnomalityAffectingNeuroAssessmentText.orig: (4/148)
# (183/195) examWhere: (152/0)
# (184/195) examWhere.orig: (141/11)
# (185/195) examWhereOtherText: (152/0)
# (186/195) examWhereOtherText.orig: (0/152)
# (187/195) examQuality: (152/0)
# (188/195) examQuality.orig: (141/11)
# (189/195) examFactorAffecting: (152/0)
# (190/195) examFactorAffecting.orig: (15/137)
# (191/195) examFactorAffectingText: (152/0)
# (192/195) examFactorAffectingText.orig: (0/152)
# (193/195) examCompleteDate: (152/0)
# (194/195) examCompleteDate.orig: (141/11)

# %% [markdown]
# ## 20-04-bayley-iii

# %%
base_filename = '20-04-bayley-iii.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/46) normalize_value: column: center
# (1/46) normalize_value: column: subjectID
# (2/46) normalize_value: column: uniqueID
# (3/46) normalize_value: column: followupCenter
# (4/46) normalize_value: column: followupID
# (5/46) normalize_value: column: siteID
# (6/46) normalize_value: column: BayleyIIICognitiveSubtest
# (7/46) normalize_value: column: BayleyIIIReasonNoSuccessCognitiveSubtestText
# (8/46) normalize_value: column: BayleyIIILanguageReceptiveSubtest
# (9/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText
# (10/46) normalize_value: column: BayleyIIILanguageExpressiveSubtest
# (11/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText
# (12/46) normalize_value: column: BayleyIIIMotorFineSubtest
# (13/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorFineSubtestText
# (14/46) normalize_value: column: BayleyIIIMotorGrossSubtest
# (15/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorGrossSubtestText
# (16/46) normalize_value: column: BayleyIIIInEnglish
# (17/46) normalize_value: column: BayleyIIIRequireInterpreter
# (18/46) normalize_value: column: BayleyIIIAdministratorMaskedToChildHistory
# (19/46) normalize_value: column: BayleyIIIReasonNoSuccessCognitiveSubtest
# (20/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageReceptiveSubtest
# (21/46) normalize_value: column: BayleyIIIReasonNoSuccessLanguageExpressiveSubtest
# (22/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorFineSubtest
# (23/46) normalize_value: column: BayleyIIIReasonNoSuccessMotorGrossSubtest
# (24/46) normalize_value: column: BayleyIIIAdjustedAgeForCognitiveTest
# (25/46) normalize_value: column: BayleyIIIAdjustedAgeForReceptiveCommunication
# (26/46) normalize_value: column: BayleyIIIAdjustedAgeForExpressiveCommunication
# (27/46) normalize_value: column: BayleyIIIAdjustedAgeForMotorFineSubtest
# (28/46) normalize_value: column: BayleyIIIAdjustedAgeForMotorGrossSubtest
# (29/46) normalize_value: column: BayleyIIICognitiveRaw
# (30/46) normalize_value: column: BayleyIIICognitiveScale
# (31/46) normalize_value: column: BayleyIIICognitiveComposite
# (32/46) normalize_value: column: BayleyIIIReceptiveRaw
# (33/46) normalize_value: column: BayleyIIIReceptiveScale
# (34/46) normalize_value: column: BayleyIIIExpressiveRaw
# (35/46) normalize_value: column: BayleyIIIExpressiveScale
# (36/46) normalize_value: column: BayleyIIISumLanguageScore
# (37/46) normalize_value: column: BayleyIIILanguageComposite
# (38/46) normalize_value: column: BayleyIIIMotorFineRaw
# (39/46) normalize_value: column: BayleyIIIMotorFineScale
# (40/46) normalize_value: column: BayleyIIIMotorGrossRaw
# (41/46) normalize_value: column: BayleyIIIMotorGrossScale
# (42/46) normalize_value: column: BayleyIIISumMotorScore
# (43/46) normalize_value: column: BayleyIIIMotorComposite
# (44/46) normalize_value: column: BayleyIIIWhere
# (45/46) normalize_value: column: BayleyIIIDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/93) center: (152/0)
# (1/93) subjectID: (152/0)
# (2/93) uniqueID: (152/0)
# (3/93) followupCenter: (152/0)
# (4/93) followupID: (152/0)
# (5/93) uniqueFollowupID: (152/0)
# (6/93) center.orig: (152/0)
# (7/93) subjectID.orig: (152/0)
# (8/93) uniqueID.orig: (152/0)
# (9/93) followupCenter.orig: (152/0)
# (10/93) followupID.orig: (152/0)
# (11/93) siteID: (152/0)
# (12/93) siteID.orig: (152/0)
# (13/93) BayleyIIICognitiveSubtest: (152/0)
# (14/93) BayleyIIICognitiveSubtest.orig: (141/11)
# (15/93) BayleyIIIReasonNoSuccessCognitiveSubtest: (152/0)
# (16/93) BayleyIIIReasonNoSuccessCognitiveSubtest.orig: (9/143)
# (17/93) BayleyIIIReasonNoSuccessCognitiveSubtestText: (152/0)
# (18/93) BayleyIIIReasonNoSuccessCognitiveSubtestText.orig: (0/152)
# (19/93) BayleyIIILanguageReceptiveSubtest: (152/0)
# (20/93) BayleyIIILanguageReceptiveSubtest.orig: (141/11)
# (21/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtest: (152/0)
# (22/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtest.orig: (9/143)
# (23/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText: (152/0)
# (24/93) BayleyIIIReasonNoSuccessLanguageReceptiveSubtestText.orig: (0/152)
# (25/93) BayleyIIILanguageExpressiveSubtest: (152/0)
# (26/93) BayleyIIILanguageExpressiveSubtest.orig: (141/11)
# (27/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtest: (152/0)
# (28/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtest.orig: (10/142)
# (29/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText: (152/0)
# (30/93) BayleyIIIReasonNoSuccessLanguageExpressiveSubtestText.orig: (0/152)
# (31/93) BayleyIIIMotorFineSubtest: (152/0)
# (32/93) BayleyIIIMotorFineSubtest.orig: (141/11)
# (33/93) BayleyIIIReasonNoSuccessMotorFineSubtest: (152/0)
# (34/93) BayleyIIIReasonNoSuccessMotorFineSubtest.orig: (9/143)
# (35/93) BayleyIIIReasonNoSuccessMotorFineSubtestText: (152/0)
# (36/93) BayleyIIIReasonNoSuccessMotorFineSubtestText.orig: (0/152)
# (37/93) BayleyIIIMotorGrossSubtest: (152/0)
# (38/93) BayleyIIIMotorGrossSubtest.orig: (141/11)
# (39/93) BayleyIIIReasonNoSuccessMotorGrossSubtest: (152/0)
# (40/93) BayleyIIIReasonNoSuccessMotorGrossSubtest.orig: (10/142)
# (41/93) BayleyIIIReasonNoSuccessMotorGrossSubtestText: (152/0)
# (42/93) BayleyIIIReasonNoSuccessMotorGrossSubtestText.orig: (0/152)
# (43/93) BayleyIIIAdjustedAgeForCognitiveTest: (152/0)
# (44/93) BayleyIIIAdjustedAgeForCognitiveTest.orig: (138/14)
# (45/93) BayleyIIIAdjustedAgeForReceptiveCommunication: (152/0)
# (46/93) BayleyIIIAdjustedAgeForReceptiveCommunication.orig: (137/15)
# (47/93) BayleyIIIAdjustedAgeForExpressiveCommunication: (152/0)
# (48/93) BayleyIIIAdjustedAgeForExpressiveCommunication.orig: (137/15)
# (49/93) BayleyIIIAdjustedAgeForMotorFineSubtest: (152/0)
# (50/93) BayleyIIIAdjustedAgeForMotorFineSubtest.orig: (139/13)
# (51/93) BayleyIIIAdjustedAgeForMotorGrossSubtest: (152/0)
# (52/93) BayleyIIIAdjustedAgeForMotorGrossSubtest.orig: (138/14)
# (53/93) BayleyIIICognitiveRaw: (152/0)
# (54/93) BayleyIIICognitiveRaw.orig: (132/20)
# (55/93) BayleyIIICognitiveScale: (152/0)
# (56/93) BayleyIIICognitiveScale.orig: (132/20)
# (57/93) BayleyIIICognitiveComposite: (152/0)
# (58/93) BayleyIIICognitiveComposite.orig: (138/14)
# (59/93) BayleyIIIReceptiveRaw: (152/0)
# (60/93) BayleyIIIReceptiveRaw.orig: (132/20)
# (61/93) BayleyIIIReceptiveScale: (152/0)
# (62/93) BayleyIIIReceptiveScale.orig: (132/20)
# (63/93) BayleyIIIExpressiveRaw: (152/0)
# (64/93) BayleyIIIExpressiveRaw.orig: (131/21)
# (65/93) BayleyIIIExpressiveScale: (152/0)
# (66/93) BayleyIIIExpressiveScale.orig: (131/21)
# (67/93) BayleyIIISumLanguageScore: (152/0)
# (68/93) BayleyIIISumLanguageScore.orig: (130/22)
# (69/93) BayleyIIILanguageComposite: (152/0)
# (70/93) BayleyIIILanguageComposite.orig: (136/16)
# (71/93) BayleyIIIMotorFineRaw: (152/0)
# (72/93) BayleyIIIMotorFineRaw.orig: (132/20)
# (73/93) BayleyIIIMotorFineScale: (152/0)
# (74/93) BayleyIIIMotorFineScale.orig: (132/20)
# (75/93) BayleyIIIMotorGrossRaw: (152/0)
# (76/93) BayleyIIIMotorGrossRaw.orig: (131/21)
# (77/93) BayleyIIIMotorGrossScale: (152/0)
# (78/93) BayleyIIIMotorGrossScale.orig: (131/21)
# (79/93) BayleyIIISumMotorScore: (152/0)
# (80/93) BayleyIIISumMotorScore.orig: (131/21)
# (81/93) BayleyIIIMotorComposite: (152/0)
# (82/93) BayleyIIIMotorComposite.orig: (138/14)
# (83/93) BayleyIIIInEnglish: (152/0)
# (84/93) BayleyIIIInEnglish.orig: (140/12)
# (85/93) BayleyIIIRequireInterpreter: (152/0)
# (86/93) BayleyIIIRequireInterpreter.orig: (17/135)
# (87/93) BayleyIIIAdministratorMaskedToChildHistory: (152/0)
# (88/93) BayleyIIIAdministratorMaskedToChildHistory.orig: (140/12)
# (89/93) BayleyIIIWhere: (152/0)
# (90/93) BayleyIIIWhere.orig: (140/12)
# (91/93) BayleyIIIDate: (152/0)
# (92/93) BayleyIIIDate.orig: (140/12)

# %% [markdown]
# ## 20-05. GMFCS

# %%
base_filename = '20-05-gmfcs.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/7) normalize_value: column: center
# (1/7) normalize_value: column: subjectID
# (2/7) normalize_value: column: uniqueID
# (3/7) normalize_value: column: followupCenter
# (4/7) normalize_value: column: followupID
# (5/7) normalize_value: column: siteID
# (6/7) normalize_value: column: grossMotorFunctionLevel

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/15) center: (152/0)
# (1/15) subjectID: (152/0)
# (2/15) uniqueID: (152/0)
# (3/15) followupCenter: (152/0)
# (4/15) followupID: (152/0)
# (5/15) uniqueFollowupID: (152/0)
# (6/15) center.orig: (152/0)
# (7/15) subjectID.orig: (152/0)
# (8/15) uniqueID.orig: (152/0)
# (9/15) followupCenter.orig: (152/0)
# (10/15) followupID.orig: (152/0)
# (11/15) siteID: (152/0)
# (12/15) siteID.orig: (152/0)
# (13/15) grossMotorFunctionLevel: (152/0)
# (14/15) grossMotorFunctionLevel.orig: (141/11)

# %% [markdown]
# ## 20-06. Status

# %%
base_filename = '20-06-status.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/13) normalize_value: column: center
# (1/13) normalize_value: column: subjectID
# (2/13) normalize_value: column: uniqueID
# (3/13) normalize_value: column: followupCenter
# (4/13) normalize_value: column: followupID
# (5/13) normalize_value: column: siteID
# (6/13) normalize_value: column: statusBirthDate
# (7/13) normalize_value: column: statusVisitDate
# (8/13) normalize_value: column: childFinalStatus
# (9/13) normalize_value: column: deathDate
# (10/13) normalize_value: column: reasonLossFollowUp
# (11/13) normalize_value: column: firstVisitDate
# (12/13) normalize_value: column: finalVisitDate

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/27) center: (152/0)
# (1/27) subjectID: (152/0)
# (2/27) uniqueID: (152/0)
# (3/27) followupCenter: (152/0)
# (4/27) followupID: (152/0)
# (5/27) uniqueFollowupID: (152/0)
# (6/27) center.orig: (152/0)
# (7/27) subjectID.orig: (152/0)
# (8/27) uniqueID.orig: (152/0)
# (9/27) followupCenter.orig: (152/0)
# (10/27) followupID.orig: (152/0)
# (11/27) siteID: (152/0)
# (12/27) siteID.orig: (152/0)
# (13/27) statusVisitDate: (152/0)
# (14/27) statusVisitDate.orig: (0/152)
# (15/27) statusBirthDate: (152/0)
# (16/27) statusBirthDate.orig: (152/0)
# (17/27) childFinalStatus: (152/0)
# (18/27) childFinalStatus.orig: (152/0)
# (19/27) deathDate: (152/0)
# (20/27) deathDate.orig: (2/150)
# (21/27) reasonLossFollowUp: (152/0)
# (22/27) reasonLossFollowUp.orig: (9/143)
# (23/27) firstVisitDate: (152/0)
# (24/27) firstVisitDate.orig: (140/12)
# (25/27) finalVisitDate: (152/0)
# (26/27) finalVisitDate.orig: (140/12)

# %% [markdown]
# ## 20-08. Lost Follow-up

# %%
base_filename = '20-08-lost.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/61) normalize_value: column: center
# (1/61) normalize_value: column: subjectID
# (2/61) normalize_value: column: uniqueID
# (3/61) normalize_value: column: followupCenter
# (4/61) normalize_value: column: followupID
# (5/61) normalize_value: column: siteID
# (6/61) normalize_value: column: lostFollowUpInformationAvailableIndirectSrc
# (7/61) normalize_value: column: lostFollowUpChildAlive
# (8/61) normalize_value: column: lostFollowUpInterview
# (9/61) normalize_value: column: lostFollowUpAnyQuestionCompleteChartReview
# (10/61) normalize_value: column: interviewWalkAlone
# (11/61) normalize_value: column: interviewSittingAlong
# (12/61) normalize_value: column: interviewHeadControl
# (13/61) normalize_value: column: interviewSee
# (14/61) normalize_value: column: interviewEyeExam
# (15/61) normalize_value: column: interviewNeedWearGlasses
# (16/61) normalize_value: column: interviewHear
# (17/61) normalize_value: column: interviewHearExam
# (18/61) normalize_value: column: interviewNeedWearHearingAid
# (19/61) normalize_value: column: interviewCombine2Words
# (20/61) normalize_value: column: interviewCombine3Words
# (21/61) normalize_value: column: interviewHydrocephalusShunt
# (22/61) normalize_value: column: interviewCerebralPalsy
# (23/61) normalize_value: column: interviewDevelopmentalDelay
# (24/61) normalize_value: column: interviewLanguageDelay
# (25/61) normalize_value: column: interviewPoorWeightGain
# (26/61) normalize_value: column: interviewSeizure
# (27/61) normalize_value: column: interviewBlindness
# (28/61) normalize_value: column: interviewOtherBehaviorProblem
# (29/61) normalize_value: column: interviewOtherBehaviorProblemText
# (30/61) normalize_value: column: interviewOtherMajorMedicalProblem
# (31/61) normalize_value: column: interviewOtherMajorMedicalProblemText
# (32/61) normalize_value: column: interviewOtherNeuraldevelopmentalProblem
# (33/61) normalize_value: column: interviewOtherNeuraldevelopmentalProblemText
# (34/61) normalize_value: column: chartReviewOtherBehaviorProblemText
# (35/61) normalize_value: column: chartReviewOtherMajorMedicalProblemText
# (36/61) normalize_value: column: chartReviewOtherNeuraldevelopmentalProblemText
# (37/61) normalize_value: column: lostFollowUpLastContactDate
# (38/61) normalize_value: column: lostFollowUpFormCompleteDate
# (39/61) normalize_value: column: lostFollowUpLastKnownAliveCorrectedAge_mo
# (40/61) normalize_value: column: lostFollowUpDeathDate
# (41/61) normalize_value: column: lostFollowUpInterviewDate
# (42/61) normalize_value: column: lostFollowUpInterviewCorrectedAge_mo
# (43/61) normalize_value: column: lostFollowUpChartReviewDate
# (44/61) normalize_value: column: lostFollowUpChartReviewCorrectedAge_mo
# (45/61) normalize_value: column: interviewChildHealth
# (46/61) normalize_value: column: interviewWalkAloneAge_mo
# (47/61) normalize_value: column: interviewNumberWordVocabulary
# (48/61) normalize_value: column: chartReviewEyeExam
# (49/61) normalize_value: column: chartReviewHearingExam
# (50/61) normalize_value: column: chartReviewNeedWearHearingAid
# (51/61) normalize_value: column: chartReviewHydrocephalusShunt
# (52/61) normalize_value: column: chartReviewCerebralPalsy
# (53/61) normalize_value: column: chartReviewDevelopmentalDelay
# (54/61) normalize_value: column: chartReviewLanguageDelay
# (55/61) normalize_value: column: chartReviewPoorWeightGain
# (56/61) normalize_value: column: chartReviewSeizure
# (57/61) normalize_value: column: chartReviewBlindness
# (58/61) normalize_value: column: chartReviewOtherBehaviorProblem
# (59/61) normalize_value: column: chartReviewOtherMajorMedicalProblem
# (60/61) normalize_value: column: chartReviewOtherNeuraldevelopmentalProblem

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/123) center: (152/0)
# (1/123) subjectID: (152/0)
# (2/123) uniqueID: (152/0)
# (3/123) followupCenter: (152/0)
# (4/123) followupID: (152/0)
# (5/123) uniqueFollowupID: (152/0)
# (6/123) center.orig: (152/0)
# (7/123) subjectID.orig: (152/0)
# (8/123) uniqueID.orig: (152/0)
# (9/123) followupCenter.orig: (152/0)
# (10/123) followupID.orig: (152/0)
# (11/123) siteID: (152/0)
# (12/123) siteID.orig: (152/0)
# (13/123) lostFollowUpInformationAvailableIndirectSrc: (152/0)
# (14/123) lostFollowUpInformationAvailableIndirectSrc.orig: (10/142)
# (15/123) lostFollowUpLastContactDate: (152/0)
# (16/123) lostFollowUpLastContactDate.orig: (3/149)
# (17/123) lostFollowUpFormCompleteDate: (152/0)
# (18/123) lostFollowUpFormCompleteDate.orig: (3/149)
# (19/123) lostFollowUpChildAlive: (152/0)
# (20/123) lostFollowUpChildAlive.orig: (7/145)
# (21/123) lostFollowUpLastKnownAliveCorrectedAge_mo: (152/0)
# (22/123) lostFollowUpLastKnownAliveCorrectedAge_mo.orig: (6/146)
# (23/123) lostFollowUpDeathDate: (152/0)
# (24/123) lostFollowUpDeathDate.orig: (1/151)
# (25/123) lostFollowUpInterview: (152/0)
# (26/123) lostFollowUpInterview.orig: (6/146)
# (27/123) lostFollowUpInterviewDate: (152/0)
# (28/123) lostFollowUpInterviewDate.orig: (2/150)
# (29/123) lostFollowUpInterviewCorrectedAge_mo: (152/0)
# (30/123) lostFollowUpInterviewCorrectedAge_mo.orig: (2/150)
# (31/123) lostFollowUpAnyQuestionCompleteChartReview: (152/0)
# (32/123) lostFollowUpAnyQuestionCompleteChartReview.orig: (6/146)
# (33/123) lostFollowUpChartReviewDate: (152/0)
# (34/123) lostFollowUpChartReviewDate.orig: (6/146)
# (35/123) lostFollowUpChartReviewCorrectedAge_mo: (152/0)
# (36/123) lostFollowUpChartReviewCorrectedAge_mo.orig: (6/146)
# (37/123) interviewChildHealth: (152/0)
# (38/123) interviewChildHealth.orig: (2/150)
# (39/123) interviewWalkAlone: (152/0)
# (40/123) interviewWalkAlone.orig: (2/150)
# (41/123) interviewWalkAloneAge_mo: (152/0)
# (42/123) interviewWalkAloneAge_mo.orig: (0/152)
# (43/123) interviewSittingAlong: (152/0)
# (44/123) interviewSittingAlong.orig: (0/152)
# (45/123) interviewHeadControl: (152/0)
# (46/123) interviewHeadControl.orig: (0/152)
# (47/123) interviewSee: (152/0)
# (48/123) interviewSee.orig: (2/150)
# (49/123) interviewEyeExam: (152/0)
# (50/123) interviewEyeExam.orig: (2/150)
# (51/123) interviewNeedWearGlasses: (152/0)
# (52/123) interviewNeedWearGlasses.orig: (2/150)
# (53/123) interviewHear: (152/0)
# (54/123) interviewHear.orig: (2/150)
# (55/123) interviewHearExam: (152/0)
# (56/123) interviewHearExam.orig: (2/150)
# (57/123) interviewNeedWearHearingAid: (152/0)
# (58/123) interviewNeedWearHearingAid.orig: (0/152)
# (59/123) interviewNumberWordVocabulary: (152/0)
# (60/123) interviewNumberWordVocabulary.orig: (1/151)
# (61/123) interviewCombine2Words: (152/0)
# (62/123) interviewCombine2Words.orig: (2/150)
# (63/123) interviewCombine3Words: (152/0)
# (64/123) interviewCombine3Words.orig: (2/150)
# (65/123) interviewHydrocephalusShunt: (152/0)
# (66/123) interviewHydrocephalusShunt.orig: (2/150)
# (67/123) interviewCerebralPalsy: (152/0)
# (68/123) interviewCerebralPalsy.orig: (2/150)
# (69/123) interviewDevelopmentalDelay: (152/0)
# (70/123) interviewDevelopmentalDelay.orig: (2/150)
# (71/123) interviewLanguageDelay: (152/0)
# (72/123) interviewLanguageDelay.orig: (2/150)
# (73/123) interviewPoorWeightGain: (152/0)
# (74/123) interviewPoorWeightGain.orig: (2/150)
# (75/123) interviewSeizure: (152/0)
# (76/123) interviewSeizure.orig: (2/150)
# (77/123) interviewBlindness: (152/0)
# (78/123) interviewBlindness.orig: (2/150)
# (79/123) interviewOtherBehaviorProblem: (152/0)
# (80/123) interviewOtherBehaviorProblem.orig: (2/150)
# (81/123) interviewOtherBehaviorProblemText: (152/0)
# (82/123) interviewOtherBehaviorProblemText.orig: (0/152)
# (83/123) interviewOtherMajorMedicalProblem: (152/0)
# (84/123) interviewOtherMajorMedicalProblem.orig: (2/150)
# (85/123) interviewOtherMajorMedicalProblemText: (152/0)
# (86/123) interviewOtherMajorMedicalProblemText.orig: (0/152)
# (87/123) interviewOtherNeuraldevelopmentalProblem: (152/0)
# (88/123) interviewOtherNeuraldevelopmentalProblem.orig: (2/150)
# (89/123) interviewOtherNeuraldevelopmentalProblemText: (152/0)
# (90/123) interviewOtherNeuraldevelopmentalProblemText.orig: (0/152)
# (91/123) chartReviewEyeExam: (152/0)
# (92/123) chartReviewEyeExam.orig: (6/146)
# (93/123) chartReviewHearingExam: (152/0)
# (94/123) chartReviewHearingExam.orig: (6/146)
# (95/123) chartReviewNeedWearHearingAid: (152/0)
# (96/123) chartReviewNeedWearHearingAid.orig: (6/146)
# (97/123) chartReviewHydrocephalusShunt: (152/0)
# (98/123) chartReviewHydrocephalusShunt.orig: (6/146)
# (99/123) chartReviewCerebralPalsy: (152/0)
# (100/123) chartReviewCerebralPalsy.orig: (6/146)
# (101/123) chartReviewDevelopmentalDelay: (152/0)
# (102/123) chartReviewDevelopmentalDelay.orig: (6/146)
# (103/123) chartReviewLanguageDelay: (152/0)
# (104/123) chartReviewLanguageDelay.orig: (6/146)
# (105/123) chartReviewPoorWeightGain: (152/0)
# (106/123) chartReviewPoorWeightGain.orig: (6/146)
# (107/123) chartReviewSeizure: (152/0)
# (108/123) chartReviewSeizure.orig: (6/146)
# (109/123) chartReviewBlindness: (152/0)
# (110/123) chartReviewBlindness.orig: (6/146)
# (111/123) chartReviewOtherBehaviorProblem: (152/0)
# (112/123) chartReviewOtherBehaviorProblem.orig: (6/146)
# (113/123) chartReviewOtherBehaviorProblemText: (152/0)
# (114/123) chartReviewOtherBehaviorProblemText.orig: (0/152)
# (115/123) chartReviewOtherMajorMedicalProblem: (152/0)
# (116/123) chartReviewOtherMajorMedicalProblem.orig: (6/146)
# (117/123) chartReviewOtherMajorMedicalProblemText: (152/0)
# (118/123) chartReviewOtherMajorMedicalProblemText.orig: (4/148)
# (119/123) chartReviewOtherNeuraldevelopmentalProblem: (152/0)
# (120/123) chartReviewOtherNeuraldevelopmentalProblem.orig: (6/146)
# (121/123) chartReviewOtherNeuraldevelopmentalProblemText: (152/0)
# (122/123) chartReviewOtherNeuraldevelopmentalProblemText.orig: (2/150)

# %% [markdown]
# ## 20-09. Secondary Analysis

# %%
base_filename = '20-09-secondary.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/12) normalize_value: column: center
# (1/12) normalize_value: column: subjectID
# (2/12) normalize_value: column: uniqueID
# (3/12) normalize_value: column: followupCenter
# (4/12) normalize_value: column: blindness
# (5/12) normalize_value: column: hearingImpairedLevel
# (6/12) normalize_value: column: hearingImpairedWithAid
# (7/12) normalize_value: column: grossMotorFunctionLevelSeverity
# (8/12) normalize_value: column: cerebralPalsyMerge
# (9/12) normalize_value: column: moderateSevereCerebralPalsy
# (10/12) normalize_value: column: followupID
# (11/12) normalize_value: column: afterDischargeSeizure

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/25) center: (168/0)
# (1/25) subjectID: (168/0)
# (2/25) uniqueID: (168/0)
# (3/25) followupCenter: (168/0)
# (4/25) followupID: (168/0)
# (5/25) uniqueFollowupID: (168/0)
# (6/25) center.orig: (168/0)
# (7/25) subjectID.orig: (168/0)
# (8/25) uniqueID.orig: (168/0)
# (9/25) followupCenter.orig: (151/17)
# (10/25) followupID.orig: (133/35)
# (11/25) blindness: (168/0)
# (12/25) blindness.orig: (141/27)
# (13/25) moderateSevereCerebralPalsy: (168/0)
# (14/25) moderateSevereCerebralPalsy.orig: (141/27)
# (15/25) cerebralPalsyMerge: (168/0)
# (16/25) cerebralPalsyMerge.orig: (141/27)
# (17/25) grossMotorFunctionLevelSeverity: (168/0)
# (18/25) grossMotorFunctionLevelSeverity.orig: (141/27)
# (19/25) hearingImpairedWithAid: (168/0)
# (20/25) hearingImpairedWithAid.orig: (141/27)
# (21/25) hearingImpairedLevel: (168/0)
# (22/25) hearingImpairedLevel.orig: (141/27)
# (23/25) afterDischargeSeizure: (168/0)
# (24/25) afterDischargeSeizure.orig: (143/25)

# %% [markdown]
# ## 20-10. Outcome

# %%
base_filename = '20-10-outcome.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, order_map=_ORDER_MAP)

df['uniqueFollowupID'] = df['uniqueID'].copy()
df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID', 'uniqueFollowupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/13) normalize_value: column: center
# (1/13) normalize_value: column: subjectID
# (2/13) normalize_value: column: uniqueID
# (3/13) normalize_value: column: followupCenter
# (4/13) normalize_value: column: BayleyIIICognitive
# (5/13) normalize_value: column: deathBeforeFollowup
# (6/13) normalize_value: column: normalPrimaryOutcome
# (7/13) normalize_value: column: deathBeforeDischarge
# (8/13) normalize_value: column: followupID
# (9/13) normalize_value: column: moderateSevereDisabilitySurvivor
# (10/13) normalize_value: column: disabilityLevelSurvivor
# (11/13) normalize_value: column: moderateSevereDisabilityOrDeath
# (12/13) normalize_value: column: disabilityLevelDeath4Category

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/27) center: (168/0)
# (1/27) subjectID: (168/0)
# (2/27) uniqueID: (168/0)
# (3/27) followupCenter: (168/0)
# (4/27) followupID: (168/0)
# (5/27) uniqueFollowupID: (168/0)
# (6/27) center.orig: (168/0)
# (7/27) subjectID.orig: (168/0)
# (8/27) uniqueID.orig: (168/0)
# (9/27) followupCenter.orig: (151/17)
# (10/27) followupID.orig: (133/35)
# (11/27) normalPrimaryOutcome: (168/0)
# (12/27) normalPrimaryOutcome.orig: (139/29)
# (13/27) BayleyIIICognitive: (168/0)
# (14/27) BayleyIIICognitive.orig: (138/30)
# (15/27) deathBeforeFollowup: (168/0)
# (16/27) deathBeforeFollowup.orig: (165/3)
# (17/27) deathBeforeDischarge: (168/0)
# (18/27) deathBeforeDischarge.orig: (167/1)
# (19/27) disabilityLevelSurvivor: (168/0)
# (20/27) disabilityLevelSurvivor.orig: (139/29)
# (21/27) disabilityLevelDeath4Category: (168/0)
# (22/27) disabilityLevelDeath4Category.orig: (157/11)
# (23/27) moderateSevereDisabilityOrDeath: (168/0)
# (24/27) moderateSevereDisabilityOrDeath.orig: (157/11)
# (25/27) moderateSevereDisabilitySurvivor: (168/0)
# (26/27) moderateSevereDisabilitySurvivor.orig: (139/29)

# %% [markdown]
# ## 20-07-readmission

# %%
_FLATTEN_IDS = ['readmissionNumber']
base_filename = '20-07-readmission.csv'

# %%
filename = os.sep.join([input_dir, base_filename])
df = pd.read_csv(filename, dtype='O')
df = COMBINE_harmonizer.normalize_value(df, _VALUE_MAP, _FLATTEN_IDS,  order_map=_ORDER_MAP)

df = COMBINE_harmonizer.postprocess(df, first_columns=['center', 'subjectID', 'uniqueID', 'followupCenter', 'followupID'])

out_filename = os.sep.join([out_dir, base_filename])
df.to_csv(out_filename, index=False)
# Out:
# (0/9) normalize_value: column: center
# (1/9) normalize_value: column: subjectID
# (2/9) normalize_value: column: uniqueID
# (3/9) normalize_value: column: followupCenter
# (4/9) normalize_value: column: followupID
# (5/9) normalize_value: column: readmissionPrimaryCauseOtherText
# (6/9) normalize_value: column: readmissionNumber
# (7/9) normalize_value: column: readmissionTimePeriod
# (8/9) normalize_value: column: readmissionPrimaryCause
# flatten_index: flatten_ids: ['readmissionNumber'] unique_id_map: {np.int64(1): np.int64(1), np.int64(2): np.int64(2), np.int64(3): np.int64(3), np.int64(4): np.int64(4), np.int64(5): np.int64(5), np.int64(6): np.int64(6), np.int64(7): np.int64(7), np.int64(8): np.int64(8), np.int64(9): np.int64(9), np.int64(10): np.int64(10), np.int64(11): np.int64(11)} the_type: int64

# %%
COMBINE_harmonizer.column_info(df)
# Out:
# (0/19) center: (65/0)
# (1/19) subjectID: (65/0)
# (2/19) uniqueID: (65/0)
# (3/19) followupCenter: (65/0)
# (4/19) followupID: (65/0)
# (5/19) center.orig: (65/0)
# (6/19) subjectID.orig: (65/0)
# (7/19) uniqueID.orig: (65/0)
# (8/19) followupCenter.orig: (65/0)
# (9/19) followupID.orig: (65/0)
# (10/19) _flatten_index: (65/0)
# (11/19) readmissionNumber: (65/0)
# (12/19) readmissionNumber.orig: (65/0)
# (13/19) readmissionTimePeriod: (65/0)
# (14/19) readmissionTimePeriod.orig: (65/0)
# (15/19) readmissionPrimaryCause: (65/0)
# (16/19) readmissionPrimaryCause.orig: (65/0)
# (17/19) readmissionPrimaryCauseOtherText: (65/0)
# (18/19) readmissionPrimaryCauseOtherText.orig: (7/58)
